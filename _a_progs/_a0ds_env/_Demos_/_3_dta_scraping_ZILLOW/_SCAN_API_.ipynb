# %%
#pd.set_option('display.max_columns', None)
import pandas as pd
import os 
pd.set_option('display.max_rows', None)        # show all rows
pd.set_option('display.max_columns', None)     # show all columns
pd.set_option('display.width', None)           # auto-detect width
pd.set_option('display.max_colwidth', None) \


API_KEY = "e8ed9c0c93msh606b92a16b58a9cp187683jsn253baf6dc2f5".strip()

# %% [markdown]
# # RENT

# %%
# -----######-----######-----######-----######-----######
# _re_1204_i6_GET_df_schema_discovery
# DISCOVER ALL VARIABLES (FLATTEN + UNION KEYS)
# -----######-----######-----######-----######-----######

import requests
import pandas as pd


def _flatten_dict(d, parent_key='', sep='_'):
    items = []
    if isinstance(d, dict):
        for k, v in d.items():
            new_key = f"{parent_key}{sep}{k}" if parent_key else k
            items.extend(_flatten_dict(v, new_key, sep=sep).items())
    elif isinstance(d, list):
        if len(d) > 0:
            items.extend(_flatten_dict(d[0], parent_key, sep=sep).items())
    else:
        items.append((parent_key, d))
    return dict(items)


def _re_1204_i6_GET_df_schema_discovery(api_key, location="Detroit, MI", n_rows=50):

    url = "https://realtor16.p.rapidapi.com/search/forrent"

    headers = {
        "X-RapidAPI-Key": api_key.strip(),
        "X-RapidAPI-Host": "realtor16.p.rapidapi.com"
    }

    params = {
        "location": location,
        "limit": n_rows
    }

    r = requests.get(url, headers=headers, params=params)

    if r.status_code != 200:
        print("❌ Request failed:", r.status_code)
        print(r.text)
        return pd.DataFrame()

    data = r.json()
    listings = data.get("properties", [])

    if not listings:
        print("⚠️ No data")
        return pd.DataFrame()

    # ---- FLATTEN ALL LISTINGS ----
    flat_rows = [_flatten_dict(l) for l in listings]

    df = pd.DataFrame(flat_rows)

    print("\n📊 TOTAL VARIABLES FOUND:", len(df.columns))
    print("\n🧠 SAMPLE COLUMNS:\n", df.columns.tolist()[:50])

    return df

# %%
#df_schema = _re_1204_i6_GET_df_schema_discovery(API_KEY)
# Out:
# 📊 TOTAL VARIABLES FOUND: 70
#
# 🧠 SAMPLE COLUMNS:
#  ['advertisers_office_phones_number', 'advertisers_office_phones_type', 'advertisers_type', 'branding_type', 'description_baths_consolidated', 'description_beds', 'description_sqft', 'description_type', 'description_year_built', 'details_category', 'details_parent_category', 'details_text', 'lead_attributes_lead_type', 'list_date', 'list_price', 'listing_id', 'location_address_city', 'location_address_coordinate_lat', 'location_address_coordinate_lon', 'location_address_country', 'location_address_line', 'location_address_postal_code', 'location_address_state_code', 'location_county_fips_code', 'location_county_name', 'other_listings_rdc_listing_id', 'other_listings_rdc_status', 'permalink', 'pet_policy_cats', 'pet_policy_dogs', 'photos_href', 'primary_photo_href', 'products_brand_name', 'products_products', 'property_id', 'source_feed_type', 'source_id', 'source_type', 'status', 'advertisers_office_name', 'advertisers_office_phones_primary', 'advertisers_phones_number', 'advertisers_phones_primary', 'advertisers_phones_type', 'branding_name', 'description_garage', 'flags_is_new_listing', 'flags_is_pending', 'price_reduced_amount', 'application_url']

# %%
df_schema.head()
# Out:
#   advertisers_office_phones_number advertisers_office_phones_type  \
# 0                       3134629181                        primary
# 1                       2484145211                         Office
# 2                       3057938447                         Office
# 3                       3057938447                         Office
# 4                              NaN                            NaN
#
#   advertisers_type branding_type description_baths_consolidated  \
# 0       management        Office                              1
# 1           seller        Office                            1.5
# 2           seller        Office                           2.5+
# 3           seller        Office                            1.5
# 4       management        Office                              1
#
#    description_beds  description_sqft description_type  \
# 0               2.0             900.0        apartment
# 1               3.0             875.0    single_family
# 2               5.0            3500.0    single_family
# 3               3.0             800.0    single_family
# 4               3.0            1600.0    single_family
#
#    description_year_built details_category details_parent_category  \
# 0                  1920.0         Bedrooms                Interior
# 1                  1950.0         Bedrooms                Interior
# 2                  1920.0         Bedrooms                Interior
# 3                  1943.0         Bedrooms                Interior
# 4                     NaN         Bedrooms                Interior
#
#   details_text lead_attributes_lead_type                    list_date  \
# 0  Bedrooms: 2          rental_go_direct  2022-05-28T03:19:24.000000Z
# 1  Bedrooms: 3          rental_basic_mls  2026-04-12T06:21:31.000000Z
# 2  Bedrooms: 5          rental_basic_mls  2026-04-12T17:51:21.000000Z
# 3  Bedrooms: 3          rental_basic_mls  2026-04-12T17:21:21.000000Z
# 4  Bedrooms: 3          rental_go_direct  2026-04-12T19:32:14.000000Z
#
#    list_price  listing_id location_address_city  \
# 0      1420.0  2943614976               Detroit
# 1      1350.0  2993568991               Detroit
# 2      2400.0  2993572983               Detroit
# 3      1300.0  2993572679               Detroit
# 4      1400.0  2993574074               Detroit
#
#    location_address_coordinate_lat  location_address_coordinate_lon  \
# 0                        42.331509                       -83.115906
# 1                        42.434621                       -83.022913
# 2                        42.380327                       -83.107384
# 3                        42.430554                       -82.951112
# 4                        42.399219                       -83.170586
#
#   location_address_country   location_address_line  \
# 0                      USA  4031 Wesson St Apt 203
# 1                      USA           8060 House St
# 2                      USA           2245 Glynn Ct
# 3                      USA          12505 Laing St
# 4                      USA       14903 Appoline St
#
#   location_address_postal_code location_address_state_code  \
# 0                        48210                          MI
# 1                        48234                          MI
# 2                        48206                          MI
# 3                        48224                          MI
# 4                        48227                          MI
#
#   location_county_fips_code location_county_name  \
# 0                     26163                Wayne
# 1                     26163                Wayne
# 2                     26163                Wayne
# 3                     26163                Wayne
# 4                     26163                Wayne
#
#   other_listings_rdc_listing_id other_listings_rdc_status  \
# 0                    2943614976                  for_rent
# 1                    2993568991                  for_rent
# 2                    2993572983                  for_rent
# 3                    2993572679                  for_rent
# 4                    2993574074                  for_rent
#
#                                               permalink pet_policy_cats  \
# 0  4031-Wesson-St-Apt-203_Detroit_MI_48210_M92241-42149            True
# 1           8060-House-St_Detroit_MI_48234_M45245-99268             NaN
# 2           2245-Glynn-Ct_Detroit_MI_48206_M45131-66847             NaN
# 3          12505-Laing-St_Detroit_MI_48224_M44292-22423             NaN
# 4       14903-Appoline-St_Detroit_MI_48227_M30241-87742             NaN
#
#   pet_policy_dogs  \
# 0            True
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
#                                                                 photos_href  \
# 0  https://ap.rdcpix.com/3a8297dd868873a34ddcbc32fd698657l-m3931431616s.jpg
# 1   https://ap.rdcpix.com/62c6525e59adad414e40e92738cab311l-m653528514s.jpg
# 2  https://ap.rdcpix.com/02c2e962065a6114cdb095213c8ff0eel-m2110934173s.jpg
# 3  https://ap.rdcpix.com/68ed277532b855d54f76c7e72fa5fe1bl-m3824297005s.jpg
# 4  https://ap.rdcpix.com/bb95277b1f4e3d82760b56048d13142bl-m2789018322s.jpg
#
#                                                          primary_photo_href  \
# 0  https://ap.rdcpix.com/3a8297dd868873a34ddcbc32fd698657l-m3931431616s.jpg
# 1   https://ap.rdcpix.com/62c6525e59adad414e40e92738cab311l-m653528514s.jpg
# 2  https://ap.rdcpix.com/02c2e962065a6114cdb095213c8ff0eel-m2110934173s.jpg
# 3  https://ap.rdcpix.com/68ed277532b855d54f76c7e72fa5fe1bl-m3824297005s.jpg
# 4  https://ap.rdcpix.com/bb95277b1f4e3d82760b56048d13142bl-m2789018322s.jpg
#
#   products_brand_name products_products property_id source_feed_type  \
# 0        basic_opt_in          co_broke  9224142149  Syndicator Unit
# 1        basic_opt_in        core.agent  4524599268              NaN
# 2                 NaN               NaN  4513166847              NaN
# 3                 NaN               NaN  4429222423              NaN
# 4        basic_opt_in          co_broke  3024187742  Syndicator Unit
#
#   source_id  source_type    status advertisers_office_name  \
# 0      RNTR  unit_rental  for_rent                     NaN
# 1      DEMI          mls  for_rent      The Home Store Llc
# 2      SWMI          mls  for_rent   Green River Homes LLC
# 3      SWMI          mls  for_rent   Green River Homes LLC
# 4      RNTS  unit_rental  for_rent                     NaN
#
#   advertisers_office_phones_primary advertisers_phones_number  \
# 0                               NaN                       NaN
# 1                              True                2484145211
# 2                              True                8456561784
# 3                              True                8456561784
# 4                               NaN                       NaN
#
#   advertisers_phones_primary advertisers_phones_type          branding_name  \
# 0                        NaN                     NaN                    NaN
# 1                       True                  Office     The Home Store Llc
# 2                       True                  Mobile  Green River Homes LLC
# 3                       True                  Mobile  Green River Homes LLC
# 4                        NaN                     NaN                    NaN
#
#    description_garage flags_is_new_listing flags_is_pending  \
# 0                 NaN                  NaN              NaN
# 1                 2.0                 True              NaN
# 2                 1.0                 True              NaN
# 3                 1.0                 True              NaN
# 4                 NaN                 True              NaN
#
#    price_reduced_amount application_url pet_policy_dogs_large  \
# 0                   NaN             NaN                   NaN
# 1                   NaN             NaN                   NaN
# 2                   NaN             NaN                   NaN
# 3                   NaN             NaN                   NaN
# 4                   NaN             NaN                   NaN
#
#   pet_policy_dogs_small  description_baths_max  description_baths_min  \
# 0                   NaN                    NaN                    NaN
# 1                   NaN                    NaN                    NaN
# 2                   NaN                    NaN                    NaN
# 3                   NaN                    NaN                    NaN
# 4                   NaN                    NaN                    NaN
#
#    description_beds_max  description_beds_min description_name  \
# 0                   NaN                   NaN              NaN
# 1                   NaN                   NaN              NaN
# 2                   NaN                   NaN              NaN
# 3                   NaN                   NaN              NaN
# 4                   NaN                   NaN              NaN
#
#    description_sqft_max  description_sqft_min  list_price_max  list_price_min  \
# 0                   NaN                   NaN             NaN             NaN
# 1                   NaN                   NaN             NaN             NaN
# 2                   NaN                   NaN             NaN             NaN
# 3                   NaN                   NaN             NaN             NaN
# 4                   NaN                   NaN             NaN             NaN
#
#    source_community_id  units_description_baths  units_description_beds  \
# 0                  NaN                      NaN                     NaN
# 1                  NaN                      NaN                     NaN
# 2                  NaN                      NaN                     NaN
# 3                  NaN                      NaN                     NaN
# 4                  NaN                      NaN                     NaN
#
#    units_description_sqft  units_list_price has_specials  \
# 0                     NaN               NaN          NaN
# 1                     NaN               NaN          NaN
# 2                     NaN               NaN          NaN
# 3                     NaN               NaN          NaN
# 4                     NaN               NaN          NaN
#
#   lead_attributes_is_schedule_a_tour units_availability_date  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#   description_sub_type
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %% [markdown]
# # BUY

# %%
# -----######-----######-----######-----######-----######
# _re_1204_i6_GET_df_schema_discovery
# DISCOVER ALL VARIABLES (FLATTEN + UNION KEYS)
# -----######-----######-----######-----######-----######

import requests
import pandas as pd


def _flatten_dict(d, parent_key='', sep='_'):
    items = []
    if isinstance(d, dict):
        for k, v in d.items():
            new_key = f"{parent_key}{sep}{k}" if parent_key else k
            items.extend(_flatten_dict(v, new_key, sep=sep).items())
    elif isinstance(d, list):
        if len(d) > 0:
            items.extend(_flatten_dict(d[0], parent_key, sep=sep).items())
    else:
        items.append((parent_key, d))
    return dict(items)


def _bu_1204_i6_GET_df_schema_discovery(api_key, location="Detroit, MI", n_rows=50):

    url = "https://realtor16.p.rapidapi.com/search/forsale"

    headers = {
        "X-RapidAPI-Key": api_key.strip(),
        "X-RapidAPI-Host": "realtor16.p.rapidapi.com"
    }

    params = {
        "location": location,
        "limit": n_rows
    }

    r = requests.get(url, headers=headers, params=params)

    if r.status_code != 200:
        print("❌ Request failed:", r.status_code)
        print(r.text)
        return pd.DataFrame()

    data = r.json()
    listings = data.get("properties", [])

    if not listings:
        print("⚠️ No data")
        return pd.DataFrame()

    # ---- FLATTEN ALL LISTINGS ----
    flat_rows = [_flatten_dict(l) for l in listings]

    df = pd.DataFrame(flat_rows)

    print("\n📊 TOTAL VARIABLES FOUND:", len(df.columns))
    print("\n🧠 SAMPLE COLUMNS:\n", df.columns.tolist()[:50])

    return df

# %%
df_buy = _bu_1204_i6_GET_df_schema_discovery(API_KEY)
# Out:
# 📊 TOTAL VARIABLES FOUND: 52
#
# 🧠 SAMPLE COLUMNS:
#  ['advertisers_type', 'branding_name', 'branding_type', 'description_baths_consolidated', 'description_beds', 'description_lot_sqft', 'description_sqft', 'description_type', 'flags_is_price_reduced', 'lead_attributes_lead_type', 'lead_attributes_market_type', 'lead_attributes_ready_connect_mortgage_show_contact_a_lender', 'lead_attributes_ready_connect_mortgage_show_veterans_united', 'lead_attributes_show_contact_an_agent', 'list_date', 'list_price', 'listing_id', 'location_address_city', 'location_address_coordinate_lat', 'location_address_coordinate_lon', 'location_address_line', 'location_address_postal_code', 'location_address_state', 'location_address_state_code', 'location_county_fips_code', 'location_county_name', 'location_street_view_url', 'permalink', 'photos_href', 'price_reduced_amount', 'primary_photo_href', 'products_brand_name', 'products_products', 'property_id', 'source_agents_office_name', 'source_id', 'source_type', 'status', 'branding_photo', 'description_sold_date', 'description_sold_price', 'flags_is_pending', 'flags_is_contingent', 'flags_is_foreclosure', 'flags_is_new_listing', 'description_sub_type', 'matterport', 'virtual_tours_href', 'flags_is_new_construction', 'flags_is_coming_soon']

# %%
len(df_buy)

#df_buy.to_pickle('df_buy.pkl')
df_buy = pd.read_pickle('df_buy.pkl')

# %% [markdown]
# # EDA

# %%
# -----######-----######-----######-----######-----######
# _re_1204_i2_GET_df_deal_engine_clean
# DEAL ENGINE (CLEAN FEATURES + ORDERED OUTPUT)
# -----######-----######-----######-----######-----######

import pandas as pd
import numpy as np
from tqdm import tqdm


def _re_1204_i2_GET_df_deal_engine_clean(df):

    df = df.copy()
    tqdm.pandas()

    # -----------------------------
    # 1. CLEAN TYPES
    # -----------------------------
    df['list_price'] = pd.to_numeric(df['list_price'], errors='coerce')
    df['description_sqft'] = pd.to_numeric(df['description_sqft'], errors='coerce')
    df['description_lot_sqft'] = pd.to_numeric(df['description_lot_sqft'], errors='coerce')
    df['description_beds'] = pd.to_numeric(df['description_beds'], errors='coerce')
    df['description_baths_consolidated'] = pd.to_numeric(df['description_baths_consolidated'], errors='coerce')
    df['price_reduced_amount'] = pd.to_numeric(df['price_reduced_amount'], errors='coerce')

    df['list_date'] = (
        pd.to_datetime(df['list_date'], errors='coerce')
        .dt.tz_convert(None)
    )

    # -----------------------------
    # 2. DERIVED FEATURES
    # -----------------------------
    today = pd.Timestamp.today()

    df['price_per_sqft'] = df['list_price'] / df['description_sqft']
    df['discount_pct'] = df['price_reduced_amount'] / df['list_price']
    df['days_on_market'] = (today - df['list_date']).dt.days

    df['discount_pct'] = df['discount_pct'].fillna(0)
    df['days_on_market'] = df['days_on_market'].fillna(0)

    # -----------------------------
    # 3. NORMALIZATION
    # -----------------------------
    def _norm(series):
        return (series - series.min()) / (series.max() - series.min() + 1e-9)

    # -----------------------------
    # 4. FEATURE SCORES
    # -----------------------------
    structure = (
        _norm(df['description_sqft']) * 0.5 +
        (1 - _norm(df['price_per_sqft'])) * 0.5
    )

    dynamics = (
        _norm(df['discount_pct']) * 0.7 +
        (1 - _norm(df['list_price'])) * 0.3
    )

    context = np.ones(len(df)) * 0.5

    friction = (
        _norm(df['days_on_market']) * 0.7 +
        df['flags_is_foreclosure'].fillna(False).astype(int) * 0.3
    )

    optionality = (
        _norm(df['description_lot_sqft']) * 0.5 +
        _norm(df['description_sqft']) * 0.5
    )

    # -----------------------------
    # 5. FINAL SCORES
    # -----------------------------
    df['score_structure'] = structure * 100
    df['score_dynamics'] = dynamics * 100
    df['score_context'] = context * 100
    df['score_friction'] = friction * 100
    df['score_optionality'] = optionality * 100

    df['deal_score'] = (
        0.25 * df['score_structure'] +
        0.30 * df['score_dynamics'] +
        0.20 * df['score_context'] +
        0.15 * (100 - df['score_friction']) +
        0.10 * df['score_optionality']
    )

    # -----------------------------
    # 6. SELECT + ORDER COLUMNS (🔥 KEY FIX)
    # -----------------------------
    cols_final = [

        # ----- IDENTIFIERS -----
        'listing_id',
        'location_address_city',
        'location_address_postal_code',
        'location_address_line',

        # ----- STRUCTURE -----
        'list_price',
        'description_sqft',
        'description_lot_sqft',
        'description_beds',
        'description_baths_consolidated',
        'price_per_sqft',

        # ----- DYNAMICS -----
        'price_reduced_amount',
        'discount_pct',

        # ----- FRICTION -----
        'list_date',
        'days_on_market',
        'flags_is_foreclosure',

        # ----- SCORES -----
        'score_structure',
        'score_dynamics',
        'score_context',
        'score_friction',
        'score_optionality',
        'deal_score'
    ]

    # keep only existing cols (safe)
    cols_final = [c for c in cols_final if c in df.columns]

    df = df[cols_final].copy()

    # -----------------------------
    # 7. SORT
    # -----------------------------
    df = df.sort_values('deal_score', ascending=False).reset_index(drop=True)

    return df

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!

df_out = _re_1204_i2_GET_df_deal_engine_clean(df_buy)

# top deals
df_out[['listing_id', 'deal_score']].head(10)
# Out:
#    listing_id  deal_score
# 0  2988906949   66.754553
# 1  2991636881   60.211597
# 2  2993157874   56.961681
# 3  2991971549   54.040910
# 4  2988235896   51.599257
# 5  2992800944   50.567180
# 6  2990579511   50.174744
# 7  2984567600   49.971513
# 8  2993207731   49.768733
# 9  2986709386   49.388917

# %%
df_out
# Out:
#      listing_id location_address_city location_address_postal_code  \
# 0    2988906949               Detroit                        48213
# 1    2991636881               Detroit                        48238
# 2    2993157874               Detroit                        48206
# 3    2991971549               Detroit                        48228
# 4    2988235896               Detroit                        48211
# 5    2992800944               Detroit                        48206
# 6    2990579511               Detroit                        48213
# 7    2984567600               Detroit                        48203
# 8    2993207731         Highland Park                        48203
# 9    2986709386               Detroit                        48204
# 10   2992839217               Detroit                        48206
# 11   2992881686               Detroit                        48204
# 12   2992328289               Detroit                        48202
# 13   2993374078               Detroit                        48221
# 14   2989704138               Detroit                        48204
# 15   2991907192               Detroit                        48205
# 16   2993098199               Detroit                        48235
# 17   2992417558               Detroit                        48238
# 18   2989205860               Detroit                        48207
# 19   2992922041               Detroit                        48213
# 20   2991425418               Detroit                        48214
# 21   2992874366               Detroit                        48202
# 22   2993416071               Detroit                        48208
# 23   2992648880               Detroit                        48221
# 24   2993475154               Detroit                        48206
# 25   2992439148               Detroit                        48227
# 26   2993018361               Detroit                        48206
# 27   2979451505               Detroit                        48203
# 28   2992118676               Detroit                        48205
# 29   2987606736         Highland Park                        48203
# 30   2993240370               Detroit                        48207
# 31   2993463445               Detroit                        48221
# 32   2991684444               Detroit                        48235
# 33   2993011974               Detroit                        48206
# 34   2993572834               Detroit                        48213
# 35   2992599188               Detroit                        48207
# 36   2993322125               Detroit                        48221
# 37   2990170176               Detroit                        48224
# 38   2993011777               Detroit                        48205
# 39   2992662834               Detroit                        48202
# 40   2993032238               Detroit                        48227
# 196                  20035 Coventry St      169999            1304.0
# 197           5766 Trumbull St Apt 207      275900            1088.0
# 198         1550 Cherboneau Pl Apt 127       39900             900.0
# 199       1300 E Lafayette St Apt 1812      269000            1210.0
#
#      description_lot_sqft  description_beds  description_baths_consolidated  \
# 0                  3920.0               4.0                             1.0
# 1                  8276.0              29.0                            24.0
# 2                 10019.0              19.0                            16.0
# 3                  5663.0               2.0                             1.0
# 4                 14810.0              20.0                            10.0
# 5                  4792.0               8.0                             4.0
# 6                 13068.0               8.0                             8.0
# 7                 22651.0               8.0                             NaN
# 8                 36155.0               5.0                             NaN
# 9                  5663.0               8.0                             4.0
# 10                 6098.0               8.0                             4.0
# 11                 6970.0               8.0                             NaN
# 12                 5663.0               8.0                             4.0
# 13                 3920.0               4.0                             2.0
# 14                 5227.0               8.0                             4.0
# 15                 7405.0               8.0                             4.0
# 16                 4792.0               5.0                             3.5
# 17                 3920.0               6.0                             3.5
# 18                 5663.0               4.0                             2.5
# 19                 9148.0               4.0                             NaN
# 20                 8712.0               6.0                             3.5
# 21                19166.0               6.0                             3.5
# 22                10019.0               5.0                             2.5
# 23                 5227.0               5.0                             2.0
# 24                 4792.0               4.0                             1.5
# 25                 3920.0               3.0                             1.0
# 26                 3049.0               3.0                             2.0
# 27               207346.0              15.0                             NaN
# 28                 3920.0               2.0                             2.5
# 29                 6098.0               6.0                             3.0
# 30                 6098.0               6.0                             3.5
# 31                 6098.0               5.0                             3.5
# 32                 4356.0               2.0                             1.0
# 33                 4792.0               5.0                             3.5
# 34                 3485.0               4.0                             1.5
# 35                 3049.0               6.0                             2.0
# 36                 3920.0               6.0                             3.5
# 37                 5227.0               4.0                             2.0
# 38                 6098.0               4.0                             2.0
# 39                16553.0               5.0                             NaN
# 40                 4792.0               3.0                             1.0
# 41                 3920.0               4.0                             2.0
# 42                 3920.0               2.0                             1.0
# 43                18731.0               7.0                             NaN
# 44                 3920.0               4.0                             3.0
# 45                11761.0               5.0                             NaN
# 46                 3920.0               3.0                             2.0
# 47                 6098.0               3.0                             1.5
# 48                 4356.0               2.0                             2.0
# 49                 4356.0               4.0                             2.0
# 50                 3485.0               4.0                             2.5
# 51                 6098.0               3.0                             1.0
# 52                 4792.0               2.0                             1.0
# 53                 6970.0               6.0                             3.5
# 54                 5663.0               3.0                             1.5
# 55                 4356.0               3.0                             1.0
# 56                 5227.0               5.0                             2.0
# 57                 3920.0               4.0                             2.0
# 58                21344.0               5.0                             4.5
# 59                 5227.0               3.0                             2.0
# 60                 4792.0               4.0                             1.0
# 61                 5663.0               3.0                             1.0
# 62                 3920.0               4.0                             2.5
# 63                 3920.0               4.0                             2.0
# 64                13939.0               5.0                             3.5
# 65                 3485.0               4.0                             2.0
# 66                 3485.0               6.0                             3.0
# 67                 8712.0               5.0                             2.5
# 68                 6970.0               3.0                             2.0
# 69                 7405.0               5.0                             3.0
# 70                 8276.0               3.0                             1.5
# 71                 4792.0               3.0                             2.0
# 72                11326.0               5.0                             5.5
