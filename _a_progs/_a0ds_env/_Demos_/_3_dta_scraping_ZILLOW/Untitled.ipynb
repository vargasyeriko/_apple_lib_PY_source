# %%
API_KEY = "e8ed9c0c93msh606b92a16b58a9cp187683jsn253baf6dc2f5".strip()

# %%
import requests


url = "https://realtor16.p.rapidapi.com/search/forrent"

headers = {
    "X-RapidAPI-Key": API_KEY,
    "X-RapidAPI-Host": "realtor16.p.rapidapi.com"
}

# MINIMAL PARAMS
params = {
    "location": "Detroit, MI"
}

r = requests.get(url, headers=headers, params=params)

print("STATUS:", r.status_code)
print("RAW:", r.text[:500])
# Out:
# STATUS: 200
# RAW: {"costar_counts":[],"count":50,"properties":[{"advertisers":[{"office":{"name":[],"phones":[{"ext":[],"number":"3134629181","primary":[],"trackable":[],"type":"primary"}]},"phones":[],"rental_management":[],"type":"management"},{"office":[],"phones":[],"rental_management":[],"type":"unit_rental"}],"application_url":[],"branding":[{"name":[],"photo":[],"type":"Office"}],"description":{"baths_consolidated":"1","baths_max":[],"baths_min":[],"beds":2,"beds_max":[],"beds_min":[],"garage":[],"garage_m
