# %%
# !python app.py DLTA
# Out:
#   ╔══════════════════════════════════════════════╗
#   ║   STOCK ANALYSIS DASHBOARD — DLTA             ║
#   ╚══════════════════════════════════════════════╝
#
#   Fetching DLTA data...
#   Got 250 bars  (2025-04-16 → 2026-04-15)
#
#   ┌─────────────────────────────────────────────┐
#   │  1/10  VOLATILITY + TREND COMPRESSION       │
#   └─────────────────────────────────────────────┘
#
#   DLTA — TREND / VOL (30D)
#   ────────────────────────────────────────────
#   Price Path:
#   ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
#
#   Volatility:
#   .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#   ────────────────────────────────────────────
#   Legend:  ▁▇ = price progression
#            . : ! = low → med → high volatility
#   Annual Vol (30D): 0.0%
#
#   ┌─────────────────────────────────────────────┐
#   │  2/10  MOMENTUM DECAY RADAR                 │
#   └─────────────────────────────────────────────┘
#
# ...

# %%
90/7
# Out:
# 12.857142857142858

# %%
((.13)*4000 +4000)*12
# Out:
# 54240.0

# %%
54240.0/(4000*12)
# Out:
# 1.13

# %%
54240.0 -40000
# Out:
# 14240.0

# %%
MAKE A STRATEGY !!

ENTRY POINT / SELL % , STRATEGY FOR DIFF (LONG TERM , SHORT) + STARTEGY 

YOU CAN DO IN PY
