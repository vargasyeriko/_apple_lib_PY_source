# %%
import os
os.getcwd()
# Out:
# '/Users/yerik/_apple_source/PY/JUPY/_pyENVS/_Source/src_env0/_mini_source/_EXAMPLES_SQL'

# %% [markdown]
# ![image.png](attachment:80bad7b1-f715-4590-ae6d-c1f0dd3673a2.png)

# %% [markdown]
# ![image.png](attachment:c01f9ec9-c32e-4baf-ab8a-a67bf9d3fb80.png)
