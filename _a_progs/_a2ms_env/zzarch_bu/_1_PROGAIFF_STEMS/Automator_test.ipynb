# %%
v_folders = [
    "/Users/yerik/Desktop/STEMS/vocals/10_percent_silence",
    "/Users/yerik/Desktop/STEMS/vocals/20_percent_silence",
    "/Users/yerik/Desktop/STEMS/vocals/30_percent_silence"
]


b_folders = [
    "/Users/yerik/Desktop/STEMS/bass/10_percent_silence",
    "/Users/yerik/Desktop/STEMS/bass/20_percent_silence",
    "/Users/yerik/Desktop/STEMS/bass/30_percent_silence"
]

d_folders = [
    "/Users/yerik/Desktop/STEMS/drums/10_percent_silence",
    "/Users/yerik/Desktop/STEMS/drums/20_percent_silence",
    "/Users/yerik/Desktop/STEMS/drums/30_percent_silence"
]

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import pickle

with open('df_b_final.pkl', 'rb') as f:
    data = pickle.load(f)

# If it's a DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                 Path  \
# 0  /Users/yerik/Desktop/STEMS/bass/10_percent_sil...
# 1  /Users/yerik/Desktop/STEMS/bass/10_percent_sil...
# 2  /Users/yerik/Desktop/STEMS/bass/20_percent_sil...
# 3  /Users/yerik/Desktop/STEMS/bass/30_percent_sil...
#
#                                              temp_id  \
# 0  TRkw__0077_23_vocals_SIL010____ARkw_Various_MX...
# 1  TRkw__0077_23_vocals_SIL010____ARkw_Various_MX...
# 2  TRkw__0077_23_vocals_SIL010____ARkw_Various_MX...
# 3  TRkw__0077_23_vocals_SIL010____ARkw_Various_MX...
#
#                                            file_name Extension  dur_seconds  \
# 0  TRkw__0077_23_vocals_SIL010____ARkw_Various_MX...     .aiff          121
# 1  TRkw__0077_23_vocals_SIL010____ARkw_Various_MX...     .aiff          121
# 2  TRkw__0077_23_vocals_SIL010____ARkw_Various_MX...     .aiff          121
# 3  TRkw__0077_23_vocals_SIL010____ARkw_Various_MX...     .aiff          121
#
#     dur_min     sr bit_depth bit_rate channels file_size file_size_human  \
# 0  2.015492  44100        16     None        2  21358160        20.37 MB
# 1  2.015492  44100        16     None        2  21358160        20.37 MB
# 2  2.015492  44100        16     None        2  21358160        20.37 MB
# 3  2.015492  44100        16     None        2  21358160        20.37 MB
#
#   num_frames error  ms_lufs ms_LUFS_code id_cat_lufs    mean_bpm   std_bpm  \
# 0    5332992  None  -32.235          NAN           A  128.849085  0.990327
# 1    5332992  None  -32.235          NAN           A  128.849085  0.990327
# 2    5332992  None  -32.235          NAN           A  128.849085  0.990327
# 3    5332992  None  -32.235          NAN           A  128.849085  0.990327
#
#       min_bpm     max_bpm  variation_percentage  dominant_bpm  \
# 0  126.048018  129.199219              0.768594           129
# 1  126.048018  129.199219              0.768594           129
# 2  126.048018  129.199219              0.768594           129
# 3  126.048018  129.199219              0.768594           129
#
#    bpm_consistency bpm_consistency_cat                  title title_file  \
# 0         0.992335                 D_9  0077 23 vocals SIL010    ID3TAGS
# 1         0.992335                 D_9  0077 23 vocals SIL010    ID3TAGS
# 2         0.992335                 D_9  0077 23 vocals SIL010    ID3TAGS
# 3         0.992335                 D_9  0077 23 vocals SIL010    ID3TAGS
#
#     artist artist_file         LABEL label_file genre genre_file rel_year  \
# 0  Various     ID3TAGS  STEMS-vocals    ID3TAGS  bass    ID3TAGS     2025
# 1  Various     ID3TAGS  STEMS-vocals    ID3TAGS  bass    ID3TAGS     2025
# 2  Various     ID3TAGS  STEMS-vocals    ID3TAGS  bass    ID3TAGS     2025
# 3  Various     ID3TAGS  STEMS-vocals    ID3TAGS  bass    ID3TAGS     2025
#
#   rel_year_file    KEY key_file  mix_name   remixer remix date_purchased  \
# 0     FILE_NAME  A#maj  ID3TAGS  original  original     O     2025-05-07
# 1     FILE_NAME  A#maj  ID3TAGS  original  original     O     2025-05-07
# 2     FILE_NAME  A#maj  ID3TAGS  original  original     O     2025-05-07
# 3     FILE_NAME  A#maj  ID3TAGS  original  original     O     2025-05-07
#
#      rel_date rel_date_file key_dj key_music                 status  \
# 0  2025-01-01       ID3TAGS     6B     A#maj  Success: TKEY updated
# 1  2025-01-01       ID3TAGS     6B     A#maj  Success: TKEY updated
# 2  2025-01-01       ID3TAGS     6B     A#maj  Success: TKEY updated
# 3  2025-01-01       ID3TAGS     6B     A#maj  Success: TKEY updated
#
#   Relative_Key Key_Up Key_Down Jaw_s_Mix Mood_Shifter       ID  \
# 0           6A     7B       5B        1B           3A  b1-5700
# 1           6A     7B       5B        1B           3A  b1-5701
# 2           6A     7B       5B        1B           3A  b2-5700
# 3           6A     7B       5B        1B           3A  b3-5700
#
#                Path_jpg_album                Path_jpg_key  \
# 0  images/cover_1_b1-5700.jpg  images/key_plotb1-5700.png
# 1  images/cover_1_b1-5701.jpg  images/key_plotb1-5701.png
# 2  images/cover_1_b2-5700.jpg  images/key_plotb2-5700.png
# 3  images/cover_1_b3-5700.jpg  images/key_plotb3-5700.png
#
#                  Path_jpg_clip                Path_png_bar_dyn  ms_LUFS_norm  \
# 0  images/clip_plotb1-5700.jpg  images/bpm_bar_dyn_b1-5700.png      3.846154
# 1  images/clip_plotb1-5701.jpg  images/bpm_bar_dyn_b1-5701.png      3.846154
# 2  images/clip_plotb2-5700.jpg  images/bpm_bar_dyn_b2-5700.png      3.846154
# 3  images/clip_plotb3-5700.jpg  images/bpm_bar_dyn_b3-5700.png      3.846154
#
#                  Path_png_bar_lufs  Spectral_Bandwidth  Spectral_Flatness  \
# 0  images/lufs_bar_dyn_b1-5700.png         2298.211863           0.000008
# 1  images/lufs_bar_dyn_b1-5701.png         2298.211863           0.000008
# 2  images/lufs_bar_dyn_b2-5700.png         2298.211863           0.000008
# 3  images/lufs_bar_dyn_b3-5700.png         2298.211863           0.000008
#
#   HEX_shape_texture              Path_png_bar_text  spec_centroid_hz  \
# 0           #3EA4FF  images/text_shape_b1-5700.png        573.181641
# 1           #3EA4FF  images/text_shape_b1-5701.png        573.181641
# 2           #3EA4FF  images/text_shape_b2-5700.png        573.181641
# 3           #3EA4FF  images/text_shape_b3-5700.png        573.181641
#
#   centroid_color              centroid_desc  \
# 0        #061539  Submerged, thick textures
# 1        #061539  Submerged, thick textures
# 2        #061539  Submerged, thick textures
# 3        #061539  Submerged, thick textures
#
#                Path_png_bar_centroid                  Path_csv_freq  \
# 0  images/centroid_donut_b1-5700.png  tables/table_freq_b1-5700.csv
# 1  images/centroid_donut_b1-5701.png  tables/table_freq_b1-5701.csv
# 2  images/centroid_donut_b2-5700.png  tables/table_freq_b2-5700.csv
# 3  images/centroid_donut_b3-5700.png  tables/table_freq_b3-5700.csv
#
#                    Path_png_dr  ID_save            Path_png_id_and_key  \
# 0  images/dbs_plot_b1-5700.png  b1-5700  images/key_and_id_b1-5700.png
# 1  images/dbs_plot_b1-5701.png  b1-5701  images/key_and_id_b1-5701.png
# 2  images/dbs_plot_b2-5700.png  b2-5700  images/key_and_id_b2-5700.png
# 3  images/dbs_plot_b3-5700.png  b3-5700  images/key_and_id_b3-5700.png
#
#   year_written_id3 bought_year  \
# 0      Unsupported        None
# 1      Unsupported        None
# 2      Unsupported        None
# 3      Unsupported        None
#
#                                              comment  \
# 0  b1-5700-6B-A#maj---25-BASS-007723vocalssil010-...
# 1  b1-5701-6B-A#maj---25-BASS-007723vocalssil010-...
# 2  b2-5700-6B-A#maj---25-BASS-007723vocalssil010-...
# 3  b3-5700-6B-A#maj---25-BASS-007723vocalssil010-...
#
#                                              re_name  \
# 0  b1-5700-6BA#maj---25-VARIOUS-007723vocalssil01...
# 1  b1-5701-6BA#maj---25-VARIOUS-007723vocalssil01...
# 2  b2-5700-6BA#maj---25-VARIOUS-007723vocalssil01...
# 3  b3-5700-6BA#maj---25-VARIOUS-007723vocalssil01...
#
#                                           audio_hash
# 0  FFmpeg Error: ffmpeg version 6.1 Copyright (c)...
# 1  FFmpeg Error: ffmpeg version 6.1 Copyright (c)...
# 2  FFmpeg Error: ffmpeg version 6.1 Copyright (c)...
# 3  FFmpeg Error: ffmpeg version 6.1 Copyright (c)...
