# %% [markdown]
# ### RUN TRUN

# %%
path_in = "/Users/yerik/Music/__00_PY/_RELEASE_.wav"

# %%
exec(open("__trun_.py",encoding="utf-8").read())
# Out:
# 🎵 Default Track Title from filename: _RELEASE_
#
# 2. Artist
# 3. Mix Type
# 4. Key
# 5. BPM
# 6. Genre
# 7. Label
# 8. Release Date
# 9. Purchase Date
# 🔁 Enter numbers of fields to override (comma-separated), or 'n' to skip:
# ✅ Done editing fields? (y/n):  y
# ✅ File successfully renamed to:
# 📁 TRkw__RELEASE__ARkw_NA_MXkw_NA_KYkw_NA_BPkw_NA_GNkw_NA_LBkw_NA_RYkw_NA_PYkw_NA.wav
# ✅ Converted + tagged: TRkw__RELEASE__ARkw_NA_MXkw_NA_KYkw_NA_BPkw_NA_GNkw_NA_LBkw_NA_RYkw_NA_PYkw_NA.aiff
# 🗑️ Deleted original WAV: TRkw__RELEASE__ARkw_NA_MXkw_NA_KYkw_NA_BPkw_NA_GNkw_NA_LBkw_NA_RYkw_NA_PYkw_NA.wav
# ✅ All done. AIFF files created ➜ tagged ➜ WAVs deleted.
# ABOUT TO CHOP
# 🔍 Low-Vol Split 1–2min: 100%|██████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.98s/it]
# ALL AIFF in correct format -> if something changes go erase the already downsized
# What is the acronym (1-2 char) ? dr
# ...

# %%
df_chunks
# Out:
#                                                 Path
# 0  /Users/yerik/Music/__00_PY/TRkw__RELEASE__ARkw...
# 1  /Users/yerik/Music/__00_PY/TRkw__RELEASE__ARkw...
# 2  /Users/yerik/Music/__00_PY/TRkw__RELEASE__ARkw...
