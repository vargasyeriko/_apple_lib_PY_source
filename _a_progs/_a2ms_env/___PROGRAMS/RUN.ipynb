# %% [markdown]
# # START
#
# ## path fns : /Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns
#
# ## path fns : Users.yerik._apple_lib._a_progs._a2ms_env.___PROGRAMS._0_fns

# %%
# sys.path.append("/Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns")

# from _#_fn_folder import (
#     _fn,
#     _fn,
# )

# %%
# %run run.py
# Out:
# ============================
#        AVAILABLE PROGRAMS
# ============================
#  0 → _0_prog_SoundcloudDwonloader.py
#  1 → _1_prog_check_mp3s.py
#  2 → _2_prog_anyfile_to_AIFF.py
# ============================
# Run program # →  0
# ▶️  Running: _0_prog_SoundcloudDwonloader.py
# Paste SoundCloud playlist/SET URL:
# >  https://soundcloud.com/yeriko_dj/sets/raph/s-KTmgbCNktby?si=ad04123451f44f3cb119181a759ff69e&utm_source=clipboard&utm_medium=text&utm_campaign=social_sharing
#
# Keyword for this download folder (e.g. salsa, halloween, reggaeton):
# >  rrr
# ==============================
#  Playlist URL : https://soundcloud.com/yeriko_dj/sets/raph/s-KTmgbCNktby?si=ad04123451f44f3cb119181a759ff69e&utm_source=clipboard&utm_medium=text&utm_campaign=social_sharing
#  Output folder: /Users/yerik/Downloads/05_09_rrr_soundcloud_audio
# ==============================
# TQM • Scraping playlists: 100%|███████████████████████████████████████████| 1/1 [00:01<00:00,  1.49s/playlist]
# Enter GENRE for this batch:  ragaeton
# TQM • Parsing titles: 100%|████████████████████████████████████████████| 12/12 [00:00<00:00, 166661.09track/s]
# TQM • Downloading SoundCloud audio:   0%|                                             | 0/12 [00:00<?, ?url/s]
# ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:   8%|███                                  | 1/12 [00:16<03:04, 16.76s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  17%|██████▏                              | 2/12 [00:17<01:15,  7.59s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  25%|█████████▎                           | 3/12 [00:18<00:41,  4.58s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  33%|████████████▎                        | 4/12 [00:20<00:25,  3.23s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  42%|███████████████▍                     | 5/12 [00:21<00:16,  2.42s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  50%|██████████████████▌                  | 6/12 [00:22<00:11,  1.96s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  58%|█████████████████████▌               | 7/12 [00:23<00:08,  1.65s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  67%|████████████████████████▋            | 8/12 [00:24<00:05,  1.44s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  75%|███████████████████████████▊         | 9/12 [00:25<00:03,  1.33s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  83%|██████████████████████████████      | 10/12 [00:26<00:02,  1.23s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio:  92%|█████████████████████████████████   | 11/12 [00:27<00:01,  1.16s/url]ERROR: [soundcloud] Unable to download JSON metadata: HTTP Error 404: Not Found (caused by <HTTPError 404: Not Found>)
# TQM • Downloading SoundCloud audio: 100%|████████████████████████████████████| 12/12 [00:28<00:00,  2.35s/url]
# ✅ Done. Download log saved to:
# /Users/yerik/Downloads/05_09_rrr_soundcloud_audio/_dl_log.csv

# %% [markdown]
# ## /Users/yerik/Music/_00_MUSIC_PY/jan19
