# %% [markdown]
# # START
#
# ## path fns : /Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns
#
# ## path fns : Users.yerik._apple_lib._a_progs._a2ms_env.___PROGRAMS._0_fns

# %%
# sys.path.append("/Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns")

# from _#_fn_folder import (
#     _fn,
#     _fn,
# )

# %%
# %run run.py
# Out:
# ...
#        AVAILABLE PROGRAMS
# ...
#  0 → _0_prog_SoundcloudDwonloader.py
#  1 → _1_prog_check_mp3s.py
#  2 → _2_prog_anyfile_to_AIFF.py
# ...
# Run program # →  2
# ▶️  Running: _2_prog_anyfile_to_AIFF.py
#
# !!! --- > THIS fn takes any audio file to AIFF, even AIFF files gets converted to desire format, and renames !!!
# !!! --- > FOR custom tags i.e. name, release year etc go inside prog  !!!
# 📁 root_folder (folder to scan):
# >  /Users/yerik/Downloads/01_19_denver_soundcloud_audio
# 📁 out_root (press Enter = None):
# >
# TQM | All → AIFF 44.1/16/stereo: 100%|█| 9/9 [00:02<00:00,  3.12file/s, OK: Todd Terry-InHouseRecords - Todd T
# [2026-01-19 19:15:38] === SUMMARY ===
# Total scanned:     9
# Planned to convert:9
# Converted OK:      9
# Broken (tagged):   0
# Failed:            0
# Skipped (exists):  0
# ✅ DONE converting files , press enter to erase original ones after checking !!!
# ...

# %% [markdown]
# ## /Users/yerik/Music/_00_MUSIC_PY/jan19
