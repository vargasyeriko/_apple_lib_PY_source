# %% [markdown]
# # START
#
# ## path fns : /Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns
#
# ## path fns : Users.yerik._apple_lib._a_progs._a2ms_env.___PROGRAMS._0_fns

# %%
# sys.path.append("/Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns")

# from _#_fn_folder import (
#     _fn,
#     _fn,
# )

# %%
# %run run.py
# Out:
# ============================
#        AVAILABLE PROGRAMS
# ============================
#  0 → _0_prog_SoundcloudDwonloader.py
#  1 → _1_prog_check_mp3s.py
#  2 → _2_prog_anyfile_to_AIFF.py
# ============================
# Run program # →  0
# ▶️  Running: _0_prog_SoundcloudDwonloader.py
# Paste SoundCloud playlist/SET URL:
# >  https://soundcloud.com/yeriko_dj/sets/spkr-dec-1/s-QE7jwvzvxZV?si=fdfaedfc996a4b5ab9620d59ce8f2157&utm_source=clipboard&utm_medium=text&utm_campaign=social_sharing
#
# Keyword for this download folder (e.g. salsa, halloween, reggaeton):
# >  House
# ==============================
#  Playlist URL : https://soundcloud.com/yeriko_dj/sets/spkr-dec-1/s-QE7jwvzvxZV?si=fdfaedfc996a4b5ab9620d59ce8f2157&utm_source=clipboard&utm_medium=text&utm_campaign=social_sharing
#  Output folder: /Users/yerik/Downloads/03_30_House_soundcloud_audio
# ==============================
# TQM • Scraping playlists: 100%|███████████████████████████████████████████| 1/1 [00:01<00:00,  1.32s/playlist]
# Enter GENRE for this batch:  house
# TQM • Parsing titles: 100%|████████████████████████████████████████████| 46/46 [00:00<00:00, 225394.84track/s]
# TQM • Downloading SoundCloud audio:   0%|                                             | 0/46 [00:00<?, ?url/s]
# TQM • Downloading SoundCloud audio: 100%|████████████████████████████████████| 46/46 [04:02<00:00,  5.28s/url]
# ✅ Done. Download log saved to:
# /Users/yerik/Downloads/03_30_House_soundcloud_audio/_dl_log.csv

# %% [markdown]
# ## /Users/yerik/Music/_00_MUSIC_PY/jan19
