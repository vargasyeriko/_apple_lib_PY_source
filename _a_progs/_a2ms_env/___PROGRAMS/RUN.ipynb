# %%
# %run run.py
# Out:
# ...
#        AVAILABLE PROGRAMS
# ...
#  0 → _0_prog_SoundcloudDwonloader.py
#  1 → _1_prog_check_mp3s.py
# ...
# Run program # →  0
# ▶️  Running: _0_prog_SoundcloudDwonloader.py
# Paste SoundCloud playlist/SET URL:
# >  https://soundcloud.com/yeriko_dj/sets/grimes/s-MymABqHBgrq?si=74b1b8bc1be94730b09dfd06291652c2&utm_source=clipboard&utm_medium=text&utm_campaign=social_sharing
#
# Keyword for this download folder (e.g. salsa, halloween, reggaeton):
# >  Grizmas
# ...
#  Playlist URL : https://soundcloud.com/yeriko_dj/sets/grimes/s-MymABqHBgrq?si=74b1b8bc1be94730b09dfd06291652c2&utm_source=clipboard&utm_medium=text&utm_campaign=social_sharing
#  Output folder: /Users/yerik/Downloads/12_14_Grizmas_soundcloud_audio
# ...
# TQM • Scraping playlists: 100%|███████████████████████████████████████████| 1/1 [00:01<00:00,  1.48s/playlist]
# Enter GENRE for this batch:  bassdance
# ...
# TQM • Downloading SoundCloud audio: 100%|██████████████████████████████████████| 4/4 [00:18<00:00,  4.56s/url]
# ...

# %%
475*.30
# Out:
# 142.5
