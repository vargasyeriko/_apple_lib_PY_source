# %% [markdown]
# # START
#
# ## path fns : /Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns
#
# ## path fns : Users.yerik._apple_lib._a_progs._a2ms_env.___PROGRAMS._0_fns

# %%
# sys.path.append("/Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns")

# from _#_fn_folder import (
#     _fn,
#     _fn,
# )

# %%
# %run run.py
# Out:
# ============================
#        AVAILABLE PROGRAMS
# ============================
#  0 → _0_prog_SoundcloudDwonloader.py
#  1 → _1_prog_check_mp3s.py
#  2 → _2_prog_anyfile_to_AIFF.py
# ============================
# Run program # →  0
# ▶️  Running: _0_prog_SoundcloudDwonloader.py
# Paste SoundCloud playlist/SET URL:
# >  https://soundcloud.com/yeriko_dj/sets/spkrbox-1?si=5a636600ea0846aea04bdc8df1f78d48&utm_source=clipboard&utm_medium=text&utm_campaign=social_sharing
#
# Keyword for this download folder (e.g. salsa, halloween, reggaeton):
# >  spkr
# ==============================
#  Playlist URL : https://soundcloud.com/yeriko_dj/sets/spkrbox-1?si=5a636600ea0846aea04bdc8df1f78d48&utm_source=clipboard&utm_medium=text&utm_campaign=social_sharing
#  Output folder: /Users/yerik/Downloads/03_29_spkr_soundcloud_audio
# ==============================
# TQM • Scraping playlists: 100%|███████████████████████████████████████████| 1/1 [00:01<00:00,  1.33s/playlist]
# Enter GENRE for this batch:  house
# TQM • Parsing titles: 100%|███████████████████████████████████████████████| 3/3 [00:00<00:00, 25165.82track/s]
# TQM • Downloading SoundCloud audio:   0%|                                              | 0/3 [00:00<?, ?url/s]
# TQM • Downloading SoundCloud audio: 100%|██████████████████████████████████████| 3/3 [00:21<00:00,  7.14s/url]
# ✅ Done. Download log saved to:
# /Users/yerik/Downloads/03_29_spkr_soundcloud_audio/_dl_log.csv

# %% [markdown]
# ## /Users/yerik/Music/_00_MUSIC_PY/jan19
