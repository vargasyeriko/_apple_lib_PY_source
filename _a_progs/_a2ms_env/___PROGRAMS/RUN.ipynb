# %% [markdown]
# # START
#
# ## path fns : /Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns
#
# ## path fns : Users.yerik._apple_lib._a_progs._a2ms_env.___PROGRAMS._0_fns

# %%
# sys.path.append("/Users/yerik/_apple_lib/_a_progs/_a2ms_env/___PROGRAMS/_0_fns")

# from _#_fn_folder import (
#     _fn,
#     _fn,
# )

# %%
# %run run.py
# Out:
# ============================
#        AVAILABLE PROGRAMS
# ============================
#  0 → _0_prog_SoundcloudDwonloader.py
#  1 → _1_prog_check_mp3s.py
#  2 → _2_prog_anyfile_to_AIFF.py
# ============================
# Run program # →  1
# === SAFE MP3 NORMALIZER + SHORT FILE CLEANER ===
# This will:
#   1) Ask you for the folder containing .mp3
#   2) Normalize safely (never clipping)
#   3) Report files < 2.5 min
#   4) Delete them after you hit ENTER
# Enter folder path where MP3 files are located:
# >  /Users/yerik/Music/_2_MP3_group_RK/_6_2026/02_23_SPKR_cdmx_det_soundcloud_audio
# [INFO] Found 7 mp3 file(s) in:
#   /Users/yerik/Music/_2_MP3_group_RK/_6_2026/02_23_SPKR_cdmx_det_soundcloud_audio
#
# [1/7] Processing: An Avrin - Partying [2101454271].mp3
#    - Peak 0.00 dBFS → applying -1.00 dB
# [2/7] Processing: An Avrin - Shining [1857260823].mp3
#    - Peak 0.00 dBFS → applying -1.00 dB
# [3/7] Processing: An Avrin - Vaqa [1857260736].mp3
#    - Peak 0.00 dBFS → applying -1.00 dB
# [4/7] Processing: Farsight - Leche de Tigre [1711675443].mp3
#    - Peak 0.00 dBFS → applying -1.00 dB
# [5/7] Processing: Farsight - Up Right Good Good (CloudCore) [1728583257].mp3
#    - Peak 0.00 dBFS → applying -1.00 dB
# [6/7] Processing: SMIFF - Dink Dink [1861034844].mp3
#    - Peak 0.00 dBFS → applying -1.00 dB
# [7/7] Processing: smokey.t - Dusty Dan - Technology (smokey.t Remix) [PREVIEW] [1922646872].mp3
#    - Peak 0.00 dBFS → applying -1.00 dB
#
# ------------------------------------------------------------
# [REPORT] Files shorter than 2.50 minutes:
#   - None (no files will be deleted).
#
# ⚠️ WARNING: _1_prog_check_mp3s.py has NO main() function.

# %% [markdown]
# ## /Users/yerik/Music/_00_MUSIC_PY/jan19
