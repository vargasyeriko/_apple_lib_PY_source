# %% [markdown]
# # start

# %%
# attn USE this for new ADDS

f"NA-TRkw_{title}_ARkw_{artist_val}_MXkw_{remix}_KYkw_{key}_"
            f"BPkw_{bpm}_GNkw_{genre_val}_LBkw_{label_val}_RYkw_{release_date_val}_"
            f"PYkw_{purchase_date_val}{ext}"
# Out:
#   Cell In[1], line 4
#     f"BPkw_{bpm}_GNkw_{genre_val}_LBkw_{label_val}_RYkw_{release_date_val}_"
#     ^
# IndentationError: unexpected indent

# %%
# -----######-----###### RENAME FINAL: FULL CONTROL + PUkw CORRECTED -----######-----######
import os
import pandas as pd
from tqdm import tqdm
from datetime import datetime

def _rename_2304_kwtagging_GET_renamed_files_from_txt(
    txt_path,
    custom_artist="DJ_Selphi",
    custom_genre="Salsa",
    custom_label="Bachata",
    custom_release_date="",
    custom_purchase_date=""
):
    """
    Rename files using a kw-tag structure with optional custom overrides.
    Pulls from TXT if any override is left blank.

    Args:
        txt_path (str): Path to UTF-16 tab-separated metadata file
        custom_artist (str): Optional override for artist (max 25 chars)
        custom_genre (str): Optional override for genre
        custom_label (str): Optional override for label
        custom_release_date (str): Optional override in YYYY_MM_DD format
        custom_purchase_date (str): Optional override in YYYY_MM_DD format

    Returns:
        pd.DataFrame: Original DataFrame + 'Renamed_Path' column
    """
    tqdm.pandas()

    df = pd.read_csv(
        txt_path,
        sep="\t",
        encoding='utf-16',
        engine='python',
        on_bad_lines='skip'
    )
    
    df.columns = df.columns.str.strip()

    def clean(s):
        return (
            str(s)
            .replace(" ", "_").replace("/", "___").replace(",", "_")
            .replace("(", "").replace(")", "").replace("!", "")
            .replace("&", "and").replace("’", "").replace("'", "")
            .replace("¿", "").replace("¡", "").replace(":", "")
            .replace(";", "").strip()
        )

    def extract_mix(title):
        title_lower = title.lower()
        if "remix" in title_lower or "mix" in title_lower:
            return clean(title)
        return "original"

    def format_filename(row):
        title = clean(row.get('Track Title', ''))[:25]
        remix = extract_mix(row.get('Track Title', ''))

        artist_val = clean(custom_artist)[:25] if custom_artist else clean(row.get('Artist', ''))[:25]
        genre_val = clean(custom_genre) if custom_genre else clean(row.get('Genre', ''))
        label_val = clean(custom_label) if custom_label else clean(row.get('Label', ''))

        # ✅ FIXED: Use Release Date column if custom_release_date not passed
        release_date_val = (
            custom_release_date if custom_release_date
            else pd.to_datetime(row.get('Release Date', ''), errors='coerce').strftime('%Y_%m_%d')
            if pd.notna(row.get('Release Date', '')) else 'NA'
        )

        key = clean(row.get('Key', 'NA')) if pd.notna(row.get('Key', '')) else 'NA'
        bpm = str(int(round(float(row.get('BPM', 0))))) if pd.notna(row.get('BPM', 0)) else 'NA'

        date_added = pd.to_datetime(row.get('Date Added', datetime.today()), errors='coerce').strftime('%Y_%m_%d')
        purchase_date_val = (
            custom_purchase_date if custom_purchase_date
            else pd.to_datetime(row.get('Purchased', datetime.today()), errors='coerce').strftime('%Y_%m_%d')
        )

        ext = os.path.splitext(row.get('Location', ''))[1]

        new_name = (
            f"TRkw_{title}_ARkw_{artist_val}_MXkw_{remix}_KYkw_{key}_"
            f"BPkw_{bpm}_GNkw_{genre_val}_LBkw_{label_val}_RYkw_{release_date_val}_"
            f"PYkw_{purchase_date_val}{ext}"
        )

        if len(new_name) > 240:
            new_name = new_name[:230] + ext

        return new_name

    new_paths = []
    log_long_names = []

    for i, row in tqdm(df.iterrows(), total=len(df), desc="Renaming files"):
        original_path = str(row.get('Location', '')).strip()

        if not os.path.isfile(original_path):
            print(f"❌ File not found (Row {i}): {original_path}")
            new_paths.append(None)
            continue

        new_filename = format_filename(row)
        new_path = os.path.join(os.path.dirname(original_path), new_filename)

        try:
            os.rename(original_path, new_path)
            new_paths.append(new_path)
        except Exception as e:
            print(f"❌ Error renaming (Row {i}): {e}")
            new_paths.append(None)
            log_long_names.append({
                "Index": i,
                "OriginalPath": original_path,
                "IntendedFilename": new_filename,
                "Error": str(e)
            })

    df['Renamed_Path'] = new_paths

    if log_long_names:
        pd.DataFrame(log_long_names).to_csv("long_name_errors_log.csv", index=False)
        print("📁 Saved log of failed renames to: long_name_errors_log.csv")

    return df

# %%
txt_path ='/Users/yerik/Desktop/MARCH_pl.txt'

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!



df = _rename_2304_kwtagging_GET_renamed_files_from_txt(
    txt_path,
    custom_artist="",           # ✅ or "" for TXT
    custom_genre="",                # ✅ or "" for TXT
    custom_label="",      # ✅ or "" for TXT
    custom_release_date="",    # ✅ or "" for fallback
    custom_purchase_date="2026_03_06"              # ✅ "" uses 'Purchased' column
)
# Out:
# Renaming files: 100%|█████████████████████████████████████████████████████| 182/182 [00:00<00:00, 3968.60it/s]
# ❌ File not found (Row 106): None
# ❌ File not found (Row 107): None
# ❌ File not found (Row 108): None
# ❌ File not found (Row 109): None
# ❌ File not found (Row 110): None
# ❌ File not found (Row 151): None
# ❌ File not found (Row 152): None
# ❌ File not found (Row 153): None
# ❌ File not found (Row 154): None
# ❌ File not found (Row 155): None

# %%
#3+17+19+13+3 #= 
8+10+15+22
# Out:
# 55

# %% [markdown]
# # check

# %%
import pandas as pd

txt_path = txt_path

# 🚀 FAST & FORGIVING READ
df = pd.read_csv(txt_path, sep="\t", encoding='latin1', engine='python', on_bad_lines='skip')
df.columns = df.columns.str.strip()  # 🧼 Clean whitespaces

# 🎯 SHOW COLUMNS
print("\n🔎 COLUMN NAMES:")
for i, col in enumerate(df.columns):
    print(f"{i:>2}: '{col}'")

df#.head(3)
# Out:
# 🔎 COLUMN NAMES:
#  0: 'ÿþ#'
#  1: 'Key'
#  2: 'File Type'
#  3: 'DJ Play Count'
#  4: 'Artist'
#  5: 'Artwork'
#  6: 'Album'
#  7: 'BPM'
#  8: 'Comments'
#  9: 'Track Title'
# 10: 'Release Date'
# 11: 'Year'
# 12: 'Label'
# 13: 'Genre'
# 14: 'Remixer'
# 15: 'Mix Name'
# 16: 'Time'
# 17: 'Rating'
# 18: 'Date Added'
# 19: 'Size'
# 20: 'File Name'
# 21: 'Bitrate'
# 22: 'Location'
# 23: 'Bitdepth'
#      ÿþ#  Key File Type DJ Play Count  \
# 0     1  10A           AIFF                         0
# 1     2    6A           AIFF                         0
# 2     3  12B           AIFF                         0
# 3     4  12A           AIFF                         0
# 4     5    7A           AIFF                         0
# 5     6    6A           AIFF                         0
# 6     7    7A           AIFF                         0
# 7     8    8A           AIFF                         0
# 8     9    7A           AIFF                         0
# 9   10    7A           AIFF                         0
# 10  11    7A           AIFF                         0
# 11  12    3A           AIFF                         0
# 12  13    8A           AIFF                         0
# 13  14  12A           AIFF                         0
# 14  15    4A           AIFF                         0
# 15  16    9A           AIFF                         0
# 16  17  11A           AIFF                         0
# 17  18    3A           AIFF                         0
# 18  19    4A           AIFF                         0
# 19  20    6A           AIFF                         0
# 20  21    2A           AIFF                         0
# 21  22    4A           AIFF                         0
# 22           None                None                        None
#
#                                         Artist Artwork  \
# 0                       Ángeles Azules
# 1           Dengue Dengue Dengue
# 2           Dengue Dengue Dengue
# 3         Dengue Dengue Dengue!
# 4                                   DJ Nirso
# 5                                       Exzakt
# 6                         Fértil Discos
# 7                               FLAKO STIK
# 8                               FunkSupply
# 9                             Klik & Frik
# 10                    KONN RECORDINGS
# 11  Los Hermanos Balanta (B...
# 12                          Mystic Crock
# 13                              Nanosphere
# 14                                Nick León
# 15                  Ovnimoon Records
# 16                                Pigmalião
# 17              The Halluci Nation
# 18                                            uji
# 19                                Heattraxx
# 20                                Heattraxx
# 21                                Heattraxx
# 22                                               None            None
#
#                                           Album        BPM  \
# 0                       El Baúl Ilegal    90.00
# 1               La Alianza Profana    95.00
# 2                       Humos EP Vol.3  103.00
# 3     Sounds and Colours Peru    94.00
# 4                                                     114.00
# 5                                                     132.00
# 6   Isla. Edits para la Vic...    88.00
# 7         PARTY STARTERS VOL. 2  127.00
# 8                                                     112.00
# 9         Botanas (Shika Shika)    92.00
# 10  Latinoamérica Edit-by M...  132.51
# 11                                                      78.00
# 12  Beyond Horizons [24 bit]  104.00
# 13  Night Visions 4 - Deser...  140.00
# 14                                      Xtasis  140.00
# 15  Atmospherika - Vida (ov...    95.00
# 16    Sounds and Colours Peru    89.00
# 17              A Tribe Called Red  133.33
# 18                                  Alborada    88.00
# 19                      HT019 - Huxley  125.00
# 20                      HT019 - Huxley  123.00
# 21                      HT019 - Huxley  129.00
# 22                                               None           None
#
#                                     Comments  \
# 0   Visit https://edmoonrec...
# 1   Visit https://dengueden...
# 2   Visit https://dengueden...
# 3   Visit https://soundsand...
# 4   Visit https://djnirso.b...
# 5   Visit https://exzakt.ba...
# 6   Visit https://fertildis...
# 7   Visit https://flakostik...
# 8   Visit https://funksuppl...
# 9   Visit https://klikandfr...
# 10  Visit https://konnrecor...
# 11  Visit https://biomigran...
# 12  Visit https://mysticcro...
# 13  Visit https://desertdwe...
# 14  Visit https://nicknoexi...
# 15  Visit https://ovnimoonr...
# 16  Visit https://soundsand...
# 17  Visit https://thehalluc...
# 18  Visit https://ujitimebe...
# 19  Visit https://heattraxx...
# 20  Visit https://heattraxx...
# 21  Visit https://heattraxx...
# 22                                               None
#
#                               Track Title  ...  \
# 0   Cómo Te Voy A Olvidar (...  ...
# 1                         Alpha & Omega  ...
# 2                                 Barrabass  ...
# 3                             Don Marcial  ...
# 4   El Buga - Mini Conga (N...  ...
# 5   RÜFÜS DU SOL - Innerblo...  ...
# 6   Andres Landero - Dejame...  ...
# 7   Jarabe de Palo - LA FLA...  ...
# 8   I've got an attitude, b...  ...
# 9   Grupo Bahia - Rumba Cho...  ...
# 10  Mosaico De Bunde -Grupo...  ...
# 11                    Mucho Hijueputa  ...
# 12                          Lost In Love  ...
# 13  Homeworld (Desert Dwell...  ...
# 14      Xtasis Feat. DJ Babatr  ...
# 15                        Ciclo de Vida  ...
# 16      En El Camino Para Zaña  ...
# 17        Electric Pow Wow Drum  ...
# 18        Alborada feat. Anicca  ...
# 19                                        Monie  ...
# 20                                  Obsessed  ...
# 21                                      Rhythm  ...
# 22                                               None  ...
#
#                       Remixer          Mix Name    Time  \
# 0   Lascivio Bohemia                Remix  03:38
# 1                                     Original Mix  03:25
# 2                                     Original Mix  04:41
# 3                                     Original Mix  04:29
# 4                         Nirso                Remix  04:16
# 5                             EXZ                Remix  05:29
# 6                     El Búho                  Edit  05:19
# 7               FLAKO STIK                  Edit  05:32
# 8                                     Original Mix  06:52
# 9             Klik & Frik                Remix  04:33
# 10          Mr. Toé Edit                  Edit  06:06
# 11    Biomigrant Edit                  Edit  03:16
# 12                                    Original Mix  09:11
# 13  Desert Dwellers                 Remix  04:06
# 14    feat. DJ Babatr                Remix  04:55
# 15                                    Original Mix  06:19
# 16                                    Original Mix  04:40
# 17                                    Original Mix  03:39
# 18                                    Original Mix  06:32
# 19                                    Original Mix  06:14
# 20                                    Original Mix  06:32
# 21                                    Original Mix  05:01
# 22                               None                       None         None
#
#    Rating  Date Added          Size  \
# 0           2025-08-01    55.3 MB
# 1           2025-08-01    34.9 MB
# 2           2025-08-01    47.4 MB
# 3           2025-08-01    45.4 MB
# 4           2025-08-01    43.3 MB
# 5           2025-08-01    55.5 MB
# 6           2025-08-01        54 MB
# 7           2025-08-01        56 MB
# 8           2025-08-01  104.1 MB
# 9           2025-08-01    46.1 MB
# 10          2025-08-01    61.8 MB
# 11          2025-08-01    49.8 MB
# 12          2025-08-01  139.3 MB
# 13          2025-08-01    41.6 MB
# 14          2025-08-01    49.9 MB
# 15          2025-08-01        64 MB
# 16          2025-08-01    70.9 MB
# 17          2025-08-01    37.1 MB
# 18          2025-08-01    99.2 MB
# 19          2025-08-01    63.1 MB
# 20          2025-08-01    66.1 MB
# 21          2025-08-01    50.8 MB
# 22          None                   None               None
#
#                                   File Name      Bitrate  \
# 0   Angeles Azules - Cómo T...  2116 kbps
# 1   Dengue Dengue Dengue - ...  1411 kbps
# 2   Dengue Dengue Dengue - ...  1411 kbps
# 3   Dengue Dengue Dengue! -...  1411 kbps
# 4   DJ Nirso - El Buga - Mi...  1411 kbps
# 5   Exzakt - RÜFÜS DU SOL -...  1411 kbps
# 6   Fértil Discos - Andres ...  1411 kbps
# 7   FLAKO STIK - Jarabe de ...  1411 kbps
# 8   FunkSupply - I've got a...  2116 kbps
# 9   Klik & Frik - Grupo Bah...  1411 kbps
# 10  KONN RECORDINGS - Mosai...  1411 kbps
# 11  Los Hermanos Balanta (B...  2116 kbps
# 12  Mystic Crock - Lost In ...  2116 kbps
# 13  Nanosphere - Homeworld ...  1411 kbps
# 14  Nick León - Xtasis Feat...  1411 kbps
# 15  Ovnimoon Records - Cicl...  1411 kbps
# 16  Pigmalião - En El Camin...  2116 kbps
# 17  The Halluci Nation - El...  1411 kbps
# 18  uji - Alborada feat. An...  2116 kbps
# 19  Heattraxx - HT019 - Hux...  1411 kbps
# 20  Heattraxx - HT019 - Hux...  1411 kbps
# 21  Heattraxx - HT019 - Hux...  1411 kbps
# 22                                               None                 None
#
#                                     Location Bitdepth
# 0   /Users/yerik/Downloads/...             24
# 1   /Users/yerik/Downloads/...             16
# 2   /Users/yerik/Downloads/...             16
# 3   /Users/yerik/Downloads/...             16
# 4   /Users/yerik/Downloads/...             16
# 5   /Users/yerik/Downloads/...             16
# 6   /Users/yerik/Downloads/...             16
# 7   /Users/yerik/Downloads/...             16
# 8   /Users/yerik/Downloads/...             24
# 9   /Users/yerik/Downloads/...             16
# 10  /Users/yerik/Downloads/...             16
# 11  /Users/yerik/Downloads/...             24
# 12  /Users/yerik/Downloads/...             24
# 13  /Users/yerik/Downloads/...             16
# 14  /Users/yerik/Downloads/...             16
# 15  /Users/yerik/Downloads/...             16
# 16  /Users/yerik/Downloads/...             24
# 17  /Users/yerik/Downloads/...             16
# 18  /Users/yerik/Downloads/...             24
# 19  /Users/yerik/Downloads/...             16
# 20  /Users/yerik/Downloads/...             16
# 21  /Users/yerik/Downloads/...             16
# 22                                               None              None
#
# [23 rows x 24 columns]

# %%
df
# Out:
#      ÿþ#  Key File Type DJ Play Count  \
# 0     1  10A           AIFF                         0
# 1     2    6A           AIFF                         0
# 2     3  12B           AIFF                         0
# 3     4  12A           AIFF                         0
# 4     5    7A           AIFF                         0
# 5     6    6A           AIFF                         0
# 6     7    7A           AIFF                         0
# 7     8    8A           AIFF                         0
# 8     9    7A           AIFF                         0
# 9   10    7A           AIFF                         0
# 10  11    7A           AIFF                         0
# 11  12    3A           AIFF                         0
# 12  13    8A           AIFF                         0
# 13  14  12A           AIFF                         0
# 14  15    4A           AIFF                         0
# 15  16    9A           AIFF                         0
# 16  17  11A           AIFF                         0
# 17  18    3A           AIFF                         0
# 18  19    4A           AIFF                         0
# 19  20    6A           AIFF                         0
# 20  21    2A           AIFF                         0
# 21  22    4A           AIFF                         0
# 22           None                None                        None
#
#                                         Artist Artwork  \
# 0                       Ángeles Azules
# 1           Dengue Dengue Dengue
# 2           Dengue Dengue Dengue
# 3         Dengue Dengue Dengue!
# 4                                   DJ Nirso
# 5                                       Exzakt
# 6                         Fértil Discos
# 7                               FLAKO STIK
# 8                               FunkSupply
# 9                             Klik & Frik
# 10                    KONN RECORDINGS
# 11  Los Hermanos Balanta (B...
# 12                          Mystic Crock
# 13                              Nanosphere
# 14                                Nick León
# 15                  Ovnimoon Records
# 16                                Pigmalião
# 17              The Halluci Nation
# 18                                            uji
# 19                                Heattraxx
# 20                                Heattraxx
# 21                                Heattraxx
# 22                                               None            None
#
#                                           Album        BPM  \
# 0                       El Baúl Ilegal    90.00
# 1               La Alianza Profana    95.00
# 2                       Humos EP Vol.3  103.00
# 3     Sounds and Colours Peru    94.00
# 4                                                     114.00
# 5                                                     132.00
# 6   Isla. Edits para la Vic...    88.00
# 7         PARTY STARTERS VOL. 2  127.00
# 8                                                     112.00
# 9         Botanas (Shika Shika)    92.00
# 10  Latinoamérica Edit-by M...  132.51
# 11                                                      78.00
# 12  Beyond Horizons [24 bit]  104.00
# 13  Night Visions 4 - Deser...  140.00
# 14                                      Xtasis  140.00
# 15  Atmospherika - Vida (ov...    95.00
# 16    Sounds and Colours Peru    89.00
# 17              A Tribe Called Red  133.33
# 18                                  Alborada    88.00
# 19                      HT019 - Huxley  125.00
# 20                      HT019 - Huxley  123.00
# 21                      HT019 - Huxley  129.00
# 22                                               None           None
#
#                                     Comments  \
# 0   Visit https://edmoonrec...
# 1   Visit https://dengueden...
# 2   Visit https://dengueden...
# 3   Visit https://soundsand...
# 4   Visit https://djnirso.b...
# 5   Visit https://exzakt.ba...
# 6   Visit https://fertildis...
# 7   Visit https://flakostik...
# 8   Visit https://funksuppl...
# 9   Visit https://klikandfr...
# 10  Visit https://konnrecor...
# 11  Visit https://biomigran...
# 12  Visit https://mysticcro...
# 13  Visit https://desertdwe...
# 14  Visit https://nicknoexi...
# 15  Visit https://ovnimoonr...
# 16  Visit https://soundsand...
# 17  Visit https://thehalluc...
# 18  Visit https://ujitimebe...
# 19  Visit https://heattraxx...
# 20  Visit https://heattraxx...
# 21  Visit https://heattraxx...
# 22                                               None
#
#                               Track Title  ...  \
# 0   Cómo Te Voy A Olvidar (...  ...
# 1                         Alpha & Omega  ...
# 2                                 Barrabass  ...
# 3                             Don Marcial  ...
# 4   El Buga - Mini Conga (N...  ...
# 5   RÜFÜS DU SOL - Innerblo...  ...
# 6   Andres Landero - Dejame...  ...
# 7   Jarabe de Palo - LA FLA...  ...
# 8   I've got an attitude, b...  ...
# 9   Grupo Bahia - Rumba Cho...  ...
# 10  Mosaico De Bunde -Grupo...  ...
# 11                    Mucho Hijueputa  ...
# 12                          Lost In Love  ...
# 13  Homeworld (Desert Dwell...  ...
# 14      Xtasis Feat. DJ Babatr  ...
# 15                        Ciclo de Vida  ...
# 16      En El Camino Para Zaña  ...
# 17        Electric Pow Wow Drum  ...
# 18        Alborada feat. Anicca  ...
# 19                                        Monie  ...
# 20                                  Obsessed  ...
# 21                                      Rhythm  ...
# 22                                               None  ...
#
#                       Remixer          Mix Name    Time  \
# 0   Lascivio Bohemia                Remix  03:38
# 1                                     Original Mix  03:25
# 2                                     Original Mix  04:41
# 3                                     Original Mix  04:29
# 4                         Nirso                Remix  04:16
# 5                             EXZ                Remix  05:29
# 6                     El Búho                  Edit  05:19
# 7               FLAKO STIK                  Edit  05:32
# 8                                     Original Mix  06:52
# 9             Klik & Frik                Remix  04:33
# 10          Mr. Toé Edit                  Edit  06:06
# 11    Biomigrant Edit                  Edit  03:16
# 12                                    Original Mix  09:11
# 13  Desert Dwellers                 Remix  04:06
# 14    feat. DJ Babatr                Remix  04:55
# 15                                    Original Mix  06:19
# 16                                    Original Mix  04:40
# 17                                    Original Mix  03:39
# 18                                    Original Mix  06:32
# 19                                    Original Mix  06:14
# 20                                    Original Mix  06:32
# 21                                    Original Mix  05:01
# 22                               None                       None         None
#
#    Rating  Date Added          Size  \
# 0           2025-08-01    55.3 MB
# 1           2025-08-01    34.9 MB
# 2           2025-08-01    47.4 MB
# 3           2025-08-01    45.4 MB
# 4           2025-08-01    43.3 MB
# 5           2025-08-01    55.5 MB
# 6           2025-08-01        54 MB
# 7           2025-08-01        56 MB
# 8           2025-08-01  104.1 MB
# 9           2025-08-01    46.1 MB
# 10          2025-08-01    61.8 MB
# 11          2025-08-01    49.8 MB
# 12          2025-08-01  139.3 MB
# 13          2025-08-01    41.6 MB
# 14          2025-08-01    49.9 MB
# 15          2025-08-01        64 MB
# 16          2025-08-01    70.9 MB
# 17          2025-08-01    37.1 MB
# 18          2025-08-01    99.2 MB
# 19          2025-08-01    63.1 MB
# 20          2025-08-01    66.1 MB
# 21          2025-08-01    50.8 MB
# 22          None                   None               None
#
#                                   File Name      Bitrate  \
# 0   Angeles Azules - Cómo T...  2116 kbps
# 1   Dengue Dengue Dengue - ...  1411 kbps
# 2   Dengue Dengue Dengue - ...  1411 kbps
# 3   Dengue Dengue Dengue! -...  1411 kbps
# 4   DJ Nirso - El Buga - Mi...  1411 kbps
# 5   Exzakt - RÜFÜS DU SOL -...  1411 kbps
# 6   Fértil Discos - Andres ...  1411 kbps
# 7   FLAKO STIK - Jarabe de ...  1411 kbps
# 8   FunkSupply - I've got a...  2116 kbps
# 9   Klik & Frik - Grupo Bah...  1411 kbps
# 10  KONN RECORDINGS - Mosai...  1411 kbps
# 11  Los Hermanos Balanta (B...  2116 kbps
# 12  Mystic Crock - Lost In ...  2116 kbps
# 13  Nanosphere - Homeworld ...  1411 kbps
# 14  Nick León - Xtasis Feat...  1411 kbps
# 15  Ovnimoon Records - Cicl...  1411 kbps
# 16  Pigmalião - En El Camin...  2116 kbps
# 17  The Halluci Nation - El...  1411 kbps
# 18  uji - Alborada feat. An...  2116 kbps
# 19  Heattraxx - HT019 - Hux...  1411 kbps
# 20  Heattraxx - HT019 - Hux...  1411 kbps
# 21  Heattraxx - HT019 - Hux...  1411 kbps
# 22                                               None                 None
#
#                                     Location Bitdepth
# 0   /Users/yerik/Downloads/...             24
# 1   /Users/yerik/Downloads/...             16
# 2   /Users/yerik/Downloads/...             16
# 3   /Users/yerik/Downloads/...             16
# 4   /Users/yerik/Downloads/...             16
# 5   /Users/yerik/Downloads/...             16
# 6   /Users/yerik/Downloads/...             16
# 7   /Users/yerik/Downloads/...             16
# 8   /Users/yerik/Downloads/...             24
# 9   /Users/yerik/Downloads/...             16
# 10  /Users/yerik/Downloads/...             16
# 11  /Users/yerik/Downloads/...             24
# 12  /Users/yerik/Downloads/...             24
# 13  /Users/yerik/Downloads/...             16
# 14  /Users/yerik/Downloads/...             16
# 15  /Users/yerik/Downloads/...             16
# 16  /Users/yerik/Downloads/...             24
# 17  /Users/yerik/Downloads/...             16
# 18  /Users/yerik/Downloads/...             24
# 19  /Users/yerik/Downloads/...             16
# 20  /Users/yerik/Downloads/...             16
# 21  /Users/yerik/Downloads/...             16
# 22                                               None              None
#
# [23 rows x 24 columns]

# %%
print(df['Year'].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(df['Year'].unique())
#
# File ~/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Year'
