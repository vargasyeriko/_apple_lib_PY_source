# %%
from  _fns import  _concat_0810_pkls_GET_df_perfolder

# %% [markdown]
# # SHOW DASHBOARD FOR DFS

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
base_dir = "/Users/yerik/_apple_lib/_a_progs/_a2ms_env/_4_PROG_Extract_Pattern_MIDI"  # change to your root containing folders
dfs_all = _concat_0810_pkls_GET_df_perfolder(base_dir)

dfs_all = _concat_0810_pkls_GET_df_perfolder(
    base_dir=base_dir,
    assign_globals=True,   # expose each concatenated DF as a variable (e.g., _dfs_STEMS)
    list_limit=50          # max PKL names to display per folder (prevents spam)
)

# Examples you can now use in this Jupyter env:
# display(_dfs_STEMS)
# display(_dfs_exports)
# display(_dfs_ALL_IDS)
# Out:
# ══════════════════════════════════════════════════════════════════
# 📁 BASE: /Users/yerik/_apple_lib/_a_progs/_a2ms_env/_4_PROG_Extract_Pattern_MIDI
# 📦 Detected '_dfs*' folders: 6
# ══════════════════════════════════════════════════════════════════
# ──────────────────────────────────────────────────────────────────
# 📂 FOLDER: _dfs_ALL_IDS
#    • PKLs found: 1
#    • Used in concat:
#      - _df_ALL_IDS_0_25_10.pkl
#    • Rows: 0
#    • Paths  →  ❌ Missing: 0 / 0   ✅ Exists: 0
#    • In-memory DF variable: dfs_ALL_IDS  (rows: 0)
# TQM | Folder Progress:  16%|████                        | 1/6
# ──────────────────────────────────────────────────────────────────
# 📂 FOLDER: _dfs_MP3
#    • PKLs found: 0
#    • Used in concat: —
#    • Concat: ⚠️ No dataframes read → 0 rows
# TQM | Folder Progress:  33%|█████████                   | 2/6
# ──────────────────────────────────────────────────────────────────
# 📂 FOLDER: _dfs_STEMS
#    • PKLs found: 1
#    • Used in concat:
# ...
