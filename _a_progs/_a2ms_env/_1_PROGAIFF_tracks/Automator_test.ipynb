# %%
import pandas as pd
# Adjust settings to display all rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', 1000)  # Set a wide display width to fit the content
pd.set_option('display.max_colwidth', None)  # Show full column content without truncation

# %% [markdown]
# # ID PROGRAM future manipulations

# %%
1343 +67 +21 +(10 +3 +31)
# Out:
# 1444

# %%
# read all pkl 
import pandas as pd
from pathlib import Path 
df = pd.concat([pd.read_pickle(p) for p in Path('_0_tracks_data').glob('*.pkl')], ignore_index=True)
#import pandas as pd; df = pd.read_pickle('df_511t_final.pkl')
len(df)
# Out:
# 1431

# %% [markdown]
# # write df to BU in icloud

# %%
####

# %% [markdown]
# ## find id

# %%
row = df[df['ID'] == 't24-580f']
row['re_name']
# Out:
# 737    dylu_0V[24]-133BPM-5A_Cmin--id_t24-580f---Trap-EPIC/FREE--by--FUTURE-rocketshiporig(O)-2019
# Name: re_name, dtype: object

# %% [markdown]
# ### ID UNIQUE

# %%
# Count duplicated 'ID' values
repeated_ids = df['ID'].duplicated(keep=False)
df_repeats = df[repeated_ids]

# Summary
num_repeated_ids = df['ID'].duplicated().sum()
print(f"🔁 Repeated IDs: {num_repeated_ids}")
print("\n🧾 Preview of repeated rows:")
df_repeats.head()
# Out:
# 🔁 Repeated IDs: 0
#
# 🧾 Preview of repeated rows:
# Empty DataFrame
# ...

# %%
#df['ID']
