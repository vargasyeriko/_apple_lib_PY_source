# %%
import pandas as pd
df = pd.read_pickle("df_selct_final.pkl")

# %%
df
# Out:
#                                                 Path  \
# 0  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 1  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 2  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 3  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 4  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 5  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 6  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 7  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 8  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 9  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
#
#                                              temp_id  \
# 0  TRkw_Szikra_ARkw_Kornel_Kovacs_MXkw_Original_M...
# 1  TRkw_At_That_Café_ARkw_Gemini_MXkw_Original_M...
# 2  TRkw_Delicious_ARkw_Rick_Wade_MXkw_Original_Mi...
# 3  TRkw_I_d_Rather_Be_With_You_ARkw_Todd_Modes_MX...
# 4  TRkw_Fundamentals_ARkw_Martin_Aquino_MXkw_Hanf...
# 5  TRkw_Back_In_Time_ARkw_Ricky_Razu_MXkw_Origina...
# ...

# %%
(200)*8 +(100)*5
# Out:
# 2100
