# %%
import pandas as pd
df = pd.read_pickle("df_zzzt_final.pkl")

# %%
df
# Out:
#                                                 Path  \
# 0  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 1  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
#
#                                              temp_id  \
# 0  TRkw_Baiana_ARkw_Space_Motion_MXkw_Original_Mi...
# 1  TRkw_90s_Dreamin__ARkw_Audiojack_MXkw_Original...
#
#                                            file_name Extension dur_seconds  \
# 0  TRkw_Baiana_ARkw_Space_Motion_MXkw_Original_Mi...     .aiff  364.426236
# 1  TRkw_90s_Dreamin__ARkw_Audiojack_MXkw_Original...     .aiff  385.090612
#
#     dur_min     sr bit_depth bit_rate channels  ...    centroid_desc  \
# 0  6.073771  44100        16     None        2  ...  Tense, decaying
# 1  6.418177  44100        16     None        2  ...    Muted emotion
#
#                Path_png_bar_centroid                  Path_csv_freq  \
# 0  images/centroid_donut_t1-8700.png  tables/table_freq_t1-8700.csv
# ...

# %%
(200)*8 +(100)*5
# Out:
# 2100
