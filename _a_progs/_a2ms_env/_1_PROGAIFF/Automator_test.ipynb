# %%
folder_list = ['/Users/yerik/Desktop/try']

# %%
counter = 0

for path in folder_list:
    try:
        print(f"\n🔁 Processing: {path}")
        my_aiff = path
        direc_jpg = "images/"
        direc_tables = "tables/"

        # Execute external script
        exec(open("run.py", encoding="utf-8").read())

        # Save first row of df using custom file name format
        pkl_name = f"df_{counter:03d}_.pkl"
        df.to_pickle(pkl_name)
        print(f"✅ Saved: {pkl_name}")
        [shutil.rmtree(f, ignore_errors=True) or os.makedirs(f, exist_ok=True) for f in ['images/', 'tables/']]
        print('images and tables folders erased')
        counter += 1

    except Exception as e:
        print(f"❌ Error in {path}: {e}")
        continue
# -----######-----######-----######-----######-----######-----#
# 0_FNS: _folderreplace_1704_i1_REPLACE_dir_with_backup
# -----######-----######-----######-----######-----######-----#

# import os
# import shutil

# def _folderreplace_1704_i1_REPLACE_dir_with_backup(test_dir, test_bu_dir):
#     """
#     Replaces the folder `test_dir` with the contents of `test_bu_dir`.
#     Prompts user to hit ENTER before proceeding with deletion and replacement.
#     """
#     if not os.path.isdir(test_dir):
#         print(f"❌ ERROR: Folder not found: {test_dir}")
#         return
#     if not os.path.isdir(test_bu_dir):
#         print(f"❌ ERROR: Backup folder not found: {test_bu_dir}")
#         return

#     print(f"\n⚠️  WARNING: This will completely delete and replace:\n'{test_dir}' ⬅️ with contents from '{test_bu_dir}'")
#     input("Press [ENTER] to continue or [CTRL+C] to cancel...")

#     shutil.rmtree(test_dir)
#     shutil.copytree(test_bu_dir, test_dir)
    
#     print(f"✅ Replaced '{test_dir}' with contents from '{test_bu_dir}'")
    
# test_dir = "/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test"
# test_bu_dir = "/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test_bu"

# _folderreplace_1704_i1_REPLACE_dir_with_backup(test_dir, test_bu_dir)
# Out:
# 🔁 Processing: /Users/yerik/Desktop/try
#
# ALL AIFF in correct format -> if something changes go erase the already downsized
# Searching for Files: 100%|████████████████████████████████████████████████| 9/9 [00:00<00:00, 14358.59files/s]
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: /Users/yerik/Desktop/try
# ***df*** will be returned having ::: 8  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 29.241
# Grand Total Size in Bytes: 30661580.000
# Grand Total Size in GB: 0.029
#
#  FREQUENCY TABLE:::
#
#   Extension  frequency  total_size_in_mb
# 0     .aiff          8         29.241161
# Audio file Attributes: 100%|██████████████████████████████████████████████████| 8/8 [00:00<00:00, 2354.37it/s]
# Computing LUFS: 100%|█████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.10file/s]
# 100%|████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 97541.95it/s]
#                                                 Path  \
# 0  /Users/yerik/Desktop/try/TRkw__119__Exports_1_...
# 1  /Users/yerik/Desktop/try/TRkw__092__Exports_1_...
# 2  /Users/yerik/Desktop/try/TRkw__147__Exports_1_...
# 3  /Users/yerik/Desktop/try/TRkw__124__Exports_1_...
# 4  /Users/yerik/Desktop/try/TRkw__088__Exports_1_...
#
#                                              temp_id  \
# 0  TRkw__119__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...
# 1  TRkw__092__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...
# 2  TRkw__147__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...
# 3  TRkw__124__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...
# 4  TRkw__088__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...
#
#                                            file_name Extension dur_seconds  \
# 0  TRkw__119__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...     .aiff        32.0
# 1  TRkw__092__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...     .aiff    1.935488
# 2  TRkw__147__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...     .aiff    31.47542
# 3  TRkw__124__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...     .aiff        32.0
# 4  TRkw__088__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_...     .aiff         8.0
#
#     dur_min     sr bit_depth bit_rate channels file_size file_size_human  \
# 0  0.533333  44100        16     None        2   5644854         5.38 MB
# 1  0.032258  44100        16     None        2    341474       333.47 KB
# 2   0.52459  44100        16     None        2   5552318         5.30 MB
# 3  0.533333  44100        16     None        2   5644854         5.38 MB
# 4  0.133333  44100        16     None        2   1411254         1.35 MB
#
#   num_frames error  ms_lufs ms_LUFS_code id_cat_lufs
# 0    1411200  None  -20.876          LuA           A
# 1      85355  None  -31.940          LuA           A
# 2    1388066  None  -17.157          LuB           L
# 3    1411200  None  -22.149          LuA           A
# 4     352800  None  -14.636          LuC           Q
# BPM per file:   0%|                                                                     | 0/8 [00:00<?, ?it/s]<string>:760: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# BPM per file:  12%|███████▋                                                     | 1/8 [00:00<00:00,  7.32it/s]<string>:774: UserWarning: ⚠️ Skipping TRkw__092__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_0_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff: Too short for one BPM window
# BPM per file:  38%|██████████████████████▉                                      | 3/8 [00:00<00:00, 11.93it/s]<string>:774: UserWarning: ⚠️ Skipping TRkw__088__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff: Too short for one BPM window
# BPM per file:  62%|██████████████████████████████████████▏                      | 5/8 [00:00<00:00, 13.45it/s]<string>:774: UserWarning: ⚠️ Skipping TRkw__142__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_109_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff: Too short for one BPM window
# BPM per file: 100%|█████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 11.85it/s]
# Extracting ID3 Titles: 100%|██████████████████████████████████████████████████| 8/8 [00:00<00:00, 3408.62it/s]
# DONE with getting 1_title
# title_file
# FILE_NAME    8
# Name: count, dtype: int64
# Writing AIFF files for title: 100%|███████████████████████████████████████████| 8/8 [00:00<00:00, 1227.98it/s]
# Total files processed for title: 8
# Extracting ID3 Artists: 100%|█████████████████████████████████████████████████| 8/8 [00:00<00:00, 1888.58it/s]
# DONE with getting 2_artist
# artist_file
# FILE_NAME    8
# Name: count, dtype: int64
# Writing AIFF files for artist: 100%|██████████████████████████████████████████| 8/8 [00:00<00:00, 1507.18it/s]
# Total files processed for artist: 8
# Extracting ID3 Labels: 100%|██████████████████████████████████████████████████| 8/8 [00:00<00:00, 1931.97it/s]
# DONE with getting 3_LABEL
# label_file
# FILE_NAME    8
# Name: count, dtype: int64
# Extracting ID3 Genres: 100%|██████████████████████████████████████████████████| 8/8 [00:00<00:00, 2190.52it/s]
# DONE with getting 4_genre
# genre_file
# FILE_NAME    8
# Name: count, dtype: int64
# Extracting ID3 Release Year: 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 1751.28it/s]
# DONE with getting 5_release_year
# rel_year_file
# FILE_NAME    8
# Name: count, dtype: int64
# Extracting ID3 Key: 100%|█████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1734.98it/s]
# DONE with getting 6_KEY
# key_file
# FILE_NAME    8
# Name: count, dtype: int64
# DONE with getting 7_mix_name & 8_remixer
#   0%|          | 0/8 [00:00<?, ?it/s]
# DONE with getting 9_date_purchased
# Writtng AIFF files for : remixer:   0%|          | 0/8 [00:00<?, ?it/s]
# DONE with WRITTING 7_mix_name & 8_remixer : to ID3TAG remixer
# Writtng AIFF files for : genre:   0%|          | 0/8 [00:00<?, ?it/s]
# Total files processed: 8
# DONE with WRITTING 4_genre : to ID3TAG genre
# Writtng AIFF files for : label:   0%|          | 0/8 [00:00<?, ?it/s]
# Total files processed for label: 8
# DONE with WRITTING 3_LABEL : to ID3TAG LABEL
# Extracting ID3 Release Date:   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
# Writing AIFF files for: release date:   0%|          | 0/8 [00:00<?, ?it/s]
# Total files processed for release date: 8
#   0%|          | 0/8 [00:00<?, ?it/s]
# /Users/yerik/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=934
#   warnings.warn(
# /Users/yerik/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=467
#   warnings.warn(
# Processing keys:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing keys:   0%|          | 0/8 [00:00<?, ?it/s]
# Writing AIFF files for comment:   0%|          | 0/8 [00:00<?, ?it/s]
# Total files processed for comment: 8
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# TQM: Processed and overwritten image images/key_plotidy_9Cq_1Y54.png
# TQM: Processed and overwritten image images/key_plotidy_9Aa_0Y4.png
# TQM: Processed and overwritten image images/key_plotidy_9Cq_1Y2.png
# TQM: Processed and overwritten image images/key_plotidy_9Cp_0Y10.png
# TQM: Processed and overwritten image images/key_plotidy_9Aa_1Y54.png
# TQM: Processed and overwritten image images/key_plotidy_9Cq_0Y54.png
# TQM: Processed and overwritten image images/key_plotidy_9Bl_1Y18.png
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__119__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Aa_1Y54.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__092__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_0_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Aa_0Y4.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__147__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_122_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Bl_1Y18.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__124__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Aa_1Y54.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__088__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cq_0Y54.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__142__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_109_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cq_1Y2.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__114__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cq_1Y54.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__055__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_80_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cp_0Y10.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__119__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Aa_1Y54.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__092__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_0_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Aa_0Y4.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__147__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_122_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Bl_1Y18.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__124__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Aa_1Y54.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__088__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cq_0Y54.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__142__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_109_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cq_1Y2.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__114__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cq_1Y54.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__055__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_80_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cp_0Y10.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__119__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Aa_1Y54.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__092__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_0_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Aa_0Y4.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__147__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_122_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Bl_1Y18.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__124__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Aa_1Y54.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__088__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cq_0Y54.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__142__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_109_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cq_1Y2.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__114__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cq_1Y54.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Desktop/try/TRkw__055__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_80_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Cp_0Y10.jpg
# Processing Cover Art:   0%|                                                             | 0/8 [00:00<?, ?it/s]
# Processed cover image saved at images/cover_1_idy_9Aa_1Y54.jpg
# Processing Cover Art:  38%|███████████████████▉                                 | 3/8 [00:00<00:00, 25.13it/s]
# Processed cover image saved at images/cover_1_idy_9Aa_0Y4.jpg
# Processed cover image saved at images/cover_1_idy_9Bl_1Y18.jpg
# Processed cover image saved at images/cover_1_idy_9Aa_1Y54.jpg
# Processed cover image saved at images/cover_1_idy_9Cq_0Y54.jpg
# Processed cover image saved at images/cover_1_idy_9Cq_1Y2.jpg
# Processing Cover Art:  88%|██████████████████████████████████████████████▍      | 7/8 [00:00<00:00, 28.52it/s]
# Processed cover image saved at images/cover_1_idy_9Cq_1Y54.jpg
# Processing Cover Art: 100%|█████████████████████████████████████████████████████| 8/8 [00:00<00:00, 27.52it/s]
# Processed cover image saved at images/cover_1_idy_9Cp_0Y10.jpg
# Processing Cover Art: 100%|█████████████████████████████████████████████████████| 8/8 [00:00<00:00, 83.73it/s]
# Processed cover image saved at images/cover_1_idy_9Aa_1Y54.jpg
# Processed cover image saved at images/cover_1_idy_9Aa_0Y4.jpg
# Processed cover image saved at images/cover_1_idy_9Bl_1Y18.jpg
# Processed cover image saved at images/cover_1_idy_9Aa_1Y54.jpg
# Processed cover image saved at images/cover_1_idy_9Cq_0Y54.jpg
# Processed cover image saved at images/cover_1_idy_9Cq_1Y2.jpg
# Processed cover image saved at images/cover_1_idy_9Cq_1Y54.jpg
# Processed cover image saved at images/cover_1_idy_9Cp_0Y10.jpg
# Overlaying Key Images:   0%|                                                            | 0/8 [00:00<?, ?it/s]
# Overlay applied and saved for album at images/cover_1_idy_9Aa_1Y54.jpg
# Overlaying Key Images:  25%|█████████████                                       | 2/8 [00:00<00:00, 14.12it/s]
# Overlay applied and saved for album at images/cover_1_idy_9Aa_0Y4.jpg
# Overlay applied and saved for album at images/cover_1_idy_9Bl_1Y18.jpg
# Overlaying Key Images:  50%|██████████████████████████                          | 4/8 [00:00<00:00, 14.71it/s]
# Overlay applied and saved for album at images/cover_1_idy_9Aa_1Y54.jpg
# Overlay applied and saved for album at images/cover_1_idy_9Cq_0Y54.jpg
# Overlaying Key Images:  75%|███████████████████████████████████████             | 6/8 [00:00<00:00, 14.82it/s]
# Overlay applied and saved for album at images/cover_1_idy_9Cq_1Y2.jpg
# Overlay applied and saved for album at images/cover_1_idy_9Cq_1Y54.jpg
# Overlaying Key Images: 100%|████████████████████████████████████████████████████| 8/8 [00:00<00:00, 14.76it/s]
# Overlay applied and saved for album at images/cover_1_idy_9Cp_0Y10.jpg
# Overlaying LUFS Circles: 100%|█████████████████████████████████████████████████| 8/8 [00:00<00:00, 121.50it/s]
# Overlay applied on image: images/cover_1_idy_9Aa_1Y54.jpg
# Overlay applied on image: images/cover_1_idy_9Aa_0Y4.jpg
# Overlay applied on image: images/cover_1_idy_9Bl_1Y18.jpg
# Overlay applied on image: images/cover_1_idy_9Aa_1Y54.jpg
# Overlay applied on image: images/cover_1_idy_9Cq_0Y54.jpg
# Overlay applied on image: images/cover_1_idy_9Cq_1Y2.jpg
# Overlay applied on image: images/cover_1_idy_9Cq_1Y54.jpg
# Overlay applied on image: images/cover_1_idy_9Cp_0Y10.jpg
# Generating clipping plots:   0%|                                                        | 0/8 [00:00<?, ?it/s]
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  12%|██████                                          | 1/8 [00:00<00:04,  1.57it/s]
# Saved plot for /Users/yerik/Desktop/try/TRkw__119__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff as images/clip_plotidy_9Aa_1Y54.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Saved plot for /Users/yerik/Desktop/try/TRkw__092__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_0_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff as images/clip_plotidy_9Aa_0Y4.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  38%|██████████████████                              | 3/8 [00:01<00:02,  2.30it/s]
# Saved plot for /Users/yerik/Desktop/try/TRkw__147__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_122_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff as images/clip_plotidy_9Bl_1Y18.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  50%|████████████████████████                        | 4/8 [00:01<00:01,  2.00it/s]
# Saved plot for /Users/yerik/Desktop/try/TRkw__124__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff as images/clip_plotidy_9Aa_1Y54.jpg
#
# Top Clipping Events (dBFS > 0.0):
#     Time (s)  Amplitude
# 0   6.511746  -1.000000
# 1   6.511701  -1.000000
# 2   4.511701  -1.000000
# 3   7.508571   0.999969
# 4   4.508549   0.999969
# 5   0.508549   0.999969
# 6   0.508594   0.999969
# 7   1.508503   0.999969
# 8   3.508503   0.999969
# 9   7.508503   0.999969
# 10  4.508503   0.999969
# 11  4.508571   0.999969
# 12  5.508503   0.999969
# 13  6.508549   0.999969
# 14  0.508503   0.999969
# 15  4.511746  -0.999939
# 16  3.508549   0.999893
# 17  5.508571   0.999893
# 18  1.508549   0.999756
# 19  3.511701  -0.999619
# 20  2.511701  -0.999481
# 21  2.511746  -0.999466
# Generating clipping plots:  75%|████████████████████████████████████            | 6/8 [00:02<00:00,  3.13it/s]
# Saved plot for /Users/yerik/Desktop/try/TRkw__088__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff as images/clip_plotidy_9Cq_0Y54.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Saved plot for /Users/yerik/Desktop/try/TRkw__142__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_109_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff as images/clip_plotidy_9Cq_1Y2.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  88%|██████████████████████████████████████████      | 7/8 [00:02<00:00,  3.02it/s]
# Saved plot for /Users/yerik/Desktop/try/TRkw__114__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff as images/clip_plotidy_9Cq_1Y54.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots: 100%|████████████████████████████████████████████████| 8/8 [00:03<00:00,  2.21it/s]
# Saved plot for /Users/yerik/Desktop/try/TRkw__055__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_80_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff as images/clip_plotidy_9Cp_0Y10.jpg
# Embedding clipping into album cover:   0%|                                              | 0/8 [00:00<?, ?it/s]<string>:951: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Embedding clipping into album cover:  38%|██████████████▎                       | 3/8 [00:00<00:00, 20.60it/s]
# Image saved to images/cover_1_idy_9Aa_1Y54.jpg
# Image saved to images/cover_1_idy_9Aa_0Y4.jpg
# Image saved to images/cover_1_idy_9Bl_1Y18.jpg
# Image saved to images/cover_1_idy_9Aa_1Y54.jpg
# Image saved to images/cover_1_idy_9Cq_0Y54.jpg
# Embedding clipping into album cover: 100%|██████████████████████████████████████| 8/8 [00:00<00:00, 20.84it/s]
# Image saved to images/cover_1_idy_9Cq_1Y2.jpg
# Image saved to images/cover_1_idy_9Cq_1Y54.jpg
# Image saved to images/cover_1_idy_9Cp_0Y10.jpg
# Saved: images/bpm_bar_dyn_idy_9Aa_1Y54.png
# Saved: images/bpm_bar_dyn_idy_9Aa_0Y4.png
# Saved: images/bpm_bar_dyn_idy_9Bl_1Y18.png
# Saved: images/bpm_bar_dyn_idy_9Aa_1Y54.png
# Saved: images/bpm_bar_dyn_idy_9Cq_0Y54.png
# <string>:147: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Saved: images/bpm_bar_dyn_idy_9Cq_1Y2.png
# Saved: images/bpm_bar_dyn_idy_9Cq_1Y54.png
# Saved: images/bpm_bar_dyn_idy_9Cp_0Y10.png
# Saved composite over album: images/cover_1_idy_9Aa_1Y54.jpg
# Saved composite over album: images/cover_1_idy_9Aa_0Y4.jpg
# Saved composite over album: images/cover_1_idy_9Bl_1Y18.jpg
# Saved composite over album: images/cover_1_idy_9Aa_1Y54.jpg
# Saved composite over album: images/cover_1_idy_9Cq_0Y54.jpg
# Saved composite over album: images/cover_1_idy_9Cq_1Y2.jpg
# Saved composite over album: images/cover_1_idy_9Cq_1Y54.jpg
# Saved composite over album: images/cover_1_idy_9Cp_0Y10.jpg
# TQM: Starting LUFS donut generation
# 100%|███████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 51.26it/s]
# <string>:420: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: LUFS donut plots complete!
# TQM: Embedded LUFS donut for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# TQM: Embedded LUFS donut for ID idy_9Aa_0Y4 at images/cover_1_idy_9Aa_0Y4.jpg
# TQM: Embedded LUFS donut for ID idy_9Bl_1Y18 at images/cover_1_idy_9Bl_1Y18.jpg
# TQM: Embedded LUFS donut for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# TQM: Embedded LUFS donut for ID idy_9Cq_0Y54 at images/cover_1_idy_9Cq_0Y54.jpg
# TQM: Embedded LUFS donut for ID idy_9Cq_1Y2 at images/cover_1_idy_9Cq_1Y2.jpg
# TQM: Embedded LUFS donut for ID idy_9Cq_1Y54 at images/cover_1_idy_9Cq_1Y54.jpg
# TQM: Embedded LUFS donut for ID idy_9Cp_0Y10 at images/cover_1_idy_9Cp_0Y10.jpg
# TQM: Spectral Shape-Texture Mapping: 100%|██████████████████████████████████████| 8/8 [00:00<00:00, 17.52it/s]
# ✅ TQM: 3-column shape-texture classification complete.
# TQM: Generating SHAPE and texture...
# 100%|██████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 184.48it/s]
# <string>:594: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:594: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: SHAPE and texture Spectral_Bandwidth	Spectral_Flatness images saved successfully!
# TQM: Embedded SHAPE bar for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_0Y4 at images/cover_1_idy_9Aa_0Y4.jpg
# TQM: Embedded SHAPE bar for ID idy_9Bl_1Y18 at images/cover_1_idy_9Bl_1Y18.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_0Y54 at images/cover_1_idy_9Cq_0Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_1Y2 at images/cover_1_idy_9Cq_1Y2.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_1Y54 at images/cover_1_idy_9Cq_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cp_0Y10 at images/cover_1_idy_9Cp_0Y10.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_0Y4 at images/cover_1_idy_9Aa_0Y4.jpg
# TQM: Embedded SHAPE bar for ID idy_9Bl_1Y18 at images/cover_1_idy_9Bl_1Y18.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_0Y54 at images/cover_1_idy_9Cq_0Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_1Y2 at images/cover_1_idy_9Cq_1Y2.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_1Y54 at images/cover_1_idy_9Cq_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cp_0Y10 at images/cover_1_idy_9Cp_0Y10.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_0Y4 at images/cover_1_idy_9Aa_0Y4.jpg
# TQM: Embedded SHAPE bar for ID idy_9Bl_1Y18 at images/cover_1_idy_9Bl_1Y18.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_0Y54 at images/cover_1_idy_9Cq_0Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_1Y2 at images/cover_1_idy_9Cq_1Y2.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_1Y54 at images/cover_1_idy_9Cq_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cp_0Y10 at images/cover_1_idy_9Cp_0Y10.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# <string>:594: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:594: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: Embedded SHAPE bar for ID idy_9Aa_0Y4 at images/cover_1_idy_9Aa_0Y4.jpg
# TQM: Embedded SHAPE bar for ID idy_9Bl_1Y18 at images/cover_1_idy_9Bl_1Y18.jpg
# TQM: Embedded SHAPE bar for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_0Y54 at images/cover_1_idy_9Cq_0Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_1Y2 at images/cover_1_idy_9Cq_1Y2.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cq_1Y54 at images/cover_1_idy_9Cq_1Y54.jpg
# TQM: Embedded SHAPE bar for ID idy_9Cp_0Y10 at images/cover_1_idy_9Cp_0Y10.jpg
# TQM: Extracting spectral centroid: 100%|████████████████████████████████████████| 8/8 [00:00<00:00, 36.08it/s]
# TQM: Generating ultra-intense centroid color donuts...
# 100%|███████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 15.34it/s]
# <string>:807: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: Intense donuts saved — pure saturation with just a tiny fade.
# ✅ TQM: Embedded CENTROID donut for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_9Aa_0Y4 at images/cover_1_idy_9Aa_0Y4.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_9Bl_1Y18 at images/cover_1_idy_9Bl_1Y18.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_9Aa_1Y54 at images/cover_1_idy_9Aa_1Y54.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_9Cq_0Y54 at images/cover_1_idy_9Cq_0Y54.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_9Cq_1Y2 at images/cover_1_idy_9Cq_1Y2.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_9Cq_1Y54 at images/cover_1_idy_9Cq_1Y54.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_9Cp_0Y10 at images/cover_1_idy_9Cp_0Y10.jpg
# TQM Processing: 100%|███████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  6.25it/s]
# TQM: Plot saved to images/dbs_plot_idy_9Aa_1Y54.png
# ✅ Saved: images/dbs_plot_idy_9Aa_1Y54.png
# TQM: Plot saved to images/dbs_plot_idy_9Aa_0Y4.png
# ✅ Saved: images/dbs_plot_idy_9Aa_0Y4.png
# TQM: Plot saved to images/dbs_plot_idy_9Bl_1Y18.png
# ✅ Saved: images/dbs_plot_idy_9Bl_1Y18.png
# TQM: Plot saved to images/dbs_plot_idy_9Aa_1Y54.png
# ✅ Saved: images/dbs_plot_idy_9Aa_1Y54.png
# TQM: Plot saved to images/dbs_plot_idy_9Cq_0Y54.png
# ✅ Saved: images/dbs_plot_idy_9Cq_0Y54.png
# TQM: Plot saved to images/dbs_plot_idy_9Cq_1Y2.png
# ✅ Saved: images/dbs_plot_idy_9Cq_1Y2.png
# TQM: Plot saved to images/dbs_plot_idy_9Cq_1Y54.png
# ✅ Saved: images/dbs_plot_idy_9Cq_1Y54.png
# TQM: Plot saved to images/dbs_plot_idy_9Cp_0Y10.png
# ✅ Saved: images/dbs_plot_idy_9Cp_0Y10.png
# <string>:993: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:1179: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Embedding covers: 100%|███████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1619.81it/s]
# Updated existing cover tag for /Users/yerik/Desktop/try/TRkw__119__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Cover image successfully embedded in /Users/yerik/Desktop/try/TRkw__119__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Updated existing cover tag for /Users/yerik/Desktop/try/TRkw__092__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_0_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Cover image successfully embedded in /Users/yerik/Desktop/try/TRkw__092__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_0_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Updated existing cover tag for /Users/yerik/Desktop/try/TRkw__147__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_122_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Cover image successfully embedded in /Users/yerik/Desktop/try/TRkw__147__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_122_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Updated existing cover tag for /Users/yerik/Desktop/try/TRkw__124__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Cover image successfully embedded in /Users/yerik/Desktop/try/TRkw__124__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Updated existing cover tag for /Users/yerik/Desktop/try/TRkw__088__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Cover image successfully embedded in /Users/yerik/Desktop/try/TRkw__088__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Updated existing cover tag for /Users/yerik/Desktop/try/TRkw__142__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_109_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Cover image successfully embedded in /Users/yerik/Desktop/try/TRkw__142__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_109_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Updated existing cover tag for /Users/yerik/Desktop/try/TRkw__114__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Cover image successfully embedded in /Users/yerik/Desktop/try/TRkw__114__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_120_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Updated existing cover tag for /Users/yerik/Desktop/try/TRkw__055__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_80_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# Cover image successfully embedded in /Users/yerik/Desktop/try/TRkw__055__Exports_1_bank_YODJ_ARkw_YODJ_MXkw_original_KYkw_NA_BPkw_80_GNkw_M-Plus-Export_LBkw_YODJ-M-Plus_RYkw_2015_01_01_PYkw_2025_01_01.aiff
# TQM: Writing YEAR tag to MP3 files...
# 100%|████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 15265.89it/s]
# TQM: Extracting bought_year: 100%|██████████████████████████████████████████| 8/8 [00:00<00:00, 135300.13it/s]
# Writing AIFF files for comment: 100%|█████████████████████████████████████████| 8/8 [00:00<00:00, 2071.39it/s]
# Total files processed for comment: 8
# Renaming AIFF files: 100%|████████████████████████████████████████████████████| 8/8 [00:00<00:00, 7379.47it/s]
# Total files renamed: 8
# DOoooooooooooo
#
#
#
#
#
#
# ne...
# ✅ Saved: df_000_.pkl
# images and tables folders erased

# %%
import shutil
import os
[shutil.rmtree(f, ignore_errors=True) or os.makedirs(f, exist_ok=True) for f in ['images/', 'tables/']]
# Out:
# [None, None]

# %%
df[['dominant_bpm']]
# Out:
#    dominant_bpm
# 0    120.185320
# 1      0.000000
# 2    123.046875
# 3    120.185320
# 4      0.000000
# 5      0.000000
# 6    120.185320
# 7    107.666016

# %%
# -----######-----######-----######-----######-----######-----#
# FUNCTION: _fs_1704_listsubdirs_GET_list_all
# -----######-----######-----######-----######-----######-----#

import os
from tqdm import tqdm

def _fs_1704_listsubdirs_GET_list_all(root_folder):
    """
    Returns a list of full paths to all immediate subfolders inside the given folder.
    
    Parameters:
        root_folder (str): Path to the root directory

    Returns:
        List of full paths to subdirectories only
    """
    print(f"🔍 Scanning for subfolders in:\n{root_folder}")
    subfolders = [
        os.path.join(root_folder, d)
        for d in os.listdir(root_folder)
        if os.path.isdir(os.path.join(root_folder, d))
    ]
    print(f"✅ Found {len(subfolders)} subfolders.")
    return subfolders
folder_list_23 = _fs_1704_listsubdirs_GET_list_all("/Users/yerik/Music/_1_NEW_SOURCE/_2023_this")
folder_list_24 = _fs_1704_listsubdirs_GET_list_all("/Users/yerik/Music/_1_NEW_SOURCE/_2024_this")
folder_list_25 = _fs_1704_listsubdirs_GET_list_all("/Users/yerik/Music/_1_NEW_SOURCE/_2025_this")

folder_list = folder_list_23 + folder_list_24 + folder_list_25
#print(folder_list)
folder_list
# Out:
# 🔍 Scanning for subfolders in:
# /Users/yerik/Music/_1_NEW_SOURCE/_2023_this
# ✅ Found 12 subfolders.
# 🔍 Scanning for subfolders in:
# /Users/yerik/Music/_1_NEW_SOURCE/_2024_this
# ✅ Found 20 subfolders.
# 🔍 Scanning for subfolders in:
# /Users/yerik/Music/_1_NEW_SOURCE/_2025_this
# ✅ Found 8 subfolders.
# ['/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_09_AN_ArtPArk',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_NEW_LODGE',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_06_ttt_SPKRBOX',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_12_Tangent_Debout',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_11_AN_SpotLite',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_02_AN_LA_VENTANA',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_10_Detroit_Hou_Tech',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_08_SL_ACAPELLAS',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_08_Barefoot',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_03_Love_Lang',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_05_AN_bigPINK',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/___YODJ_N0Supervisi0n',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_06_Metroplex_2_and_RNDMgood',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_04_BBssBBssBBs_BandCamp',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_11_11_albm_LordECHO_JAZZ',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/___DJ_friends_Nun',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_07_Puma_BurningMan_indian',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_11_Dinner_Materia_Puma_Jazzy',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_11_11_albm_MimSuleiman_TRIBAL',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_12_fixed_and_added',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_04_NorthL_BadBunny_LatinFast',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_05_MVMNT_block_is_HOT',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_12_Dinner_HipHop_Indian_Puma',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_11_11_N0_Supervisi0n_SPKRbox',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_09_Ghettotech_HiTECH_stu',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_08_Barefoot_and_FREE',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_06_Metroplex_1_and_RNDMgood',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_06_Detroit_Brazil_Funky',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_12_NYE_25',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_09_Eagle_SPKR_Techno',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2024_this/__24_08_Xime_13_Memorial',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__25_04_BP_Rapharazzi_BDAY',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__25_04_BCAL_SalsaEstrellasPa',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__25_04_BCAL_TerapiaLatina',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__25_04_BP_ximMAYBDAY_HOUSY_PARTY_LATIN',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__25_02_DETROIT_PUMA_SPKR',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__25_04_BP_LATIN_HOUSE',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__25_02_CDMX_SecretoRoom',
#  '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__25_03_CAPSULE_House_Latin']
