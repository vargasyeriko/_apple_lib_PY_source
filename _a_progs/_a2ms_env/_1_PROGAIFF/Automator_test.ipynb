# %%
folder_list = ['/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test']

# %%
counter = 0

for path in folder_list:
    try:
        print(f"\n🔁 Processing: {path}")
        my_aiff = path
        direc_jpg = "images/"
        direc_tables = "tables/"

        # Execute external script
        exec(open("run.py", encoding="utf-8").read())

        # Save first row of df using custom file name format
        pkl_name = f"df_{counter:03d}_.pkl"
        df.to_pickle(pkl_name)
        print(f"✅ Saved: {pkl_name}")
        [shutil.rmtree(f, ignore_errors=True) or os.makedirs(f, exist_ok=True) for f in ['images/', 'tables/']]
        print('images and tables folders erased')
        counter += 1

    except Exception as e:
        print(f"❌ Error in {path}: {e}")
        continue
# -----######-----######-----######-----######-----######-----#
# 0_FNS: _folderreplace_1704_i1_REPLACE_dir_with_backup
# -----######-----######-----######-----######-----######-----#

import os
import shutil

def _folderreplace_1704_i1_REPLACE_dir_with_backup(test_dir, test_bu_dir):
    """
    Replaces the folder `test_dir` with the contents of `test_bu_dir`.
    Prompts user to hit ENTER before proceeding with deletion and replacement.
    """
    if not os.path.isdir(test_dir):
        print(f"❌ ERROR: Folder not found: {test_dir}")
        return
    if not os.path.isdir(test_bu_dir):
        print(f"❌ ERROR: Backup folder not found: {test_bu_dir}")
        return

    print(f"\n⚠️  WARNING: This will completely delete and replace:\n'{test_dir}' ⬅️ with contents from '{test_bu_dir}'")
    input("Press [ENTER] to continue or [CTRL+C] to cancel...")

    shutil.rmtree(test_dir)
    shutil.copytree(test_bu_dir, test_dir)
    
    print(f"✅ Replaced '{test_dir}' with contents from '{test_bu_dir}'")
    
test_dir = "/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test"
test_bu_dir = "/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test_bu"

_folderreplace_1704_i1_REPLACE_dir_with_backup(test_dir, test_bu_dir)
# Out:
# 🔁 Processing: /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test
#    Sample Rate (Hz)  Bit Depth  Count
# 0             44100         16      1
#
# ALL AIFF in correct format -> if something changes go erase the already downsized
# Searching for Files: 100%|█████████████████████████████████████████████████| 2/2 [00:00<00:00, 8886.24files/s]
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test
# ***df*** will be returned having ::: 1  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 54.521
# Grand Total Size in Bytes: 57168956.000
# Grand Total Size in GB: 0.053
#
#  FREQUENCY TABLE:::
#
#   Extension  frequency  total_size_in_mb
# 0     .aiff          1         54.520565
# Audio file Attributes: 100%|██████████████████████████████████████████████████| 1/1 [00:00<00:00, 2058.05it/s]
# Computing LUFS: 100%|█████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.62file/s]
# 100%|████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13025.79it/s]
# Processing BPM Dynamic: 100%|███████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.60s/it]
# Extracting ID3 Titles: 100%|███████████████████████████████████████████████████| 1/1 [00:00<00:00, 199.13it/s]
# DONE with getting 1_title
# title_file
# ID3TAGS    1
# Name: count, dtype: int64
# Writing AIFF files for title: 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 129.36it/s]
# Total files processed for title: 1
# Extracting ID3 Artists: 100%|██████████████████████████████████████████████████| 1/1 [00:00<00:00, 347.93it/s]
# DONE with getting 2_artist
# artist_file
# ID3TAGS    1
# Name: count, dtype: int64
# Writing AIFF files for artist: 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 538.56it/s]
# Total files processed for artist: 1
# Extracting ID3 Labels: 100%|███████████████████████████████████████████████████| 1/1 [00:00<00:00, 199.40it/s]
# DONE with getting 3_LABEL
# label_file
# ID3TAGS    1
# Name: count, dtype: int64
# Extracting ID3 Genres: 100%|████████████████████████████████████████████████████| 1/1 [00:00<00:00, 90.65it/s]
# DONE with getting 4_genre
# genre_file
# ID3TAGS    1
# Name: count, dtype: int64
# Extracting ID3 Release Year: 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 760.39it/s]
# DONE with getting 5_release_year
# rel_year_file
# ID3TAGS    1
# Name: count, dtype: int64
# Extracting ID3 Key: 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00, 422.30it/s]
# DONE with getting 6_KEY
# key_file
# ID3TAGS    1
# Name: count, dtype: int64
# DONE with getting 7_mix_name & 8_remixer
#   0%|          | 0/1 [00:00<?, ?it/s]
# DONE with getting 9_date_purchased
# Writtng AIFF files for : remixer:   0%|          | 0/1 [00:00<?, ?it/s]
# DONE with WRITTING 7_mix_name & 8_remixer : to ID3TAG remixer
# Writtng AIFF files for : genre: 0it [00:00, ?it/s]
# Total files processed: 0
# DONE with WRITTING 4_genre : to ID3TAG genre
# Writtng AIFF files for : label: 0it [00:00, ?it/s]
# Total files processed for label: 0
# DONE with WRITTING 3_LABEL : to ID3TAG LABEL
# Extracting ID3 Release Date:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing AIFF files for: release date:   0%|          | 0/1 [00:00<?, ?it/s]
# Total files processed for release date: 1
#   0%|          | 0/1 [00:00<?, ?it/s]
# Processing keys:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing keys:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing AIFF files for comment:   0%|          | 0/1 [00:00<?, ?it/s]
# Total files processed for comment: 1
# DONE
# TQM: Processed and overwritten image images/key_plotidy_9Et_lB95.png
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Los_Provincianos_ARkw_Salsa_various_MXkw_original_KYkw_5A_BPkw_92_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Et_lB95.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Los_Provincianos_ARkw_Salsa_various_MXkw_original_KYkw_5A_BPkw_92_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Et_lB95.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Los_Provincianos_ARkw_Salsa_various_MXkw_original_KYkw_5A_BPkw_92_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Et_lB95.jpg
# Processing Cover Art: 100%|█████████████████████████████████████████████████████| 1/1 [00:00<00:00, 24.97it/s]
# Processed cover image saved at images/cover_1_idy_9Et_lB95.jpg
# Processing Cover Art: 100%|█████████████████████████████████████████████████████| 1/1 [00:00<00:00, 88.00it/s]
# Processed cover image saved at images/cover_1_idy_9Et_lB95.jpg
# Overlaying Key Images: 100%|████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.13it/s]
# Overlay applied and saved for album at images/cover_1_idy_9Et_lB95.jpg
# Overlaying LUFS Circles: 100%|█████████████████████████████████████████████████| 1/1 [00:00<00:00, 122.20it/s]
# Overlay applied on image: images/cover_1_idy_9Et_lB95.jpg
# Generating clipping plots:   0%|                                                        | 0/1 [00:00<?, ?it/s]
# Top Clipping Events (dBFS > 0.0):
#       Time (s)  Amplitude
# 0   275.214875  -1.000000
# 1   250.003175   0.999969
# 2   248.276009   0.999969
# 3   248.274739   0.999969
# 4   233.801338   0.999969
# 5   221.428390   0.999969
# 6   214.907914   0.999969
# 7    86.530998   0.999969
# 8    55.262925   0.999969
# 9    28.488345   0.999969
# 10   20.678118   0.999969
# 11   59.953243   0.999954
# 12   86.458435   0.999939
# 13  211.296780   0.999924
# 14   90.063696   0.999924
# 15   89.818231   0.999802
# Generating clipping plots: 100%|████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.11s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Los_Provincianos_ARkw_Salsa_various_MXkw_original_KYkw_5A_BPkw_92_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.aiff as images/clip_plotidy_9Et_lB95.jpg
# Embedding clipping into album cover:   0%|                                              | 0/1 [00:00<?, ?it/s]<string>:951: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Embedding clipping into album cover: 100%|██████████████████████████████████████| 1/1 [00:00<00:00, 19.16it/s]
# <string>:147: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Image saved to images/cover_1_idy_9Et_lB95.jpg
# Saved: images/bpm_bar_dyn_idy_9Et_lB95.png
# Saved composite over album: images/cover_1_idy_9Et_lB95.jpg
# TQM: Starting LUFS donut generation
# 100%|███████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 28.82it/s]
# <string>:420: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: LUFS donut plots complete!
# TQM: Embedded LUFS donut for ID idy_9Et_lB95 at images/cover_1_idy_9Et_lB95.jpg
# TQM: Spectral Shape-Texture Mapping: 100%|██████████████████████████████████████| 1/1 [00:00<00:00,  1.05it/s]
# ✅ TQM: 3-column shape-texture classification complete.
# TQM: Generating SHAPE and texture...
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 173.97it/s]
# <string>:594: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:594: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:594: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:594: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: SHAPE and texture Spectral_Bandwidth	Spectral_Flatness images saved successfully!
# TQM: Embedded SHAPE bar for ID idy_9Et_lB95 at images/cover_1_idy_9Et_lB95.jpg
# TQM: Embedded SHAPE bar for ID idy_9Et_lB95 at images/cover_1_idy_9Et_lB95.jpg
# TQM: Embedded SHAPE bar for ID idy_9Et_lB95 at images/cover_1_idy_9Et_lB95.jpg
# TQM: Embedded SHAPE bar for ID idy_9Et_lB95 at images/cover_1_idy_9Et_lB95.jpg
# TQM: Extracting spectral centroid: 100%|████████████████████████████████████████| 1/1 [00:00<00:00,  2.15it/s]
# TQM: Generating ultra-intense centroid color donuts...
# 100%|███████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.85it/s]
# <string>:807: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: Intense donuts saved — pure saturation with just a tiny fade.
# ✅ TQM: Embedded CENTROID donut for ID idy_9Et_lB95 at images/cover_1_idy_9Et_lB95.jpg
# TQM Processing: 100%|███████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.46s/it]
# <string>:993: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:1179: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: Plot saved to images/dbs_plot_idy_9Et_lB95.png
# ✅ Saved: images/dbs_plot_idy_9Et_lB95.png
# Embedding covers: 100%|████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 767.63it/s]
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Los_Provincianos_ARkw_Salsa_various_MXkw_original_KYkw_5A_BPkw_92_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Los_Provincianos_ARkw_Salsa_various_MXkw_original_KYkw_5A_BPkw_92_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.aiff
# DOoooooooooooo
#
#
#
#
#
#
# ne...
# ✅ Saved: df_000_.pkl
# images and tables folders erased
#
# ⚠️  WARNING: This will completely delete and replace:
# '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test' ⬅️ with contents from '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test_bu'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 54
#      51 test_dir = "/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test"
#      52 test_bu_dir = "/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test_bu"
# ---> 54 _folderreplace_1704_i1_REPLACE_dir_with_backup(test_dir, test_bu_dir)
#
# Cell In[6], line 44, in _folderreplace_1704_i1_REPLACE_dir_with_backup(test_dir, test_bu_dir)
#      41     return
#      43 print(f"\n⚠️  WARNING: This will completely delete and replace:\n'{test_dir}' ⬅️ with contents from '{test_bu_dir}'")
# ---> 44 input("Press [ENTER] to continue or [CTRL+C] to cancel...")
#      46 shutil.rmtree(test_dir)
#      47 shutil.copytree(test_bu_dir, test_dir)
#
# File ~/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import shutil
import os
[shutil.rmtree(f, ignore_errors=True) or os.makedirs(f, exist_ok=True) for f in ['images/', 'tables/']]
# Out:
# [None, None]

# %%
# -----######-----######-----######-----######-----######-----#
# FUNCTION: _fs_1704_listsubdirs_GET_list_all
# -----######-----######-----######-----######-----######-----#

import os
from tqdm import tqdm

def _fs_1704_listsubdirs_GET_list_all(root_folder):
    """
    Returns a list of full paths to all immediate subfolders inside the given folder.
    
    Parameters:
        root_folder (str): Path to the root directory

    Returns:
        List of full paths to subdirectories only
    """
    print(f"🔍 Scanning for subfolders in:\n{root_folder}")
    subfolders = [
        os.path.join(root_folder, d)
        for d in os.listdir(root_folder)
        if os.path.isdir(os.path.join(root_folder, d))
    ]
    print(f"✅ Found {len(subfolders)} subfolders.")
    return subfolders
folder_list_23 = _fs_1704_listsubdirs_GET_list_all("/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this")
folder_list_24 = _fs_1704_listsubdirs_GET_list_all("/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this")
folder_list_25 = _fs_1704_listsubdirs_GET_list_all("/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this")

folder_list = folder_list_23 + folder_list_24 + folder_list_25
#print(folder_list)
folder_list
# Out:
# 🔍 Scanning for subfolders in:
# /Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this
# ✅ Found 12 subfolders.
# 🔍 Scanning for subfolders in:
# /Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this
# ✅ Found 20 subfolders.
# 🔍 Scanning for subfolders in:
# /Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this
# ✅ Found 8 subfolders.
# ['/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_02_AN_LA_VENTANA',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_03_Love_Lang',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_04_NEW_LODGE',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_05_AN_bigPINK',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_06_ttt_SPKRBOX',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_08_Barefoot',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_08_SL_ACAPELLAS',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_09_AN_ArtPArk',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_10_Detroit_Hou_Tech',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_11_AN_SpotLite',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2023_this/_23_12_Tangent_Debout',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_04_BBssBBssBBs_BandCamp',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_04_NorthL_BadBunny_LatinFast',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_05_MVMNT_block_is_HOT',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_06_Detroit_Brazil_Funky',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_06_Metroplex_1_and_RNDMgood',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_06_Metroplex_2_and_RNDMgood',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_07_Puma_BurningMan_indian',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_08_Barefoot_and_FREE',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_08_Xime_13_Memorial',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_09_Eagle_SPKR_Techno',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_09_Ghettotech_HiTECH_stu',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_11_11_N0_Supervisi0n_SPKRbox',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_11_11_albm_LordECHO_JAZZ',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_11_11_albm_MimSuleiman_TRIBAL',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_11_Dinner_Materia_Puma_Jazzy',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_12_Dinner_HipHop_Indian_Puma',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_12_NYE_25',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/__24_12_fixed_and_added',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/___DJ_friends_Nun',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2024_this/___YODJ_N0Supervisi0n',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this/__25_02_CDMX_SecretoRoom',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this/__25_02_DETROIT_PUMA_SPKR',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this/__25_03_CAPSULE_House_Latin',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this/__25_04_BCAL_SalsaEstrellasPa',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this/__25_04_BCAL_TerapiaLatina',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this/__25_04_BP_LATIN_HOUSE',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this/__25_04_BP_Rapharazzi_BDAY',
#  '/Volumes/MUSIC_PROD/_1_NEW_SOURCE/_2025_this/__25_04_BP_ximMAYBDAY_HOUSY_PARTY_LATIN']
