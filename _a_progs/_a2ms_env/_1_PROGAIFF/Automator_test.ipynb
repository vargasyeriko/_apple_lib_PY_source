# %%
folder_list = ['/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test']

# %%
counter = 0

for path in folder_list:
    try:
        print(f"\n🔁 Processing: {path}")
        my_aiff = path
        direc_jpg = "images/"
        direc_tables = "tables/"

        # Execute external script
        exec(open("run.py", encoding="utf-8").read())

        # Save first row of df using custom file name format
        pkl_name = f"df_{counter:03d}_.pkl"
        df.to_pickle(pkl_name)
        print(f"✅ Saved: {pkl_name}")
        [shutil.rmtree(f, ignore_errors=True) or os.makedirs(f, exist_ok=True) for f in ['images/', 'tables/']]
        print('images and tables folders erased')
        counter += 1

    except Exception as e:
        print(f"❌ Error in {path}: {e}")
        continue
# -----######-----######-----######-----######-----######-----#
# 0_FNS: _folderreplace_1704_i1_REPLACE_dir_with_backup
# -----######-----######-----######-----######-----######-----#

import os
import shutil

def _folderreplace_1704_i1_REPLACE_dir_with_backup(test_dir, test_bu_dir):
    """
    Replaces the folder `test_dir` with the contents of `test_bu_dir`.
    Prompts user to hit ENTER before proceeding with deletion and replacement.
    """
    if not os.path.isdir(test_dir):
        print(f"❌ ERROR: Folder not found: {test_dir}")
        return
    if not os.path.isdir(test_bu_dir):
        print(f"❌ ERROR: Backup folder not found: {test_bu_dir}")
        return

    print(f"\n⚠️  WARNING: This will completely delete and replace:\n'{test_dir}' ⬅️ with contents from '{test_bu_dir}'")
    input("Press [ENTER] to continue or [CTRL+C] to cancel...")

    shutil.rmtree(test_dir)
    shutil.copytree(test_bu_dir, test_dir)
    
    print(f"✅ Replaced '{test_dir}' with contents from '{test_bu_dir}'")
    
test_dir = "/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test"
test_bu_dir = "/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test_bu"

_folderreplace_1704_i1_REPLACE_dir_with_backup(test_dir, test_bu_dir)
# Out:
# 🔁 Processing: /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test
# <string>:209: DeprecationWarning: 'aifc' is deprecated and slated for removal in Python 3.13
#    Sample Rate (Hz)  Bit Depth  Count
# 0             44100         16      4
#
# ALL AIFF in correct format -> if something changes go erase the already downsized
# Searching for Files: 100%|████████████████████████████████████████████████| 5/5 [00:00<00:00, 16021.02files/s]
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test
# ***df*** will be returned having ::: 4  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 160.399
# Grand Total Size in Bytes: 168190540.000
# Grand Total Size in GB: 0.157
#
#  FREQUENCY TABLE:::
#
#   Extension  frequency  total_size_in_mb
# 0     .aiff          4        160.398998
# Audio file Attributes: 100%|██████████████████████████████████████████████████| 4/4 [00:00<00:00, 3960.63it/s]
# Computing LUFS: 100%|█████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.06file/s]
# 100%|████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 55553.70it/s]
# Processing BPM Dynamic: 100%|███████████████████████████████████████████████████| 4/4 [00:05<00:00,  1.44s/it]
# Extracting ID3 Titles: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 264.22it/s]
# DONE with getting 1_title
# title_file
# ID3TAGS    4
# Name: count, dtype: int64
# Writing AIFF files for title: 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 317.14it/s]
# Total files processed for title: 4
# Extracting ID3 Artists: 100%|██████████████████████████████████████████████████| 4/4 [00:00<00:00, 785.71it/s]
# DONE with getting 2_artist
# artist_file
# ID3TAGS    4
# Name: count, dtype: int64
# Writing AIFF files for artist: 100%|███████████████████████████████████████████| 4/4 [00:00<00:00, 461.90it/s]
# Total files processed for artist: 4
# Extracting ID3 Labels: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 243.18it/s]
# DONE with getting 3_LABEL
# label_file
# ID3TAGS    4
# Name: count, dtype: int64
# Extracting ID3 Genres: 100%|██████████████████████████████████████████████████| 4/4 [00:00<00:00, 1334.70it/s]
# DONE with getting 4_genre
# genre_file
# ID3TAGS    4
# Name: count, dtype: int64
# Extracting ID3 Release Year: 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 581.84it/s]
# DONE with getting 5_release_year
# rel_year_file
# ID3TAGS    4
# Name: count, dtype: int64
# Extracting ID3 Key: 100%|█████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1383.57it/s]
# DONE with getting 6_KEY
# key_file
# ID3TAGS    4
# Name: count, dtype: int64
# DONE with getting 7_mix_name & 8_remixer
#   0%|          | 0/4 [00:00<?, ?it/s]
# DONE with getting 9_date_purchased
# Writtng AIFF files for : remixer:   0%|          | 0/4 [00:00<?, ?it/s]
# DONE with WRITTING 7_mix_name & 8_remixer : to ID3TAG remixer
# Writtng AIFF files for : genre: 0it [00:00, ?it/s]
# Total files processed: 0
# DONE with WRITTING 4_genre : to ID3TAG genre
# Writtng AIFF files for : label: 0it [00:00, ?it/s]
# Total files processed for label: 0
# DONE with WRITTING 3_LABEL : to ID3TAG LABEL
# Extracting ID3 Release Date:   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Writing AIFF files for: release date:   0%|          | 0/4 [00:00<?, ?it/s]
# Error processing file /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/Edson Conceição - Filhos de Gandhi (Um Abraço em Gilberto Gil) (Mike Burns Edit).aiff: Invalid ID3TimeStamp: None
# Total files processed for release date: 3
#   0%|          | 0/4 [00:00<?, ?it/s]
# Processing keys:   0%|          | 0/4 [00:00<?, ?it/s]
# Processing keys:   0%|          | 0/4 [00:00<?, ?it/s]
# Writing AIFF files for comment:   0%|          | 0/4 [00:00<?, ?it/s]
# Total files processed for comment: 4
# DONE
# DONE
# DONE
# DONE
# TQM: Processed and overwritten image images/key_plotidy_0Et_fE07.png
# TQM: Processed and overwritten image images/key_plotidy_9Ds_gL43.png
# TQM: Processed and overwritten image images/key_plotidy_3Fu_tK41.png
# TQM: Processed and overwritten image images/key_plotidy_0Eu_gF61.png
# Error processing file /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_tendrly_ARkw_Knxwledge_MXkw_Original_Mix_KYkw_A_Minor_BPkw_156_GNkw_Trap___Future_Bass_RMkw__LBkw_Stones_Throw_Records_RYkw_2020_06_22_PYkw_2024_12_02.aiff: cannot write mode P as JPEG
# 🖤 Default black cover saved as fallback: images/cover_1_idy_3Fu_tK41.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Guaguancò_Del_Solar_ARkw_Salsa_various_MXkw_original_KYkw_4A_BPkw_110_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Ds_gL43.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/Edson Conceição - Filhos de Gandhi (Um Abraço em Gilberto Gil) (Mike Burns Edit).jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_0Et_fE07.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Gloriole_ARkw_Fouk_MXkw_Original_Mix_KYkw_F_Major_BPkw_121_GNkw_Deep_House_RMkw__LBkw_House_Of_Disco_Records__RYkw_2019_07_12_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_0Eu_gF61.jpg
# Error processing file /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_tendrly_ARkw_Knxwledge_MXkw_Original_Mix_KYkw_A_Minor_BPkw_156_GNkw_Trap___Future_Bass_RMkw__LBkw_Stones_Throw_Records_RYkw_2020_06_22_PYkw_2024_12_02.aiff: cannot write mode P as JPEG
# 🖤 Default black cover saved as fallback: images/cover_1_idy_3Fu_tK41.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Guaguancò_Del_Solar_ARkw_Salsa_various_MXkw_original_KYkw_4A_BPkw_110_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Ds_gL43.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/Edson Conceição - Filhos de Gandhi (Um Abraço em Gilberto Gil) (Mike Burns Edit).jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_0Et_fE07.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Gloriole_ARkw_Fouk_MXkw_Original_Mix_KYkw_F_Major_BPkw_121_GNkw_Deep_House_RMkw__LBkw_House_Of_Disco_Records__RYkw_2019_07_12_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_0Eu_gF61.jpg
# Error processing file /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_tendrly_ARkw_Knxwledge_MXkw_Original_Mix_KYkw_A_Minor_BPkw_156_GNkw_Trap___Future_Bass_RMkw__LBkw_Stones_Throw_Records_RYkw_2020_06_22_PYkw_2024_12_02.aiff: cannot write mode P as JPEG
# 🖤 Default black cover saved as fallback: images/cover_1_idy_3Fu_tK41.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Guaguancò_Del_Solar_ARkw_Salsa_various_MXkw_original_KYkw_4A_BPkw_110_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_9Ds_gL43.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/Edson Conceição - Filhos de Gandhi (Um Abraço em Gilberto Gil) (Mike Burns Edit).jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_0Et_fE07.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Gloriole_ARkw_Fouk_MXkw_Original_Mix_KYkw_F_Major_BPkw_121_GNkw_Deep_House_RMkw__LBkw_House_Of_Disco_Records__RYkw_2019_07_12_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM ✅ Cover saved: images/cover_1_idy_0Eu_gF61.jpg
# Processing Cover Art: 100%|█████████████████████████████████████████████████████| 4/4 [00:00<00:00, 28.84it/s]
# Processed cover image saved at images/cover_1_idy_3Fu_tK41.jpg
# Processed cover image saved at images/cover_1_idy_9Ds_gL43.jpg
# Processed cover image saved at images/cover_1_idy_0Et_fE07.jpg
# Processed cover image saved at images/cover_1_idy_0Eu_gF61.jpg
# Processing Cover Art:   0%|                                                             | 0/4 [00:00<?, ?it/s]
# Processed cover image saved at images/cover_1_idy_3Fu_tK41.jpg
# Processed cover image saved at images/cover_1_idy_9Ds_gL43.jpg
# Processed cover image saved at images/cover_1_idy_0Et_fE07.jpg
# Processing Cover Art: 100%|█████████████████████████████████████████████████████| 4/4 [00:00<00:00, 91.11it/s]
# Processed cover image saved at images/cover_1_idy_0Eu_gF61.jpg
# Overlaying Key Images:  50%|██████████████████████████                          | 2/4 [00:00<00:00, 16.36it/s]
# Overlay applied and saved for album at images/cover_1_idy_3Fu_tK41.jpg
# Overlay applied and saved for album at images/cover_1_idy_9Ds_gL43.jpg
# Overlay applied and saved for album at images/cover_1_idy_0Et_fE07.jpg
# Overlaying Key Images: 100%|████████████████████████████████████████████████████| 4/4 [00:00<00:00, 16.30it/s]
# Overlay applied and saved for album at images/cover_1_idy_0Eu_gF61.jpg
# Overlaying LUFS Circles:   0%|                                                          | 0/4 [00:00<?, ?it/s]
# Overlay applied on image: images/cover_1_idy_3Fu_tK41.jpg
# Overlay applied on image: images/cover_1_idy_9Ds_gL43.jpg
# Overlaying LUFS Circles: 100%|█████████████████████████████████████████████████| 4/4 [00:00<00:00, 126.59it/s]
# Overlay applied on image: images/cover_1_idy_0Et_fE07.jpg
# Overlay applied on image: images/cover_1_idy_0Eu_gF61.jpg
# Generating clipping plots:   0%|                                                        | 0/4 [00:00<?, ?it/s]
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  25%|████████████                                    | 1/4 [00:01<00:05,  1.95s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_tendrly_ARkw_Knxwledge_MXkw_Original_Mix_KYkw_A_Minor_BPkw_156_GNkw_Trap___Future_Bass_RMkw__LBkw_Stones_Throw_Records_RYkw_2020_06_22_PYkw_2024_12_02.aiff as images/clip_plotidy_3Fu_tK41.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  50%|████████████████████████                        | 2/4 [00:05<00:05,  2.78s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Guaguancò_Del_Solar_ARkw_Salsa_various_MXkw_original_KYkw_4A_BPkw_110_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.aiff as images/clip_plotidy_9Ds_gL43.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  75%|████████████████████████████████████            | 3/4 [00:09<00:03,  3.49s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/Edson Conceição - Filhos de Gandhi (Um Abraço em Gilberto Gil) (Mike Burns Edit).aiff as images/clip_plotidy_0Et_fE07.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots: 100%|████████████████████████████████████████████████| 4/4 [00:14<00:00,  3.72s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Gloriole_ARkw_Fouk_MXkw_Original_Mix_KYkw_F_Major_BPkw_121_GNkw_Deep_House_RMkw__LBkw_House_Of_Disco_Records__RYkw_2019_07_12_PYkw_2025_03_27.aiff as images/clip_plotidy_0Eu_gF61.jpg
# Embedding clipping into album cover:   0%|                                              | 0/4 [00:00<?, ?it/s]<string>:948: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Embedding clipping into album cover:  50%|███████████████████                   | 2/4 [00:00<00:00, 18.94it/s]
# Image saved to images/cover_1_idy_3Fu_tK41.jpg
# Image saved to images/cover_1_idy_9Ds_gL43.jpg
# Image saved to images/cover_1_idy_0Et_fE07.jpg
# Embedding clipping into album cover: 100%|██████████████████████████████████████| 4/4 [00:00<00:00, 18.69it/s]
# Image saved to images/cover_1_idy_0Eu_gF61.jpg
# Saved: images/bpm_bar_dyn_idy_3Fu_tK41.png
# <string>:146: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Saved: images/bpm_bar_dyn_idy_9Ds_gL43.png
# Saved: images/bpm_bar_dyn_idy_0Et_fE07.png
# Saved: images/bpm_bar_dyn_idy_0Eu_gF61.png
# Saved composite over album: images/cover_1_idy_3Fu_tK41.jpg
# Saved composite over album: images/cover_1_idy_9Ds_gL43.jpg
# Saved composite over album: images/cover_1_idy_0Et_fE07.jpg
# Saved composite over album: images/cover_1_idy_0Eu_gF61.jpg
# TQM: Starting LUFS donut generation
# 100%|███████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 43.26it/s]
# TQM: LUFS donut plots complete!
# <string>:417: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: Embedded LUFS donut for ID idy_3Fu_tK41 at images/cover_1_idy_3Fu_tK41.jpg
# TQM: Embedded LUFS donut for ID idy_9Ds_gL43 at images/cover_1_idy_9Ds_gL43.jpg
# TQM: Embedded LUFS donut for ID idy_0Et_fE07 at images/cover_1_idy_0Et_fE07.jpg
# TQM: Embedded LUFS donut for ID idy_0Eu_gF61 at images/cover_1_idy_0Eu_gF61.jpg
# TQM: Spectral Shape-Texture Mapping: 100%|██████████████████████████████████████| 4/4 [00:02<00:00,  1.42it/s]
# ✅ TQM: 3-column shape-texture classification complete.
# TQM: Generating SHAPE and texture...
# 100%|██████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 197.28it/s]
# <string>:586: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:586: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:586: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: SHAPE and texture Spectral_Bandwidth	Spectral_Flatness images saved successfully!
# TQM: Embedded SHAPE bar for ID idy_3Fu_tK41 at images/cover_1_idy_3Fu_tK41.jpg
# TQM: Embedded SHAPE bar for ID idy_9Ds_gL43 at images/cover_1_idy_9Ds_gL43.jpg
# TQM: Embedded SHAPE bar for ID idy_0Et_fE07 at images/cover_1_idy_0Et_fE07.jpg
# TQM: Embedded SHAPE bar for ID idy_0Eu_gF61 at images/cover_1_idy_0Eu_gF61.jpg
# TQM: Embedded SHAPE bar for ID idy_3Fu_tK41 at images/cover_1_idy_3Fu_tK41.jpg
# TQM: Embedded SHAPE bar for ID idy_9Ds_gL43 at images/cover_1_idy_9Ds_gL43.jpg
# TQM: Embedded SHAPE bar for ID idy_0Et_fE07 at images/cover_1_idy_0Et_fE07.jpg
# TQM: Embedded SHAPE bar for ID idy_0Eu_gF61 at images/cover_1_idy_0Eu_gF61.jpg
# TQM: Embedded SHAPE bar for ID idy_3Fu_tK41 at images/cover_1_idy_3Fu_tK41.jpg
# TQM: Embedded SHAPE bar for ID idy_9Ds_gL43 at images/cover_1_idy_9Ds_gL43.jpg
# TQM: Embedded SHAPE bar for ID idy_0Et_fE07 at images/cover_1_idy_0Et_fE07.jpg
# <string>:586: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: Embedded SHAPE bar for ID idy_0Eu_gF61 at images/cover_1_idy_0Eu_gF61.jpg
# TQM: Embedded SHAPE bar for ID idy_3Fu_tK41 at images/cover_1_idy_3Fu_tK41.jpg
# TQM: Embedded SHAPE bar for ID idy_9Ds_gL43 at images/cover_1_idy_9Ds_gL43.jpg
# TQM: Embedded SHAPE bar for ID idy_0Et_fE07 at images/cover_1_idy_0Et_fE07.jpg
# TQM: Embedded SHAPE bar for ID idy_0Eu_gF61 at images/cover_1_idy_0Eu_gF61.jpg
# TQM: Extracting spectral centroid: 100%|████████████████████████████████████████| 4/4 [00:01<00:00,  2.91it/s]
# TQM: Generating centroid color donuts...
# 100%|███████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 11.84it/s]
# <string>:796: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# TQM: Donut-fade images saved successfully!
# ✅ TQM: Embedded CENTROID donut for ID idy_3Fu_tK41 at images/cover_1_idy_3Fu_tK41.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_9Ds_gL43 at images/cover_1_idy_9Ds_gL43.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_0Et_fE07 at images/cover_1_idy_0Et_fE07.jpg
# ✅ TQM: Embedded CENTROID donut for ID idy_0Eu_gF61 at images/cover_1_idy_0Eu_gF61.jpg
# TQM Processing: 100%|███████████████████████████████████████████████████████████| 4/4 [00:07<00:00,  1.81s/it]
# TQM: Plot saved to images/dbs_plot_idy_3Fu_tK41.png
# ✅ Saved: images/dbs_plot_idy_3Fu_tK41.png
# TQM: Plot saved to images/dbs_plot_idy_9Ds_gL43.png
# ✅ Saved: images/dbs_plot_idy_9Ds_gL43.png
# TQM: Plot saved to images/dbs_plot_idy_0Et_fE07.png
# ✅ Saved: images/dbs_plot_idy_0Et_fE07.png
# TQM: Plot saved to images/dbs_plot_idy_0Eu_gF61.png
# ✅ Saved: images/dbs_plot_idy_0Eu_gF61.png
# <string>:982: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# <string>:1168: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Embedding covers: 100%|████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 837.90it/s]
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_tendrly_ARkw_Knxwledge_MXkw_Original_Mix_KYkw_A_Minor_BPkw_156_GNkw_Trap___Future_Bass_RMkw__LBkw_Stones_Throw_Records_RYkw_2020_06_22_PYkw_2024_12_02.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_tendrly_ARkw_Knxwledge_MXkw_Original_Mix_KYkw_A_Minor_BPkw_156_GNkw_Trap___Future_Bass_RMkw__LBkw_Stones_Throw_Records_RYkw_2020_06_22_PYkw_2024_12_02.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Guaguancò_Del_Solar_ARkw_Salsa_various_MXkw_original_KYkw_4A_BPkw_110_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Guaguancò_Del_Solar_ARkw_Salsa_various_MXkw_original_KYkw_4A_BPkw_110_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/Edson Conceição - Filhos de Gandhi (Um Abraço em Gilberto Gil) (Mike Burns Edit).aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/Edson Conceição - Filhos de Gandhi (Um Abraço em Gilberto Gil) (Mike Burns Edit).aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Gloriole_ARkw_Fouk_MXkw_Original_Mix_KYkw_F_Major_BPkw_121_GNkw_Deep_House_RMkw__LBkw_House_Of_Disco_Records__RYkw_2019_07_12_PYkw_2025_03_27.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test/TRkw_Gloriole_ARkw_Fouk_MXkw_Original_Mix_KYkw_F_Major_BPkw_121_GNkw_Deep_House_RMkw__LBkw_House_Of_Disco_Records__RYkw_2019_07_12_PYkw_2025_03_27.aiff
# DOoooooooooooo
#
#
#
#
#
#
# ne...
# ✅ Saved: df_000_.pkl
# images and tables folders erased
#
# ⚠️  WARNING: This will completely delete and replace:
# '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test' ⬅️ with contents from '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test_bu'
# Press [ENTER] to continue or [CTRL+C] to cancel...
# ✅ Replaced '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test' with contents from '/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/test_bu'

# %%
import shutil
import os
[shutil.rmtree(f, ignore_errors=True) or os.makedirs(f, exist_ok=True) for f in ['images/', 'tables/']]
# Out:
# [None, None]
