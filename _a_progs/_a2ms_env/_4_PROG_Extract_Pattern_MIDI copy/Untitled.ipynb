# %%
import pandas as pd
df_rk_aiff_25_07 = pd.read_pickle("_df_aiff_rk_1635_25_07.pkl")

# %%
df_rk_aiff_25_07[['title', 'artist']]
# Out:
#                                    title                    artist
# 0         Patada De Culebra Original Mix            Tribilin Sound
# 1                Bushi Neng Original Mix                      Ka b
# 2                   Guajira Original Mix           Robot Needs Oil
# 3                     Hypno Original Mix                      Viot
# 4       One Night In Havana Original Mix  DJ Chus Gonzalo Gonzalez
# ...                                  ...                       ...
# 1630                Elevate Original Mix                   Heidy P
# 1631              Mao Negra Original Mix                Alma Negra
# 1632  Manhattan to Brooklyn Original Mix             Tour Maubourg
# 1633              Red Brick Original Mix                  Kikiorix
# 1634      The Love Triangle Original Mix           Robot Needs Oil
#
# [1635 rows x 2 columns]

# %%
# -----######-----###### LOAD PLAYLIST TXT TO DF (UTF-16 / TAB-SEP) -----######-----###### #
import pandas as pd

def _pltxt_0808_df_GET_loaded(txt_path):
    """
    Load a Rekordbox/playlist TXT file into a cleaned pandas DataFrame.

    Args:
        txt_path: str - Path to the UTF-16 tab-separated TXT playlist.

    Returns:
        DataFrame with cleaned column names and stripped values.
    """
    # Read TXT as UTF-16 tab-separated
    df = pd.read_csv(
        txt_path,
        sep="\t",
        encoding='utf-16',
        engine='python',
        on_bad_lines='skip'
    )

    # Clean column names
    df.columns = df.columns.str.strip()

    # Clean string cells (remove trailing spaces, normalize)
    for col in df.select_dtypes(include=["object"]).columns:
        df[col] = df[col].astype(str).str.strip()

    return df

# %%
# Example usage

txt_path = "/Users/yerik/Desktop/_D32_Tulum DINNER.txt"  # Replace with your playlist path

df_pl = _pltxt_0808_df_GET_loaded(txt_path)

# See first few rows
print(df_pl.head())

# Export full playlist to CSV for inspection
df_pl.to_csv("playlist_loaded.csv", index=False)
print("✅ Playlist exported to playlist_loaded.csv")
# Out:
#    # Key  Artwork File Type    BPM        Comments  DJ Play Count  \
# 0  1  6A      NaN       MP3  121.0  OOOLD_SRC_YODJ              1
# 1  2  6A      NaN       MP3  124.0  OOOLD_SRC_YODJ              1
# 2  3  6A      NaN       MP3  120.0  OOOLD_SRC_YODJ              0
# 3  4  1A      NaN       WAV  118.0  OOOLD_SRC_YODJ              0
# 4  5  4A      NaN       WAV  120.0  OOOLD_SRC_YODJ              0
#
#                                      Track Title  \
# 0                      Eme Lelu (Adam Port Edit)
# 1  Eye Nyam Nam 'A' Mensuro (Henrik Schwarz Dub)
# 2                        Everyday (Shimza Remix)
# 3             Forbidden feat. Sio (Original Mix)
# 4              Falling into Place (Original Mix)
#
#                                    Artist       Genre  ...        Label  \
# 0            Quim Manuel O Espirito Santo  Afro House  ...          nan
# 1  Pat Thomas, Ebo Taylor, Henrik Schwarz       House  ...        Strut
# ...

# %%
df_pl
# Out:
#      #  Key  Artwork File Type     BPM        Comments  DJ Play Count  \
# 0    1   6A      NaN       MP3  121.00  OOOLD_SRC_YODJ              1
# 1    2   6A      NaN       MP3  124.00  OOOLD_SRC_YODJ              1
# 2    3   6A      NaN       MP3  120.00  OOOLD_SRC_YODJ              0
# 3    4   1A      NaN       WAV  118.00  OOOLD_SRC_YODJ              0
# 4    5   4A      NaN       WAV  120.00  OOOLD_SRC_YODJ              0
# ..  ..  ...      ...       ...     ...             ...            ...
# 87  88   8A      NaN       MP3  100.00  OOOLD_SRC_YODJ              0
# 88  89   7A      NaN       MP3  102.00  OOOLD_SRC_YODJ              0
# 89  90  11A      NaN       MP3  125.00  OOOLD_SRC_YODJ              0
# 90  91   6A      NaN       MP3  120.00  OOOLD_SRC_YODJ              0
# 91  92   4B      NaN       WAV  119.98  OOOLD_SRC_YODJ              0
#
#                                           Track Title  \
# 0                           Eme Lelu (Adam Port Edit)
# ...

# %%
# -----######-----###### FUZZY MATCH: TITLE + ARTIST (2 DFS OUT) -----######-----###### #
import pandas as pd
import re
import unicodedata
from difflib import SequenceMatcher
from tqdm import tqdm

def _match_0808_artisttitle_GET_2dfs_fuzzy(
    df_left,
    df_right,
    col_left_title="Track Title",
    col_left_artist="Artist",
    col_right_title="title",
    col_right_artist="artist",
    w_title=0.6,
    w_artist=0.4,
    threshold=0.85,
    return_top_k=1
):
    """
    -----######-----###### CORE IMPORTABLE FUNCTION -----######-----###### 
    Fuzzy-match rows from df_left (playlist) against df_right (Rekordbox AIFF table)
    using Title + Artist. Returns two DataFrames:
      1) df_matches: rows with best_combo_score >= threshold
      2) df_nonmatches: rows with best_combo_score < threshold (with top candidate shown)

    Inputs:
      df_left, df_right : pandas DataFrames
      col_left_title, col_left_artist : columns in df_left
      col_right_title, col_right_artist : columns in df_right
      w_title, w_artist : weights for combining similarity scores (sum to 1.0)
      threshold : minimum combined score to consider a row 'matched'
      return_top_k : keep top K candidates in the outputs (usually 1)

    Outputs:
      df_matches, df_nonmatches (both with columns showing best candidates + scores)
    """

    tqdm.pandas()

    # ---------- helpers ----------
    def _normalize(s):
        if pd.isna(s):
            s = ""
        s = str(s)
        # deaccent
        s = unicodedata.normalize("NFKD", s)
        s = "".join(ch for ch in s if not unicodedata.combining(ch))
        # lowercase, remove bracketed junk like (feat. ...), [remix]
        s = s.lower()
        s = re.sub(r"\(.*?\)|\[.*?\]|{.*?}", " ", s)
        # common noise removal
        s = s.replace("&", "and")
        s = re.sub(r"\bfeat\.?|\bft\.?|\bfeaturing\b", " ", s)
        s = re.sub(r"[^a-z0-9\s\-]", " ", s)
        s = re.sub(r"\s+", " ", s).strip()
        return s

    def _token_sort(s):
        toks = s.split()
        toks.sort()
        return " ".join(toks)

    def _ratio(a, b):
        # try both raw and token-sort for stability
        r1 = SequenceMatcher(None, a, b).ratio()
        r2 = SequenceMatcher(None, _token_sort(a), _token_sort(b)).ratio()
        return max(r1, r2)

    # ---------- prep right table for faster candidate filtering ----------
    rk = df_right.copy()
    rk["_n_title"]  = rk[col_right_title].map(_normalize)
    rk["_n_artist"] = rk[col_right_artist].map(_normalize)
    rk["_tok_title"]  = rk["_n_title"].map(lambda s: set(s.split()))
    rk["_tok_artist"] = rk["_n_artist"].map(lambda s: set(s.split()))
    rk["_first_t"] = rk["_n_title"].map(lambda s: s[:1] if s else "")

    # Build simple inverted index by first letter of title for coarse pruning
    buckets = {}
    for idx, first in rk["_first_t"].items():
        buckets.setdefault(first, []).append(idx)

    # ---------- iterate left with a TQM bar ----------
    records = []
    for i, row in tqdm(df_left.iterrows(), total=len(df_left), desc="Matching by title+artist"):
        lt_raw = row.get(col_left_title, "")
        la_raw = row.get(col_left_artist, "")

        lt = _normalize(lt_raw)
        la = _normalize(la_raw)
        lt_tokens = set(lt.split())
        la_tokens = set(la.split())
        first_key = lt[:1] if lt else ""

        # coarse candidate pool
        cand_idx = set(buckets.get(first_key, []))

        # if too small, add token overlaps (title)
        if len(cand_idx) < 5 and lt_tokens:
            # add rows where token overlap exists in title OR artist
            overlap_title = rk.index[rk["_tok_title"].map(lambda s: len(s & lt_tokens) > 0)]
            overlap_artist = rk.index[rk["_tok_artist"].map(lambda s: len(s & la_tokens) > 0)]
            cand_idx |= set(overlap_title[:200].tolist())
            cand_idx |= set(overlap_artist[:200].tolist())

        if not cand_idx:
            # no candidates at all
            records.append({
                "left_index": i,
                "left_title": lt_raw,
                "left_artist": la_raw,
                "best_right_index": None,
                "best_right_title": None,
                "best_right_artist": None,
                "score_title": 0.0,
                "score_artist": 0.0,
                "score_combo": 0.0
            })
            continue

        # score candidates
        scores = []
        for j in cand_idx:
            rt = rk.at[j, "_n_title"]
            ra = rk.at[j, "_n_artist"]
            st = _ratio(lt, rt)
            sa = _ratio(la, ra)
            combo = (w_title * st) + (w_artist * sa)
            scores.append((j, st, sa, combo))

        # pick top-k
        scores.sort(key=lambda x: x[3], reverse=True)
        topk = scores[:return_top_k]

        # store best candidate as main line; also attach top-k as JSON-ish column if needed
        if topk:
            j, st, sa, combo = topk[0]
            records.append({
                "left_index": i,
                "left_title": lt_raw,
                "left_artist": la_raw,
                "best_right_index": j,
                "best_right_title": df_right.at[j, col_right_title],
                "best_right_artist": df_right.at[j, col_right_artist],
                "score_title": round(st, 4),
                "score_artist": round(sa, 4),
                "score_combo": round(combo, 4),
            })
        else:
            records.append({
                "left_index": i,
                "left_title": lt_raw,
                "left_artist": la_raw,
                "best_right_index": None,
                "best_right_title": None,
                "best_right_artist": None,
                "score_title": 0.0,
                "score_artist": 0.0,
                "score_combo": 0.0
            })

    df_scored = pd.DataFrame.from_records(records)

    # join in the actual right-row if matched (optional)
    # df_scored = df_scored.merge(df_right.add_prefix("right_"), left_on="best_right_index", right_index=True, how="left")

    df_matches = df_scored[df_scored["score_combo"] >= threshold].reset_index(drop=True)
    df_nonmatches = df_scored[df_scored["score_combo"] < threshold].reset_index(drop=True)

    return df_matches, df_nonmatches

# %%
# Inputs you already have:
# df_pl  -> from your TXT loader; columns: 'Track Title', 'Artist'
# df_rk_aiff_25_07 -> your Rekordbox AIFF DF; columns: 'title', 'artist'

# Example run (keeps title a bit more important than artist, threshold 0.85)
df_matches, df_others = _match_0808_artisttitle_GET_2dfs_fuzzy(
    df_left=df_pl,
    df_right=df_rk_aiff_25_07,
    col_left_title="Track Title",
    col_left_artist="Artist",
    col_right_title="title",
    col_right_artist="artist",
    w_title=0.6,
    w_artist=0.4,
    threshold=0.85,
    return_top_k=1
)

# Quick peeks
print("✅ Matches:", len(df_matches))
print(df_matches.head(10))
print("\n❗ Not matched (closest candidates shown):", len(df_others))
print(df_others.head(10))

# Optional: save out
# df_matches.to_csv("matched_title_artist.csv", index=False)
# df_others.to_csv("unmatched_title_artist_with_best_candidate.csv", index=False)
# Out:
# Matching by title+artist: 100%|██████████████████████████████████████████████| 92/92 [00:00<00:00, 174.12it/s]
# ✅ Matches: 0
# Empty DataFrame
# Columns: [left_index, left_title, left_artist, best_right_index, best_right_title, best_right_artist, score_title, score_artist, score_combo]
# Index: []
#
# ❗ Not matched (closest candidates shown): 92
#    left_index                                         left_title  \
# 0           0                          Eme Lelu (Adam Port Edit)
# 1           1      Eye Nyam Nam 'A' Mensuro (Henrik Schwarz Dub)
# 2           2                            Everyday (Shimza Remix)
# 3           3                 Forbidden feat. Sio (Original Mix)
# 4           4                  Falling into Place (Original Mix)
# 5           5                             Fatoumata_Original_Mix
# 6           6                          Footprints (Extended Mix)
# 7           7                                              Freya
# ...

# %%
df_matches
# Out:
# Empty DataFrame
# Columns: [left_index, left_title, left_artist, best_right_index, best_right_title, best_right_artist, score_title, score_artist, score_combo]
# Index: []
