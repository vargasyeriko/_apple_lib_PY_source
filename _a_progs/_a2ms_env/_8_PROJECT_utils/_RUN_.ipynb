# %% [markdown]
# # load Modules

# %%
from src.make_folder_structure import _fld_1803_i1_GET_project_structure
from src.rename_SAMPLE_files import _ren_1803_i5_GET_df_samples

# %% [markdown]
# # make a new folder structure for a new project in Ableton

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!

base_dir = "/Users/yergooik/Music/_5_ABLETON"
project_name = "2026_03_18_keyword_2"

project_path = _fld_1803_i1_GET_project_structure(base_dir, project_name)
# Out:
# Creating project structure: 100%|███████████████████████████████████████████| 14/14 [00:00<00:00, 4443.12it/s]
# ✅ Project created at:/Users/yerik/Music/_5_ABLETON/2026_03_18_keyword_2

# %% [markdown]
# # RENAME FILES IN FOLDER AND GET DF

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
base_dir = "/Users/yerik/Music/_5_ABLETON"
project_name = "2026_03_18_keyword"

samples_path = f"{base_dir}/{project_name}/_SAMPLES"
input(samples_path)
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
df = _ren_1803_i5_GET_df_samples(samples_path)
# Out:
# /Users/yerik/Music/_5_ABLETON/2026_03_18_keyword/_SAMPLES
# ...
# Processing kicks: 100%|███████████████████████████████████████████████████| 11/11 [00:00<00:00, 322638.77it/s]
# Processing song_starters: 0it [00:00, ?it/s]
# ✅ Total files processed: 0

# %%
print(project_path)
# Out:
# /Users/yerik/Music/_5_ABLETON/2026_03_18_keyword/_SAMPLES
