# %%
#-----######-----###### CUT WAV FILE FUNCTION -----######-----######

from pydub import AudioSegment

def _cut_30sec_0812_audio_GET_short_wav(input_wav, output_wav="/Users/yerik/Downloads/downloads_CLIENTS/_au_0_.wav"):
    """
    Cuts the first 30 seconds of an input WAV file and saves it as a new file.
    Args:
    - input_wav (str): Path to the input WAV file.
    - output_wav (str): Path to the output WAV file (default: 'short_vr.wav').
    Returns:
    - str: Confirmation message with the output file path.
    """
    # Load the WAV file
    audio = AudioSegment.from_file(input_wav, format="wav")

    # Extract first 30 seconds
    short_audio = audio[:30 * 1000]  # 30 seconds in milliseconds

    # Export to a new file
    short_audio.export(output_wav, format="wav")
    return f"Exported {output_wav} successfully!"

# Replace 'your_file.wav' with the actual file path of your input WAV file
input_file = wav_path

# Run the function
result_message = _cut_30sec_0812_audio_GET_short_wav(input_file)
print(result_message)
# Out:
# Exported /Users/yerik/Downloads/downloads_CLIENTS/_au_0_.wav successfully!

# %%
# AUDIO MANIPULATION
import sounddevice as sd
import soundfile as sf

# PLAY recording  and Analyze GAIN
from _ms_pod_global_functions import wav_play ,wav_analyze_gain
# Analyze FREQ distribution
from _ms_pod_global_functions import wav_freq_dist_pie_chart, wav_freq_dist_plot,wav_plot_spectrogram

# MIXED plots #PLOT amplitud, lufs, spectogram 
from _ms_pod_global_functions import  wav_plot_3 ,wav_audio_ana_6

# COMPARE DIRECTORY  input for wav files IN ONE FOLDER
from _ms_pod_global_functions import direc_wav_compare_spct

# %%
file_path = f"/Users/yerik/Downloads/downloads_CLIENTS/vr_OR.mp3"
_path = file_path

# %%
################## MP3 to WAV 
new_file = _convert_0812_mp3_to_wav_GET_file(file_path)
wav_path = "/Users/yerik/Downloads/downloads_CLIENTS/wav_vr.wav"
path_use = "/Users/yerik/Downloads/downloads_CLIENTS/_au_0_.wav"
# Out:
# ffmpeg version 6.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with clang version 16.0.6
#   configuration: --prefix=/Users/runner/miniforge3/conda-bld/ffmpeg_1699837992312/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1699837992312/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1699837992312/_build_env/bin/pkg-config
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mp3, from '/Users/yerik/Downloads/downloads_CLIENTS/vr_OR.mp3':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:56:19.15, start: 0.025057, bitrate: 320 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 320 kb/s
#     Metadata:
#       encoder         : Lavc61.3.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/Users/yerik/Downloads/downloads_CLIENTS/wav_vr.wav':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     ISFT            : Lavf60.16.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc60.31.102 pcm_s16le
# [out#0/wav @ 0x60000019c540] video:0kB audio:582104kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000013%
# size=  582104kB time=00:56:19.09 bitrate=1411.2kbits/s speed= 826x

# %% [markdown]
# # fns

# %% [markdown]
# # PODCAST ANALYSIS - 0 EDA -- 1 VOL & -- 2 FREQ
# # 3 # PODCAST EDITING  - (a) HP (b) NR (c) NG

# %%
# Global 


# AUDIO MANIPULATION
import sounddevice as sd
import soundfile as sf

# PLAY recording  and Analyze GAIN
from _ms_pod_global_functions import wav_play ,wav_analyze_gain
# Analyze FREQ distribution
from _ms_pod_global_functions import wav_freq_dist_pie_chart, wav_freq_dist_plot,wav_plot_spectrogram

# MIXED plots #PLOT amplitud, lufs, spectogram 
from _ms_pod_global_functions import  wav_plot_3 ,wav_audio_ana_6

# COMPARE DIRECTORY  input for wav files IN ONE FOLDER
from _ms_pod_global_functions import direc_wav_compare_spct

# %% [markdown]
# ### <<< 0 >>> Audio MANIPULATION

# %%
# Query and print all audio devices
sd.query_devices()

# # PLAY AUDIO without being saved
# sd.play(audio_data, RATE, device=2 )
# sd.wait()

# ATTN -> miss fn to get wav 1 channel from any format and client info/tags get info of lenght etc 
# RAW AUDIO input 
direc_wav = "_pod_1_recording"

#file_path = f"{direc_wav}/_0_vr_raw_.wav" # RAW
file_path =  _path #f"{direc_wav}/_0_voc_vr.wav"  # w DEMCUS 

#wav_play(file_path)

# %% [markdown]
# ###  <<< 1 >>> VOLUME ANALYSIS:

# %%
wav_analyze_gain(file_path) # CHECK AMPLITUDE FOR GAIN PURPOSES - ### low GAIN  ### CLIPPING WARNING
# Out:
# Peak Level (linear scale): 1.060
# RMS Level (linear scale): 0.195
# RMS Level (dBFS): -14.20 dB
# Warning: The audio might be clipping!
#
# Frequency Band Power (dB):
# Super Low (< 50Hz): 20.12 dB
# Low (50Hz - 400Hz): 57.63 dB
# Mid (400Hz - 4kHz): 39.49 dB
# High (> 4kHz): 7.28 dB
#
# Interpretation:
# - Your recording level is within the typical range for spoken content.
# - Your recording might have clipping. This can lead to distortion. Reduce the volume or rerecording.
# signfc power in low frequencies, which add unnecessary rumble or noise. Consider using a high-pass filter.

# %% [markdown]
# ###  <<< 2 >>>  FREQUENCY ANALYSIS:
#
# ##### 0 to 50 Hz: Purpose: This very low-end range provides the rumble and sub-bass content. --->  < 5%
# ##### 50 to 400 Hz: freq of male voices mostly reside here, giving the voice body/fullness.  --->  ~ 40%
# ##### 400 to 4000 Hz: freq w harmonic content, presence/clarity. vital for intelligibility.  --->  ~ 55%

# %%
wav_freq_dist_pie_chart(file_path) # CHECK FREQ DISTRIUTION
#wav_freq_dist_plot(file_path) # check freq distributions PLOTS
wav_plot_spectrogram(file_path)

# FURTHER ANALYSIS--------- PLOTS

wav_plot_3(file_path)
wav_audio_ana_6(file_path)

# AFTER MODIFyING COMPARE FOLDER ----------- ALL wavs in FOLDER PLOTS
direc_wav_compare_spct(direc_wav)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 wav_freq_dist_pie_chart(file_path) # CHECK FREQ DISTRIUTION
#       2 #wav_freq_dist_plot(file_path) # check freq distributions PLOTS
# ----> 3 wav_plot_spectrogram(file_path)
#       5 # FURTHER ANALYSIS--------- PLOTS
#       7 wav_plot_3(file_path)
#
# File ~/_apple_source/PY/JUPY/py2ms/_APP_/DEVANKAR/ms_2_PODCASTS_CAI/_ms_pod_global_functions.py:68, in wav_plot_spectrogram(file_path)
#      66 # Plot the spectrogram
#      67 plt.figure(figsize=(10, 4))
# ---> 68 librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='hz')
#      69 plt.colorbar(format='%+2.0f dB')
#      70 plt.title('Spectrogram')
#
# File ~/_envs/_2ms_envs/ms_env/lib/python3.8/site-packages/librosa/display.py:1208, in specshow(data, x_coords, y_coords, x_axis, y_axis, sr, hop_length, n_fft, win_length, fmin, fmax, tuning, bins_per_octave, key, Sa, mela, thaat, auto_aspect, htk, unicode, intervals, unison, ax, **kwargs)
#    1204 x_coords = __mesh_coords(x_axis, x_coords, data.shape[1], **all_params)
#    1206 axes = __check_axes(ax)
# -> 1208 out = axes.pcolormesh(x_coords, y_coords, data, **kwargs)
#    1210 __set_current_image(ax, out)
#    1212 # Set up axis scaling
#
# File ~/_envs/_2ms_envs/ms_env/lib/python3.8/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~/_envs/_2ms_envs/ms_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py:6072, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6068 C = C.ravel()
#    6070 kwargs.setdefault('snap', rcParams['pcolormesh.snap'])
# -> 6072 collection = mcoll.QuadMesh(
#    6073     coords, antialiased=antialiased, shading=shading,
#    6074     array=C, cmap=cmap, norm=norm, alpha=alpha, **kwargs)
#    6075 collection._scale_norm(norm, vmin, vmax)
#    6076 self._pcolor_grid_deprecation_helper()
#
# File ~/_envs/_2ms_envs/ms_env/lib/python3.8/site-packages/matplotlib/collections.py:2015, in QuadMesh.__init__(self, *args, **kwargs)
#    2012 self._bbox.update_from_data_xy(self._coordinates.reshape(-1, 2))
#    2013 # super init delayed after own init because array kwarg requires
#    2014 # self._coordinates and self._shading
# -> 2015 super().__init__(**kwargs)
#    2016 self.mouseover = False
#
# File ~/_envs/_2ms_envs/ms_env/lib/python3.8/site-packages/matplotlib/collections.py:217, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     214 self._transOffset = transOffset
#     216 self._path_effects = None
# --> 217 self.update(kwargs)
#     218 self._paths = None
#
# File ~/_envs/_2ms_envs/ms_env/lib/python3.8/site-packages/matplotlib/artist.py:1069, in Artist.update(self, props)
#    1066             if not callable(func):
#    1067                 raise AttributeError(f"{type(self).__name__!r} object "
#    1068                                      f"has no property {k!r}")
# -> 1069             ret.append(func(v))
#    1070 if ret:
#    1071     self.pchanged()
#
# File ~/_envs/_2ms_envs/ms_env/lib/python3.8/site-packages/matplotlib/collections.py:2077, in QuadMesh.set_array(self, A)
#    2072     if faulty_data:
#    2073         raise TypeError(
#    2074             f"Dimensions of A {A.shape} are incompatible with "
#    2075             f"X ({width}) and/or Y ({height})")
# -> 2077 return super().set_array(A)
#
# File ~/_envs/_2ms_envs/ms_env/lib/python3.8/site-packages/matplotlib/cm.py:475, in ScalarMappable.set_array(self, A)
#     472     self._A = None
#     473     return
# --> 475 A = cbook.safe_masked_invalid(A, copy=True)
#     476 if not np.can_cast(A.dtype, float, "same_kind"):
#     477     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     478                     "converted to float")
#
# File ~/_envs/_2ms_envs/ms_env/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:701, in safe_masked_invalid(x, copy)
#     700 def safe_masked_invalid(x, copy=False):
# --> 701     x = np.array(x, subok=True, copy=copy)
#     702     if not x.dtype.isnative:
#     703         # If we have already made a copy, do the byteswap in place, else make a
#     704         # copy with the byte order swapped.
#     705         x = x.byteswap(inplace=copy).newbyteorder('N')  # Swap to native order.
#
# KeyboardInterrupt:

# %% [markdown]
# # <<< 3 4 5 >>> AUDIO EDITING

# %%
# HP functions
from _ms_pod_editing_functions import wav_hp_mod_1
# NR functions
from _ms_pod_editing_functions import wav_nr_mod_1 ,wav_nr_mod_2
# NOISE GATE
from _ms_pod_editing_functions import wav_ng_mod_1, wav_ng_mod_2_pad
# NORMALIZATION 

from _ms_pod_editing_functions import wav_norm_first, wav_comp_norm_lufs

#from _ms_pod_editing_functions import

print(f' EDITING functions working currently in ::: \n*\n*\n*\n*{file_path}\n*\n*\n*\n*')

# %% [markdown]
# ### ::: 3a ::: High Pass

# %%
# Usage example
y_hpf, sr = wav_hp_mod_1(file_path, cutoff_frequency=50, order=6)

# Save the high-pass filtered audio
out_file_path_hp_m1 = f"{direc_wav}/_1_vr_raw_iii_HP50"
# Write
sf.write(f'{out_file_path_hp_m1}.wav', y_hpf, sr)

# %% [markdown]
# ### ::: 3b ::: Noise Reduction (NR) mod_1

# %%
# Usage
# Adjust 'audio_path', 'noise_reduction_level', and 'sensitivity' as needed
noise_reduced_output_1 = wav_nr_mod_1(f'{out_file_path_hp_m1}.wav', 0.9, 0.9)

# Save the high-pass filtered audio
out_file_path_nr_m1 = f"{direc_wav}/_2_vr_HP50_iii_NR"
# Write
sf.write(f'{out_file_path_nr_m1}.wav', noise_reduced_output_1, sr)
# Write to a file

# %% [markdown]
# ##### Noise Reduction (NR) mod_2

# %%
# Adjust 'audio_file_path', 'noise_reduction_factor', 'frame_length', and hop_length' as needed
noise_reduced_output_2, sample_rate = wav_nr_mod_2(f'{out_file_path_nr_m1}.wav', 9.8)


# Save the high-pass filtered audio
out_file_path_nr_m2 = f"{direc_wav}/_2b_vr_NR_iii_NR_mod_2"
# Write
sf.write(f'{out_file_path_nr_m2}.wav', noise_reduced_output_2, sample_rate)
# Write to a file

# %% [markdown]
# ### ::: 3c ::: NOISE GATE - NOT PADDiNG - for low volumes (-80,-60) -- mod_1

# %%
#So, 0.01 seconds is equivalent to 10 milliseconds. , attack ~ .01 , release~ .3 (300)

input_file = f'{out_file_path_nr_m2}.wav'

out_file_path_ng_m1 = f"{direc_wav}/_3_vr_NR_mod_2_iii_NG-70_ARdot0105"

# SAVE and EXPORT inside the fn 
wav_ng_mod_1(input_file, f'{out_file_path_ng_m1}.wav', gate_threshold=-63.0, attack=0.29, release=.05)

# %% [markdown]
# # <<< 4 >>>   NORMALIZATION and Second NOiSE GATE

# %% [markdown]
# #### ::: 4a ::: first Normalization - PEAK NORMALIZATION

# %%
# Assume the normalize_audio function is already defined as provided earlier
norm_type = 'peak'  # or 'rms'
# Using the function
input_file_path = f'{out_file_path_ng_m1}.wav' # Replace with your input file path
out_file_path_norm_1 = f"{direc_wav}/_4_vr_NORM_{norm_type}"#{my_level}"

norm_1_audio,sample_rate = wav_norm_first(input_file_path, normalization_type=norm_type, target_level=-0.9)

# Export the normalized audio to a file
sf.write(f"{out_file_path_norm_1}.wav",norm_1_audio, sample_rate)

# %% [markdown]
# #### ::: 4b ::: second NG

# %%
input_file_path = f'{out_file_path_norm_1}.wav' # Replace with your input file path

out_file_path_norm_ng = f"{direc_wav}/_4b_vr_NORM_{norm_type}_to_NG"#{my_level}"


wav_ng_mod_2_pad(input_file_path, f"{out_file_path_norm_ng}.wav", gate_threshold=-63.0, attack=0.19, release=0.02)

# %% [markdown]
# # <<< 5 >>> COMPRESSION and LAST NORMALIZATIONzz

# %%
# Usage
input_file = f"{out_file_path_norm_ng}.wav"#{my_level}"

out_comp_norm_lufs = f"{direc_wav}/_5_vr_LUFS_comp_and_norm"

wav_comp_norm_lufs(input_file, f"{out_comp_norm_lufs}.wav", threshold=-0.95, ratio=2.0, attack=0.29, release=0.02, target_lufs=-26.0)

# %% [markdown]
# # END

# %%
# further research - DE- ESSER and MULTI BADN COMOPRESSOR

# %% [markdown]
# # NOTES

# %% [markdown]
# ![image.png](attachment:00d274a9-f914-4a0b-a100-7d40d68c52e4.png)

# %% [markdown]
# Both steps are crucial for professional audio processing, especially for podcasts and broadcast content. Compression ensures consistent audibility within the track, and LUFS normalization ensures that the overall loudness meets the standards of the intended platform, providing a uniform listening experience. This combination is key to achieving high-quality, platform-compliant audio content.
#
# Adjust the Compression Threshold: Lowering the compression threshold means that more parts of the audio will be subjected to compression

# %% [markdown]
# ![image.png](attachment:6c027a14-9e23-44b3-af84-7809322dcc39.png)

# %%
#-----######-----###### Main Function -----######-----######

import subprocess
import os

def _convert_0812_mp3_to_wav_GET_file(file_path):
    """
    Converts an MP3 file to WAV format using FFmpeg.

    Parameters:
    file_path: Original file path as a string

    Returns:
    wav_file_path: Path of the converted WAV file
    """
    # Extract directory and create new file path
    base_dir = os.path.dirname(file_path)
    wav_file_path = os.path.join(base_dir, "wav_vr.wav")
    
    try:
        # Run FFmpeg command
        subprocess.run([
            "ffmpeg", "-y", "-i", file_path, wav_file_path
        ], check=True)
        
        return wav_file_path

    except subprocess.CalledProcessError as e:
        print(f"Error during conversion: {e}")
        return None
