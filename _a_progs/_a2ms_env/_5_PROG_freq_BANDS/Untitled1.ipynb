# %%
exec(open("_1_run.py",encoding="utf-8").read())
# Out:
# Launching 3-band live EQ console (Textual)...
# Tip: Use your mouse to drag the sliders. Press Ctrl+C to quit.
# Enter AIFF file path:  /Users/yerik/Downloads/___Delete_analyze again /try.aiff
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 exec(open("_1_run.py",encoding="utf-8").read())
#
# File <string>:34
#
# File <string>:30, in main()
#
# File ~/_apple_lib/_a_progs/_a2ms_env/_5_PROG_freq_BANDS/_0_fns.py:440, in _audio_0611_textual3band_GET_live_eq_console()
#     438 engine = _ThreeBandEngine(aiff_path, blocksize=256)
#     439 app = _EQApp(engine)
# --> 440 app.run()
#
# File ~/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/textual/app.py:2251, in App.run(self, headless, inline, inline_no_clear, mouse, size, auto_pilot, loop)
#    2246 if loop is None:
#    2247     if _ASYNCIO_GET_EVENT_LOOP_IS_DEPRECATED:
# ...

# %%
/Users/yerik/Downloads/___Delete_analyze again /try.aiff

# %%
exec(open("run.py",encoding="utf-8").read())
# Out:
# TQM | Peak: [--------------------------------------------------] 0.013 | XRuns: 0

# %%
# -----######----- RUN THIS TO LAUNCH -----######-----
if __name__ == "__main__":
    _audio_0611_textual3band_GET_live_eq_console()
# Out:
# Enter AIFF file path:  /Users/yerik/Downloads/___Delete_analyze again /try.aiff
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 3
#       1 # -----######----- RUN THIS TO LAUNCH -----######-----
#       2 if __name__ == "__main__":
# ----> 3     _audio_0611_textual3band_GET_live_eq_console()
#
# File <string>:305, in _audio_0611_textual3band_GET_live_eq_console()
#
# File ~/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/textual/app.py:2251, in App.run(self, headless, inline, inline_no_clear, mouse, size, auto_pilot, loop)
#    2246 if loop is None:
#    2247     if _ASYNCIO_GET_EVENT_LOOP_IS_DEPRECATED:
#    2248         # N.B. This does work with Python<3.10, but global Locks, Events, etc
#    2249         # eagerly bind the event loop, and result in Future bound to wrong
#    2250         # loop errors.
# ...
