# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random, string

direc_jpg = 'images/'
exec(open("_key_plot.py",encoding="utf-8").read())
##### get df
df = pd.read_pickle("df_cover.pkl")
# id
df['ID'] = [''.join(random.choices(string.ascii_uppercase, k=2)) + ''.join(random.choices(string.digits, k=2)) for _ in range(len(df))]  # TQM: |████████████████████|
df.head(1)
len(df)
# Out:
# 7

# %%
###### create KEY plot chamelot map 
key_plot()
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
# Minimal execution code: Set the directory with your PNG images and call the function.
input_directory = direc_jpg # Directory containing the PNG images that need processing

# Call the function to process and overwrite the images in the same folder.
_png_2409_wbrem_GET_overwrite_imgs(input_directory, tolerance=200)

#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
# Minimal execution code: Ensure that 'df' is your DataFrame with "Path" and "ID" columns.
# Set the folder where you wish to save the renamed cover images.
output_folder = direc_jpg  # Change this to your desired output folder

# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None)
# Out:
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# TQM: Processed and overwritten image images/key_plotXG58.png
# TQM: Processed and overwritten image images/key_plotZB02.png
# TQM: Processed and overwritten image images/key_plotHI38.png
# TQM: Processed and overwritten image images/key_plotSI57.png
# TQM: Processed and overwritten image images/key_plotYS87.png
# TQM: Processed and overwritten image images/key_plotDA08.png
# TQM: Processed and overwritten image images/key_plotJP74.png
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Original_Mix_KYkw_G_Minor_BPkw_124_GNkw_House_RMkw__LBkw_XDM_Records_RYkw_2020_02_14_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID SI57 saved as images/cover_1_SI57.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_Lisbon_MXkw_Low_End_Specialists_Mix_KYkw_G_Minor_BPkw_127_GNkw_House_RMkw_Low_End_Specialists_LBkw_Kaos_Records_Portugal_RYkw_2017_06_09_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID JP74 saved as images/cover_1_JP74.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulphiction_Remix_KYkw_E_Minor_BPkw_122_GNkw_Deep_House_RMkw_Soulphiction_LBkw_Heist_Recordings_RYkw_2017_05_08_PYkw_2025_03_27 2.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID XG58 saved as images/cover_1_XG58.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulphiction_Remix_KYkw_E_Minor_BPkw_122_GNkw_Deep_House_RMkw_Soulphiction_LBkw_Heist_Recordings_RYkw_2017_05_08_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID HI38 saved as images/cover_1_HI38.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Laope_ARkw_Salsa_various_MXkw_original_KYkw_7A_BPkw_91_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID YS87 saved as images/cover_1_YS87.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_original_KYkw_5A_BPkw_105_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID DA08 saved as images/cover_1_DA08.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_Y_Su_Trabuco_MXkw_Original_Mix_KYkw_A_Minor_BPkw_98_GNkw_House_RMkw__LBkw_Planet_Records_RYkw_2019_09_01_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID ZB02 saved as images/cover_1_ZB02.jpg

# %% [markdown]
# # check point

# %%
df
# Out:
#                                                 Path  \
# 0  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 1  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 2  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 3  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 4  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 5  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 6  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
#
#                                              temp_id  \
# 0  TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Ori...
# 1  TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_...
# 2  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...
# 3  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...
# 4  TRkw_Laope_ARkw_Salsa_various_MXkw_original_KY...
# 5  TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_ori...
# 6  TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_...
#
#                                            file_name Extension dur_seconds  \
# 0  TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Ori...     .aiff   312.58068
# 1  TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_...     .aiff      376.44
# 2  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...     .aiff  334.964717
# 3  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...     .aiff  334.964717
# 4  TRkw_Laope_ARkw_Salsa_various_MXkw_original_KY...     .aiff  188.650385
# 5  TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_ori...     .aiff  170.649819
# 6  TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_...     .aiff  277.733333
#
#     dur_min     sr bit_depth bit_rate channels  ... rel_date_file key_dj  \
# 0  5.209678  44100        16     None        2  ...       ID3TAGS     6A
# 1     6.274  44100        16     None        2  ...       ID3TAGS    10A
# 2  5.582745  44100        16     None        2  ...       ID3TAGS     9A
# 3  5.582745  44100        16     None        2  ...       ID3TAGS     9A
# 4  3.144173  44100        16     None        2  ...       ID3TAGS     8B
# 5  2.844164  44100        16     None        2  ...       ID3TAGS     6A
# 6  4.628889  44100        16     None        2  ...       ID3TAGS     8A
#
#   key_music                 status  Relative_Key Key_Up  Key_Down  Jaw_s_Mix  \
# 0      Gmin  Success: TKEY updated            6B     7A        5A         1A
# 1      Bmin  Success: TKEY updated           10B    11A        9A         5A
# 2      Emin  Success: TKEY updated            9B    10A        8A         4A
# 3      Emin  Success: TKEY updated            9B    10A        8A         4A
# 4      Cmaj  Success: TKEY updated            8A     9B        7B         3B
# 5      Gmin  Success: TKEY updated            6B     7A        5A         1A
# 6      Amin  Success: TKEY updated            8B     9A        7A         3A
#
#    Mood_Shifter    ID
# 0            9B  SI57
# 1            1B  JP74
# 2           12B  XG58
# 3           12B  HI38
# 4            5A  YS87
# 5            9B  DA08
# 6           11B  ZB02
#
# [7 rows x 51 columns]

# %%
df['Path_jpg_album'] = f'{direc_jpg}' + 'cover_1_' + df['ID'] + '.jpg'
df
# Out:
#                                                 Path  \
# 0  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 1  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 2  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 3  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 4  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 5  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 6  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
#
#                                              temp_id  \
# 0  TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Ori...
# 1  TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_...
# 2  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...
# 3  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...
# 4  TRkw_Laope_ARkw_Salsa_various_MXkw_original_KY...
# 5  TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_ori...
# 6  TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_...
#
#                                            file_name Extension dur_seconds  \
# 0  TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Ori...     .aiff   312.58068
# 1  TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_...     .aiff      376.44
# 2  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...     .aiff  334.964717
# 3  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...     .aiff  334.964717
# 4  TRkw_Laope_ARkw_Salsa_various_MXkw_original_KY...     .aiff  188.650385
# 5  TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_ori...     .aiff  170.649819
# 6  TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_...     .aiff  277.733333
#
#     dur_min     sr bit_depth bit_rate channels  ... key_dj key_music  \
# 0  5.209678  44100        16     None        2  ...     6A      Gmin
# 1     6.274  44100        16     None        2  ...    10A      Bmin
# 2  5.582745  44100        16     None        2  ...     9A      Emin
# 3  5.582745  44100        16     None        2  ...     9A      Emin
# 4  3.144173  44100        16     None        2  ...     8B      Cmaj
# 5  2.844164  44100        16     None        2  ...     6A      Gmin
# 6  4.628889  44100        16     None        2  ...     8A      Amin
#
#                   status Relative_Key  Key_Up Key_Down  Jaw_s_Mix  \
# 0  Success: TKEY updated           6B      7A       5A         1A
# 1  Success: TKEY updated          10B     11A       9A         5A
# 2  Success: TKEY updated           9B     10A       8A         4A
# 3  Success: TKEY updated           9B     10A       8A         4A
# 4  Success: TKEY updated           8A      9B       7B         3B
# 5  Success: TKEY updated           6B      7A       5A         1A
# 6  Success: TKEY updated           8B      9A       7A         3A
#
#    Mood_Shifter    ID           Path_jpg_album
# 0            9B  SI57  images/cover_1_SI57.jpg
# 1            1B  JP74  images/cover_1_JP74.jpg
# 2           12B  XG58  images/cover_1_XG58.jpg
# 3           12B  HI38  images/cover_1_HI38.jpg
# 4            5A  YS87  images/cover_1_YS87.jpg
# 5            9B  DA08  images/cover_1_DA08.jpg
# 6           11B  ZB02  images/cover_1_ZB02.jpg
#
# [7 rows x 52 columns]
