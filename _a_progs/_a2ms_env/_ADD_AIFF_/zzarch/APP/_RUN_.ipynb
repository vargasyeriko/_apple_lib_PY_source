# %%
import pandas as pd
# Adjust settings to display all rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', 1000)  # Set a wide display width to fit the content
pd.set_option('display.max_colwidth', None)  # Show full column content without truncation

# %%
my_aiff  ='/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy'
#my_aiff ="/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy"#/_2025_this"#/test"
#my_aiff ="/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover"

# %%
exec(open("run.py",encoding="utf-8").read())
# important 'bpm_consistency_cat','dominant_bpm',] D_0 being 100 in same BPM 
# #df['ID'] = df['bpm_consistency_cat'].str[1]  
# df['ID'] = ('dy' + df['bpm_consistency_cat'].str[2] 
#             + df['ms_LUFS_code'].str[2].str.upper() 
#             + df['id_cat_lufs'].str.lower() +'_'
#             + df['titile'].str[0].str.lower()
#             + df['artist'].str[0].str.upper()
#             + df['file_size'].astype(str).str[:2])


# df['ms_lufs']
# df.sort_values(by='ID')
# Out:
#    Sample Rate (Hz)  Bit Depth  Count
# 0             44100         16      9
#
# ALL AIFF in correct format -> if something changes go erase the already downsized
# ENTER to analyze
# Searching for Files: 100%|█████████████████████████████████████████████████| 9/9 [00:00<00:00, 8815.68files/s]
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel
# ***df*** will be returned having ::: 9  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 494.586
# Grand Total Size in Bytes: 518611108.000
# Grand Total Size in GB: 0.483
#
#  FREQUENCY TABLE:::
#
#   Extension  frequency  total_size_in_mb
# 0     .aiff          9        494.586094
# Audio file Attributes: 100%|██████████████████████████████████████████████████| 9/9 [00:00<00:00, 2637.01it/s]
# Computing LUFS: 100%|█████████████████████████████████████████████████████████| 9/9 [00:05<00:00,  1.59file/s]
# 100%|███████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 121770.12it/s]
# Processing BPM Dynamic: 100%|███████████████████████████████████████████████████| 9/9 [00:14<00:00,  1.64s/it]
# Extracting ID3 Titles: 100%|██████████████████████████████████████████████████| 9/9 [00:00<00:00, 2049.67it/s]
# DONE with getting 1_title
# title_file
# ID3TAGS    9
# Name: count, dtype: int64
# Writing AIFF files for title: 100%|████████████████████████████████████████████| 9/9 [00:00<00:00, 648.31it/s]
# Total files processed for title: 9
# Extracting ID3 Artists: 100%|█████████████████████████████████████████████████| 9/9 [00:00<00:00, 2364.02it/s]
# DONE with getting 2_artist
# artist_file
# ID3TAGS    9
# Name: count, dtype: int64
# Writing AIFF files for artist: 100%|███████████████████████████████████████████| 9/9 [00:00<00:00, 708.10it/s]
# Total files processed for artist: 9
# Extracting ID3 Labels: 100%|██████████████████████████████████████████████████| 9/9 [00:00<00:00, 1643.61it/s]
# DONE with getting 3_LABEL
# label_file
# ID3TAGS    9
# Name: count, dtype: int64
# Extracting ID3 Genres: 100%|██████████████████████████████████████████████████| 9/9 [00:00<00:00, 2267.06it/s]
# DONE with getting 4_genre
# genre_file
# ID3TAGS    9
# Name: count, dtype: int64
# Extracting ID3 Release Year: 100%|████████████████████████████████████████████| 9/9 [00:00<00:00, 1825.90it/s]
# DONE with getting 5_release_year
# rel_year_file
# FILE_NAME    9
# Name: count, dtype: int64
# Extracting ID3 Key: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 1203.07it/s]
# DONE with getting 6_KEY
# key_file
# ID3TAGS    9
# Name: count, dtype: int64
# DONE with getting 7_mix_name & 8_remixer
#   0%|          | 0/9 [00:00<?, ?it/s]
# DONE with getting 9_date_purchased
# Writtng AIFF files for : remixer:   0%|          | 0/9 [00:00<?, ?it/s]
# DONE with WRITTING 7_mix_name & 8_remixer : to ID3TAG remixer
# Writtng AIFF files for : genre: 0it [00:00, ?it/s]
# Total files processed: 0
# DONE with WRITTING 4_genre : to ID3TAG genre
# Writtng AIFF files for : label: 0it [00:00, ?it/s]
# Total files processed for label: 0
# DONE with WRITTING 3_LABEL : to ID3TAG LABEL
# Extracting ID3 Release Date:   0%|          | 0/9 [00:00<?, ?it/s]
# Writing AIFF files for: release date:   0%|          | 0/9 [00:00<?, ?it/s]
# Total files processed for release date: 9
#   0%|          | 0/9 [00:00<?, ?it/s]
# Processing keys:   0%|          | 0/9 [00:00<?, ?it/s]
# Processing keys:   0%|          | 0/9 [00:00<?, ?it/s]
# Writing AIFF files for comment:   0%|          | 0/9 [00:00<?, ?it/s]
# Total files processed for comment: 9
# DOoooooooooooo
#
#
#
#
#
#
# ne...

# %%
#df = df.head(20)
    
    # Save the selected DataFrame portion to a pickle file
#
#df.to_pickle("all_df.pkl")
df#.head(1)
# Out:
#                                                                                                                                                                                                                                                                     Path                                                                                                                                                                                       temp_id                                                                                                                                                                                          file_name Extension dur_seconds   dur_min     sr bit_depth bit_rate channels file_size file_size_human num_frames error  ms_lufs ms_LUFS_code id_cat_lufs    mean_bpm       std_bpm     min_bpm     max_bpm  variation_percentage  dominant_bpm  bpm_consistency bpm_consistency_cat              title title_file                     artist artist_file  \
# 0                      /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.aiff                      TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07                      TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.aiff     .aiff      341.76     5.696  44100        16     None        2  60287580        57.49 MB   15071616  None   -7.684          LuF           W  125.982776  4.376583e-01  123.046875  126.048018          3.473953e-01           126        97.826087                 D_1            Work It    ID3TAGS  Kevin McKay Milos Pesovic     ID3TAGS
# 1                                  /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.aiff                                  TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07                                  TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.aiff     .aiff       112.0  1.866667  44100        16     None        2  19757916        18.84 MB    4939200  None   -9.882          LuF           U  120.185320  2.842171e-14  120.185320  120.185320          2.364824e-14           120       100.000000                 D_0     London Grammar    ID3TAGS                Tube Velvet     ID3TAGS
# 2                                   /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.aiff                                   TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07                                   TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.aiff     .aiff  405.853673  6.764228  44100        16     None        2  71593704        68.28 MB   17898147  None  -11.964          Lue           T  123.281677  6.219802e+00   97.508844  161.499023          5.045196e+00           123        96.363636                 D_1          Tesseract    ID3TAGS               Pablo Fierro     ID3TAGS
# 3  /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.aiff  TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07  TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.aiff     .aiff  432.360998  7.206017  44100        16     None        2  76269596        72.74 MB   19067120  None  -11.163          Lue           T  120.185320  2.842171e-14  120.185320  120.185320          2.364824e-14           120       100.000000                 D_0  Never Sleep Again    ID3TAGS                    Solomun     ID3TAGS
# 4                                                  /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.aiff                                                  TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07                                                  TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.aiff     .aiff  405.966327  6.766105  44100        16     None        2  71613576        68.30 MB   17903115  None  -10.570          Lue           U  123.046875  0.000000e+00  123.046875  123.046875          0.000000e+00           123       100.000000                 D_0         Booom Shak    ID3TAGS                 Rene Amesz     ID3TAGS
# 5                                                /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.aiff                                                TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07                                                TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.aiff     .aiff  168.755646  2.812594  44100        16     None        2  29769612        28.39 MB    7442124  None   -9.900          LuF           U   97.421773  1.761155e+01   87.592691  156.605114          1.807763e+01            88        63.636364                 D_6     Ta Que Tiembla    ID3TAGS                 Buscabulla     ID3TAGS
# 6                                                    /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.aiff                                                    TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07                                                    TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.aiff     .aiff  312.195125  5.203252  44100        16     None        2  55072336        52.52 MB   13767805  None   -9.661          LuF           V  123.046875  0.000000e+00  123.046875  123.046875          0.000000e+00           123       100.000000                 D_0         Dancing To    ID3TAGS              Kurd Maverick     ID3TAGS
# 7                                                 /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.aiff                                                 TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07                                                 TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.aiff     .aiff  359.211542  5.986859  44100        16     None        2  63366032        60.43 MB   15841229  None  -10.595          Lue           U  123.108123  4.243374e-01  123.046875  126.048018          3.446867e-01           123        97.959184                 D_1           Camaleon    ID3TAGS               Pablo Fierro     ID3TAGS
# 8                                     /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.aiff                                     TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07                                     TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.aiff     .aiff  401.812018  6.696867  44100        16     None        2  70880756        67.60 MB   17719910  None  -11.795          Lue           T  123.101441  4.009783e-01  123.046875  126.048018          3.257300e-01           123        98.181818                 D_0      Reincarnation    ID3TAGS               Pablo Fierro     ID3TAGS
#
#                  LABEL label_file                    genre genre_file rel_year rel_year_file    KEY key_file           mix_name                                             remixer remix date_purchased    rel_date rel_date_file key_dj key_music                 status Relative_Key Key_Up Key_Down Jaw_s_Mix Mood_Shifter          ID           comment                                                        audio_hash
# 0  Glasgow Underground    ID3TAGS              Tech House     ID3TAGS     None     FILE_NAME   Gmaj  ID3TAGS  Extended_Club_Mix                                   Extended Club Mix     U     2023-05-07  2020-10-23       ID3TAGS     9B      Gmaj  Success: TKEY updated           9A    10B       8B        4B           6A  dy1Fw_wK60   dy1Fw_wK60_Gmaj  28e5310f24787b20cabc7dd4823a908acf63b251bf0e4ec571f5fe12a17cb35c
# 1               PRYZMA    ID3TAGS              Tech House     ID3TAGS     None     FILE_NAME   Cmin  ID3TAGS       Original_Mix                           Original Mix Weekend Mode     U     2023-05-07  2021-11-22       ID3TAGS     5A      Cmin  Success: TKEY updated           5B     6A       4A       12A           8B  dy0Fu_lT19   dy0Fu_lT19_Cmin  b148225dfaf2dc923c2f585df0358b34bcf3cd7766c7beeb31d307ea5280dfb2
# 2           WE RE HERE    ID3TAGS  Melodic House & Techno     ID3TAGS     None     FILE_NAME  A#maj  ID3TAGS       Original_Mix                                        Original Mix     U     2023-05-07  2022-06-10       ID3TAGS     6B     A#maj  Success: TKEY updated           6A     7B       5B        1B           3A  dy1Et_tP71  dy1Et_tP71_A#maj  2a7f87d937bc6a9d621b7cb022e8b8ab73f4ccf5b9b2d9f1390b71dc37c46747
# 3                 NINL    ID3TAGS  Melodic House & Techno     ID3TAGS     None     FILE_NAME   Cmaj  ID3TAGS   Keinemusik_Remix  Keinemusik Remix &ME, Rampa, Adam Port, Keinemusik     R     2023-05-07  2022-06-10       ID3TAGS     8B      Cmaj  Success: TKEY updated           8A     9B       7B        3B           5A  dy0Et_nS76   dy0Et_nS76_Cmaj  75cc896698d83a0e642e0d36bd0a3358e1186f4688ae85de37460a0a4354edf9
# 4       Armada Subjekt    ID3TAGS                   House     ID3TAGS     None     FILE_NAME   Fmaj  ID3TAGS       Extended_Mix                                        Extended Mix     U     2023-05-07  2017-12-04       ID3TAGS     7B      Fmaj  Success: TKEY updated           7A     8B       6B        2B           4A  dy0Eu_bR71   dy0Eu_bR71_Fmaj  bca590151c2473acfa704c1801ad3314efcaedf9f5afb3d80095eaf2ebdf1f6b
# 5         Ribbon Music    ID3TAGS                   House     ID3TAGS     None     FILE_NAME   Gmin  ID3TAGS       Original_Mix                                        Original Mix     U     2023-05-07  2020-05-08       ID3TAGS     6A      Gmin  Success: TKEY updated           6B     7A       5A        1A           9B  dy6Fu_tB29   dy6Fu_tB29_Gmin  8ea40f1a002b80c2fa8b085003a1c2f658e5ef38975d2eb92874b5fba2364fa5
# 6             Toolroom    ID3TAGS                   House     ID3TAGS     None     FILE_NAME   Fmin  ID3TAGS       Extended_Mix                                        Extended Mix     U     2023-05-07  2020-12-18       ID3TAGS     4A      Fmin  Success: TKEY updated           4B     5A       3A       11A           7B  dy0Fv_dK55   dy0Fv_dK55_Fmin  148ee39f859988efa3c1cf15a5f50ed5315980a42d0051ea79da3f69a9e11c71
# 7           WE RE HERE    ID3TAGS              Afro House     ID3TAGS     None     FILE_NAME   Dmin  ID3TAGS       Original_Mix                                        Original Mix     U     2023-05-07  2022-06-24       ID3TAGS     7A      Dmin  Success: TKEY updated           7B     8A       6A        2A          10B  dy1Eu_cP63   dy1Eu_cP63_Dmin  42e2a0eefdac0fad403cf2325276e702870fb54a7b9cff918ce5ddc61968b2ef
# 8    Watergate Records    ID3TAGS              Afro House     ID3TAGS     None     FILE_NAME   Emin  ID3TAGS       Original_Mix                                        Original Mix     U     2023-05-07  2020-11-30       ID3TAGS     9A      Emin  Success: TKEY updated           9B    10A       8A        4A          12B  dy0Et_rP70   dy0Et_rP70_Emin  bcfd855f359048155a0ff65e5f406eee2a8cf2bf74bdf98d34c89b570efb4065

# %% [markdown]
# # COVER IMAGE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random, string

direc_jpg = 'images/'
exec(open("_cover_fns.py",encoding="utf-8").read())
##### get df
#df = pd.read_pickle("df_cover.pkl")
# id
#df['ID'] = [''.join(random.choices(string.ascii_uppercase, k=2)) + ''.join(random.choices(string.digits, k=2)) for _ in range(len(df))]  # TQM: |████████████████████|
df.head(1)
print(len(df))
# Out:
# 9

# %%
###### create KEY plot chamelot map 
key_plot()
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
# Minimal execution code: Set the directory with your PNG images and call the function.
input_directory = direc_jpg
output_folder = direc_jpg# Directory containing the PNG images that need processing

# Call the function to process and overwrite the images in the same folder.
_png_2409_wbrem_GET_overwrite_imgs(input_directory, tolerance=200)
# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None)
# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None)
# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None) # three times to make picture small
# Out:
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# TQM: Processed and overwritten image images/key_plotdy0Fu_lT19.png
# TQM: Processed and overwritten image images/key_plotdy1Fw_wK60.png
# TQM: Processed and overwritten image images/key_plotdy0Et_rP70.png
# TQM: Processed and overwritten image images/key_plotdy0Et_nS76.png
# TQM: Processed and overwritten image images/key_plotdy1Eu_cP63.png
# TQM: Processed and overwritten image images/key_plotdy0Eu_bR71.png
# TQM: Processed and overwritten image images/key_plotdy6Fu_tB29.png
# TQM: Processed and overwritten image images/key_plotdy0Fv_dK55.png
# TQM: Processed and overwritten image images/key_plotdy1Et_tP71.png
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy1Fw_wK60 saved as images/cover_1_dy1Fw_wK60.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fu_lT19 saved as images/cover_1_dy0Fu_lT19.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy1Et_tP71 saved as images/cover_1_dy1Et_tP71.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_nS76 saved as images/cover_1_dy0Et_nS76.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Eu_bR71 saved as images/cover_1_dy0Eu_bR71.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy6Fu_tB29 saved as images/cover_1_dy6Fu_tB29.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fv_dK55 saved as images/cover_1_dy0Fv_dK55.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy1Eu_cP63 saved as images/cover_1_dy1Eu_cP63.jpg
# No cover found. Generated a black square image.
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_rP70 saved as images/cover_1_dy0Et_rP70.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy1Fw_wK60 saved as images/cover_1_dy1Fw_wK60.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fu_lT19 saved as images/cover_1_dy0Fu_lT19.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy1Et_tP71 saved as images/cover_1_dy1Et_tP71.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_nS76 saved as images/cover_1_dy0Et_nS76.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Eu_bR71 saved as images/cover_1_dy0Eu_bR71.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy6Fu_tB29 saved as images/cover_1_dy6Fu_tB29.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fv_dK55 saved as images/cover_1_dy0Fv_dK55.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy1Eu_cP63 saved as images/cover_1_dy1Eu_cP63.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_rP70 saved as images/cover_1_dy0Et_rP70.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy1Fw_wK60 saved as images/cover_1_dy1Fw_wK60.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fu_lT19 saved as images/cover_1_dy0Fu_lT19.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy1Et_tP71 saved as images/cover_1_dy1Et_tP71.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_nS76 saved as images/cover_1_dy0Et_nS76.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Eu_bR71 saved as images/cover_1_dy0Eu_bR71.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy6Fu_tB29 saved as images/cover_1_dy6Fu_tB29.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fv_dK55 saved as images/cover_1_dy0Fv_dK55.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy1Eu_cP63 saved as images/cover_1_dy1Eu_cP63.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_rP70 saved as images/cover_1_dy0Et_rP70.jpg

# %%
# create new IDs
df['Path_jpg_album'] = f'{direc_jpg}' + 'cover_1_' + df['ID'] + '.jpg'
df['Path_jpg_key'] = f'{direc_jpg}' + 'key_plot' + df['ID'] + '.png'

###########################
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!


# Use the 'dominant_bpm' column for the text overlay:
_img_2409_process_df_coverart_GET_output(
    df,
    circle_size_ratio=0.25,         # Increase the size of the circle relative to the image size
    position="top-left",         # Change the position of the circle
    circle_color=(0, 0, 0, 255),    # Use a red circle
    text_color=(0, 255, 25, 255),      # Use a green color for the text
    text_scale=0.5,                 # Adjust the text scale
    text_column="dominant_bpm"      # Use the dominant BPM as text
)

# Example using a different column (e.g., 'artist_name'):
# _img_2409_process_df_coverart_GET_output(
#     df,
#     circle_size_ratio=0.25,
#     position="bottom-left",
#     circle_color=(255, 0, 0, 255),
#     text_color=(0, 255, 0, 255),
#     text_scale=0.7,
#     text_column="artist_name"      # Now the overlay will show the artist name
# )



#Example with no text overlay:
_img_2409_process_df_coverart_GET_output(
    df,
    circle_size_ratio=0.33,
    position="top-right",
    circle_color=(255, 255, 255, 255),
    text_color=(0, 255, 25, 255),
    text_scale=0.5,
    text_column=None               # Passing None will result in no text being drawn
)

#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#! FOR KEY overly 


# Process each row in the DataFrame by overlaying the key image onto the album cover.
_img_2409_overlay_df_key_GET_output(
    df,
    resize_factor=0.265,         # Adjust as needed to scale the overlay image
    position_right_cm=-0.232,    # Distance from the right edge in cm
    position_top_cm=-0.59,       # Distance from the top edge in cm
    dpi=300                      # DPI used for conversion from cm to pixels
)


# Process the DataFrame: for each row, the overlay function uses the LUFS code from 'ms_LUFS_code'
_overlay_df_circle_custom_0501_GET_image(
    df,
    circle_position=(-0.379, -1.2098003),  # Custom fractional position
    circle_diameter=2755,                  # Custom circle diameter in pixels
    ms_LUFS_column='ms_LUFS_code'           # Column from which to take the LUFS code
)

########### cliping graph 
_audio_2409_i2_GET_generate_clipping_plots(df,save_directory="images")
df['Path_jpg_clip'] = f'{direc_jpg}' + 'clip_plot' + df['ID'] + '.jpg'
# embed freq to pic 
_img_2409_i3_GET_embed_clipping_on_album(df)
# Out:
# Processing Cover Art:  56%|█████████████████████████████▍                       | 5/9 [00:00<00:00, 21.88it/s]
# Processed cover image saved at images/cover_1_dy1Fw_wK60.jpg
# Processed cover image saved at images/cover_1_dy0Fu_lT19.jpg
# Processed cover image saved at images/cover_1_dy1Et_tP71.jpg
# Processed cover image saved at images/cover_1_dy0Et_nS76.jpg
# Processed cover image saved at images/cover_1_dy0Eu_bR71.jpg
# Processing Cover Art: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 23.34it/s]
# Processed cover image saved at images/cover_1_dy6Fu_tB29.jpg
# Processed cover image saved at images/cover_1_dy0Fv_dK55.jpg
# Processed cover image saved at images/cover_1_dy1Eu_cP63.jpg
# Processed cover image saved at images/cover_1_dy0Et_rP70.jpg
# Processing Cover Art:   0%|                                                             | 0/9 [00:00<?, ?it/s]
# Processed cover image saved at images/cover_1_dy1Fw_wK60.jpg
# Processed cover image saved at images/cover_1_dy0Fu_lT19.jpg
# Processed cover image saved at images/cover_1_dy1Et_tP71.jpg
# Processed cover image saved at images/cover_1_dy0Et_nS76.jpg
# Processed cover image saved at images/cover_1_dy0Eu_bR71.jpg
# Processed cover image saved at images/cover_1_dy6Fu_tB29.jpg
# Processed cover image saved at images/cover_1_dy0Fv_dK55.jpg
# Processed cover image saved at images/cover_1_dy1Eu_cP63.jpg
# Processing Cover Art: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 93.89it/s]
# Processed cover image saved at images/cover_1_dy0Et_rP70.jpg
# Overlaying Key Images:   0%|                                                            | 0/9 [00:00<?, ?it/s]
# Overlay applied and saved for album at images/cover_1_dy1Fw_wK60.jpg
# Overlaying Key Images:  22%|███████████▌                                        | 2/9 [00:00<00:00, 15.73it/s]
# Overlay applied and saved for album at images/cover_1_dy0Fu_lT19.jpg
# Overlay applied and saved for album at images/cover_1_dy1Et_tP71.jpg
# Overlaying Key Images:  44%|███████████████████████                             | 4/9 [00:00<00:00, 15.79it/s]
# Overlay applied and saved for album at images/cover_1_dy0Et_nS76.jpg
# Overlay applied and saved for album at images/cover_1_dy0Eu_bR71.jpg
# Overlaying Key Images:  67%|██████████████████████████████████▋                 | 6/9 [00:00<00:00, 15.89it/s]
# Overlay applied and saved for album at images/cover_1_dy6Fu_tB29.jpg
# Overlay applied and saved for album at images/cover_1_dy0Fv_dK55.jpg
# Overlaying Key Images:  89%|██████████████████████████████████████████████▏     | 8/9 [00:00<00:00, 16.03it/s]
# Overlay applied and saved for album at images/cover_1_dy1Eu_cP63.jpg
# Overlaying Key Images: 100%|████████████████████████████████████████████████████| 9/9 [00:00<00:00, 16.00it/s]
# Overlay applied and saved for album at images/cover_1_dy0Et_rP70.jpg
# Overlaying LUFS Circles:   0%|                                                          | 0/9 [00:00<?, ?it/s]
# Overlay applied on image: images/cover_1_dy1Fw_wK60.jpg
# Overlay applied on image: images/cover_1_dy0Fu_lT19.jpg
# Overlaying LUFS Circles: 100%|█████████████████████████████████████████████████| 9/9 [00:00<00:00, 130.87it/s]
# Overlay applied on image: images/cover_1_dy1Et_tP71.jpg
# Overlay applied on image: images/cover_1_dy0Et_nS76.jpg
# Overlay applied on image: images/cover_1_dy0Eu_bR71.jpg
# Overlay applied on image: images/cover_1_dy6Fu_tB29.jpg
# Overlay applied on image: images/cover_1_dy0Fv_dK55.jpg
# Overlay applied on image: images/cover_1_dy1Eu_cP63.jpg
# Overlay applied on image: images/cover_1_dy0Et_rP70.jpg
# Generating clipping plots:   0%|                                                        | 0/9 [00:00<?, ?it/s]
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  11%|█████▎                                          | 1/9 [00:05<00:43,  5.42s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.aiff as images/clip_plotdy1Fw_wK60.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  22%|██████████▋                                     | 2/9 [00:07<00:23,  3.32s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.aiff as images/clip_plotdy0Fu_lT19.jpg
#
# Top Clipping Events (dBFS > 0.0):
#      Time (s)  Amplitude
# 0  341.513039  -0.999512
# Generating clipping plots:  33%|████████████████                                | 3/9 [00:13<00:28,  4.72s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.aiff as images/clip_plotdy1Et_tP71.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  44%|█████████████████████▎                          | 4/9 [00:20<00:28,  5.61s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.aiff as images/clip_plotdy0Et_nS76.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  56%|██████████████████████████▋                     | 5/9 [00:26<00:23,  5.87s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.aiff as images/clip_plotdy0Eu_bR71.jpg
#
# Top Clipping Events (dBFS > 0.0):
#      Time (s)  Amplitude
# 0   76.593243  -0.999893
# 1  124.523764  -0.999832
# 2   74.546599  -0.999771
# 3   39.773787  -0.999725
# Generating clipping plots:  67%|████████████████████████████████                | 6/9 [00:29<00:14,  4.82s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.aiff as images/clip_plotdy6Fu_tB29.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  78%|█████████████████████████████████████▎          | 7/9 [00:34<00:09,  4.89s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.aiff as images/clip_plotdy0Fv_dK55.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  89%|██████████████████████████████████████████▋     | 8/9 [00:40<00:05,  5.12s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.aiff as images/clip_plotdy1Eu_cP63.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots: 100%|████████████████████████████████████████████████| 9/9 [00:46<00:00,  5.17s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.aiff as images/clip_plotdy0Et_rP70.jpg
# Embedding clipping into album cover:   0%|                                              | 0/9 [00:00<?, ?it/s]<string>:890: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Embedding clipping into album cover:  22%|████████▍                             | 2/9 [00:00<00:00, 18.20it/s]
# Image saved to images/cover_1_dy1Fw_wK60.jpg
# Image saved to images/cover_1_dy0Fu_lT19.jpg
# Image saved to images/cover_1_dy1Et_tP71.jpg
# Embedding clipping into album cover:  44%|████████████████▉                     | 4/9 [00:00<00:00, 18.39it/s]
# Image saved to images/cover_1_dy0Et_nS76.jpg
# Embedding clipping into album cover:  67%|█████████████████████████▎            | 6/9 [00:00<00:00, 18.41it/s]
# Image saved to images/cover_1_dy0Eu_bR71.jpg
# Image saved to images/cover_1_dy6Fu_tB29.jpg
# Image saved to images/cover_1_dy0Fv_dK55.jpg
# Embedding clipping into album cover:  89%|█████████████████████████████████▊    | 8/9 [00:00<00:00, 18.51it/s]
# Image saved to images/cover_1_dy1Eu_cP63.jpg
# Embedding clipping into album cover: 100%|██████████████████████████████████████| 9/9 [00:00<00:00, 18.49it/s]
# Image saved to images/cover_1_dy0Et_rP70.jpg

# %% [markdown]
# # EMBED  to AIFF ____ LAST STEP

# %%
#_aiff_2409_i1_GET_embed_aiff_covers(df)

# %% [markdown]
# # dynamic BPM

# %%
# 0_FNS
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# ###########################################################################
# ########## CORE FUNCTION: _bpm_2610_i3_GET_partialdonut_bpmdynamic   ########
# ###########################################################################
def _bpm_2610_i3_GET_partialdonut_bpmdynamic(df: pd.DataFrame, save_dir: str = "images") -> None:
    """
    Iterates over the provided DataFrame and saves an individual PNG for each row.
    Each PNG contains a donut chart that illustrates the BPM dynamic percentage as 
    a colored wedge (based on 'bpm_consistency_cat') with the remainder of the circle transparent.
    
    The donut is only partially complete in reference to the provided percentage.
    The figure is saved as a PNG with a transparent background and no extra labels.
    
    The PNG files are saved using the value from the 'ID' column in the DataFrame.
    
    Parameters:
        df (pd.DataFrame): DataFrame with columns:
                           - 'bpm_consistency': numeric value between 0 and 100.
                           - 'bpm_consistency_cat': dynamic category label (e.g., 'D_0', 'D_1', 'D_3', 'D_6', 'D_9'),
                             with D_0 being least dynamic (yellow) and D_9 super dynamic (dark gray).
                           - 'ID': unique identifier for each row/song used for file naming.
        save_dir (str): Directory where the PNG images will be saved. Defaults to "images".
    """
    # Define a cohesive color mapping using a Material Design–inspired gradient.
    color_mapping = {
         'D_0': "#FFEB3B",  # Bright yellow (original)
    'D_1': "#E6D435",  # 90% brightness of D_0
    'D_3': "#CCBC2F",  # 80% brightness of D_0
    'D_6': "#998D23",  # 60% brightness of D_0
    'D_9': "#665E17"    # Near-black
    }
    
    # Ensure the save directory exists.
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    if not save_dir.endswith(os.sep):
        save_dir += os.sep

    # ------------------ TQM BAR: Starting donut generation with 50% thinner ring ------------------
    # Iterate over each row in the DataFrame.
    for _, row in df.iterrows():
        dynamic_value = row['bpm_consistency']  # Percentage value (0 to 100)
        dynamic_cat = row['bpm_consistency_cat']
        
        # Compute the segments: filled part equals dynamic percentage; remainder (to 100) is transparent.
        segments = [dynamic_value, 100 - dynamic_value]
        colors = [color_mapping.get(dynamic_cat, '#9E9E9E'), (0, 0, 0, 0)]
        
        # Create figure and axis.
        fig, ax = plt.subplots(figsize=(6, 6))
        ax.axis('off')  # Remove axes for a clean image.
        
        # Draw the donut chart using wedgeprops to create a hole in the center.
        # Updated wedge width to 0.15 (i.e., 50% thinner than the original 0.3)
        ax.pie(
            segments, 
            colors=colors, 
            startangle=90, 
            counterclock=False, 
            wedgeprops={'width': 0.15, 'edgecolor': 'none'}
        )
        
        # Use the value in the 'ID' column as the file name.
        file_name = f"{save_dir}bpm_bar_dyn_{row['ID']}.png"
        plt.savefig(file_name, bbox_inches='tight', pad_inches=0, transparent=True)
        plt.close(fig)
        print(f"Saved: {file_name}")
    # ------------------ TQM BAR: Donut generation completed ------------------
# ########## END OF CORE FUNCTION ###########################################
# ########## END OF CORE FUNCTION ###########################################
_bpm_2610_i3_GET_partialdonut_bpmdynamic(df, save_dir="images")
df['Path_png_bar_dyn'] = f'{direc_jpg}' + 'bpm_bar_dyn_' + df['ID'] + '.png'
df
# Out:
# Saved: images/bpm_bar_dyn_dy1Fw_wK60.png
# Saved: images/bpm_bar_dyn_dy0Fu_lT19.png
# Saved: images/bpm_bar_dyn_dy1Et_tP71.png
# Saved: images/bpm_bar_dyn_dy0Et_nS76.png
# Saved: images/bpm_bar_dyn_dy0Eu_bR71.png
# Saved: images/bpm_bar_dyn_dy6Fu_tB29.png
# Saved: images/bpm_bar_dyn_dy0Fv_dK55.png
# Saved: images/bpm_bar_dyn_dy1Eu_cP63.png
# Saved: images/bpm_bar_dyn_dy0Et_rP70.png
#                                                                                                                                                                                                                                                                     Path                                                                                                                                                                                       temp_id                                                                                                                                                                                          file_name Extension dur_seconds   dur_min     sr bit_depth bit_rate channels file_size file_size_human num_frames error  ms_lufs ms_LUFS_code id_cat_lufs    mean_bpm       std_bpm     min_bpm     max_bpm  variation_percentage  dominant_bpm  bpm_consistency bpm_consistency_cat              title title_file                     artist artist_file  \
# 0                      /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.aiff                      TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07                      TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.aiff     .aiff      341.76     5.696  44100        16     None        2  60287580        57.49 MB   15071616  None   -7.684          LuF           W  125.982776  4.376583e-01  123.046875  126.048018          3.473953e-01           126        97.826087                 D_1            Work It    ID3TAGS  Kevin McKay Milos Pesovic     ID3TAGS
# 1                                  /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.aiff                                  TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07                                  TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.aiff     .aiff       112.0  1.866667  44100        16     None        2  19757916        18.84 MB    4939200  None   -9.882          LuF           U  120.185320  2.842171e-14  120.185320  120.185320          2.364824e-14           120       100.000000                 D_0     London Grammar    ID3TAGS                Tube Velvet     ID3TAGS
# 2                                   /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.aiff                                   TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07                                   TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.aiff     .aiff  405.853673  6.764228  44100        16     None        2  71593704        68.28 MB   17898147  None  -11.964          Lue           T  123.281677  6.219802e+00   97.508844  161.499023          5.045196e+00           123        96.363636                 D_1          Tesseract    ID3TAGS               Pablo Fierro     ID3TAGS
# 3  /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.aiff  TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07  TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.aiff     .aiff  432.360998  7.206017  44100        16     None        2  76269596        72.74 MB   19067120  None  -11.163          Lue           T  120.185320  2.842171e-14  120.185320  120.185320          2.364824e-14           120       100.000000                 D_0  Never Sleep Again    ID3TAGS                    Solomun     ID3TAGS
# 4                                                  /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.aiff                                                  TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07                                                  TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.aiff     .aiff  405.966327  6.766105  44100        16     None        2  71613576        68.30 MB   17903115  None  -10.570          Lue           U  123.046875  0.000000e+00  123.046875  123.046875          0.000000e+00           123       100.000000                 D_0         Booom Shak    ID3TAGS                 Rene Amesz     ID3TAGS
# 5                                                /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.aiff                                                TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07                                                TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.aiff     .aiff  168.755646  2.812594  44100        16     None        2  29769612        28.39 MB    7442124  None   -9.900          LuF           U   97.421773  1.761155e+01   87.592691  156.605114          1.807763e+01            88        63.636364                 D_6     Ta Que Tiembla    ID3TAGS                 Buscabulla     ID3TAGS
# 6                                                    /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.aiff                                                    TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07                                                    TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.aiff     .aiff  312.195125  5.203252  44100        16     None        2  55072336        52.52 MB   13767805  None   -9.661          LuF           V  123.046875  0.000000e+00  123.046875  123.046875          0.000000e+00           123       100.000000                 D_0         Dancing To    ID3TAGS              Kurd Maverick     ID3TAGS
# 7                                                 /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.aiff                                                 TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07                                                 TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.aiff     .aiff  359.211542  5.986859  44100        16     None        2  63366032        60.43 MB   15841229  None  -10.595          Lue           U  123.108123  4.243374e-01  123.046875  126.048018          3.446867e-01           123        97.959184                 D_1           Camaleon    ID3TAGS               Pablo Fierro     ID3TAGS
# 8                                     /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.aiff                                     TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07                                     TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.aiff     .aiff  401.812018  6.696867  44100        16     None        2  70880756        67.60 MB   17719910  None  -11.795          Lue           T  123.101441  4.009783e-01  123.046875  126.048018          3.257300e-01           123        98.181818                 D_0      Reincarnation    ID3TAGS               Pablo Fierro     ID3TAGS
#
#                  LABEL label_file                    genre genre_file rel_year rel_year_file    KEY key_file           mix_name                                             remixer remix date_purchased    rel_date rel_date_file key_dj key_music                 status Relative_Key Key_Up Key_Down Jaw_s_Mix Mood_Shifter          ID           comment                                                        audio_hash                 Path_jpg_album                   Path_jpg_key                   Path_jpg_clip                   Path_png_bar_dyn
# 0  Glasgow Underground    ID3TAGS              Tech House     ID3TAGS     None     FILE_NAME   Gmaj  ID3TAGS  Extended_Club_Mix                                   Extended Club Mix     U     2023-05-07  2020-10-23       ID3TAGS     9B      Gmaj  Success: TKEY updated           9A    10B       8B        4B           6A  dy1Fw_wK60   dy1Fw_wK60_Gmaj  28e5310f24787b20cabc7dd4823a908acf63b251bf0e4ec571f5fe12a17cb35c  images/cover_1_dy1Fw_wK60.jpg  images/key_plotdy1Fw_wK60.png  images/clip_plotdy1Fw_wK60.jpg  images/bpm_bar_dyn_dy1Fw_wK60.png
# 1               PRYZMA    ID3TAGS              Tech House     ID3TAGS     None     FILE_NAME   Cmin  ID3TAGS       Original_Mix                           Original Mix Weekend Mode     U     2023-05-07  2021-11-22       ID3TAGS     5A      Cmin  Success: TKEY updated           5B     6A       4A       12A           8B  dy0Fu_lT19   dy0Fu_lT19_Cmin  b148225dfaf2dc923c2f585df0358b34bcf3cd7766c7beeb31d307ea5280dfb2  images/cover_1_dy0Fu_lT19.jpg  images/key_plotdy0Fu_lT19.png  images/clip_plotdy0Fu_lT19.jpg  images/bpm_bar_dyn_dy0Fu_lT19.png
# 2           WE RE HERE    ID3TAGS  Melodic House & Techno     ID3TAGS     None     FILE_NAME  A#maj  ID3TAGS       Original_Mix                                        Original Mix     U     2023-05-07  2022-06-10       ID3TAGS     6B     A#maj  Success: TKEY updated           6A     7B       5B        1B           3A  dy1Et_tP71  dy1Et_tP71_A#maj  2a7f87d937bc6a9d621b7cb022e8b8ab73f4ccf5b9b2d9f1390b71dc37c46747  images/cover_1_dy1Et_tP71.jpg  images/key_plotdy1Et_tP71.png  images/clip_plotdy1Et_tP71.jpg  images/bpm_bar_dyn_dy1Et_tP71.png
# 3                 NINL    ID3TAGS  Melodic House & Techno     ID3TAGS     None     FILE_NAME   Cmaj  ID3TAGS   Keinemusik_Remix  Keinemusik Remix &ME, Rampa, Adam Port, Keinemusik     R     2023-05-07  2022-06-10       ID3TAGS     8B      Cmaj  Success: TKEY updated           8A     9B       7B        3B           5A  dy0Et_nS76   dy0Et_nS76_Cmaj  75cc896698d83a0e642e0d36bd0a3358e1186f4688ae85de37460a0a4354edf9  images/cover_1_dy0Et_nS76.jpg  images/key_plotdy0Et_nS76.png  images/clip_plotdy0Et_nS76.jpg  images/bpm_bar_dyn_dy0Et_nS76.png
# 4       Armada Subjekt    ID3TAGS                   House     ID3TAGS     None     FILE_NAME   Fmaj  ID3TAGS       Extended_Mix                                        Extended Mix     U     2023-05-07  2017-12-04       ID3TAGS     7B      Fmaj  Success: TKEY updated           7A     8B       6B        2B           4A  dy0Eu_bR71   dy0Eu_bR71_Fmaj  bca590151c2473acfa704c1801ad3314efcaedf9f5afb3d80095eaf2ebdf1f6b  images/cover_1_dy0Eu_bR71.jpg  images/key_plotdy0Eu_bR71.png  images/clip_plotdy0Eu_bR71.jpg  images/bpm_bar_dyn_dy0Eu_bR71.png
# 5         Ribbon Music    ID3TAGS                   House     ID3TAGS     None     FILE_NAME   Gmin  ID3TAGS       Original_Mix                                        Original Mix     U     2023-05-07  2020-05-08       ID3TAGS     6A      Gmin  Success: TKEY updated           6B     7A       5A        1A           9B  dy6Fu_tB29   dy6Fu_tB29_Gmin  8ea40f1a002b80c2fa8b085003a1c2f658e5ef38975d2eb92874b5fba2364fa5  images/cover_1_dy6Fu_tB29.jpg  images/key_plotdy6Fu_tB29.png  images/clip_plotdy6Fu_tB29.jpg  images/bpm_bar_dyn_dy6Fu_tB29.png
# 6             Toolroom    ID3TAGS                   House     ID3TAGS     None     FILE_NAME   Fmin  ID3TAGS       Extended_Mix                                        Extended Mix     U     2023-05-07  2020-12-18       ID3TAGS     4A      Fmin  Success: TKEY updated           4B     5A       3A       11A           7B  dy0Fv_dK55   dy0Fv_dK55_Fmin  148ee39f859988efa3c1cf15a5f50ed5315980a42d0051ea79da3f69a9e11c71  images/cover_1_dy0Fv_dK55.jpg  images/key_plotdy0Fv_dK55.png  images/clip_plotdy0Fv_dK55.jpg  images/bpm_bar_dyn_dy0Fv_dK55.png
# 7           WE RE HERE    ID3TAGS              Afro House     ID3TAGS     None     FILE_NAME   Dmin  ID3TAGS       Original_Mix                                        Original Mix     U     2023-05-07  2022-06-24       ID3TAGS     7A      Dmin  Success: TKEY updated           7B     8A       6A        2A          10B  dy1Eu_cP63   dy1Eu_cP63_Dmin  42e2a0eefdac0fad403cf2325276e702870fb54a7b9cff918ce5ddc61968b2ef  images/cover_1_dy1Eu_cP63.jpg  images/key_plotdy1Eu_cP63.png  images/clip_plotdy1Eu_cP63.jpg  images/bpm_bar_dyn_dy1Eu_cP63.png
# 8    Watergate Records    ID3TAGS              Afro House     ID3TAGS     None     FILE_NAME   Emin  ID3TAGS       Original_Mix                                        Original Mix     U     2023-05-07  2020-11-30       ID3TAGS     9A      Emin  Success: TKEY updated           9B    10A       8A        4A          12B  dy0Et_rP70   dy0Et_rP70_Emin  bcfd855f359048155a0ff65e5f406eee2a8cf2bf74bdf98d34c89b570efb4065  images/cover_1_dy0Et_rP70.jpg  images/key_plotdy0Et_rP70.png  images/clip_plotdy0Et_rP70.jpg  images/bpm_bar_dyn_dy0Et_rP70.png

# %%
# 0_FNS
import os
from PIL import Image
import pandas as pd

# ###########################################################################
# ########## CORE FUNCTION: _bpm_2610_i4_GET_embedded_album_dynamic_custom ########
# ###########################################################################
def _bpm_2610_i4_GET_embedded_album_dynamic_custom(
    df: pd.DataFrame,
    position: str = "top_left",
    x_offset: int = 10,
    y_offset: int = 10,
    scale: float = 1.0,
    custom_coords: tuple = None
) -> None:
    """
    Overlays each dynamic (donut) PNG image onto its corresponding album JPG image
    and saves the composite by overwriting the original album file (keeping the same file name).
    
    For each row in the DataFrame, the function:
      - Opens the album image from 'Path_jpg_album'.
      - Opens the dynamic overlay image from 'Path_png_bar_dyn'.
      - Optionally rescales the overlay image using the scale factor.
      - Determines placement based on the provided 'position' parameter and separate
        'x_offset' and 'y_offset' values:
          * For "top_left": shifts right by x_offset and downward by y_offset.
          * For "top_right": shifts left by x_offset and downward by y_offset.
          * For "bottom_left": shifts right by x_offset and upward by y_offset.
          * For "bottom_right": shifts left by x_offset and upward by y_offset.
          * For "custom": exact coordinates must be provided in custom_coords.
      - Pastes the overlay onto the album image using its alpha channel.
      - Saves the composite image over the original album JPG (preserving its file name).
    
    Parameters:
        df (pd.DataFrame): DataFrame containing:
            - 'ID': Unique identifier.
            - 'Path_png_bar_dyn': File path to the dynamic overlay PNG image.
            - 'Path_jpg_album': File path to the album JPG image (and destination for the composite).
        position (str): Anchor position for the overlay relative to the album image.
                        Options: "top_left", "top_right", "bottom_left", "bottom_right", "custom".
                        Default is "top_left".
        x_offset (int): Horizontal offset (in pixels) from the anchor position.
                        For "top_left" and "bottom_left", positive values shift the overlay right.
                        For "top_right" and "bottom_right", positive values shift the overlay left.
        y_offset (int): Vertical offset (in pixels) from the anchor position.
                        For "top_left" and "top_right", positive values shift the overlay downward.
                        For "bottom_left" and "bottom_right", positive values shift the overlay upward.
        scale (float): Scaling factor for the overlay image. Default is 1.0 (no scaling).
        custom_coords (tuple): If position is "custom", supply exact (x, y) coordinates.
    """
    for _, row in df.iterrows():
        album_path = row['Path_jpg_album']
        overlay_path = row['Path_png_bar_dyn']
        
        try:
            album_img = Image.open(album_path).convert("RGBA")
            overlay_img = Image.open(overlay_path).convert("RGBA")
        except Exception as e:
            print(f"Error opening images for ID {row['ID']}: {e}")
            continue
        
        # Apply scaling if the scale factor is not 1.0.
        if scale != 1.0:
            new_size = (int(overlay_img.width * scale), int(overlay_img.height * scale))
            overlay_img = overlay_img.resize(new_size, Image.ANTIALIAS)
        
        # Determine placement coordinates based on the selected position.
        if position == "top_left":
            x = x_offset
            y = y_offset
        elif position == "top_right":
            x = album_img.width - overlay_img.width - x_offset
            y = y_offset
        elif position == "bottom_left":
            x = x_offset
            y = album_img.height - overlay_img.height - y_offset
        elif position == "bottom_right":
            x = album_img.width - overlay_img.width - x_offset
            y = album_img.height - overlay_img.height - y_offset
        elif position == "custom":
            if custom_coords is None:
                raise ValueError("Custom coordinates must be provided when position is 'custom'.")
            else:
                x, y = custom_coords
        else:
            raise ValueError("Invalid position value. Choose from: top_left, top_right, bottom_left, bottom_right, custom.")
        
        # Paste the overlay image onto the album image with transparency.
        album_img.paste(overlay_img, (x, y), overlay_img)
        
        # Save the composite over the original album image (converting from RGBA to RGB).
        album_img.convert("RGB").save(album_path, "JPEG")
        print(f"Saved composite over album: {album_path}")
# ########## END OF CORE FUNCTION ###########################################

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
# With your DataFrame 'df' (which contains 'ID', 'Path_png_bar_dyn', and 'Path_jpg_album'),
# call the function to overlay the dynamic PNG onto the album JPG.
_bpm_2610_i4_GET_embedded_album_dynamic_custom(
    df,
    position="top_left",  # adjust as needed: "top_left", "top_right", "bottom_left", "bottom_right", "custom"
    x_offset=-1,          # horizontal offset: increase to move right (for top_left or bottom_left) or left (for top_right or bottom_right)
    y_offset=-8,          # vertical offset: increase to move down (for top positions) or up (for bottom positions)
    scale=.65             # adjust the scale if needed
    # custom_coords=(x, y) can be provided if position is "custom"
)
# Out:
# Saved composite over album: images/cover_1_dy1Fw_wK60.jpg
# Saved composite over album: images/cover_1_dy0Fu_lT19.jpg
# Saved composite over album: images/cover_1_dy1Et_tP71.jpg
# Saved composite over album: images/cover_1_dy0Et_nS76.jpg
# Saved composite over album: images/cover_1_dy0Eu_bR71.jpg
# Saved composite over album: images/cover_1_dy6Fu_tB29.jpg
# Saved composite over album: images/cover_1_dy0Fv_dK55.jpg
# Saved composite over album: images/cover_1_dy1Eu_cP63.jpg
# Saved composite over album: images/cover_1_dy0Et_rP70.jpg
# /var/folders/pp/n6z2gh0x56ngpvp6vx5ml9j00000gn/T/ipykernel_69190/2552276737.py:66: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   overlay_img = overlay_img.resize(new_size, Image.ANTIALIAS)

# %% [markdown]
# # EMBED

# %%
_aiff_2409_i1_GET_embed_aiff_covers(df)
# Out:
# Embedding covers: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 806.82it/s]
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Work_It_ARkw_Kevin_McKay,_Milos_Pesovic_MXkw_Extended_Club_Mix_KYkw_C_Major_BPkw_125_GNkw_Tech_House_RMkw__LBkw_Glasgow_Underground_RYkw_2020_10_23_PYkw_2023_05_07.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_London_Grammar_ARkw_Tube_&_Velvet_MXkw_Original_Mix_KYkw_C_Minor_BPkw_120_GNkw_Tech_House_RMkw_Weekend_Mode_LBkw_PRYZMA_RYkw_2021_11_22_PYkw_2023_05_07.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Tesseract_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_Bb_Major_BPkw_123_GNkw_Melodic_House_&_Techno_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_10_PYkw_2023_05_07.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Never_Sleep_Again_ARkw_Solomun_MXkw_Keinemusik_Remix_KYkw_G_Minor_BPkw_120_GNkw_Melodic_House_&_Techno_RMkw_&ME,_Rampa,_Adam_Port,_Keinemusik_LBkw_NINL_RYkw_2022_06_10_PYkw_2023_05_07.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Booom_Shak_ARkw_Rene_Amesz_MXkw_Extended_Mix_KYkw_F_Major_BPkw_123_GNkw_House_RMkw__LBkw_Armada_Subjekt_RYkw_2017_12_04_PYkw_2023_05_07.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Ta_Que_Tiembla_ARkw_Buscabulla_MXkw_Original_Mix_KYkw_G#_Minor_BPkw_88_GNkw_House_RMkw__LBkw_Ribbon_Music_RYkw_2020_05_08_PYkw_2023_05_07.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Dancing_To_ARkw_Kurd_Maverick_MXkw_Extended_Mix_KYkw_A#_Minor_BPkw_123_GNkw_House_RMkw__LBkw_Toolroom_RYkw_2020_12_18_PYkw_2023_05_07.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Camaleon_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_F_Major_BPkw_123_GNkw_Afro_House_RMkw__LBkw_WE_RE_HERE_RYkw_2022_06_24_PYkw_2023_05_07.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2023_this/_23_04_Foundation_Hotel/TRkw_Reincarnation_ARkw_Pablo_Fierro_MXkw_Original_Mix_KYkw_A_Minor_BPkw_124_GNkw_Afro_House_RMkw__LBkw_Watergate_Records_RYkw_2020_11_30_PYkw_2023_05_07.aiff

# %%
# last step rename 
df['re_name'] = ( df['ID'] +'_'
                 +'BY_'+ df['artist'].astype(str).str[:5]
                 +'_'+df['title'].astype(str).str[:9]
                 +'_'+ df['remix'].astype(str))
####
##
#
_rename_aiff_files_bulk(df)
# Out:
# Renaming AIFF files: 100%|████████████████████████████████████████████████████| 9/9 [00:00<00:00, 8093.64it/s]
# Total files renamed: 9
# 9
