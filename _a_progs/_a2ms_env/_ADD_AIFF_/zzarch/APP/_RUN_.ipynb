# %%
exec(open("run.py",encoding="utf-8").read())
# Out:
# <string>:209: DeprecationWarning: 'aifc' is deprecated and slated for removal in Python 3.13
#    Sample Rate (Hz)  Bit Depth  Count
# 0             44100         16     68
#
# ALL AIFF in correct format -> if something changes go erase the already downsized
# ENTER to analyze
# Searching for Files: 100%|██████████████████████████████████████████████| 75/75 [00:00<00:00, 10225.02files/s]
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: /Users/yerik/Music/_1_NEW_SOURCE/_2025_this
# ***df*** will be returned having ::: 68  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 3920.450
# Grand Total Size in Bytes: 4110889990.000
# Grand Total Size in GB: 3.829
#
#  FREQUENCY TABLE:::
#
#   Extension  frequency  total_size_in_mb
# 0     .aiff         68       3920.450201
# Processing Audio Files: 100%|███████████████████████████████████████████████| 68/68 [00:00<00:00, 2446.12it/s]

# %%
df
# Out:
#                                                  Path  \
# 0   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 1   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 2   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 3   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 4   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# ..                                                ...
# 63  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 64  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 65  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 66  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
# 67  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/__...
#
#                                               temp_id  \
# 0   TRkw_Baila_Chabacana_ARkw_Colectivo_Miramar_MX...
# 1   TRkw_Que_Calor_Golfo_De_México_Mix_Bonus_ARkw...
# 2   TRkw_El_Poder_Del_Merengue_ARkw_Colectivo_Mira...
# 3   TRkw_Dulce__Sexy_y_Sensual_ARkw_Colectivo_Mira...
# ...
