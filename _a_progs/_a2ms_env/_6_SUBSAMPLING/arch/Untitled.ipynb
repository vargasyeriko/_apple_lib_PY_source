# %%
# In Jupyter / your test script:

from _0_fns import _kick_0911_i1_GET_kicks_from_loops

# Single mp3 path
mp3_path = "/Users/yerik/Downloads/__DRUM_SAMPLE_TEST/test.mp3"
exported_kicks = _kick_0911_i1_GET_kicks_from_loops(mp3_path)

# Or list of paths
# paths = ["/path/to/loop1.mp3", "/path/to/loop2.mp3"]
# exported_kicks = _kick_0911_i1_GET_kicks_from_loops(paths)

# Or df['Path'] if you already have a DataFrame in the notebook:
# exported_kicks = _kick_0911_i1_GET_kicks_from_loops(df['Path'])
# Out:
# TQM kick extract: 100%|███████████████████████████| 1/1 [00:00<00:00,  9.26it/s]
# [success] kick 01 exported -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_01.wav
# [success] kick 02 exported -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_02.wav
# [success] kick 03 exported -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_03.wav
# [success] kick 04 exported -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_04.wav
# [success] kick 05 exported -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_05.wav
# [success] kick 06 exported -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_06.wav
# [success] kick 07 exported -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_07.wav
# [success] kick 08 exported -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_08.wav
# [success] kick 09 exported -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_09.wav
# ...

# %%
from _0_fns_dashboard import _kick_0911_story_GET_dashboard_png

if __name__ == "__main__":
    kick_path = "/Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_01.wav"
    out_png = _kick_0911_story_GET_dashboard_png(kick_path)
    print(out_png)
# Out:
# [TQM] |#####-------------------------| 1/6 Checking file path...
# [TQM] |##########--------------------| 2/6 Loading audio...
# [TQM] |###############---------------| 3/6 Computing core stats...
# [TQM] |####################----------| 4/6 Analyzing spectrum...
# [TQM] |#########################-----| 5/6 Building spectrogram...
# [TQM] |##############################| 6/6 Rendering dashboard...
# [SUCCESS] Kick dashboard saved -> /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_01_kick_story.png
# /Users/yerik/Downloads/__DRUM_SAMPLE_TEST/_kicks/test_kick_01_kick_story.png
