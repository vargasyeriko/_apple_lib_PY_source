# %%
import pandas as pd
# Adjust settings to display all rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', 1000)  # Set a wide display width to fit the content
pd.set_option('display.max_colwidth', None)  # Show full column content without truncation

# %%
my_aiff  ='/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA'
#my_aiff ="/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy"#/_2025_this"#/test"
#my_aiff ="/Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover"

# %%
exec(open("run.py",encoding="utf-8").read())
# important 'bpm_consistency_cat','dominant_bpm',] D_0 being 100 in same BPM 
# #df['ID'] = df['bpm_consistency_cat'].str[1]  
# df['ID'] = ('dy' + df['bpm_consistency_cat'].str[2] 
#             + df['ms_LUFS_code'].str[2].str.upper() 
#             + df['id_cat_lufs'].str.lower() +'_'
#             + df['titile'].str[0].str.lower()
#             + df['artist'].str[0].str.upper()
#             + df['file_size'].astype(str).str[:2])


# df['ms_lufs']
# df.sort_values(by='ID')
# Out:
#    Sample Rate (Hz)  Bit Depth  Count
# 0             44100         16      8
#
# ALL AIFF in correct format -> if something changes go erase the already downsized
# ENTER to analyze
# Searching for Files: 100%|██████████████████████████████████████████████| 16/16 [00:00<00:00, 22795.13files/s]
# ATTN ::: <E>  AFTER making sure that you have assigned the DIRECTORY PATH to ::: var ::: /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA
# ***df*** will be returned having ::: 8  rows, write df in next cell to see your DATA FRAME
#
# second part FREQUENCIES OF df :::
#
# Grand Total Size in MB: 354.055
# Grand Total Size in Bytes: 371253724.000
# Grand Total Size in GB: 0.346
#
#  FREQUENCY TABLE:::
#
#   Extension  frequency  total_size_in_mb
# 0     .aiff          8        354.055141
# Audio file Attributes: 100%|██████████████████████████████████████████████████| 8/8 [00:00<00:00, 2842.87it/s]
# Computing LUFS: 100%|█████████████████████████████████████████████████████████| 8/8 [00:04<00:00,  1.82file/s]
# 100%|████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 96144.50it/s]
# Processing BPM Dynamic: 100%|███████████████████████████████████████████████████| 8/8 [00:10<00:00,  1.34s/it]
# Extracting ID3 Titles: 100%|██████████████████████████████████████████████████| 8/8 [00:00<00:00, 1002.61it/s]
# DONE with getting 1_title
# title_file
# ID3TAGS    8
# Name: count, dtype: int64
# Writing AIFF files for title: 0it [00:00, ?it/s]
# Total files processed for title: 0
# Extracting ID3 Artists: 100%|█████████████████████████████████████████████████| 8/8 [00:00<00:00, 1490.38it/s]
# DONE with getting 2_artist
# artist_file
# ID3TAGS    8
# Name: count, dtype: int64
# Writing AIFF files for artist: 0it [00:00, ?it/s]
# Total files processed for artist: 0
# Extracting ID3 Labels: 100%|██████████████████████████████████████████████████| 8/8 [00:00<00:00, 1350.88it/s]
# DONE with getting 3_LABEL
# label_file
# ID3TAGS    8
# Name: count, dtype: int64
# Extracting ID3 Genres: 100%|██████████████████████████████████████████████████| 8/8 [00:00<00:00, 1067.66it/s]
# DONE with getting 4_genre
# genre_file
# ID3TAGS    8
# Name: count, dtype: int64
# Extracting ID3 Release Year: 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 1051.80it/s]
# DONE with getting 5_release_year
# rel_year_file
# FILE_NAME    8
# Name: count, dtype: int64
# Extracting ID3 Key: 100%|█████████████████████████████████████████████████████| 8/8 [00:00<00:00, 1107.41it/s]
# DONE with getting 6_KEY
# key_file
# ID3TAGS    8
# Name: count, dtype: int64
# DONE with getting 7_mix_name & 8_remixer
#   0%|          | 0/8 [00:00<?, ?it/s]
# DONE with getting 9_date_purchased
# Writtng AIFF files for : remixer:   0%|          | 0/8 [00:00<?, ?it/s]
# DONE with WRITTING 7_mix_name & 8_remixer : to ID3TAG remixer
# Writtng AIFF files for : genre: 0it [00:00, ?it/s]
# Total files processed: 0
# DONE with WRITTING 4_genre : to ID3TAG genre
# Writtng AIFF files for : label: 0it [00:00, ?it/s]
# Total files processed for label: 0
# DONE with WRITTING 3_LABEL : to ID3TAG LABEL
# Extracting ID3 Release Date:   0%|          | 0/8 [00:00<?, ?it/s]
# Writing AIFF files for: release date:   0%|          | 0/8 [00:00<?, ?it/s]
# Total files processed for release date: 8
#   0%|          | 0/8 [00:00<?, ?it/s]
# Processing keys:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing keys:   0%|          | 0/8 [00:00<?, ?it/s]
# Writing AIFF files for comment:   0%|          | 0/8 [00:00<?, ?it/s]
# Total files processed for comment: 8
# DOoooooooooooo
#
#
#
#
#
#
# ne...

# %%
#df = df.head(20)
    
    # Save the selected DataFrame portion to a pickle file
#
#df.to_pickle("all_df.pkl")
df#.head(1)
# Out:
#                                                                                                                                                                                                                                                                                                     Path                                                                                                                                                                                                                    temp_id                                                                                                                                                                                                                       file_name Extension dur_seconds   dur_min     sr bit_depth bit_rate channels file_size file_size_human num_frames error  ms_lufs ms_LUFS_code id_cat_lufs    mean_bpm       std_bpm     min_bpm     max_bpm  variation_percentage  dominant_bpm  bpm_consistency  \
# 0                                           /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.aiff                                           TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29                                           TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.aiff     .aiff  286.875011   4.78125  44100        16     None        2  50630984        48.29 MB   12651188  None   -7.168          LuF           W  129.199219  0.000000e+00  129.199219  129.199219          0.000000e+00           129       100.000000
# 1  /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.aiff  TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29  TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.aiff     .aiff  363.779546  6.062992  44100        16     None        2  64196984        61.22 MB   16042678  None   -7.305          LuF           W  126.048018  1.421085e-14  126.048018  126.048018          1.127416e-14           126       100.000000
# 2                                                   /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.aiff                                                   TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29                                                   TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.aiff     .aiff  184.799977      3.08  44100        16     None        2  32624938        31.11 MB    8149679  None   -7.362          LuF           W  128.371019  1.095606e+01   99.384014  132.512019          8.534682e+00           133        87.500000
# 3                                                                                      /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.aiff                                                                                      TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29                                                                                      TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.aiff     .aiff       254.0  4.233333  44100        16     None        2  44831788        42.75 MB   11201400  None   -6.471          LuF           X  126.048018  0.000000e+00  126.048018  126.048018          0.000000e+00           126       100.000000
# 4                                      /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.aiff                                      TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29                                      TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.aiff     .aiff      257.28     4.288  44100        16     None        2  45410430        43.31 MB   11346048  None   -7.525          LuF           W  129.199219  0.000000e+00  129.199219  129.199219          0.000000e+00           129       100.000000
# 5                                         /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.aiff                                         TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29                                         TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.aiff     .aiff  286.901746  4.781696  44100        16     None        2  50635700        48.29 MB   12652367  None   -9.061          LuF           V  126.381897  1.234708e+01   63.802083  129.199219          9.769655e+00           129        94.871795
# 6                                                                     /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.aiff                                                                     TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29                                                                     TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.aiff     .aiff  289.787347  4.829789  44100        16     None        2  51144692        48.78 MB   12779622  None   -8.224          LuF           W  126.048018  1.421085e-14  126.048018  126.048018          1.127416e-14           126       100.000000
# 7                                                                 /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.aiff                                                                 TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29                                                                 TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.aiff     .aiff       180.0       3.0  44100        16     None        2  31778208        30.31 MB    7938000  None   -6.901          LuF           W  129.199219  0.000000e+00  129.199219  129.199219          0.000000e+00           129       100.000000
#
#   bpm_consistency_cat                            titile title_file                       artist artist_file                               LABEL label_file        genre genre_file rel_year rel_year_file    KEY key_file                                       mix_name                                                                      remixer remix date_purchased    rel_date rel_date_file key_dj key_music                 status Relative_Key Key_Up Key_Down Jaw_s_Mix Mood_Shifter          ID comment                                                        audio_hash
# 0                 D_0                       _Back_Seat_    ID3TAGS  _Anna_Lunoe,_Genesis_Owusu_     ID3TAGS                         NLV Records    ID3TAGS   Bass House    ID3TAGS     None     FILE_NAME   Gmin  ID3TAGS                            Chris_Lorenzo_Remix                                            Chris Lorenzo Remix Chris Lorenzo     R     2023-03-29  2022-01-13       ID3TAGS     6A      Gmin  Success: TKEY updated           6B     7A       5A        1A           9B  dy0Fw___50     NaN  f929d7513e0824451ab22009f5fb180d1444dc5baa7c3aa69aa428e9ad562901
# 1                 D_0  _Could_Heaven_Ever_Be_Like_This_    ID3TAGS             _Idris_Muhammad_     ID3TAGS                               Ultra    ID3TAGS        House    ID3TAGS     None     FILE_NAME   Dmin  ID3TAGS  Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix  Walker & Royce and Chris Lorenzo Extended Mix Walker & Royce, Chris Lorenzo     U     2023-03-29  2022-08-12       ID3TAGS     7A      Dmin  Success: TKEY updated           7B     8A       6A        2A          10B  dy0Fw___64     NaN  5529059e9612d6b97cc77bcf12dee71e8c983aa9fa642a04b49a13714a462488
# 2                 D_3                   _Disco_Maghreb_    ID3TAGS                   _DJ_Snake_     ID3TAGS  DJ Snake Music Productions Limited    ID3TAGS  Dance   Pop    ID3TAGS     None     FILE_NAME   Gmin  ID3TAGS                                   Original_Mix                                                                 Original Mix     U     2023-03-29  2022-05-31       ID3TAGS     6A      Gmin  Success: TKEY updated           6B     7A       5A        1A           9B  dy3Fw___32     NaN  b388202ceb4d3f63d7f00c99b6d4f066f882ae4f5cfb6176feeb94301ce69614
# 3                 D_0                        _Esa_Nena_    ID3TAGS                      _Chuwe_     ID3TAGS                           DistroKid    ID3TAGS   Tech House    ID3TAGS     None     FILE_NAME   Emaj  ID3TAGS                                   Original_Mix                                                                 Original Mix     U     2023-03-29  2022-03-18       ID3TAGS    12B      Emaj  Success: TKEY updated          12A     1B      11B        7B           9A  dy0Fx___44     NaN  5f0a7a1941e3214a0e2a3266550ceac8250236ef706ade59d8e4c4318693384d
# 4                 D_0                     _In_Da_Getto_    ID3TAGS         _Skrillex,_J_Balvin_     ID3TAGS               Sueños Globales, LLC    ID3TAGS   Bass House    ID3TAGS     None     FILE_NAME  D#min  ID3TAGS                            Chris_Lorenzo_Remix                                            Chris Lorenzo Remix Chris Lorenzo     R     2023-03-29  2021-12-15       ID3TAGS     2A     D#min  Success: TKEY updated           2B     3A       1A        9A           5B  dy0Fw___45     NaN  2adba579e83144e7754861a42d55136422ca94c1dece7883a713943d59586a0e
# 5                 D_3             _MAMI_(feat._COBRAH)_    ID3TAGS              _Chris_Lorenzo_     ID3TAGS                       Late Checkout    ID3TAGS   Bass House    ID3TAGS     None     FILE_NAME  D#min  ID3TAGS                       AC_Slater_Extended_Remix                                           AC Slater Extended Remix AC Slater     R     2023-03-29  2022-10-14       ID3TAGS     2A     D#min  Success: TKEY updated           2B     3A       1A        9A           5B  dy3Fv___50     NaN  2b2ad147c53612bee1642be3fc5873a6f6749d6a56680f0d48282e01c3b49090
# 6                 D_0                            _MAMI_    ID3TAGS      _Chris_Lorenzo,_COBRAH_     ID3TAGS                       Late Checkout    ID3TAGS   Bass House    ID3TAGS     None     FILE_NAME   Dmaj  ID3TAGS                                   Extended_Mix                                                                 Extended Mix     U     2023-03-29  2022-07-22       ID3TAGS    10B      Dmaj  Success: TKEY updated          10A    11B       9B        5B           7A  dy0Fw___51     NaN  94db1c67d5808b427fc84cb9181a7475b3b542826c876fd3fe9bd6895b7dc048
# 7                 D_0                           _TURMA_    ID3TAGS                   _Twogangs_     ID3TAGS        Good Times Bad Times Records    ID3TAGS  Bass   Club    ID3TAGS     None     FILE_NAME   Cmin  ID3TAGS                                   Original_Mix                                                                 Original Mix     U     2023-03-29  2020-05-22       ID3TAGS     5A      Cmin  Success: TKEY updated           5B     6A       4A       12A           8B  dy0Fw___31     NaN  dc12e0087e6c26177d59684c1c24f6d2502a53310e257208fc7613eb1fb0d9f0

# %% [markdown]
# # COVER IMAGE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random, string

direc_jpg = 'images/'
exec(open("_cover_fns.py",encoding="utf-8").read())
##### get df
#df = pd.read_pickle("df_cover.pkl")
# id
#df['ID'] = [''.join(random.choices(string.ascii_uppercase, k=2)) + ''.join(random.choices(string.digits, k=2)) for _ in range(len(df))]  # TQM: |████████████████████|
df.head(1)
print(len(df))
# Out:
# 8

# %%
###### create KEY plot chamelot map 
key_plot()
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
# Minimal execution code: Set the directory with your PNG images and call the function.
input_directory = direc_jpg
output_folder = direc_jpg# Directory containing the PNG images that need processing

# Call the function to process and overwrite the images in the same folder.
_png_2409_wbrem_GET_overwrite_imgs(input_directory, tolerance=200)
# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None)
# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None)
# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None) # three times to make picture small
# Out:
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# TQM: Processed and overwritten image images/key_plotdy0Fw___64.png
# TQM: Processed and overwritten image images/key_plotdy0Fx___44.png
# TQM: Processed and overwritten image images/key_plotdy3Fv___50.png
# TQM: Processed and overwritten image images/key_plotdy3Fw___32.png
# TQM: Processed and overwritten image images/key_plotdy0Fw___31.png
# TQM: Processed and overwritten image images/key_plotdy0Fw___45.png
# TQM: Processed and overwritten image images/key_plotdy0Fw___51.png
# TQM: Processed and overwritten image images/key_plotdy0Fw___50.png
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___50.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___64.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy3Fw___32.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fx___44.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___45.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy3Fv___50.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___51.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___31.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___50.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___64.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy3Fw___32.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fx___44.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___45.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy3Fv___50.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___51.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___31.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___50.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___64.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy3Fw___32.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fx___44.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_In_Da_Getto_ARkw_Skrillex,_J_Balvin_MXkw_Chris_Lorenzo_Remix_KYkw_E_Major_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_Sueños_Globales,_LLC_RYkw_2021_12_15_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___45.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_(feat._COBRAH)_ARkw_Chris_Lorenzo_MXkw_AC_Slater_Extended_Remix_KYkw_Eb_Minor_BPkw_128_GNkw_Bass_House_RMkw_AC_Slater_LBkw_Late_Checkout_RYkw_2022_10_14_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy3Fv___50.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_MAMI_ARkw_Chris_Lorenzo,_COBRAH_MXkw_Extended_Mix_KYkw_Bb_Major_BPkw_126_GNkw_Bass_House_RMkw__LBkw_Late_Checkout_RYkw_2022_07_22_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___51.jpg'
# Cover extracted, resized, framed, and saved as /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.jpg
# Resized and framed cover embedded back into the AIFF file.
# Error renaming cover image for file /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.aiff: [Errno 18] Cross-device link: '/Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_TURMA_ARkw_Twogangs_MXkw_Original_Mix_KYkw_A#_Minor_BPkw_128_GNkw_Bass___Club_RMkw__LBkw_Good_Times_Bad_Times_Records_RYkw_2020_05_22_PYkw_2023_03_29.jpg' -> 'images/cover_1_dy0Fw___31.jpg'

# %%
# create new IDs
df['Path_jpg_album'] = f'{direc_jpg}' + 'cover_1_' + df['ID'] + '.jpg'
df['Path_jpg_key'] = f'{direc_jpg}' + 'key_plot' + df['ID'] + '.png'

###########################
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!


# Use the 'dominant_bpm' column for the text overlay:
_img_2409_process_df_coverart_GET_output(
    df,
    circle_size_ratio=0.25,         # Increase the size of the circle relative to the image size
    position="top-left",         # Change the position of the circle
    circle_color=(0, 0, 0, 255),    # Use a red circle
    text_color=(0, 255, 25, 255),      # Use a green color for the text
    text_scale=0.5,                 # Adjust the text scale
    text_column="dominant_bpm"      # Use the dominant BPM as text
)

# Example using a different column (e.g., 'artist_name'):
# _img_2409_process_df_coverart_GET_output(
#     df,
#     circle_size_ratio=0.25,
#     position="bottom-left",
#     circle_color=(255, 0, 0, 255),
#     text_color=(0, 255, 0, 255),
#     text_scale=0.7,
#     text_column="artist_name"      # Now the overlay will show the artist name
# )



#Example with no text overlay:
_img_2409_process_df_coverart_GET_output(
    df,
    circle_size_ratio=0.33,
    position="top-right",
    circle_color=(255, 255, 255, 255),
    text_color=(0, 255, 25, 255),
    text_scale=0.5,
    text_column=None               # Passing None will result in no text being drawn
)

#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#! FOR KEY overly 


# Process each row in the DataFrame by overlaying the key image onto the album cover.
_img_2409_overlay_df_key_GET_output(
    df,
    resize_factor=0.265,         # Adjust as needed to scale the overlay image
    position_right_cm=-0.232,    # Distance from the right edge in cm
    position_top_cm=-0.59,       # Distance from the top edge in cm
    dpi=300                      # DPI used for conversion from cm to pixels
)


# Process the DataFrame: for each row, the overlay function uses the LUFS code from 'ms_LUFS_code'
_overlay_df_circle_custom_0501_GET_image(
    df,
    circle_position=(-0.379, -1.2098003),  # Custom fractional position
    circle_diameter=2755,                  # Custom circle diameter in pixels
    ms_LUFS_column='ms_LUFS_code'           # Column from which to take the LUFS code
)

########### cliping graph 
_audio_2409_i2_GET_generate_clipping_plots(df,save_directory="images")
df['Path_jpg_clip'] = f'{direc_jpg}' + 'clip_plot' + df['ID'] + '.jpg'
# embed freq to pic 
_img_2409_i3_GET_embed_clipping_on_album(df)
# Out:
# Processing Cover Art: 100%|████████████████████████████████████████████| 1178/1178 [00:00<00:00, 41791.91it/s]
# Error processing cover art for /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Back_Seat_ARkw_Anna_Lunoe,_Genesis_Owusu_MXkw_Chris_Lorenzo_Remix_KYkw_G_Minor_BPkw_128_GNkw_Bass_House_RMkw_Chris_Lorenzo_LBkw_NLV_Records_RYkw_2022_01_13_PYkw_2023_03_29.aiff: No matching cover image found at images/cover_1_dy0Fw___50.jpg
# Error processing cover art for /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Could_Heaven_Ever_Be_Like_This_ARkw_Idris_Muhammad_MXkw_Walker_&_Royce_and_Chris_Lorenzo_Extended_Mix_KYkw_D_Minor_BPkw_127_GNkw_House_RMkw_Walker_&_Royce,_Chris_Lorenzo_LBkw_Ultra_RYkw_2022_08_12_PYkw_2023_03_29.aiff: No matching cover image found at images/cover_1_dy0Fw___64.jpg
# Error processing cover art for /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Disco_Maghreb_ARkw_DJ_Snake_MXkw_Original_Mix_KYkw_Ab_Major_BPkw_100_GNkw_Dance___Pop_RMkw__LBkw_DJ_Snake_Music_Productions_Limited_RYkw_2022_05_31_PYkw_2023_03_29.aiff: No matching cover image found at images/cover_1_dy3Fw___32.jpg
# Error processing cover art for /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw_Esa_Nena_ARkw_Chuwe_MXkw_Original_Mix_KYkw_B_Minor_BPkw_125_GNkw_Tech_House_RMkw__LBkw_DistroKid_RYkw_2022_03_18_PYkw_2023_03_29.aiff: No matching cover image found at images/cover_1_dy0Fx___44.jpg
# Error processing cover art for /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2023_this/_23_02_AN_LA_VENTANA/TRkw
PYkw_2025_04_04.aiff: No album cover found at images/cover_1_dy0Ds_wB68.jpg
# Error overlaying key for /Volumes/MUSIC_PROD/_1_NEW_SOURCE copy/_2025_this/__25_04_BP_LATIN_HOUSE/TRkw_Yeti_Unknown_ARkw_Lui_Mafuta,_Rudiger_Eisberg_MXkw_Original_Mix_KYkw_Gb_Minor_BPkw_109_GNkw_Organic_House_RMkw__LBkw_Tropical_Twista_Records_RYkw_2024_12_13_PYkw_2025_04_04.aiff: No album cover found at images/cover_1_dy0Et_yL81.jpg
# Overlaying LUFS Circles:   0%|                                                       | 0/1178 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <string>:657, in _overlay_circle_custom_0501_GET_image(input_string, image_path, circle_position, circle_diameter)
#
# File ~/_apple_lib/_b_envs/2ms_env/lib/python3.11/site-packages/PIL/Image.py:3236, in open(fp, mode, formats)
#    3235 if filename:
# -> 3236     fp = builtins.open(filename, "rb")
#    3237     exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/cover_1_dy0Fw___50.jpg'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 58
#      48 _img_2409_overlay_df_key_GET_output(
#      49     df,
#      50     resize_factor=0.265,         # Adjust as needed to scale the overlay image
#    (...)     53     dpi=300                      # DPI used for conversion from cm to pixels
#      54 )
#      57 # Process the DataFrame: for each row, the overlay function uses the LUFS code from 'ms_LUFS_code'
# ---> 58 _overlay_df_circle_custom_0501_GET_image(
#      59     df,
#      60     circle_position=(-0.379, -1.2098003),  # Custom fractional position
#      61     circle_diameter=2755,                  # Custom circle diameter in pixels
#      62     ms_LUFS_column='ms_LUFS_code'           # Column from which to take the LUFS code
#      63 )
#      65 ########### cliping graph
#      66 _audio_2409_i2_GET_generate_clipping_plots(df,save_directory="images")
#
# File <string>:713, in _overlay_df_circle_custom_0501_GET_image(df, circle_position, circle_diameter, ms_LUFS_column)
#
# File <string>:659, in _overlay_circle_custom_0501_GET_image(input_string, image_path, circle_position, circle_diameter)
#
# FileNotFoundError: Image file not found at images/cover_1_dy0Fw___50.jpg

# %% [markdown]
# # EMBED  to AIFF ____ LAST STEP

# %%
#_aiff_2409_i1_GET_embed_aiff_covers(df)

# %% [markdown]
# # dynamic BPM

# %%
# 0_FNS
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# ###########################################################################
# ########## CORE FUNCTION: _bpm_2610_i3_GET_partialdonut_bpmdynamic   ########
# ###########################################################################
def _bpm_2610_i3_GET_partialdonut_bpmdynamic(df: pd.DataFrame, save_dir: str = "images") -> None:
    """
    Iterates over the provided DataFrame and saves an individual PNG for each row.
    Each PNG contains a donut chart that illustrates the BPM dynamic percentage as 
    a colored wedge (based on 'bpm_consistency_cat') with the remainder of the circle transparent.
    
    The donut is only partially complete in reference to the provided percentage.
    The figure is saved as a PNG with a transparent background and no extra labels.
    
    The PNG files are saved using the value from the 'ID' column in the DataFrame.
    
    Parameters:
        df (pd.DataFrame): DataFrame with columns:
                           - 'bpm_consistency': numeric value between 0 and 100.
                           - 'bpm_consistency_cat': dynamic category label (e.g., 'D_0', 'D_1', 'D_3', 'D_6', 'D_9'),
                             with D_0 being least dynamic (yellow) and D_9 super dynamic (dark gray).
                           - 'ID': unique identifier for each row/song used for file naming.
        save_dir (str): Directory where the PNG images will be saved. Defaults to "images".
    """
    # Define a cohesive color mapping using a Material Design–inspired gradient.
    color_mapping = {
         'D_0': "#FFEB3B",  # Bright yellow (original)
    'D_1': "#E6D435",  # 90% brightness of D_0
    'D_3': "#CCBC2F",  # 80% brightness of D_0
    'D_6': "#998D23",  # 60% brightness of D_0
    'D_9': "#665E17"    # Near-black
    }
    
    # Ensure the save directory exists.
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    if not save_dir.endswith(os.sep):
        save_dir += os.sep

    # ------------------ TQM BAR: Starting donut generation with 50% thinner ring ------------------
    # Iterate over each row in the DataFrame.
    for _, row in df.iterrows():
        dynamic_value = row['bpm_consistency']  # Percentage value (0 to 100)
        dynamic_cat = row['bpm_consistency_cat']
        
        # Compute the segments: filled part equals dynamic percentage; remainder (to 100) is transparent.
        segments = [dynamic_value, 100 - dynamic_value]
        colors = [color_mapping.get(dynamic_cat, '#9E9E9E'), (0, 0, 0, 0)]
        
        # Create figure and axis.
        fig, ax = plt.subplots(figsize=(6, 6))
        ax.axis('off')  # Remove axes for a clean image.
        
        # Draw the donut chart using wedgeprops to create a hole in the center.
        # Updated wedge width to 0.15 (i.e., 50% thinner than the original 0.3)
        ax.pie(
            segments, 
            colors=colors, 
            startangle=90, 
            counterclock=False, 
            wedgeprops={'width': 0.15, 'edgecolor': 'none'}
        )
        
        # Use the value in the 'ID' column as the file name.
        file_name = f"{save_dir}bpm_bar_dyn_{row['ID']}.png"
        plt.savefig(file_name, bbox_inches='tight', pad_inches=0, transparent=True)
        plt.close(fig)
        print(f"Saved: {file_name}")
    # ------------------ TQM BAR: Donut generation completed ------------------
# ########## END OF CORE FUNCTION ###########################################
# ########## END OF CORE FUNCTION ###########################################
_bpm_2610_i3_GET_partialdonut_bpmdynamic(df, save_dir="images")
df['Path_png_bar_dyn'] = f'{direc_jpg}' + 'bpm_bar_dyn_' + df['ID'] + '.png'
df

# %%
# 0_FNS
import os
from PIL import Image
import pandas as pd

# ###########################################################################
# ########## CORE FUNCTION: _bpm_2610_i4_GET_embedded_album_dynamic_custom ########
# ###########################################################################
def _bpm_2610_i4_GET_embedded_album_dynamic_custom(
    df: pd.DataFrame,
    position: str = "top_left",
    x_offset: int = 10,
    y_offset: int = 10,
    scale: float = 1.0,
    custom_coords: tuple = None
) -> None:
    """
    Overlays each dynamic (donut) PNG image onto its corresponding album JPG image
    and saves the composite by overwriting the original album file (keeping the same file name).
    
    For each row in the DataFrame, the function:
      - Opens the album image from 'Path_jpg_album'.
      - Opens the dynamic overlay image from 'Path_png_bar_dyn'.
      - Optionally rescales the overlay image using the scale factor.
      - Determines placement based on the provided 'position' parameter and separate
        'x_offset' and 'y_offset' values:
          * For "top_left": shifts right by x_offset and downward by y_offset.
          * For "top_right": shifts left by x_offset and downward by y_offset.
          * For "bottom_left": shifts right by x_offset and upward by y_offset.
          * For "bottom_right": shifts left by x_offset and upward by y_offset.
          * For "custom": exact coordinates must be provided in custom_coords.
      - Pastes the overlay onto the album image using its alpha channel.
      - Saves the composite image over the original album JPG (preserving its file name).
    
    Parameters:
        df (pd.DataFrame): DataFrame containing:
            - 'ID': Unique identifier.
            - 'Path_png_bar_dyn': File path to the dynamic overlay PNG image.
            - 'Path_jpg_album': File path to the album JPG image (and destination for the composite).
        position (str): Anchor position for the overlay relative to the album image.
                        Options: "top_left", "top_right", "bottom_left", "bottom_right", "custom".
                        Default is "top_left".
        x_offset (int): Horizontal offset (in pixels) from the anchor position.
                        For "top_left" and "bottom_left", positive values shift the overlay right.
                        For "top_right" and "bottom_right", positive values shift the overlay left.
        y_offset (int): Vertical offset (in pixels) from the anchor position.
                        For "top_left" and "top_right", positive values shift the overlay downward.
                        For "bottom_left" and "bottom_right", positive values shift the overlay upward.
        scale (float): Scaling factor for the overlay image. Default is 1.0 (no scaling).
        custom_coords (tuple): If position is "custom", supply exact (x, y) coordinates.
    """
    for _, row in df.iterrows():
        album_path = row['Path_jpg_album']
        overlay_path = row['Path_png_bar_dyn']
        
        try:
            album_img = Image.open(album_path).convert("RGBA")
            overlay_img = Image.open(overlay_path).convert("RGBA")
        except Exception as e:
            print(f"Error opening images for ID {row['ID']}: {e}")
            continue
        
        # Apply scaling if the scale factor is not 1.0.
        if scale != 1.0:
            new_size = (int(overlay_img.width * scale), int(overlay_img.height * scale))
            overlay_img = overlay_img.resize(new_size, Image.ANTIALIAS)
        
        # Determine placement coordinates based on the selected position.
        if position == "top_left":
            x = x_offset
            y = y_offset
        elif position == "top_right":
            x = album_img.width - overlay_img.width - x_offset
            y = y_offset
        elif position == "bottom_left":
            x = x_offset
            y = album_img.height - overlay_img.height - y_offset
        elif position == "bottom_right":
            x = album_img.width - overlay_img.width - x_offset
            y = album_img.height - overlay_img.height - y_offset
        elif position == "custom":
            if custom_coords is None:
                raise ValueError("Custom coordinates must be provided when position is 'custom'.")
            else:
                x, y = custom_coords
        else:
            raise ValueError("Invalid position value. Choose from: top_left, top_right, bottom_left, bottom_right, custom.")
        
        # Paste the overlay image onto the album image with transparency.
        album_img.paste(overlay_img, (x, y), overlay_img)
        
        # Save the composite over the original album image (converting from RGBA to RGB).
        album_img.convert("RGB").save(album_path, "JPEG")
        print(f"Saved composite over album: {album_path}")
# ########## END OF CORE FUNCTION ###########################################

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
# With your DataFrame 'df' (which contains 'ID', 'Path_png_bar_dyn', and 'Path_jpg_album'),
# call the function to overlay the dynamic PNG onto the album JPG.
_bpm_2610_i4_GET_embedded_album_dynamic_custom(
    df,
    position="top_left",  # adjust as needed: "top_left", "top_right", "bottom_left", "bottom_right", "custom"
    x_offset=-1,          # horizontal offset: increase to move right (for top_left or bottom_left) or left (for top_right or bottom_right)
    y_offset=-8,          # vertical offset: increase to move down (for top positions) or up (for bottom positions)
    scale=.65             # adjust the scale if needed
    # custom_coords=(x, y) can be provided if position is "custom"
)

# %% [markdown]
# # EMBED

# %%
_aiff_2409_i1_GET_embed_aiff_covers(df)

# %%
# last step rename 
df['re_name'] = ( df['ID'] +'_'
                 +'BY_'+ df['artist'].astype(str).str[:5]
                 +'_'+df['titile'].astype(str).str[:9]
                 +'_'+ df['remix'].astype(str))
####
##
#
_rename_aiff_files_bulk(df)
