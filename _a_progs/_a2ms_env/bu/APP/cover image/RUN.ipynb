# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random, string

direc_jpg = 'images/'
exec(open("cover_fns.py",encoding="utf-8").read())
##### get df
df = pd.read_pickle("df_cover.pkl")
# id
#df['ID'] = [''.join(random.choices(string.ascii_uppercase, k=2)) + ''.join(random.choices(string.digits, k=2)) for _ in range(len(df))]  # TQM: |████████████████████|
df.head(1)
print(len(df))
# Out:
# 13

# %%
direc_jpg
# Out:
# 'images/'

# %%
###### create KEY plot chamelot map 
key_plot()
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
# Minimal execution code: Set the directory with your PNG images and call the function.
input_directory = direc_jpg
output_folder = direc_jpg# Directory containing the PNG images that need processing

# Call the function to process and overwrite the images in the same folder.
_png_2409_wbrem_GET_overwrite_imgs(input_directory, tolerance=200)
# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None)
# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None)
# Example: Calling the iteration function
_aiff_2409_coveriter_GET_save(df, output_folder, default_pic=None) # three times to make picture small
# Out:
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# DONE
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy3Fv_qC55.png
# TQM: Processed and overwritten image images/key_plotdy9Dr_pL45.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy9Fv_sU66.png
# TQM: Processed and overwritten image images/key_plotdy6Et_lM32.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy6Et_lM32.png
# TQM: Processed and overwritten image images/key_plotdy9Fv_sU66.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy9Dr_pL45.png
# TQM: Processed and overwritten image images/key_plotdy3Fv_qC55.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy9Fv_lM50.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy0Et_vK61.png
# TQM: Processed and overwritten image images/key_plotdy0Et_vK61.png
# TQM: Processed and overwritten image images/key_plotdy9Fv_lM50.png
# TQM: Processed and overwritten image images/key_plotdy0Fu_eA59.png
# TQM: Processed and overwritten image images/key_plotdy9Co_lT33.png
# TQM: Processed and overwritten image images/key_plotdy0Fv_aM60.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy0Fv_aM60.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy9Co_lT33.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy0Fu_eA59.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy0Et_iS62.png
# TQM: Processed and overwritten image images/key_plotdy9Dr_lB30.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy0Et_fE49.png
# TQM: Processed and overwritten image images/key_plotdy0Et_fE49.png
# TQM: Processed and overwritten image images/bpm_bar_dyn_dy9Dr_lB30.png
# TQM: Processed and overwritten image images/key_plotdy0Et_iS62.png
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Original_Mix_KYkw_G_Minor_BPkw_124_GNkw_House_RMkw__LBkw_XDM_Records_RYkw_2020_02_14_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy3Fv_qC55 saved as images/cover_1_dy3Fv_qC55.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Puerto_Rico_ARkw_Salsa_various_MXkw_original_KYkw_6A_BPkw_109_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy9Dr_pL45 saved as images/cover_1_dy9Dr_pL45.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_Lisbon_MXkw_Low_End_Specialists_Mix_KYkw_G_Minor_BPkw_127_GNkw_House_RMkw_Low_End_Specialists_LBkw_Kaos_Records_Portugal_RYkw_2017_06_09_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy9Fv_sU66 saved as images/cover_1_dy9Fv_sU66.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_La_Loca_Eres_Tu_ARkw_Salsa_various_MXkw_original_KYkw_2B_BPkw_105_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy6Et_lM32 saved as images/cover_1_dy6Et_lM32.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Violet_ARkw_Keita_Sano_MXkw_Original_Mix_KYkw_F_Minor_BPkw_113_GNkw_Nu_Disco___Disco_RMkw__LBkw_Delusions_Of_Grandeur_RYkw_2023_10_27_PYkw_2025_02_21.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_vK61 saved as images/cover_1_dy0Et_vK61.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Into_The_Night_ARkw_Soul_of_Hex_MXkw_Original_Mix_KYkw_F_Major_BPkw_120_GNkw_Deep_House_RMkw__LBkw_Delusions_Of_Grandeur_RYkw_2024_11_22_PYkw_2025_02_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_iS62 saved as images/cover_1_dy0Et_iS62.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulphiction_Remix_KYkw_E_Minor_BPkw_122_GNkw_Deep_House_RMkw_Soulphiction_LBkw_Heist_Recordings_RYkw_2017_05_08_PYkw_2025_03_27 2.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fu_eA59 saved as images/cover_1_dy0Fu_eA59.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulphiction_Remix_KYkw_E_Minor_BPkw_122_GNkw_Deep_House_RMkw_Soulphiction_LBkw_Heist_Recordings_RYkw_2017_05_08_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0
jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Puerto_Rico_ARkw_Salsa_various_MXkw_original_KYkw_6A_BPkw_109_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy9Dr_pL45 saved as images/cover_1_dy9Dr_pL45.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_Lisbon_MXkw_Low_End_Specialists_Mix_KYkw_G_Minor_BPkw_127_GNkw_House_RMkw_Low_End_Specialists_LBkw_Kaos_Records_Portugal_RYkw_2017_06_09_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy9Fv_sU66 saved as images/cover_1_dy9Fv_sU66.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_La_Loca_Eres_Tu_ARkw_Salsa_various_MXkw_original_KYkw_2B_BPkw_105_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy6Et_lM32 saved as images/cover_1_dy6Et_lM32.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Violet_ARkw_Keita_Sano_MXkw_Original_Mix_KYkw_F_Minor_BPkw_113_GNkw_Nu_Disco___Disco_RMkw__LBkw_Delusions_Of_Grandeur_RYkw_2023_10_27_PYkw_2025_02_21.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_vK61 saved as images/cover_1_dy0Et_vK61.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Into_The_Night_ARkw_Soul_of_Hex_MXkw_Original_Mix_KYkw_F_Major_BPkw_120_GNkw_Deep_House_RMkw__LBkw_Delusions_Of_Grandeur_RYkw_2024_11_22_PYkw_2025_02_07.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_iS62 saved as images/cover_1_dy0Et_iS62.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulphiction_Remix_KYkw_E_Minor_BPkw_122_GNkw_Deep_House_RMkw_Soulphiction_LBkw_Heist_Recordings_RYkw_2017_05_08_PYkw_2025_03_27 2.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fu_eA59 saved as images/cover_1_dy0Fu_eA59.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulphiction_Remix_KYkw_E_Minor_BPkw_122_GNkw_Deep_House_RMkw_Soulphiction_LBkw_Heist_Recordings_RYkw_2017_05_08_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fu_eA59 saved as images/cover_1_dy0Fu_eA59.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/Edson Conceição - Filhos de Gandhi (Um Abraço em Gilberto Gil) (Mike Burns Edit).jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Et_fE49 saved as images/cover_1_dy0Et_fE49.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Laope_ARkw_Salsa_various_MXkw_original_KYkw_7A_BPkw_91_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy9Co_lT33 saved as images/cover_1_dy9Co_lT33.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_original_KYkw_5A_BPkw_105_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy9Dr_lB30 saved as images/cover_1_dy9Dr_lB30.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_Y_Su_Trabuco_MXkw_Original_Mix_KYkw_A_Minor_BPkw_98_GNkw_House_RMkw__LBkw_Planet_Records_RYkw_2019_09_01_PYkw_2025_03_27.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy9Fv_lM50 saved as images/cover_1_dy9Fv_lM50.jpg
# Cover extracted, resized, framed, and saved as /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Alright_ARkw_Men_I_Trust_MXkw_Haveck_Remix_KYkw_A_Major_BPkw_118_GNkw_Indie_Dance_RMkw_Haveck_LBkw_Audio_B_RYkw_2020_01_26_PYkw_2025_02_21.jpg
# Resized and framed cover embedded back into the AIFF file.
# TQM: Cover image for ID dy0Fv_aM60 saved as images/cover_1_dy0Fv_aM60.jpg

# %%
# create new IDs
df['Path_jpg_album'] = f'{direc_jpg}' + 'cover_1_' + df['ID'] + '.jpg'
df['Path_jpg_key'] = f'{direc_jpg}' + 'key_plot' + df['ID'] + '.png'

###########################
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!


# Use the 'dominant_bpm' column for the text overlay:
_img_2409_process_df_coverart_GET_output(
    df,
    circle_size_ratio=0.25,         # Increase the size of the circle relative to the image size
    position="top-left",         # Change the position of the circle
    circle_color=(0, 0, 0, 255),    # Use a red circle
    text_color=(0, 255, 25, 255),      # Use a green color for the text
    text_scale=0.5,                 # Adjust the text scale
    text_column="dominant_bpm"      # Use the dominant BPM as text
)

# Example using a different column (e.g., 'artist_name'):
# _img_2409_process_df_coverart_GET_output(
#     df,
#     circle_size_ratio=0.25,
#     position="bottom-left",
#     circle_color=(255, 0, 0, 255),
#     text_color=(0, 255, 0, 255),
#     text_scale=0.7,
#     text_column="artist_name"      # Now the overlay will show the artist name
# )



#Example with no text overlay:
_img_2409_process_df_coverart_GET_output(
    df,
    circle_size_ratio=0.33,
    position="top-right",
    circle_color=(255, 255, 255, 255),
    text_color=(0, 255, 25, 255),
    text_scale=0.5,
    text_column=None               # Passing None will result in no text being drawn
)

#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#! FOR KEY overly 


# Process each row in the DataFrame by overlaying the key image onto the album cover.
_img_2409_overlay_df_key_GET_output(
    df,
    resize_factor=0.265,         # Adjust as needed to scale the overlay image
    position_right_cm=-0.232,    # Distance from the right edge in cm
    position_top_cm=-0.59,       # Distance from the top edge in cm
    dpi=300                      # DPI used for conversion from cm to pixels
)


# Process the DataFrame: for each row, the overlay function uses the LUFS code from 'ms_LUFS_code'
_overlay_df_circle_custom_0501_GET_image(
    df,
    circle_position=(-0.379, -1.2098003),  # Custom fractional position
    circle_diameter=2755,                  # Custom circle diameter in pixels
    ms_LUFS_column='ms_LUFS_code'           # Column from which to take the LUFS code
)

########### cliping graph 
_audio_2409_i2_GET_generate_clipping_plots(df,save_directory="images")
df['Path_jpg_clip'] = f'{direc_jpg}' + 'clip_plot' + df['ID'] + '.jpg'
# embed freq to pic 
_img_2409_i3_GET_embed_clipping_on_album(df)
# Out:
# Processing Cover Art:  38%|████████████████████                                | 5/13 [00:00<00:00, 24.12it/s]
# Processed cover image saved at images/cover_1_dy3Fv_qC55.jpg
# Processed cover image saved at images/cover_1_dy9Dr_pL45.jpg
# Processed cover image saved at images/cover_1_dy9Fv_sU66.jpg
# Processed cover image saved at images/cover_1_dy6Et_lM32.jpg
# Processed cover image saved at images/cover_1_dy0Et_vK61.jpg
# Processed cover image saved at images/cover_1_dy0Et_iS62.jpg
# Processing Cover Art:  92%|███████████████████████████████████████████████    | 12/13 [00:00<00:00, 27.21it/s]
# Processed cover image saved at images/cover_1_dy0Fu_eA59.jpg
# Processed cover image saved at images/cover_1_dy0Fu_eA59.jpg
# Processed cover image saved at images/cover_1_dy0Et_fE49.jpg
# Processed cover image saved at images/cover_1_dy9Co_lT33.jpg
# Processed cover image saved at images/cover_1_dy9Dr_lB30.jpg
# Processed cover image saved at images/cover_1_dy9Fv_lM50.jpg
# Processing Cover Art: 100%|███████████████████████████████████████████████████| 13/13 [00:00<00:00, 26.53it/s]
# Processed cover image saved at images/cover_1_dy0Fv_aM60.jpg
# Processing Cover Art: 100%|███████████████████████████████████████████████████| 13/13 [00:00<00:00, 95.59it/s]
# Processed cover image saved at images/cover_1_dy3Fv_qC55.jpg
# Processed cover image saved at images/cover_1_dy9Dr_pL45.jpg
# Processed cover image saved at images/cover_1_dy9Fv_sU66.jpg
# Processed cover image saved at images/cover_1_dy6Et_lM32.jpg
# Processed cover image saved at images/cover_1_dy0Et_vK61.jpg
# Processed cover image saved at images/cover_1_dy0Et_iS62.jpg
# Processed cover image saved at images/cover_1_dy0Fu_eA59.jpg
# Processed cover image saved at images/cover_1_dy0Fu_eA59.jpg
# Processed cover image saved at images/cover_1_dy0Et_fE49.jpg
# Processed cover image saved at images/cover_1_dy9Co_lT33.jpg
# Processed cover image saved at images/cover_1_dy9Dr_lB30.jpg
# Processed cover image saved at images/cover_1_dy9Fv_lM50.jpg
# Processed cover image saved at images/cover_1_dy0Fv_aM60.jpg
# Overlaying Key Images:   0%|                                                           | 0/13 [00:00<?, ?it/s]
# Overlay applied and saved for album at images/cover_1_dy3Fv_qC55.jpg
# Overlaying Key Images:  31%|███████████████▋                                   | 4/13 [00:00<00:00, 16.65it/s]
# Overlay applied and saved for album at images/cover_1_dy9Dr_pL45.jpg
# Overlay applied and saved for album at images/cover_1_dy9Fv_sU66.jpg
# Overlay applied and saved for album at images/cover_1_dy6Et_lM32.jpg
# Overlay applied and saved for album at images/cover_1_dy0Et_vK61.jpg
# Overlaying Key Images:  62%|███████████████████████████████▍                   | 8/13 [00:00<00:00, 16.64it/s]
# Overlay applied and saved for album at images/cover_1_dy0Et_iS62.jpg
# Overlay applied and saved for album at images/cover_1_dy0Fu_eA59.jpg
# Overlay applied and saved for album at images/cover_1_dy0Fu_eA59.jpg
# Overlay applied and saved for album at images/cover_1_dy0Et_fE49.jpg
# Overlaying Key Images:  92%|██████████████████████████████████████████████▏   | 12/13 [00:00<00:00, 16.70it/s]
# Overlay applied and saved for album at images/cover_1_dy9Co_lT33.jpg
# Overlay applied and saved for album at images/cover_1_dy9Dr_lB30.jpg
# Overlay applied and saved for album at images/cover_1_dy9Fv_lM50.jpg
# Overlaying Key Images: 100%|██████████████████████████████████████████████████| 13/13 [00:00<00:00, 16.66it/s]
# Overlay applied and saved for album at images/cover_1_dy0Fv_aM60.jpg
# Overlaying LUFS Circles:   0%|                                                         | 0/13 [00:00<?, ?it/s]
# Overlay applied on image: images/cover_1_dy3Fv_qC55.jpg
# Overlay applied on image: images/cover_1_dy9Dr_pL45.jpg
# Overlaying LUFS Circles: 100%|███████████████████████████████████████████████| 13/13 [00:00<00:00, 132.99it/s]
# Overlay applied on image: images/cover_1_dy9Fv_sU66.jpg
# Overlay applied on image: images/cover_1_dy6Et_lM32.jpg
# Overlay applied on image: images/cover_1_dy0Et_vK61.jpg
# Overlay applied on image: images/cover_1_dy0Et_iS62.jpg
# Overlay applied on image: images/cover_1_dy0Fu_eA59.jpg
# Overlay applied on image: images/cover_1_dy0Fu_eA59.jpg
# Overlay applied on image: images/cover_1_dy0Et_fE49.jpg
# Overlay applied on image: images/cover_1_dy9Co_lT33.jpg
# Overlay applied on image: images/cover_1_dy9Dr_lB30.jpg
# Overlay applied on image: images/cover_1_dy9Fv_lM50.jpg
# Overlay applied on image: images/cover_1_dy0Fv_aM60.jpg
# Generating clipping plots:   0%|                                                       | 0/13 [00:00<?, ?it/s]
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:   8%|███▌                                           | 1/13 [00:04<00:56,  4.69s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Original_Mix_KYkw_G_Minor_BPkw_124_GNkw_House_RMkw__LBkw_XDM_Records_RYkw_2020_02_14_PYkw_2025_03_27.aiff as images/clip_plotdy3Fv_qC55.jpg
#
# Top Clipping Events (dBFS > 0.0):
# Empty DataFrame
# Columns: [Time (s), Amplitude]
# Index: []
# Generating clipping plots:  15%|███████▏                                       | 2/13 [00:08<00:46,  4.22s/it]
# Saved plot for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Puerto_Rico_ARkw_Salsa_various_MXkw_original_KYkw_6A_BPkw_109_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.ai
DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
# Embedding clipping into album cover:  15%|█████▋                               | 2/13 [00:00<00:00, 18.09it/s]
# Image saved to images/cover_1_dy3Fv_qC55.jpg
# Image saved to images/cover_1_dy9Dr_pL45.jpg
# Image saved to images/cover_1_dy9Fv_sU66.jpg
# Embedding clipping into album cover:  31%|███████████▍                         | 4/13 [00:00<00:00, 18.69it/s]
# Image saved to images/cover_1_dy6Et_lM32.jpg
# Embedding clipping into album cover:  46%|█████████████████                    | 6/13 [00:00<00:00, 18.93it/s]
# Image saved to images/cover_1_dy0Et_vK61.jpg
# Image saved to images/cover_1_dy0Et_iS62.jpg
# Image saved to images/cover_1_dy0Fu_eA59.jpg
# Embedding clipping into album cover:  62%|██████████████████████▊              | 8/13 [00:00<00:00, 18.95it/s]
# Image saved to images/cover_1_dy0Fu_eA59.jpg
# Embedding clipping into album cover:  77%|███████████████████████████▋        | 10/13 [00:00<00:00, 19.13it/s]
# Image saved to images/cover_1_dy0Et_fE49.jpg
# Image saved to images/cover_1_dy9Co_lT33.jpg
# Image saved to images/cover_1_dy9Dr_lB30.jpg
# Embedding clipping into album cover:  92%|█████████████████████████████████▏  | 12/13 [00:00<00:00, 19.27it/s]
# Image saved to images/cover_1_dy9Fv_lM50.jpg
# Embedding clipping into album cover: 100%|████████████████████████████████████| 13/13 [00:00<00:00, 19.07it/s]
# Image saved to images/cover_1_dy0Fv_aM60.jpg

# %% [markdown]
# # EMBED  to AIFF ____ LAST STEP

# %%
#_aiff_2409_i1_GET_embed_aiff_covers(df)

# %% [markdown]
# # dynamic BPM

# %%
# 0_FNS
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# ###########################################################################
# ########## CORE FUNCTION: _bpm_2610_i3_GET_partialdonut_bpmdynamic   ########
# ###########################################################################
def _bpm_2610_i3_GET_partialdonut_bpmdynamic(df: pd.DataFrame, save_dir: str = "images") -> None:
    """
    Iterates over the provided DataFrame and saves an individual PNG for each row.
    Each PNG contains a donut chart that illustrates the BPM dynamic percentage as 
    a colored wedge (based on 'bpm_consistency_cat') with the remainder of the circle transparent.
    
    The donut is only partially complete in reference to the provided percentage.
    The figure is saved as a PNG with a transparent background and no extra labels.
    
    The PNG files are saved using the value from the 'ID' column in the DataFrame.
    
    Parameters:
        df (pd.DataFrame): DataFrame with columns:
                           - 'bpm_consistency': numeric value between 0 and 100.
                           - 'bpm_consistency_cat': dynamic category label (e.g., 'D_0', 'D_1', 'D_3', 'D_6', 'D_9'),
                             with D_0 being least dynamic (yellow) and D_9 super dynamic (dark gray).
                           - 'ID': unique identifier for each row/song used for file naming.
        save_dir (str): Directory where the PNG images will be saved. Defaults to "images".
    """
    # Define a cohesive color mapping using a Material Design–inspired gradient.
    color_mapping = {
         'D_0': "#FFEB3B",  # Bright yellow (original)
    'D_1': "#E6D435",  # 90% brightness of D_0
    'D_3': "#CCBC2F",  # 80% brightness of D_0
    'D_6': "#998D23",  # 60% brightness of D_0
    'D_9': "#665E17"    # Near-black
    }
    
    # Ensure the save directory exists.
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    if not save_dir.endswith(os.sep):
        save_dir += os.sep

    # ------------------ TQM BAR: Starting donut generation with 50% thinner ring ------------------
    # Iterate over each row in the DataFrame.
    for _, row in df.iterrows():
        dynamic_value = row['bpm_consistency']  # Percentage value (0 to 100)
        dynamic_cat = row['bpm_consistency_cat']
        
        # Compute the segments: filled part equals dynamic percentage; remainder (to 100) is transparent.
        segments = [dynamic_value, 100 - dynamic_value]
        colors = [color_mapping.get(dynamic_cat, '#9E9E9E'), (0, 0, 0, 0)]
        
        # Create figure and axis.
        fig, ax = plt.subplots(figsize=(6, 6))
        ax.axis('off')  # Remove axes for a clean image.
        
        # Draw the donut chart using wedgeprops to create a hole in the center.
        # Updated wedge width to 0.15 (i.e., 50% thinner than the original 0.3)
        ax.pie(
            segments, 
            colors=colors, 
            startangle=90, 
            counterclock=False, 
            wedgeprops={'width': 0.15, 'edgecolor': 'none'}
        )
        
        # Use the value in the 'ID' column as the file name.
        file_name = f"{save_dir}bpm_bar_dyn_{row['ID']}.png"
        plt.savefig(file_name, bbox_inches='tight', pad_inches=0, transparent=True)
        plt.close(fig)
        print(f"Saved: {file_name}")
    # ------------------ TQM BAR: Donut generation completed ------------------
# ########## END OF CORE FUNCTION ###########################################
# ########## END OF CORE FUNCTION ###########################################
_bpm_2610_i3_GET_partialdonut_bpmdynamic(df, save_dir="images")
df['Path_png_bar_dyn'] = f'{direc_jpg}' + 'bpm_bar_dyn_' + df['ID'] + '.png'
df
# Out:
# Saved: images/bpm_bar_dyn_dy3Fv_qC55.png
# Saved: images/bpm_bar_dyn_dy9Dr_pL45.png
# Saved: images/bpm_bar_dyn_dy9Fv_sU66.png
# Saved: images/bpm_bar_dyn_dy6Et_lM32.png
# Saved: images/bpm_bar_dyn_dy0Et_vK61.png
# Saved: images/bpm_bar_dyn_dy0Et_iS62.png
# Saved: images/bpm_bar_dyn_dy0Fu_eA59.png
# Saved: images/bpm_bar_dyn_dy0Fu_eA59.png
# Saved: images/bpm_bar_dyn_dy0Et_fE49.png
# Saved: images/bpm_bar_dyn_dy9Co_lT33.png
# Saved: images/bpm_bar_dyn_dy9Dr_lB30.png
# Saved: images/bpm_bar_dyn_dy9Fv_lM50.png
# Saved: images/bpm_bar_dyn_dy0Fv_aM60.png
#                                                  Path  \
# 0   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 1   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 2   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 3   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 4   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 5   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 6   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 7   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 8   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 9   /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 10  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 11  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 12  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
#
#                                               temp_id  \
# 0   TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Ori...
# 1   TRkw_Puerto_Rico_ARkw_Salsa_various_MXkw_origi...
# 2   TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_...
# 3   TRkw_La_Loca_Eres_Tu_ARkw_Salsa_various_MXkw_o...
# 4   TRkw_Violet_ARkw_Keita_Sano_MXkw_Original_Mix_...
# 5   TRkw_Into_The_Night_ARkw_Soul_of_Hex_MXkw_Orig...
# 6   TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...
# 7   TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...
# 8   Edson Conceição - Filhos de Gandhi (Um Abrac...
# 9   TRkw_Laope_ARkw_Salsa_various_MXkw_original_KY...
# 10  TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_ori...
# 11  TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_...
# 12  TRkw_Alright_ARkw_Men_I_Trust_MXkw_Haveck_Remi...
#
#                                             file_name Extension dur_seconds  \
# 0   TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Ori...     .aiff   312.58068
# 1   TRkw_Puerto_Rico_ARkw_Salsa_various_MXkw_origi...     .aiff  259.765374
# 2   TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_...     .aiff      376.44
# 3   TRkw_La_Loca_Eres_Tu_ARkw_Salsa_various_MXkw_o...     .aiff  184.297234
# 4   TRkw_Violet_ARkw_Keita_Sano_MXkw_Original_Mix_...     .aiff  342.486893
# 5   TRkw_Into_The_Night_ARkw_Soul_of_Hex_MXkw_Orig...     .aiff  352.452154
# 6   TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...     .aiff  334.964717
# 7   TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...     .aiff  334.964717
# 8   Edson Conceição - Filhos de Gandhi (Um Abrac...     .aiff  278.181814
# 9   TRkw_Laope_ARkw_Salsa_various_MXkw_original_KY...     .aiff  188.650385
# 10  TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_ori...     .aiff  170.649819
# 11  TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_...     .aiff  277.733333
# 12  TRkw_Alright_ARkw_Men_I_Trust_MXkw_Haveck_Remi...     .aiff  341.694921
#
#      dur_min     sr bit_depth bit_rate channels  ... Relative_Key Key_Up  \
# 0   5.209678  44100        16     None        2  ...           6B     7A
# 1   4.329423  44100        16     None        2  ...           9A    10B
# 2      6.274  44100        16     None        2  ...          10B    11A
# 3   3.071621  44100        16     None        2  ...           6A     7B
# 4   5.708115  44100        16     None        2  ...           4B     5A
# 5   5.874203  44100        16     None        2  ...           6B     7A
# 6   5.582745  44100        16     None        2  ...           9B    10A
# 7   5.582745  44100        16     None        2  ...           9B    10A
# 8   4.636364  44100        16     None        2  ...          10B    11A
# 9   3.144173  44100        16     None        2  ...           8A     9B
# 10  2.844164  44100        16     None        2  ...           6B     7A
# 11  4.628889  44100        16     None        2  ...           8B     9A
# 12  5.694915  44100        16     None        2  ...          11B    12A
#
#    Key_Down Jaw_s_Mix  Mood_Shifter          ID  \
# 0        5A        1A            9B  dy3Fv_qC55
# 1        8B        4B            6A  dy9Dr_pL45
# 2        9A        5A            1B  dy9Fv_sU66
# 3        5B        1B            3A  dy6Et_lM32
# 4        3A       11A            7B  dy0Et_vK61
# 5        5A        1A            9B  dy0Et_iS62
# 6        8A        4A           12B  dy0Fu_eA59
# 7        8A        4A           12B  dy0Fu_eA59
# 8        9A        5A            1B  dy0Et_fE49
# 9        7B        3B            5A  dy9Co_lT33
# 10       5A        1A            9B  dy9Dr_lB30
# 11       7A        3A           11B  dy9Fv_lM50
# 12      10A        6A            2B  dy0Fv_aM60
#
#                    Path_jpg_album                   Path_jpg_key  \
# 0   images/cover_1_dy3Fv_qC55.jpg  images/key_plotdy3Fv_qC55.png
# 1   images/cover_1_dy9Dr_pL45.jpg  images/key_plotdy9Dr_pL45.png
# 2   images/cover_1_dy9Fv_sU66.jpg  images/key_plotdy9Fv_sU66.png
# 3   images/cover_1_dy6Et_lM32.jpg  images/key_plotdy6Et_lM32.png
# 4   images/cover_1_dy0Et_vK61.jpg  images/key_plotdy0Et_vK61.png
# 5   images/cover_1_dy0Et_iS62.jpg  images/key_plotdy0Et_iS62.png
# 6   images/cover_1_dy0Fu_eA59.jpg  images/key_plotdy0Fu_eA59.png
# 7   images/cover_1_dy0Fu_eA59.jpg  images/key_plotdy0Fu_eA59.png
# 8   images/cover_1_dy0Et_fE49.jpg  images/key_plotdy0Et_fE49.png
# 9   images/cover_1_dy9Co_lT33.jpg  images/key_plotdy9Co_lT33.png
# 10  images/cover_1_dy9Dr_lB30.jpg  images/key_plotdy9Dr_lB30.png
# 11  images/cover_1_dy9Fv_lM50.jpg  images/key_plotdy9Fv_lM50.png
# 12  images/cover_1_dy0Fv_aM60.jpg  images/key_plotdy0Fv_aM60.png
#
#                      Path_jpg_clip                   Path_png_bar_dyn
# 0   images/clip_plotdy3Fv_qC55.jpg  images/bpm_bar_dyn_dy3Fv_qC55.png
# 1   images/clip_plotdy9Dr_pL45.jpg  images/bpm_bar_dyn_dy9Dr_pL45.png
# 2   images/clip_plotdy9Fv_sU66.jpg  images/bpm_bar_dyn_dy9Fv_sU66.png
# 3   images/clip_plotdy6Et_lM32.jpg  images/bpm_bar_dyn_dy6Et_lM32.png
# 4   images/clip_plotdy0Et_vK61.jpg  images/bpm_bar_dyn_dy0Et_vK61.png
# 5   images/clip_plotdy0Et_iS62.jpg  images/bpm_bar_dyn_dy0Et_iS62.png
# 6   images/clip_plotdy0Fu_eA59.jpg  images/bpm_bar_dyn_dy0Fu_eA59.png
# 7   images/clip_plotdy0Fu_eA59.jpg  images/bpm_bar_dyn_dy0Fu_eA59.png
# 8   images/clip_plotdy0Et_fE49.jpg  images/bpm_bar_dyn_dy0Et_fE49.png
# 9   images/clip_plotdy9Co_lT33.jpg  images/bpm_bar_dyn_dy9Co_lT33.png
# 10  images/clip_plotdy9Dr_lB30.jpg  images/bpm_bar_dyn_dy9Dr_lB30.png
# 11  images/clip_plotdy9Fv_lM50.jpg  images/bpm_bar_dyn_dy9Fv_lM50.png
# 12  images/clip_plotdy0Fv_aM60.jpg  images/bpm_bar_dyn_dy0Fv_aM60.png
#
# [13 rows x 56 columns]

# %%
# 0_FNS
import os
from PIL import Image
import pandas as pd

# ###########################################################################
# ########## CORE FUNCTION: _bpm_2610_i4_GET_embedded_album_dynamic_custom ########
# ###########################################################################
def _bpm_2610_i4_GET_embedded_album_dynamic_custom(
    df: pd.DataFrame,
    position: str = "top_left",
    x_offset: int = 10,
    y_offset: int = 10,
    scale: float = 1.0,
    custom_coords: tuple = None
) -> None:
    """
    Overlays each dynamic (donut) PNG image onto its corresponding album JPG image
    and saves the composite by overwriting the original album file (keeping the same file name).
    
    For each row in the DataFrame, the function:
      - Opens the album image from 'Path_jpg_album'.
      - Opens the dynamic overlay image from 'Path_png_bar_dyn'.
      - Optionally rescales the overlay image using the scale factor.
      - Determines placement based on the provided 'position' parameter and separate
        'x_offset' and 'y_offset' values:
          * For "top_left": shifts right by x_offset and downward by y_offset.
          * For "top_right": shifts left by x_offset and downward by y_offset.
          * For "bottom_left": shifts right by x_offset and upward by y_offset.
          * For "bottom_right": shifts left by x_offset and upward by y_offset.
          * For "custom": exact coordinates must be provided in custom_coords.
      - Pastes the overlay onto the album image using its alpha channel.
      - Saves the composite image over the original album JPG (preserving its file name).
    
    Parameters:
        df (pd.DataFrame): DataFrame containing:
            - 'ID': Unique identifier.
            - 'Path_png_bar_dyn': File path to the dynamic overlay PNG image.
            - 'Path_jpg_album': File path to the album JPG image (and destination for the composite).
        position (str): Anchor position for the overlay relative to the album image.
                        Options: "top_left", "top_right", "bottom_left", "bottom_right", "custom".
                        Default is "top_left".
        x_offset (int): Horizontal offset (in pixels) from the anchor position.
                        For "top_left" and "bottom_left", positive values shift the overlay right.
                        For "top_right" and "bottom_right", positive values shift the overlay left.
        y_offset (int): Vertical offset (in pixels) from the anchor position.
                        For "top_left" and "top_right", positive values shift the overlay downward.
                        For "bottom_left" and "bottom_right", positive values shift the overlay upward.
        scale (float): Scaling factor for the overlay image. Default is 1.0 (no scaling).
        custom_coords (tuple): If position is "custom", supply exact (x, y) coordinates.
    """
    for _, row in df.iterrows():
        album_path = row['Path_jpg_album']
        overlay_path = row['Path_png_bar_dyn']
        
        try:
            album_img = Image.open(album_path).convert("RGBA")
            overlay_img = Image.open(overlay_path).convert("RGBA")
        except Exception as e:
            print(f"Error opening images for ID {row['ID']}: {e}")
            continue
        
        # Apply scaling if the scale factor is not 1.0.
        if scale != 1.0:
            new_size = (int(overlay_img.width * scale), int(overlay_img.height * scale))
            overlay_img = overlay_img.resize(new_size, Image.ANTIALIAS)
        
        # Determine placement coordinates based on the selected position.
        if position == "top_left":
            x = x_offset
            y = y_offset
        elif position == "top_right":
            x = album_img.width - overlay_img.width - x_offset
            y = y_offset
        elif position == "bottom_left":
            x = x_offset
            y = album_img.height - overlay_img.height - y_offset
        elif position == "bottom_right":
            x = album_img.width - overlay_img.width - x_offset
            y = album_img.height - overlay_img.height - y_offset
        elif position == "custom":
            if custom_coords is None:
                raise ValueError("Custom coordinates must be provided when position is 'custom'.")
            else:
                x, y = custom_coords
        else:
            raise ValueError("Invalid position value. Choose from: top_left, top_right, bottom_left, bottom_right, custom.")
        
        # Paste the overlay image onto the album image with transparency.
        album_img.paste(overlay_img, (x, y), overlay_img)
        
        # Save the composite over the original album image (converting from RGBA to RGB).
        album_img.convert("RGB").save(album_path, "JPEG")
        print(f"Saved composite over album: {album_path}")
# ########## END OF CORE FUNCTION ###########################################

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
# With your DataFrame 'df' (which contains 'ID', 'Path_png_bar_dyn', and 'Path_jpg_album'),
# call the function to overlay the dynamic PNG onto the album JPG.
_bpm_2610_i4_GET_embedded_album_dynamic_custom(
    df,
    position="top_left",  # adjust as needed: "top_left", "top_right", "bottom_left", "bottom_right", "custom"
    x_offset=-1,          # horizontal offset: increase to move right (for top_left or bottom_left) or left (for top_right or bottom_right)
    y_offset=-8,          # vertical offset: increase to move down (for top positions) or up (for bottom positions)
    scale=.65             # adjust the scale if needed
    # custom_coords=(x, y) can be provided if position is "custom"
)
# Out:
# Saved composite over album: images/cover_1_dy3Fv_qC55.jpg
# Saved composite over album: images/cover_1_dy9Dr_pL45.jpg
# Saved composite over album: images/cover_1_dy9Fv_sU66.jpg
# /var/folders/pp/n6z2gh0x56ngpvp6vx5ml9j00000gn/T/ipykernel_44654/2552276737.py:66: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#
BPkw_105_GNkw_Mexican_House_RMkw__LBkw_ Sabrosura_Records_RYkw_2014_06_28_PYkw_2025_04_01.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_Y_Su_Trabuco_MXkw_Original_Mix_KYkw_A_Minor_BPkw_98_GNkw_House_RMkw__LBkw_Planet_Records_RYkw_2019_09_01_PYkw_2025_03_27.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_Y_Su_Trabuco_MXkw_Original_Mix_KYkw_A_Minor_BPkw_98_GNkw_House_RMkw__LBkw_Planet_Records_RYkw_2019_09_01_PYkw_2025_03_27.aiff
# Updated existing cover tag for /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Alright_ARkw_Men_I_Trust_MXkw_Haveck_Remix_KYkw_A_Major_BPkw_118_GNkw_Indie_Dance_RMkw_Haveck_LBkw_Audio_B_RYkw_2020_01_26_PYkw_2025_02_21.aiff
# Cover image successfully embedded in /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/cover/TRkw_Alright_ARkw_Men_I_Trust_MXkw_Haveck_Remix_KYkw_A_Major_BPkw_118_GNkw_Indie_Dance_RMkw_Haveck_LBkw_Audio_B_RYkw_2020_01_26_PYkw_2025_02_21.aiff

# %% [markdown]
# # frequency

# %%
df
# Out:
#                                                 Path  \
# 0  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 1  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 2  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 3  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 4  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 5  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
# 6  /Users/yerik/Music/_1_NEW_SOURCE/_2025_this/co...
#
#                                              temp_id  \
# 0  TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Ori...
# 1  TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_...
# 2  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...
# 3  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...
# 4  TRkw_Laope_ARkw_Salsa_various_MXkw_original_KY...
# 5  TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_ori...
# 6  TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_...
#
#                                            file_name Extension dur_seconds  \
# 0  TRkw_Quizas_(Extended)_ARkw_CASUAL_SX_MXkw_Ori...     .aiff   312.58068
# 1  TRkw_So_Get_Up_2002_ARkw_Underground_Sound_of_...     .aiff      376.44
# 2  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...     .aiff  334.964717
# 3  TRkw_Endless_Summer_ARkw_Alma_Negra_MXkw_Soulp...     .aiff  334.964717
# 4  TRkw_Laope_ARkw_Salsa_various_MXkw_original_KY...     .aiff  188.650385
# 5  TRkw_Los_Drasticos_ARkw_Salsa_various_MXkw_ori...     .aiff  170.649819
# 6  TRkw_La_Habana_Me_Llama_ARkw_Manolito_Simonet_...     .aiff  277.733333
#
#     dur_min     sr bit_depth bit_rate channels  ... key_music  \
# 0  5.209678  44100        16     None        2  ...      Gmin
# 1     6.274  44100        16     None        2  ...      Bmin
# 2  5.582745  44100        16     None        2  ...      Emin
# 3  5.582745  44100        16     None        2  ...      Emin
# 4  3.144173  44100        16     None        2  ...      Cmaj
# 5  2.844164  44100        16     None        2  ...      Gmin
# 6  4.628889  44100        16     None        2  ...      Amin
#
#                   status Relative_Key Key_Up  Key_Down Jaw_s_Mix  \
# 0  Success: TKEY updated           6B     7A        5A        1A
# 1  Success: TKEY updated          10B    11A        9A        5A
# 2  Success: TKEY updated           9B    10A        8A        4A
# 3  Success: TKEY updated           9B    10A        8A        4A
# 4  Success: TKEY updated           8A     9B        7B        3B
# 5  Success: TKEY updated           6B     7A        5A        1A
# 6  Success: TKEY updated           8B     9A        7A        3A
#
#    Mood_Shifter    ID           Path_jpg_album             Path_jpg_key
# 0            9B  UU03  images/cover_1_UU03.jpg  images/key_plotUU03.png
# 1            1B  JU68  images/cover_1_JU68.jpg  images/key_plotJU68.png
# 2           12B  AK75  images/cover_1_AK75.jpg  images/key_plotAK75.png
# 3           12B  DC18  images/cover_1_DC18.jpg  images/key_plotDC18.png
# 4            5A  HH52  images/cover_1_HH52.jpg  images/key_plotHH52.png
# 5            9B  UI66  images/cover_1_UI66.jpg  images/key_plotUI66.png
# 6           11B  QP47  images/cover_1_QP47.jpg  images/key_plotQP47.png
#
# [7 rows x 53 columns]
