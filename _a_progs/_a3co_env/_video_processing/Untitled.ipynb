# %%
vids_input = "/Users/yerik/Desktop/_2_DJ_VIDS/PUMA_VIDS_in"

# %%
# -----######-----###### ULTRA VERIFIED RENAME: REAL FPS, RES, DURATION, TIMESTAMP -----######-----######
import subprocess, os
from pathlib import Path
from datetime import datetime, timedelta
import cv2

def _video_0506_pipe_GET_realdata_verifiedrename(folder_path):
    folder = Path(folder_path)
    video_files = sorted(list(folder.rglob("*.mp4")) + list(folder.rglob("*.MP4")))
    if not video_files:
        print("❌ No MP4 files found.")
        return

    for f in video_files:
        print(f"\n📼 Verifying: {f.name}")
        os.system(f'open "{f}"')
        keyword = input("🎤 Enter keyword for this clip (e.g. DJ name, event): ").strip().replace(" ", "_")

        try:
            # --- Get creation time from ffprobe ---
            cmd = [
                "ffprobe", "-v", "error",
                "-select_streams", "v:0",
                "-show_entries", "stream_tags=creation_time",
                "-of", "default=noprint_wrappers=1:nokey=0",
                str(f)
            ]
            output = subprocess.check_output(cmd).decode().splitlines()
            creation_line = next((l for l in output if "TAG:creation_time=" in l), None)
            if not creation_line:
                print(f"❌ No creation_time in metadata: {f.name}")
                continue
            creation_time = creation_line.split("=", 1)[1].strip()
            dt = datetime.fromisoformat(creation_time.replace("Z", "+00:00"))

            # --- OpenCV for actual duration, resolution, fps ---
            cap = cv2.VideoCapture(str(f))
            if not cap.isOpened():
                print(f"❌ Cannot open video for frame analysis: {f.name}")
                continue

            width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = cap.get(cv2.CAP_PROP_FPS)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            cap.release()

            if width == 0 or height == 0 or fps == 0:
                print(f"❌ Invalid resolution/FPS for: {f.name}")
                continue

            duration_sec = int(frame_count / fps)
            duration_min = round(duration_sec / 60)

            # --- Aspect ratio label ---
            ratio = round(width / height, 2)
            if abs(ratio - 16/9) < 0.05:
                aspect = "16_9"
            elif abs(ratio - 4/3) < 0.05:
                aspect = "4_3"
            else:
                aspect = str(ratio).replace(".", "_")

            # --- Compose filename ---
            ext = f.suffix.lower()
            fps_label = round(fps)
            new_name = (
                f"vid_{dt.strftime('%Y_%m_%d')}_Hr_{dt.strftime('%H_%M_%S')}_"
                f"Yfram_{fps_label}_Yvres_{width}x{height}_Yaspr_{aspect}_Ydura_{duration_min}_MIN_{keyword}{ext}"
            )
            new_path = f.with_name(new_name)

            # --- Collision handling ---
            counter = 1
            while new_path.exists():
                new_name = f"{new_path.stem}_no_{counter}{ext}"
                new_path = f.with_name(new_name)
                counter += 1

            print(f"\n🔁 Verified Rename:\n→ {f.name} ➡️ {new_path.name}")
            input("✅ Press ENTER to confirm, or CTRL+C to skip...")
            f.rename(new_path)
            print(f"✅ Renamed to: {new_path.name}")

        except Exception as e:
            print(f"❌ Error: {e}")

# %%
_video_0506_pipe_GET_realdata_verifiedrename(vids_input)
# Out:
# 📼 Verifying: GX010043.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  ERASE
# 🔁 Verified Rename:
# → GX010043.MP4 ➡️ vid_2025_03_28_Hr_21_16_09_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_ERASE.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_03_28_Hr_21_16_09_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_ERASE.mp4
#
# 📼 Verifying: GX010046.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  ERASE
# 🔁 Verified Rename:
# → GX010046.MP4 ➡️ vid_2025_03_28_Hr_21_20_46_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_ERASE.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_03_28_Hr_21_20_46_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_ERASE.mp4
#
# 📼 Verifying: GX010048.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJDIFFANGLE
# 🔁 Verified Rename:
# → GX010048.MP4 ➡️ vid_2025_03_28_Hr_23_16_25_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJDIFFANGLE.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_03_28_Hr_23_16_25_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJDIFFANGLE.mp4
#
# 📼 Verifying: GX010049.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJ_DIFF ANGLE
# 🔁 Verified Rename:
# → GX010049.MP4 ➡️ vid_2025_03_29_Hr_23_12_31_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_YODJ_DIFF_ANGLE.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_03_29_Hr_23_12_31_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_YODJ_DIFF_ANGLE.mp4
#
# 📼 Verifying: GX010051.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJDIFF ANGLE
# 🔁 Verified Rename:
# → GX010051.MP4 ➡️ vid_2025_03_29_Hr_23_12_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_1_MIN_YODJDIFF_ANGLE.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_03_29_Hr_23_12_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_1_MIN_YODJDIFF_ANGLE.mp4
#
# 📼 Verifying: GX010052.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJ DIFF ANGLE
# 🔁 Verified Rename:
# → GX010052.MP4 ➡️ vid_2025_04_05_Hr_23_10_35_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_DIFF_ANGLE.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_05_Hr_23_10_35_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_DIFF_ANGLE.mp4
#
# 📼 Verifying: GX010056.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJGOOD ONE
# 🔁 Verified Rename:
# → GX010056.MP4 ➡️ vid_2025_04_11_Hr_23_18_33_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJGOOD_ONE.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_11_Hr_23_18_33_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJGOOD_ONE.mp4
#
# 📼 Verifying: GX010057.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  ERASE
# 🔁 Verified Rename:
# → GX010057.MP4 ➡️ vid_2025_04_14_Hr_22_57_36_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_ERASE.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_14_Hr_22_57_36_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_ERASE.mp4
#
# 📼 Verifying: GX020048.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJ TOWARDS NIGHT
# 🔁 Verified Rename:
# → GX020048.MP4 ➡️ vid_2025_03_28_Hr_23_16_25_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_72_MIN_YODJ_TOWARDS_NIGHT.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_03_28_Hr_23_16_25_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_72_MIN_YODJ_TOWARDS_NIGHT.mp4
#
# 📼 Verifying: GX020052.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJ TOWARDS NIGHTT
# 🔁 Verified Rename:
# → GX020052.MP4 ➡️ vid_2025_04_05_Hr_23_10_35_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_60_MIN_YODJ_TOWARDS_NIGHTT.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_05_Hr_23_10_35_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_60_MIN_YODJ_TOWARDS_NIGHTT.mp4
#
# 📼 Verifying: GX020055.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  SINC
# 🔁 Verified Rename:
# → GX020055.MP4 ➡️ vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_SINC.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_SINC.mp4
#
# 📼 Verifying: GX020056.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJ
# 🔁 Verified Rename:
# → GX020056.MP4 ➡️ vid_2025_04_11_Hr_23_18_33_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_42_MIN_YODJ.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_11_Hr_23_18_33_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_42_MIN_YODJ.mp4
#
# 📼 Verifying: GX020059.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  ATM
# 🔁 Verified Rename:
# → GX020059.MP4 ➡️ vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ATM.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ATM.mp4
#
# 📼 Verifying: GX030055.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  SINC
# 🔁 Verified Rename:
# → GX030055.MP4 ➡️ vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_SINC_no_1.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_SINC_no_1.mp4
#
# 📼 Verifying: GX030059.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  ATM
# 🔁 Verified Rename:
# → GX030059.MP4 ➡️ vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_21_MIN_ATM.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_21_MIN_ATM.mp4
#
# 📼 Verifying: both_.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJ SINC
# 🔁 Verified Rename:
# → both_.MP4 ➡️ vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_SINC.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_SINC.mp4
#
# 📼 Verifying: both_ATM_YODJ.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  YODJ ATM
# 🔁 Verified Rename:
# → both_ATM_YODJ.MP4 ➡️ vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_ATM.mp4
# ✅ Press ENTER to confirm, or CTRL+C to skip...
# ✅ Renamed to: vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_ATM.mp4

# %%
# -----######-----###### FULL BATCH W/ CUSTOM CUT OPTION + TQDM -----######-----######
from moviepy.editor import VideoFileClip
from pathlib import Path
from tqdm import tqdm
import random

def _video_0506_storybatch_GET_all9_random_custom(input_folder, duration=60):
    input_folder = Path(input_folder)
    video_paths = [p for p in input_folder.iterdir() if p.suffix.lower() == '.mp4']

    if not video_paths:
        return "❌ No .mp4 files found in input folder."

    for video_path in video_paths:
        clip = VideoFileClip(str(video_path))
        total_duration = clip.duration
        usable_range = total_duration - duration

        if usable_range <= 0:
            print(f"⚠️ Skipping {video_path.name} (too short)")
            continue

        output_dir = input_folder / video_path.stem
        output_dir.mkdir(exist_ok=True)

        base_points = [usable_range * i / 9 for i in range(9)]
        random_offsets = [random.uniform(0, usable_range / 9) for _ in range(9)]
        start_times = [min(bp + ro, usable_range) for bp, ro in zip(base_points, random_offsets)]

        print(f"\n📤 Processing: {video_path.name}")
        for i, start_time in tqdm(enumerate(start_times), total=9, desc=f"⏳ {video_path.stem[:20]}"):
            subclip = clip.subclip(start_time, start_time + duration)
            subclip_resized = subclip.resize(height=1080).crop(x_center=subclip.w / 2, width=608)
            out_path = output_dir / f"{video_path.stem}_story_{i+1:02}.mp4"
            subclip_resized.write_videofile(str(out_path), codec="libx264", audio_codec="aac", verbose=False, logger=None)

        print(f"✅ 9 random clips saved for: {video_path.stem}")

        custom_index = 1
        while True:
            response = 'n'#input(f"✂️  Export custom cut from {video_path.name}? (y/n): ").strip().lower()
            if response != 'y':
                break

            range_str = input("🕐 Enter start-end in minutes (e.g. 1.2 - 3.2): ").strip()
            try:
                start_min, end_min = [float(x.strip()) for x in range_str.split("-")]
                start_sec = start_min * 60
                end_sec = end_min * 60

                if end_sec > total_duration or start_sec >= end_sec:
                    print("❌ Invalid range. Try again.")
                    continue

                subclip = clip.subclip(start_sec, end_sec)
                subclip_resized = subclip.resize(height=1080).crop(x_center=subclip.w / 2, width=608)
                out_path = output_dir / f"__custom_{video_path.stem}_{custom_index}.mp4"
                subclip_resized.write_videofile(str(out_path), codec="libx264", audio_codec="aac", verbose=False, logger=None)
                print(f"✅ Custom clip saved: {out_path.name}")
                custom_index += 1

            except Exception as e:
                print(f"❌ Error parsing input: {e}")
                continue

    return "✅ All videos processed with optional custom cuts."

# %%
_video_0506_storybatch_GET_all9_random_custom(
    vids_input,
    duration=60
)
# Out:
# 📤 Processing: vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_ATM.mp4
# ⏳ vid_2025_04_15_Hr_00: 100%|█| 9/9 [03:01<00:00, 20.
# ✅ 9 random clips saved for: vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_ATM
# ⚠️ Skipping vid_2025_04_14_Hr_22_57_36_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_ERASE.mp4 (too short)
# ⚠️ Skipping vid_2025_03_29_Hr_23_12_31_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_YODJ_DIFF_ANGLE.mp4 (too short)
#
# 📤 Processing: vid_2025_03_28_Hr_23_16_25_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJDIFFANGLE.mp4
# ⏳ vid_2025_03_28_Hr_23: 100%|█| 9/9 [03:08<00:00, 20.
# ✅ 9 random clips saved for: vid_2025_03_28_Hr_23_16_25_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJDIFFANGLE
#
# 📤 Processing: vid_2025_04_11_Hr_23_18_33_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJGOOD_ONE.mp4
# ⏳ vid_2025_04_11_Hr_23: 100%|█| 9/9 [02:51<00:00, 19.
# ✅ 9 random clips saved for: vid_2025_04_11_Hr_23_18_33_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJGOOD_ONE
#
# 📤 Processing: vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_SINC_no_1.mp4
# ⏳ vid_2025_04_08_Hr_00: 100%|█| 9/9 [02:22<00:00, 15.
# ✅ 9 random clips saved for: vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_SINC_no_1
# ⚠️ Skipping vid_2025_03_28_Hr_21_20_46_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_ERASE.mp4 (too short)
#
# 📤 Processing: vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_SINC.mp4
# ⏳ vid_2025_04_08_Hr_00: 100%|█| 9/9 [02:32<00:00, 16.
# ✅ 9 random clips saved for: vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_SINC
# ⚠️ Skipping vid_2025_03_28_Hr_21_16_09_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_0_MIN_ERASE.mp4 (too short)
#
# 📤 Processing: vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_SINC.mp4
# ⏳ vid_2025_04_08_Hr_00: 100%|█| 9/9 [02:27<00:00, 16.
# ✅ 9 random clips saved for: vid_2025_04_08_Hr_00_08_06_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_SINC
#
# 📤 Processing: vid_2025_03_28_Hr_23_16_25_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_72_MIN_YODJ_TOWARDS_NIGHT.mp4
# ⏳ vid_2025_03_28_Hr_23: 100%|█| 9/9 [02:25<00:00, 16.
# ✅ 9 random clips saved for: vid_2025_03_28_Hr_23_16_25_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_72_MIN_YODJ_TOWARDS_NIGHT
#
# 📤 Processing: vid_2025_04_05_Hr_23_10_35_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_60_MIN_YODJ_TOWARDS_NIGHTT.mp4
# ⏳ vid_2025_04_05_Hr_23: 100%|█| 9/9 [02:31<00:00, 16.
# ✅ 9 random clips saved for: vid_2025_04_05_Hr_23_10_35_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_60_MIN_YODJ_TOWARDS_NIGHTT
#
# 📤 Processing: vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ATM.mp4
# ⏳ vid_2025_04_15_Hr_00: 100%|█| 9/9 [02:24<00:00, 16.
# ✅ 9 random clips saved for: vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ATM
#
# 📤 Processing: vid_2025_04_11_Hr_23_18_33_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_42_MIN_YODJ.mp4
# ⏳ vid_2025_04_11_Hr_23: 100%|█| 9/9 [04:30<00:00, 30.
# ✅ 9 random clips saved for: vid_2025_04_11_Hr_23_18_33_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_42_MIN_YODJ
#
# 📤 Processing: vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_21_MIN_ATM.mp4
# ⏳ vid_2025_04_15_Hr_00: 100%|█| 9/9 [02:38<00:00, 17.
# ✅ 9 random clips saved for: vid_2025_04_15_Hr_00_08_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_21_MIN_ATM
#
# 📤 Processing: vid_2025_03_29_Hr_23_12_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_1_MIN_YODJDIFF_ANGLE.mp4
# ⏳ vid_2025_03_29_Hr_23: 100%|█| 9/9 [02:25<00:00, 16.
# ✅ 9 random clips saved for: vid_2025_03_29_Hr_23_12_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_1_MIN_YODJDIFF_ANGLE
#
# 📤 Processing: vid_2025_04_05_Hr_23_10_35_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_DIFF_ANGLE.mp4
# ⏳ vid_2025_04_05_Hr_23: 100%|█| 9/9 [02:33<00:00, 17.
# ✅ 9 random clips saved for: vid_2025_04_05_Hr_23_10_35_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_YODJ_DIFF_ANGLE
# '✅ All videos processed with optional custom cuts.'
