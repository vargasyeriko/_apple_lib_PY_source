# %%
###############
##########
######
vids_input = "/Users/yerik/Movies/morning_rave"
base_name = "Morning_Rave"
custom_length = input(f"✂️  Export custom NORMAL cut from ? (y/n): ").strip().lower()
custom = input(f"✂️  Export custom STORY cut from ? (y/n): ").strip().lower()
#####
########
#############
from _fn_go_pro import _video_1308_goproseq_GET_renamed_files
from _fn_go_pro import _video_1408_mp4chop_GET_export_clips
from _fn_go_pro import _video_0506_pipe_GET_realdata_verifiedrename
from _fn_go_pro import _video_story_mp4
from _fn_go_pro import _video_together_and_mp3
#############
########
###
# Out:
# ✂️  Export custom NORMAL cut from ? (y/n):  n
# ✂️  Export custom STORY cut from ? (y/n):  n

# %% [markdown]
# # rename but check if right progression ---???? check with the next ... be careful

# %%
# folder_or_paths = vids_input

# video_extensions = [".mp4", ".mov", ".m4v", ".MP4", ".MOV", ".M4V"]

# # Dry run first
# map_df = _video_1308_goproseq_GET_renamed_files(
#     inputs=folder_or_paths,
#     base_name=base_name,
#     video_extensions=video_extensions,
#     prefix="_gp",
#     start_index=1,
#     dry_run=False,
#     overwrite=False
# )
# print(map_df)

# %% [markdown]
# # rename with gp1 etc and also name DJS ? and also change to .mov ?

# %%
input("remeber to rename with gp1 gp2 gp3 etc ... ")
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#! # 
_video_0506_pipe_GET_realdata_verifiedrename(
    folder_path=vids_input,  # ⬅️ your video folder
    delete='n'  # set to 'n' to keep the original MP4
)

# %% [markdown]
# ## chop off video for normal size

# %%
duration_seconds = 90
number_of_clips = 9

_video_1408_mp4chop_GET_export_clips(
    vids_input,
    duration=duration_seconds,
    n_clips=number_of_clips,
    custom_length=custom_length
)
# Out:
# 📤 Processing: vid_2025_08_10_Hr_15_00_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1.mp4  •  Total: 4864.00s  •  Clips: 9 × 90s
# ⏳ vid_2025_08_10_Hr_15: 100%|██████████████████████████████████████████████████| 9/9 [04:08<00:00, 27.58s/it]
# ✅ 9 clips saved for: vid_2025_08_10_Hr_15_00_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1
#
# 📤 Processing: vid_2025_08_10_Hr_17_15_52_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_68_MIN_gp4.mp4  •  Total: 4071.44s  •  Clips: 9 × 90s
# ⏳ vid_2025_08_10_Hr_17:  44%|██████████████████████▏                           | 4/9 [01:37<02:02, 24.40s/it]

# %% [markdown]
# ## chop off video for sorty size IG

# %%
_video_story_mp4(
    vids_input,
    duration=90,
    x_offset_percent=0,
    custom=custom
)

# %% [markdown]
# ## after we CONCAT all videos together resizing down ! keeping the original mp4, and extracting the mp3 Audio FILE
#
# #### NEXT is to archive shorts and originals -> only keep .mov FINAL movie of the dj set, and the mp3 audio file
#
# ##### Next is to normalize Audio, put it back , ready to post in youtube
#
#
# ## for shorts we may do a pool in doc for tik tok etc ? youtube shorts ?? ---> research

# %%
#_video_together_and_mp3(vids_input)

result = _video_together_and_mp3(vids_input)
print(result)
# Out:
# 🔎 Proposed progression (top-level only):
#   [01] gp=1  —  vid_2025_08_10_Hr_15_00_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1.mp4
#   [02] gp=2  —  vid_2025_08_10_Hr_15_00_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_39_MIN_gp2_SG.mp4
#   [03] gp=3  —  vid_2025_08_10_Hr_17_15_52_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp3_sg.mp4
#   [04] gp=4  —  vid_2025_08_10_Hr_17_15_52_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_68_MIN_gp4.mp4
# ❓ Is this the right progression? [y/N]:  y
# TQM •   0%|                                                                                         | 0/1 step[concat @ 0x136f049d0] Could not find codec parameters for stream 2 (Unknown: none): unknown codec
# Consider increasing the value for the 'analyzeduration' (0) and 'probesize' (5000000) options
# Input #0, concat, from '/var/folders/pp/n6z2gh0x56ngpvp6vx5ml9j00000gn/T/tmp9_w21ejt.txt':
#   Duration: N/A, start: 0.000000, bitrate: 9913 kb/s
#   Stream #0:0(eng): Video: hevc (Main) (hvc1 / 0x31637668), yuvj420p(pc, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 9675 kb/s, 25 fps, 25 tbr, 90k tbn
#       Metadata:
#         creation_time   : 2025-08-10T15:00:57.000000Z
#         handler_name    : GoPro H.265
#         vendor_id       : [0][0][0][0]
#         encoder         : GoPro H.265 encoder
#         timecode        : 10:00:57:02
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s
#       Metadata:
#         creation_time   : 2025-08-10T15:00:57.000000Z
#         handler_name    : GoPro AAC
#         vendor_id       : [0][0][0][0]
#         timecode        : 10:00:57:02
#   Stream #0:2: Unknown: none
#   Stream #0:3(eng): Data: bin_data (gpmd / 0x646D7067), 48 kb/s
#       Metadata:
#         creation_time   : 2025-08-10T15:00:57.000000Z
#         handler_name    : GoPro MET
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to '/Users/yerik/Movies/morning_rave/__final_vid_2025_08_10_Hr_15_00_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ALL.mp4':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0(eng): Video: hevc (Main) (hvc1 / 0x31637668), yuvj420p(pc, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 9675 kb/s, 25 fps, 25 tbr, 90k tbn
#       Metadata:
#         creation_time   : 2025-08-10T15:00:57.000000Z
#         handler_name    : GoPro H.265
#         vendor_id       : [0][0][0][0]
#         encoder         : GoPro H.265 encoder
#         timecode        : 10:00:57:02
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s
#       Metadata:
#         creation_time   : 2025-08-10T15:00:57.000000Z
#         handler_name    : GoPro AAC
#         vendor_id       : [0][0][0][0]
#         timecode        : 10:00:57:02
# Press [q] to stop, [?] for help
# ▶️ Concatenating 4 part(s) → __final_vid_2025_08_10_Hr_15_00_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ALL.mp4
# [out#0/mp4 @ 0x6000002083c0] video:15375666KiB audio:373041KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.076715%
# frame=403443 fps=10412 q=-1.0 Lsize=15760788KiB time=04:28:57.68 bitrate=8000.7kbits/s speed= 416x
# TQM • 100%|████████████████████████████████████████████████████████████████████████████████████████ | 1/1 step
# ✅ Movie created.
# {'out_mp4': '/Users/yerik/Movies/morning_rave/__final_vid_2025_08_10_Hr_15_00_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ALL.mp4', 'parts': ['/Users/yerik/Movies/morning_rave/vid_2025_08_10_Hr_15_00_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1.mp4', '/Users/yerik/Movies/morning_rave/vid_2025_08_10_Hr_15_00_57_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_39_MIN_gp2_SG.mp4', '/Users/yerik/Movies/morning_rave/vid_2025_08_10_Hr_17_15_52_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp3_sg.mp4', '/Users/yerik/Movies/morning_rave/vid_2025_08_10_Hr_17_15_52_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_68_MIN_gp4.mp4']}
