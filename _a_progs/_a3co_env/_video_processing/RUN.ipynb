# %%
vids_input = "/Users/yerik/Desktop/_2_DJ_VIDS/__2025/_07_City_Glow_Beacon_Park"

# %%
from _fn_go_pro import _video_0506_pipe_GET_realdata_verifiedrename
from _fn_go_pro import _video_story

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
_video_0506_pipe_GET_realdata_verifiedrename(
    folder_path=vids_input,  # ⬅️ your video folder
    delete='n'  # set to 'n' to keep the original MP4
)
# Out:
# 📼 Verifying: GX010118.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  07_24
# 🔁 Verified Rename:
# → GX010118.MP4 ➡️ vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mp4
# ✅ Press ENTER to confirm rename and convert to .mov...
# ✅ Renamed to: vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mp4
# 🎞️ Converting to MOV:
# → vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mov
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.0.13.3)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/yerik/Desktop/_2_DJ_VIDS/__2025/_07_City_Glow_Beacon_Park/vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mp4':
#   Metadata:
#     major_brand     : mp41
#     minor_version   : 538120216
#     compatible_brands: mp41
#     creation_time   : 2025-07-25T00:54:34.000000Z
#     firmware        : H23.01.02.32.00
#   Duration: 01:02:09.04, start: 0.000000, bitrate: 13740 kb/s
#   Stream #0:0[0x1](eng): Video: hevc (Main) (hvc1 / 0x31637668), yuvj420p(pc, bt709), 3840x2160 [SAR 1:1 DAR 16:9], 13486 kb/s, 25 fps, 25 tbr, 90k tbn (default)
#       Metadata:
#         creation_time   : 2025-07-25T00:54:34.000000Z
#         handler_name    : GoPro H.265
#         vendor_id       : [0][0][0][0]
#         encoder         : GoPro H.265 encoder
#         timecode        : 19:54:34:18
#   Stream #0:1[0x2]: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s (default)
#       Metadata:
#         creation_time   : 2025-07-25T00:54:34.000000Z
#         handler_name    : GoPro AAC
#         vendor_id       : [0][0][0][0]
#         timecode        : 19:54:34:18
#   Stream #0:2[0x3](eng): Data: none (tmcd / 0x64636D74) (default)
#       Metadata:
#         creation_time   : 2025-07-25T00:54:34.000000Z
#         handler_name    : GoPro TCD
#         timecode        : 19:54:34:18
#   Stream #0:3[0x4](eng): Data: bin_data (gpmd / 0x646D7067), 48 kb/s (default)
#       Metadata:
#         creation_time   : 2025-07-25T00:54:34.000000Z
#         handler_name    : GoPro MET
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mov, to '/Users/yerik/Desktop/_2_DJ_VIDS/__2025/_07_City_Glow_Beacon_Park/vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mov':
#   Metadata:
#     major_brand     : mp41
#     minor_version   : 538120216
#     compatible_brands: mp41
#     firmware        : H23.01.02.32.00
#     encoder         : Lavf61.7.100
#   Stream #0:0(eng): Video: hevc (Main) (hvc1 / 0x31637668), yuvj420p(pc, bt709), 3840x2160 [SAR 1:1 DAR 16:9], q=2-31, 13486 kb/s, 25 fps, 25 tbr, 90k tbn (default)
#       Metadata:
#         creation_time   : 2025-07-25T00:54:34.000000Z
#         handler_name    : GoPro H.265
#         vendor_id       : [0][0][0][0]
#         encoder         : GoPro H.265 encoder
#         timecode        : 19:54:34:18
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s (default)
#       Metadata:
#         creation_time   : 2025-07-25T00:54:34.000000Z
#         handler_name    : GoPro AAC
#         vendor_id       : [0][0][0][0]
#         timecode        : 19:54:34:18
# Press [q] to stop, [?] for help
# frame=88424 fps=17522 q=-1.0 size= 5897984KiB time=00:58:57.02 bitrate=13660.2kbits/s speed= 701x
# ✅ MOV created: vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mov
# [out#0/mov @ 0x60000018c540] video:6139056KiB audio:86147KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.044873%
# frame=93226 fps=17477 q=-1.0 Lsize= 6227997KiB time=01:02:08.98 bitrate=13682.0kbits/s speed= 699x

# %%
_video_story(vids_input, duration=60, x_offset_percent=20)
# Out:
# 📤 Processing: vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mov
# ⏳ vid_2025_07_25_Hr_00: 100%|██████████████████████████████████████████████████| 9/9 [13:00<00:00, 86.68s/it]
# ✅ 9 IG story clips saved for: vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24
# ✂️  Export custom cut from vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mov? (y/n):  y
# 🕐 Enter start-end in minutes (e.g. 1.2 - 3.2):  57.3-59
# ✅ Custom clip saved: __custom_vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24_1.mp4
# ✂️  Export custom cut from vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mov? (y/n):  y
# 🕐 Enter start-end in minutes (e.g. 1.2 - 3.2):  19.4-20.4
# ✅ Custom clip saved: __custom_vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24_2.mp4
# ✂️  Export custom cut from vid_2025_07_25_Hr_00_54_34_Yfram_25_Yvres_3840x2160_Yaspr_16_9_Ydura_62_MIN_07_24.mov? (y/n):
# '✅ All videos exported in 9:16 IG format, with optional custom cuts.'
