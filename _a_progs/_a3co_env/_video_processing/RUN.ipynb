# %%
vids_input = "/Users/yerik/Desktop/_2_DJ_VIDS/__2025/_PUMA_VIDS_July_19"

# %%
from _fn_go_pro import _video_0506_pipe_GET_realdata_verifiedrename
from _fn_go_pro import _video_story_mp4
from _fn_go_pro import _video_together_and_mp3
#_video_story_mov

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
_video_0506_pipe_GET_realdata_verifiedrename(
    folder_path=vids_input,  # ⬅️ your video folder
    delete='n'  # set to 'n' to keep the original MP4
)

# %%
custom = input(f"✂️  Export custom cut from ? (y/n): ").strip().lower()
duration_vid= 45
minus_plus_100_xOFFSET=-18

_video_story_mp4(vids_input, duration=duration_vid, x_offset_percent=minus_plus_100_xOFFSET,custom = custom)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 custom = input(f"✂️  Export custom cut from ? (y/n): ").strip().lower()
#       2 duration_vid= 45
#       3 minus_plus_100_xOFFSET=-18
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/ipykernel/kernelbase.py:1251, in Kernel.raw_input(self, prompt)
#    1249     msg = "raw_input was called, but this frontend does not support input requests."
#    1250     raise StdinNotImplementedError(msg)
# -> 1251 return self._input_request(
#    1252     str(prompt),
#    1253     self._parent_ident["shell"],
#    1254     self.get_parent("shell"),
#    1255     password=False,
#    1256 )
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/ipykernel/kernelbase.py:1295, in Kernel._input_request(self, prompt, ident, parent, password)
#    1292 except KeyboardInterrupt:
#    1293     # re-raise KeyboardInterrupt, to truncate traceback
#    1294     msg = "Interrupted by user"
# -> 1295     raise KeyboardInterrupt(msg) from None
#    1296 except Exception:
#    1297     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## after we CONCAT all videos together resizing down ! keeping the original mp4, and extracting the mp3 Audio FILE
#
# #### NEXT is to archive shorts and originals -> only keep .mov FINAL movie of the dj set, and the mp3 audio file
#
# ##### Next is to normalize Audio, put it back , ready to post in youtube
#
#
# ## for shorts we may do a pool in doc for tik tok etc ? youtube shorts ?? ---> research

# %%
_video_together_and_mp3(vids_input)
# Out:
# 🧾 Proposed video order:
# 1. 1_vid_2025_07_19_Hr_23_29_14_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_no_1.mp4
# 2. 2_vid_2025_07_19_Hr_23_29_14_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_no_2.mp4
# 3. 3_vid_2025_07_19_Hr_23_29_14_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_no_3.mp4
# 4. 4_vid_2025_07_19_Hr_23_29_14_Yfram_25_Yvres_1920x1080_Yaspr_16_9_Ydura_6_MIN_no_4.mp4
# ❓ Is this the correct progression? (Press ENTER to continue or Ctrl+C to abort):
# 🎬 Compressing MP4 to MOV: 100%|███████████████████████████████████████████████| 4/4 [49:08<00:00, 737.14s/it]
# 📦 Merging MOV files...
# 🧹 Deleting temporary .mov files...
# 🔊 Extracting MP3 from merged video...
#
# ✅ All done!
# 🎞 Final video: final_merged_video.mov
# 🎧 Extracted audio: final_merged_video.mp3
# (PosixPath('/Users/yerik/Desktop/_2_DJ_VIDS/__2025/_PUMA_VIDS_July_19/final_merged_video.mov'),
#  PosixPath('/Users/yerik/Desktop/_2_DJ_VIDS/__2025/_PUMA_VIDS_July_19/final_merged_video.mp3'))
