# %%
###############
##########
######
vids_input = "/Users/yerik/Downloads/_AUG16"
base_name = "Morning_Rave"
custom_length = input(f"✂️  Export custom NORMAL cut from ? (y/n): ").strip().lower()
custom = input(f"✂️  Export custom STORY cut from ? (y/n): ").strip().lower()
#####
########
#############
from _fn_go_pro import _video_1308_goproseq_GET_renamed_files
from _fn_go_pro import _video_1408_mp4chop_GET_export_clips
from _fn_go_pro import _video_0506_pipe_GET_realdata_verifiedrename
from _fn_go_pro import _video_story_mp4
from _fn_go_pro import _video_together_and_mp3
from _fn_go_pro import _video_0108_vmono_peaknorm_GET_cleanfolder
from _fn_go_pro import _video_1508_finalvid_GET_mp3
#############
########
###
# Out:
# ✂️  Export custom NORMAL cut from ? (y/n):  n
# ✂️  Export custom STORY cut from ? (y/n):  n

# %% [markdown]
# # fix audio first - Monoand normalize

# %%
input('ENTER to Nomarlize audio and CHange mono - Stereo')
_video_0108_vmono_peaknorm_GET_cleanfolder(vids_input)
# Out:
# ENTER to Nomarlize audio and CHange mono - Stereo
# 🎬 Normalizing Videos: 0it [00:00, ?it/s]

# %% [markdown]
# # rename but check if right progression ---???? check with the next ... be careful

# %%
# folder_or_paths = vids_input

# video_extensions = [".mp4", ".mov", ".m4v", ".MP4", ".MOV", ".M4V"]

# # Dry run first
# map_df = _video_1308_goproseq_GET_renamed_files(
#     inputs=folder_or_paths,
#     base_name=base_name,
#     video_extensions=video_extensions,
#     prefix="_gp",
#     start_index=1,
#     dry_run=False,
#     overwrite=False
# )
# print(map_df)

# %% [markdown]
# # rename with gp1 etc and also name DJS ? and also change to .mov ?

# %%
input("remeber to rename with gp1 gp2 gp3 etc ... ")
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#! # 
_video_0506_pipe_GET_realdata_verifiedrename(
    folder_path=vids_input,  # ⬅️ your video folder
    delete='n'  # set to 'n' to keep the original MP4
)
# Out:
# remeber to rename with gp1 gp2 gp3 etc ...
# 🎬 MOV CONVERSION FOR ENTIRE BATCH?
# 💡 Type 'y' to convert all videos to .mov after rename, or press ENTER to skip:
# 📼 Verifying: GX010142.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  gp1
# 🔁 Rename:
# → GX010142.MP4 ➡️ vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1.mp4
# ✅ Press ENTER to confirm rename...
# ✅ Renamed to: vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1.mp4
#
# 📼 Verifying: GX020142.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  gp2
# 🔁 Rename:
# → GX020142.MP4 ➡️ vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp2.mp4
# ✅ Press ENTER to confirm rename...
# ✅ Renamed to: vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp2.mp4
#
# 📼 Verifying: GX030142.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  gp3
# 🔁 Rename:
# → GX030142.MP4 ➡️ vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_61_MIN_gp3.mp4
# ✅ Press ENTER to confirm rename...
# ✅ Renamed to: vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_61_MIN_gp3.mp4

# %% [markdown]
# ## chop off video for normal size

# %%
duration_seconds = 45
number_of_clips = 30

_video_1408_mp4chop_GET_export_clips(
    vids_input,
    duration=duration_seconds,
    n_clips=number_of_clips,
    custom_length=custom_length
)
# Out:
# 📤 Processing: vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp2.mp4  •  Total: 4868.86s  •  Clips: 30 × 45s
# ⏳ vid_2025_08_16_Hr_22:  70%|█████████████████████████████████▌              | 21/30 [06:02<02:35, 17.28s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 4
#       1 duration_seconds = 45
#       2 number_of_clips = 30
# ----> 4 _video_1408_mp4chop_GET_export_clips(
#       5     vids_input,
#       6     duration=duration_seconds,
#       7     n_clips=number_of_clips,
#       8     custom_length=custom_length
#       9 )
#
# File ~/_apple_lib/_a_progs/_a3co_env/_video_processing/_fn_go_pro.py:337, in _video_1408_mp4chop_GET_export_clips(input_folder, duration, n_clips, custom_length, seed)
#     335     subclip = clip.subclip(start_time, end_time)
#     336     out_path = output_dir / f"{video_path.stem}_{i:02}.mp4"
# --> 337     subclip.write_videofile(
#     338         str(out_path),
#     339         codec="libx264",
#     340         audio_codec="aac",
#     341         verbose=False,
#     342         logger=None
#     343     )
#     344     subclip.close()
#     346 print(f"✅ {n_clips} clips saved for: {video_path.stem}")
#
# File <decorator-gen-73>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File <decorator-gen-72>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:135, in use_clip_fps_by_default(f, clip, *a, **k)
#     130 new_a = [fun(arg) if (name=='fps') else arg
#     131          for (arg, name) in zip(a, names)]
#     132 new_kw = {k: fun(v) if k=='fps' else v
#     133          for (k,v) in k.items()}
# --> 135 return f(clip, *new_a, **new_kw)
#
# File <decorator-gen-71>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:22, in convert_masks_to_RGB(f, clip, *a, **k)
#      20 if clip.ismask:
#      21     clip = clip.to_RGB()
# ---> 22 return f(clip, *a, **k)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/video/VideoClip.py:293, in VideoClip.write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     291 logger(message="Moviepy - Building video %s." % filename)
#     292 if make_audio:
# --> 293     self.audio.write_audiofile(audiofile, audio_fps,
#     294                                audio_nbytes, audio_bufsize,
#     295                                audio_codec, bitrate=audio_bitrate,
#     296                                write_logfile=write_logfile,
#     297                                verbose=verbose,
#     298                                logger=logger)
#     300 ffmpeg_write_video(self, filename, fps, codec,
#     301                    bitrate=bitrate,
#     302                    preset=preset,
#    (...)
#     306                    ffmpeg_params=ffmpeg_params,
#     307                    logger=logger)
#     309 if remove_temp and make_audio:
#
# File <decorator-gen-63>:2, in write_audiofile(self, filename, fps, nbytes, buffersize, codec, bitrate, ffmpeg_params, write_logfile, verbose, logger)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/audio/AudioClip.py:206, in AudioClip.write_audiofile(self, filename, fps, nbytes, buffersize, codec, bitrate, ffmpeg_params, write_logfile, verbose, logger)
#     201     except KeyError:
#     202         raise ValueError("MoviePy couldn't find the codec associated "
#     203                          "with the filename. Provide the 'codec' "
#     204                          "parameter in write_audiofile.")
# --> 206 return ffmpeg_audiowrite(self, filename, fps, nbytes, buffersize,
#     207                          codec=codec, bitrate=bitrate,
#     208                          write_logfile=write_logfile, verbose=verbose,
#     209                          ffmpeg_params=ffmpeg_params,
#     210                          logger=logger)
#
# File <decorator-gen-27>:2, in ffmpeg_audiowrite(clip, filename, fps, nbytes, buffersize, codec, bitrate, write_logfile, verbose, ffmpeg_params, logger)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/audio/io/ffmpeg_audiowriter.py:166, in ffmpeg_audiowrite(clip, filename, fps, nbytes, buffersize, codec, bitrate, write_logfile, verbose, ffmpeg_params, logger)
#     160 logger(message="MoviePy - Writing audio in %s" % filename)
#     161 writer = FFMPEG_AudioWriter(filename, fps, nbytes, clip.nchannels,
#     162                             codec=codec, bitrate=bitrate,
#     163                             logfile=logfile,
#     164                             ffmpeg_params=ffmpeg_params)
# --> 166 for chunk in clip.iter_chunks(chunksize=buffersize,
#     167                               quantize=True,
#     168                               nbytes=nbytes, fps=fps,
#     169                               logger=logger):
#     170     writer.write_frames(chunk)
#     172 writer.close()
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/audio/AudioClip.py:85, in AudioClip.iter_chunks(self, chunksize, chunk_duration, fps, quantize, nbytes, logger)
#      83 assert(size <= chunksize)
#      84 tt = (1.0/fps)*np.arange(pospos[i], pospos[i+1])
# ---> 85 yield self.to_soundarray(tt, nbytes=nbytes, quantize=quantize,
#      86                             fps=fps, buffersize=chunksize)
#
# File <decorator-gen-62>:2, in to_soundarray(self, tt, fps, quantize, nbytes, buffersize)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/audio/AudioClip.py:127, in AudioClip.to_soundarray(self, tt, fps, quantize, nbytes, buffersize)
#     117 """
#     118 elif len(tt)> 1.5*buffersize:
#     119     nchunks = int(len(tt)/buffersize+1)
#    (...)
#     123                       for ttc in tt_chunks])
#     124 """
#     125 #print tt.max() - tt.min(), tt.min(), tt.max()
# --> 127 snd_array = self.get_frame(tt)
#     129 if quantize:
#     130     snd_array = np.maximum(-0.99, np.minimum(0.99, snd_array))
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:136, in Clip.fl.<locals>.<lambda>(t)
#     133     apply_to = []
#     135 #mf = copy(self.make_frame)
# --> 136 newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     138 if not keep_duration:
#     139     newclip.duration = None
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:187, in Clip.fl_time.<locals>.<lambda>(gf, t)
#     184 if apply_to is None:
#     185     apply_to = []
# --> 187 return self.fl(lambda gf, t: gf(t_func(t)), apply_to,
#     188                keep_duration=keep_duration)
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/audio/io/AudioFileClip.py:77, in AudioFileClip.__init__.<locals>.<lambda>(t)
#      74 self.end = self.reader.duration
#      75 self.buffersize = self.reader.buffersize
# ---> 77 self.make_frame = lambda t: self.reader.get_frame(t)
#      78 self.nchannels = self.reader.nchannels
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/audio/io/readers.py:186, in FFMPEG_AudioReader.get_frame(self, tt)
#     182     self.buffer_around(fr_min)
#     183 elif not (0 <=
#     184             (fr_max - self.buffer_startframe)
#     185                  < len(self.buffer)):
# --> 186     self.buffer_around(fr_max)
#     188 try:
#     189     result = np.zeros((len(tt),self.nchannels))
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/audio/io/readers.py:240, in FFMPEG_AudioReader.buffer_around(self, framenumber)
#     238     conserved = current_f_end - new_bufferstart + 1
#     239     chunksize = self.buffersize-conserved
# --> 240     array = self.read_chunk(chunksize)
#     241     self.buffer = np.vstack([self.buffer[-conserved:], array])
#     242 else:
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/audio/io/readers.py:113, in FFMPEG_AudioReader.read_chunk(self, chunksize)
#     111 chunksize = int(round(chunksize))
#     112 L = self.nchannels*chunksize*self.nbytes
# --> 113 s = self.proc.stdout.read(L)
#     114 dt = {1: 'int8',2:'int16',4:'int32'}[self.nbytes]
#     115 if hasattr(np, 'frombuffer'):
#
# AttributeError: 'NoneType' object has no attribute 'stdout'

# %% [markdown]
# ## chop off video for sorty size IG

# %%
dur_story = 2
x_offset_story = 0

# for custom do 1.2-2.3

# move X off set ( negative to move angle to LEFT, positive RIGHT)
_video_story_mp4(
    vids_input,
    duration=dur_story,
    x_offset_percent= x_offset_story,
    custom=custom
)
# Out:
# 📤 Processing: vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_gp1.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 7
#       2 x_offset_story = 0
#       4 # for custom do 1.2-2.3
#       5
#       6 # move X off set ( negative to move angle to LEFT, positive RIGHT)
# ----> 7 _video_story_mp4(
#       8     vids_input,
#       9     duration=dur_story,
#      10     x_offset_percent= x_offset_story,
#      11     custom=custom
#      12 )
#
# File ~/_apple_lib/_a_progs/_a3co_env/_video_processing/_fn_go_pro.py:454, in _video_story_mp4(input_folder, duration, x_offset_percent, custom)
#     452 cropped = subclip.crop(x_center=x_center, width=ig_width)
#     453 out_path = output_dir / f"{video_path.stem}_story_{i+1:02}.mp4"
# --> 454 cropped.write_videofile(
#     455     str(out_path),
#     456     codec="libx264",
#     457     audio_codec="aac",
#     458     verbose=False,
#     459     logger=None
#     460 )
#     461 subclip.close()
#     462 cropped.close()
#
# File <decorator-gen-73>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# File <decorator-gen-72>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:135, in use_clip_fps_by_default(f, clip, *a, **k)
#     130 new_a = [fun(arg) if (name=='fps') else arg
#     131          for (arg, name) in zip(a, names)]
#     132 new_kw = {k: fun(v) if k=='fps' else v
#     133          for (k,v) in k.items()}
# --> 135 return f(clip, *new_a, **new_kw)
#
# File <decorator-gen-71>:2, in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:22, in convert_masks_to_RGB(f, clip, *a, **k)
#      20 if clip.ismask:
#      21     clip = clip.to_RGB()
# ---> 22 return f(clip, *a, **k)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/video/VideoClip.py:300, in VideoClip.write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     292 if make_audio:
#     293     self.audio.write_audiofile(audiofile, audio_fps,
#     294                                audio_nbytes, audio_bufsize,
#     295                                audio_codec, bitrate=audio_bitrate,
#     296                                write_logfile=write_logfile,
#     297                                verbose=verbose,
#     298                                logger=logger)
# --> 300 ffmpeg_write_video(self, filename, fps, codec,
#     301                    bitrate=bitrate,
#     302                    preset=preset,
#     303                    write_logfile=write_logfile,
#     304                    audiofile=audiofile,
#     305                    verbose=verbose, threads=threads,
#     306                    ffmpeg_params=ffmpeg_params,
#     307                    logger=logger)
#     309 if remove_temp and make_audio:
#     310     if os.path.exists(audiofile):
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/video/io/ffmpeg_writer.py:220, in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, logger)
#     213 with FFMPEG_VideoWriter(filename, clip.size, fps, codec = codec,
#     214                             preset=preset, bitrate=bitrate, logfile=logfile,
#     215                             audiofile=audiofile, threads=threads,
#     216                             ffmpeg_params=ffmpeg_params) as writer:
#     218     nframes = int(clip.duration*fps)
# --> 220     for t,frame in clip.iter_frames(logger=logger, with_times=True,
#     221                                     fps=fps, dtype="uint8"):
#     222         if withmask:
#     223             mask = (255*clip.mask.get_frame(t))
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:472, in Clip.iter_frames(self, fps, with_times, logger, dtype)
#     470 logger = proglog.default_bar_logger(logger)
#     471 for t in logger.iter_bar(t=np.arange(0, self.duration, 1.0/fps)):
# --> 472     frame = self.get_frame(t)
#     473     if (dtype is not None) and (frame.dtype != dtype):
#     474         frame = frame.astype(dtype)
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:136, in Clip.fl.<locals>.<lambda>(t)
#     133     apply_to = []
#     135 #mf = copy(self.make_frame)
# --> 136 newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     138 if not keep_duration:
#     139     newclip.duration = None
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/video/VideoClip.py:490, in VideoClip.fl_image.<locals>.<lambda>(gf, t)
#     485 """
#     486 Modifies the images of a clip by replacing the frame
#     487 `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     488 """
#     489 apply_to = apply_to or []
# --> 490 return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:136, in Clip.fl.<locals>.<lambda>(t)
#     133     apply_to = []
#     135 #mf = copy(self.make_frame)
# --> 136 newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     138 if not keep_duration:
#     139     newclip.duration = None
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:187, in Clip.fl_time.<locals>.<lambda>(gf, t)
#     184 if apply_to is None:
#     185     apply_to = []
# --> 187 return self.fl(lambda gf, t: gf(t_func(t)), apply_to,
#     188                keep_duration=keep_duration)
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/Clip.py:136, in Clip.fl.<locals>.<lambda>(t)
#     133     apply_to = []
#     135 #mf = copy(self.make_frame)
# --> 136 newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     138 if not keep_duration:
#     139     newclip.duration = None
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/video/VideoClip.py:490, in VideoClip.fl_image.<locals>.<lambda>(gf, t)
#     485 """
#     486 Modifies the images of a clip by replacing the frame
#     487 `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     488 """
#     489 apply_to = apply_to or []
# --> 490 return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#
# File ~/_apple_lib/_b_envs/3co_env/lib/python3.10/site-packages/moviepy/video/fx/resize.py:150, in resize.<locals>.<lambda>(pic)
#     147     fl = lambda pic: 1.0*resizer((255 * pic).astype('uint8'), newsize)/255.0
#     149 else:
# --> 150     fl = lambda pic: resizer(pic.astype('uint8'), newsize)
#     152 newclip = clip.fl_image(fl)
#     154 if apply_to_mask and clip.mask is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## after we CONCAT all videos together resizing down ! keeping the original mp4, and extracting the mp3 Audio FILE
#
# #### NEXT is to archive shorts and originals -> only keep .mov FINAL movie of the dj set, and the mp3 audio file
#
# ##### Next is to normalize Audio, put it back , ready to post in youtube
#
#
# ## for shorts we may do a pool in doc for tik tok etc ? youtube shorts ?? ---> research

# %%
#_video_together_and_mp3(vids_input)

result = _video_together_and_mp3(vids_input)
print(result)
# Out:
# 🔎 Proposed progression (top-level only):
#   [01] gp=1  —  vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1.mp4
#   [02] gp=2  —  vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp2.mp4
#   [03] gp=3  —  vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_61_MIN_gp3.mp4
# ❓ Is this the right progression? [y/N]:  y
# TQM •   0%|                                                                                         | 0/1 step[concat @ 0x14ee06d20] Could not find codec parameters for stream 2 (Unknown: none): unknown codec
# Consider increasing the value for the 'analyzeduration' (0) and 'probesize' (5000000) options
# Input #0, concat, from '/var/folders/pp/n6z2gh0x56ngpvp6vx5ml9j00000gn/T/tmppdnvedve.txt':
#   Duration: N/A, start: 0.000000, bitrate: 3045 kb/s
#   Stream #0:0(eng): Video: hevc (Main) (hvc1 / 0x31637668), yuvj420p(pc, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2803 kb/s, 29.97 fps, 29.97 tbr, 30k tbn
#       Metadata:
#         creation_time   : 2025-08-16T22:11:36.000000Z
#         handler_name    : GoPro H.265
#         vendor_id       : [0][0][0][0]
#         encoder         : GoPro H.265 encoder
#         timecode        : 18:11:36;09
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s
#       Metadata:
#         creation_time   : 2025-08-16T22:11:36.000000Z
#         handler_name    : GoPro AAC
#         vendor_id       : [0][0][0][0]
#         timecode        : 18:11:36;09
#   Stream #0:2: Unknown: none
#   Stream #0:3(eng): Data: bin_data (gpmd / 0x646D7067), 51 kb/s
#       Metadata:
#         creation_time   : 2025-08-16T22:11:36.000000Z
#         handler_name    : GoPro MET
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to '/Users/yerik/Downloads/_AUG16/__final_vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ALL.mp4':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0(eng): Video: hevc (Main) (hvc1 / 0x31637668), yuvj420p(pc, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 2803 kb/s, 29.97 fps, 29.97 tbr, 30k tbn
#       Metadata:
#         creation_time   : 2025-08-16T22:11:36.000000Z
#         handler_name    : GoPro H.265
#         vendor_id       : [0][0][0][0]
#         encoder         : GoPro H.265 encoder
#         timecode        : 18:11:36;09
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s
#       Metadata:
#         creation_time   : 2025-08-16T22:11:36.000000Z
#         handler_name    : GoPro AAC
#         vendor_id       : [0][0][0][0]
#         timecode        : 18:11:36;09
# Press [q] to stop, [?] for help
# ▶️ Concatenating 3 part(s) → __final_vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ALL.mp4
# [out#0/mp4 @ 0x6000031c0000] video:3091229KiB audio:309660KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.332659%
# frame=401459 fps=32657 q=-1.0 Lsize= 3412203KiB time=03:43:15.34 bitrate=2086.8kbits/s speed=1.09e+03x
# TQM • 100%|████████████████████████████████████████████████████████████████████████████████████████ | 1/1 step
# ✅ Movie created.
# {'out_mp4': '/Users/yerik/Downloads/_AUG16/__final_vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_ALL.mp4', 'parts': ['/Users/yerik/Downloads/_AUG16/vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1.mp4', '/Users/yerik/Downloads/_AUG16/vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp2.mp4', '/Users/yerik/Downloads/_AUG16/vid_2025_08_16_Hr_22_11_36_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_61_MIN_gp3.mp4']}

# %% [markdown]
# ### get mp3

# %%
# Run (keeps stereo, 44.1 kHz, CBR 320 kbps). If multiple matches exist, newest is used.
out_mp3_path = _video_1508_finalvid_GET_mp3(
    vids_input=vids_input,
    mp3_bitrate_k=320,
    sr=44100,
    channels=2,
    choose="newest"  # or "largest"
)

print("Output:", out_mp3_path)
# Out:
# ✅ MP3 created: /Users/yerik/Downloads/_AUG16/_AUG16.mp3
# Output: /Users/yerik/Downloads/_AUG16/_AUG16.mp3
