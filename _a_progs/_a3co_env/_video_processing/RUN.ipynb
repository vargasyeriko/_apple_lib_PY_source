# %%
###############
##########
######
vids_input = "/Users/yerik/Downloads/_AN/GP-sound"
base_name = "Morning_Rave"
custom_length = input(f"✂️  Export custom NORMAL cut from ? (y/n): ").strip().lower()
custom = input(f"✂️  Export custom STORY cut from ? (y/n): ").strip().lower()
#####
########
#############
from _fn_go_pro import _video_1308_goproseq_GET_renamed_files
from _fn_go_pro import _video_1408_mp4chop_GET_export_clips
from _fn_go_pro import _video_0506_pipe_GET_realdata_verifiedrename
from _fn_go_pro import _video_story_mp4
from _fn_go_pro import _video_together_and_mp3
from _fn_go_pro import _video_0108_vmono_peaknorm_GET_cleanfolder
from _fn_go_pro import _video_1508_finalvid_GET_mp3
#############
########
###
# Out:
# ✂️  Export custom NORMAL cut from ? (y/n):  n
# ✂️  Export custom STORY cut from ? (y/n):  n

# %% [markdown]
# # fix audio first - Monoand normalize

# %%
input('ENTER to Nomarlize audio and CHange mono - Stereo')
_video_0108_vmono_peaknorm_GET_cleanfolder(vids_input)
# Out:
# ENTER to Nomarlize audio and CHange mono - Stereo
# 🎬 Normalizing Videos: 0it [00:00, ?it/s]

# %% [markdown]
# # rename but check if right progression ---???? check with the next ... be careful

# %%
# folder_or_paths = vids_input

# video_extensions = [".mp4", ".mov", ".m4v", ".MP4", ".MOV", ".M4V"]

# # Dry run first
# map_df = _video_1308_goproseq_GET_renamed_files(
#     inputs=folder_or_paths,
#     base_name=base_name,
#     video_extensions=video_extensions,
#     prefix="_gp",
#     start_index=1,
#     dry_run=False,
#     overwrite=False
# )
# print(map_df)

# %% [markdown]
# # rename with gp1 etc and also name DJS ? and also change to .mov ?

# %%
input("remeber to rename with gp1 gp2 gp3 etc ... ")
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#! # 
_video_0506_pipe_GET_realdata_verifiedrename(
    folder_path=vids_input,  # ⬅️ your video folder
    delete='n'  # set to 'n' to keep the original MP4
)
# Out:
# remeber to rename with gp1 gp2 gp3 etc ...
# 🎬 MOV CONVERSION FOR ENTIRE BATCH?
# 💡 Type 'y' to convert all videos to .mov after rename, or press ENTER to skip:
# 📼 Verifying: 1-GX010144.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  gp1
# 🔁 Rename:
# → 1-GX010144.MP4 ➡️ vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_gp1.mp4
# ✅ Press ENTER to confirm rename...
# ✅ Renamed to: vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_gp1.mp4
#
# 📼 Verifying: 2-GX020144.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  gp2
# 🔁 Rename:
# → 2-GX020144.MP4 ➡️ vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_9_MIN_gp2.mp4
# ✅ Press ENTER to confirm rename...
# ✅ Renamed to: vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_9_MIN_gp2.mp4
#
# 📼 Verifying: psy_GX010146.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  psy
# 🔁 Rename:
# → psy_GX010146.MP4 ➡️ vid_2025_08_21_Hr_05_35_34_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_31_MIN_psy.mp4
# ✅ Press ENTER to confirm rename...
# ✅ Renamed to: vid_2025_08_21_Hr_05_35_34_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_31_MIN_psy.mp4

# %% [markdown]
# ## chop off video for normal size

# %%
duration_seconds = 45
number_of_clips = 9

_video_1408_mp4chop_GET_export_clips(
    vids_input,
    duration=duration_seconds,
    n_clips=number_of_clips,
    custom_length=custom_length
)
# Out:
# 📤 Processing: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp2.mp4  •  Total: 4868.86s  •  Clips: 9 × 45s
# ⏳ vid_2025_08_15_Hr_22: 100%|██████████████████████████████████████████████████| 9/9 [02:08<00:00, 14.27s/it]
# ✅ 9 clips saved for: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp2
#
# 📤 Processing: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1.mp4  •  Total: 4868.86s  •  Clips: 9 × 45s
# ⏳ vid_2025_08_15_Hr_22: 100%|██████████████████████████████████████████████████| 9/9 [02:11<00:00, 14.66s/it]
# ✅ 9 clips saved for: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1
#
# 📤 Processing: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_57_MIN_gp3.mp4  •  Total: 3412.24s  •  Clips: 9 × 45s
# ⏳ vid_2025_08_15_Hr_22: 100%|██████████████████████████████████████████████████| 9/9 [02:00<00:00, 13.40s/it]
# ✅ 9 clips saved for: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_57_MIN_gp3
# '✅ All .mp4 videos chopped with optional custom cuts.'

# %% [markdown]
# ## chop off video for sorty size IG

# %%
dur_story = 45
x_offset_story = 3

# for custom do 1.2-2.3

# move X off set ( negative to move angle to LEFT, positive RIGHT)
_video_story_mp4(
    vids_input,
    duration=dur_story,
    x_offset_percent= x_offset_story,
    custom=custom
)
# Out:
# 📤 Processing: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp2.mp4
# ✅ 9 IG story clips saved for: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp2
#
# 📤 Processing: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1.mp4
# ✅ 9 IG story clips saved for: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_81_MIN_gp1
#
# 📤 Processing: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_57_MIN_gp3.mp4
# ✅ 9 IG story clips saved for: vid_2025_08_15_Hr_22_06_45_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_57_MIN_gp3
# '✅ All .mp4 videos exported in IG story format with optional custom cuts.'

# %% [markdown]
# ## after we CONCAT all videos together resizing down ! keeping the original mp4, and extracting the mp3 Audio FILE
#
# #### NEXT is to archive shorts and originals -> only keep .mov FINAL movie of the dj set, and the mp3 audio file
#
# ##### Next is to normalize Audio, put it back , ready to post in youtube
#
#
# ## for shorts we may do a pool in doc for tik tok etc ? youtube shorts ?? ---> research

# %%
#_video_together_and_mp3(vids_input)

result = _video_together_and_mp3(vids_input)
print(result)
# Out:
# 🔎 Proposed progression (top-level only):
#   [01] gp=1  —  vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_gp1.mp4
#   [02] gp=2  —  vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_9_MIN_gp2.mp4
# ❓ Is this the right progression? [y/N]:  y
# TQM •   0%|                                                                                         | 0/1 step[concat @ 0x140e06650] Could not find codec parameters for stream 2 (Unknown: none): unknown codec
# Consider increasing the value for the 'analyzeduration' (0) and 'probesize' (5000000) options
# Input #0, concat, from '/var/folders/pp/n6z2gh0x56ngpvp6vx5ml9j00000gn/T/tmps671z1i1.txt':
#   Duration: N/A, start: 0.000000, bitrate: 18403 kb/s
#   Stream #0:0(eng): Video: hevc (Main) (hvc1 / 0x31637668), yuvj420p(pc, bt709), 3840x2160 [SAR 1:1 DAR 16:9], 18162 kb/s, 29.97 fps, 29.97 tbr, 30k tbn
#       Metadata:
#         creation_time   : 2025-08-21T00:08:45.000000Z
#         handler_name    : GoPro H.265
#         vendor_id       : [0][0][0][0]
#         encoder         : GoPro H.265 encoder
#         timecode        : 20:08:45;03
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s
#       Metadata:
#         creation_time   : 2025-08-21T00:08:45.000000Z
#         handler_name    : GoPro AAC
#         vendor_id       : [0][0][0][0]
#         timecode        : 20:08:45;03
#   Stream #0:2: Unknown: none
#   Stream #0:3(eng): Data: bin_data (gpmd / 0x646D7067), 50 kb/s
#       Metadata:
#         creation_time   : 2025-08-21T00:08:45.000000Z
#         handler_name    : GoPro MET
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to '/Users/yerik/Downloads/_AN/GP-sound/__final_vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_ALL.mp4':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0(eng): Video: hevc (Main) (hvc1 / 0x31637668), yuvj420p(pc, bt709), 3840x2160 [SAR 1:1 DAR 16:9], q=2-31, 18162 kb/s, 29.97 fps, 29.97 tbr, 30k tbn
#       Metadata:
#         creation_time   : 2025-08-21T00:08:45.000000Z
#         handler_name    : GoPro H.265
#         vendor_id       : [0][0][0][0]
#         encoder         : GoPro H.265 encoder
#         timecode        : 20:08:45;03
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 189 kb/s
#       Metadata:
#         creation_time   : 2025-08-21T00:08:45.000000Z
#         handler_name    : GoPro AAC
#         vendor_id       : [0][0][0][0]
#         timecode        : 20:08:45;03
# Press [q] to stop, [?] for help
# ▶️ Concatenating 2 part(s) → __final_vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_ALL.mp4
# [out#0/mp4 @ 0x6000021243c0] video:12419366KiB audio:124648KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.046379%
# frame=161606 fps=6174 q=-1.0 Lsize=12549832KiB time=01:29:52.21 bitrate=19066.1kbits/s speed= 206x
# TQM • 100%|████████████████████████████████████████████████████████████████████████████████████████ | 1/1 step
# ✅ Movie created.
# {'out_mp4': '/Users/yerik/Downloads/_AN/GP-sound/__final_vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_ALL.mp4', 'parts': ['/Users/yerik/Downloads/_AN/GP-sound/vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_gp1.mp4', '/Users/yerik/Downloads/_AN/GP-sound/vid_2025_08_21_Hr_00_08_45_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_9_MIN_gp2.mp4']}

# %% [markdown]
# ### get mp3

# %%
# Run (keeps stereo, 44.1 kHz, CBR 320 kbps). If multiple matches exist, newest is used.
out_mp3_path = _video_1508_finalvid_GET_mp3(
    vids_input=vids_input,
    mp3_bitrate_k=320,
    sr=44100,
    channels=2,
    choose="newest"  # or "largest"
)

print("Output:", out_mp3_path)
# Out:
# ✅ MP3 created: /Users/yerik/Downloads/_AN/GP-sound/GP-sound.mp3
# Output: /Users/yerik/Downloads/_AN/GP-sound/GP-sound.mp3
