# %%
vids_input = "/Users/yerik/Desktop/_2_DJ_VIDS/__2025/_YODJ-stu_07_stu202"

# %%
from _fn_go_pro import _video_0506_pipe_GET_realdata_verifiedrename
from _fn_go_pro import _video_story_mp4
from _fn_go_pro import _video_together_and_mp3
#_video_story_mov

# %%
#!#!#!#!#! RUNNING STATEMENTS #!#!#!#!#!
_video_0506_pipe_GET_realdata_verifiedrename(
    folder_path=vids_input,  # ⬅️ your video folder
    delete='n'  # set to 'n' to keep the original MP4
)
# Out:
# 🎬 MOV CONVERSION FOR ENTIRE BATCH?
# 💡 Type 'y' to convert all videos to .mov after rename, or press ENTER to skip:
# 📼 Verifying: GX010005.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  n_1
# 🔁 Rename:
# → GX010005.MP4 ➡️ vid_2025_07_30_Hr_06_42_19_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_19_MIN_n_1.mp4
# ✅ Press ENTER to confirm rename...
# ✅ Renamed to: vid_2025_07_30_Hr_06_42_19_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_19_MIN_n_1.mp4
#
# 📼 Verifying: GX010006.MP4
# 🎤 Enter keyword for this clip (e.g. DJ name, event):  n_2
# 🔁 Rename:
# → GX010006.MP4 ➡️ vid_2025_07_30_Hr_07_02_30_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_69_MIN_n_2.mp4
# ✅ Press ENTER to confirm rename...
# ✅ Renamed to: vid_2025_07_30_Hr_07_02_30_Yfram_30_Yvres_1920x1080_Yaspr_16_9_Ydura_69_MIN_n_2.mp4

# %%
custom = input(f"✂️  Export custom cut from ? (y/n): ").strip().lower()
duration_vid= 1
minus_plus_100_xOFFSET= 5
#52.0  - 61.2 
_video_story_mp4(vids_input, duration=duration_vid, x_offset_percent=minus_plus_100_xOFFSET,custom = custom)
# Out:
# ✂️  Export custom cut from ? (y/n):  y
# 📤 Processing: vid_2025_07_30_Hr_06_42_19_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_19_MIN_n_1.mp4
# ⏳ vid_2025_07_30_Hr_06: 100%|██████████████████████████████████████████████████| 9/9 [00:20<00:00,  2.24s/it]
# ✅ 9 IG story clips saved for: vid_2025_07_30_Hr_06_42_19_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_19_MIN_n_1
# 🕐 Enter start-end in minutes (e.g. 1.2 - 3.2):  7.50 - 19.09

# %% [markdown]
# ## after we CONCAT all videos together resizing down ! keeping the original mp4, and extracting the mp3 Audio FILE
#
# #### NEXT is to archive shorts and originals -> only keep .mov FINAL movie of the dj set, and the mp3 audio file
#
# ##### Next is to normalize Audio, put it back , ready to post in youtube
#
#
# ## for shorts we may do a pool in doc for tik tok etc ? youtube shorts ?? ---> research

# %%
_video_together_and_mp3(vids_input)
# Out:
# 🧾 Proposed video order:
# 1. 1_vid_2025_07_29_Hr_01_44_17_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_QNTZ.mp4
# 2. 2_vid_2025_07_29_Hr_01_44_17_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_QNTZ_no_1.mp4
# 3. 3_vid_2025_07_29_Hr_01_44_17_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_81_MIN_YODJ.mp4
# 4. 4_vid_2025_07_29_Hr_01_44_17_Yfram_30_Yvres_3840x2160_Yaspr_16_9_Ydura_12_MIN_Raph.mp4
# ❓ Is this the correct progression? (Press ENTER to continue or Ctrl+C to abort):
# 🎬 Compressing MP4 to MOV:   0%|                                                      | 0/4 [3:53:14<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 _video_together_and_mp3(vids_input)
#
# File ~/_apple_lib/_a_progs/_a3co_env/_video_processing/_fn_go_pro.py:426, in _video_together_and_mp3(folder_path)
#     423 clip_resized = clip.resize(newsize=new_size)
# ...
