# %% [markdown]
# # VARIABLES

# %%
# -----######-----######-----######-----######-----######-----
# Core City Coffee Party – PDF Generator with Clickable Gear Links
# -----######-----######-----######-----######-----######-----

from reportlab.lib.pagesizes import A4
from reportlab.pdfgen import canvas
from reportlab.lib.colors import HexColor
from reportlab.lib.utils import ImageReader
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
import os

# %%
proposal_lines = [
    "",
    "         \t CORE CITY × CAFE PRINCE × YerikODJ PRESENTS        ",
    "",
    "            \t COMMUNITY COFFEE PARTY — SUNDAY SERIES          ",
    "",
    "        \t A Ritual for the Community · By the Community       ",
    "",
    " o-oo-o-o-oo-o-o-oo-o-o-oo-o-o-oo-o-o-oo-o-o-oo-o-o-oo-o-o-oo-o-oo-o-o-oo-o-o-oo-o-oo-o-oo-o-oo-o",
    "",
    "» 1. COMMUNITY FIRST",
    "── ─ ─ ─ ─ ─ ─ ─ ─ ─ ── ",
    "• Inclusive space for all",
    "• Neighbors, dancers, artists, friends — all welcome",
    "• A gentle reset: music · food · coffee · daylight vibes",
    "",
    "» 2. THE EXPERIENCE",
    "── ─ ─ ─ ─ ─ ─ ─ ─ ── ",
    "• 4-hour DJ sets: 9:00 AM – 2:00 PM",
    "• Coffee opens at 9 — setup from 8:30 to 9:00",
    "• Flier idea:",
    "    COFFEE + FOOD + DJ (9–2PM) · Every Other Sunday",
    "",
    "» 3. CORE CITY",
    "── ─ ─ ─ ─ ─ ──",
    "• Soft, warm, natural design",
    "• Welcomes early risers & afterparty heads alike",
    "• A post-club stop — coffee and food for the community",
    "  (e.g., SPKRBOX runs 9AM–3PM events)",
    "• No banners — the event blends into the space",
    "",
    "» 4. SOUND & SETUP",
    "── ─ ─ ─ ─ ─ ─ ─ ── ",
    "Speakers:",
    "  – Two EV speakers outside",
    "  – Two small monitors inside (until full system is installed)",
    "  – Balanced: louder outside, gentler inside",
    "",
    "Layout:",
    "  – DJ setup inside the café corner (by bar monitors)",
    "  – Fully integrated into the CAFE PRINCE experience",
    "",
    "» 5. STREAMING",
    "── ─ ─ ─ ─ ─ ── ",
    "• Goal: stream and record raw audio + video",
    "• Ideal gear setup:",
    "    – 1–2 GoPros",
    "    – GoPro Media Mod",
    "    – Elgato CamLink",
    "    – UGREEN USB-C Adapter",
    "    – AUX cable into audio interface",
    "• Requires MacBook Pro",
    "• No banners — clean visual integration only",
    "",
    "» 6. WHO’S BEHIND THIS",
    "── ─ ─ ─ ─ ─ ─ ─ ─ ─ ── ",
    "• YerikODJ — curator · DJ · Detroit community builder",
    "• 1–3 rotating local DJs — rooted · intentional · vibey",
    "• Featuring neighbors, vendors, collectives, creatives",
    "",
    "» 7. OPERATIONS",
    "── ─ ─ ─ ─ ─ ─ ── ",
    "• Event starts at 9 AM — hard stop at 2 PM",
    "• Vendors(if approved) arrive before 9 to set up ·exit by 2",
    "• All sets recorded — more cameras = better edits",
    "• Weekly content from footage (Shorts, Reels, etc.)",
    "• Rain? Bring both speakers inside",
    "• Always: flexible · intentional · respectful",
    "",
    "» 8. PROPOSED DATES — 2024 SUNDAYS",
    "── ─ ─ ─ ─ ─ ─ ─ ─ ─ ─ ─ ─ ─ ─ ─ ─ ── ",
    "  JUL 13     ·     JUL 27",
    "  AUG 10     ·     AUG 24",
    "  SEP 07     ·     SEP 21   ← Fall Equinox Special",
    "  OCT 05     ·     OCT 19   ← Final Community Sendoff",
    "",
    "» 9. VISUALS & FLIERS",
    "── ─ ─ ─ ─ ─ ─ ─ ─ ── ",
    "• Flier reads: COFFEE + FOOD + DJ (Templates in Page.- 3)",
    "• Time: 9AM–2PM",
    "• Mood: inclusive · bright · minimal",
    "• Color palette: White + King Blue",
    "• Formats: Digital · Short-Videos · Social Media",
    "",
    "» 10. GEAR LINKS",
    "── ─ ─ ─ ─ ─ ─ ── ",
    "– GoPro HERO12:",
    "– GoPro Media Mod:",
    "– Elgato CamLink:",
    "– UGREEN USB-C Adapter:",
    "– AUX Cable (VIOY):",
    "",
    "────────────────────────────────────────────────────────────",
    "       A CELEBRATION OF COFFEE · MUSIC · COMMUNITY         ",
    "     Morning vibes for afterparties & neighborhood heads   ",
    "       Designed to be inclusive · bright · beautiful       ",
    "────────────────────────────────────────────────────────────"
]

gear_links = {
    "GoPro HERO12": "https://www.amazon.com/dp/B0CDDY8F9L",
    "GoPro Media Mod": "https://gopro.com/en/us/shop/mounts-accessories/camera-media-mod/ADFMD-001.html",
    "Elgato CamLink": "https://www.amazon.com/dp/B07K3FN5MR",
    "UGREEN USB-C Adapter": "https://www.amazon.com/dp/B08P8X2DBZ",
    "AUX Cable (VIOY)": "https://www.amazon.com/dp/B0B9WJRRNQ"
}
# Flier paths
flier_1 = '_0_data_fliers/_flier_1_.png'
flier_2 = '_0_data_fliers/_flier_2_.png'
flier_3 = '_0_data_fliers/_flier_3_.png'
flier_4 = '_0_data_fliers/_flier_4_.png'

# %%
# def _pdf_0907_corecity_GET_clickablewords_pdf(output_path, content_lines, link_map):
#     king_blue = HexColor("#3366CC")
#     yellow = HexColor("#3366CC")
#     green = HexColor("#3366CC")
#     background_blue = HexColor("#EAF2FB")
#     flier_paths = [flier_1, flier_2, flier_3, flier_4]

#     try:
#         pdfmetrics.registerFont(TTFont("Professional", "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"))
#         font_name = "Professional"
#     except:
#         font_name = "Helvetica"

#     c = canvas.Canvas(output_path, pagesize=A4)
#     width, height = A4
#     margin = 40
#     page_count = 1

#     def draw_framed_background(frame_color):
#         c.setStrokeColor(frame_color)
#         c.setLineWidth(3)
#         c.rect(margin, margin, width - 2 * margin, height - 2 * margin)
#         c.setFillColor(background_blue)
#         c.rect(margin + 2, margin + 2, width - 2 * margin - 4, height - 2 * margin - 4, fill=1, stroke=0)

#     draw_framed_background(king_blue)

#     text = c.beginText(margin + 10, height - 60)
#     text.setFont(font_name, 11)
#     text.setFillColor(HexColor("#000000"))

#     for line in content_lines:
#         y = text.getY()

#         for label, url in link_map.items():
#             if label in line:
#                 x = margin + 10 + (line.index(label) * 5.9)
#                 c.linkURL(url, (x, y - 2, x + len(label) * 6, y + 10), relative=1, color=king_blue)
#                 break

#         text.textLine(line)

#         if text.getY() < 80:
#             c.drawText(text)
#             c.showPage()
#             page_count += 1
#             frame_color = yellow if page_count == 2 else green
#             draw_framed_background(frame_color)
#             text = c.beginText(margin + 10, height - 60)
#             text.setFont(font_name, 11)
#             text.setFillColor(HexColor("#000000"))

#     c.drawText(text)

#     # -------- Add Flier Grid Page (Blue Frame) -------- #
#     c.showPage()
#     draw_framed_background(king_blue)

#     flier_w = (width - 2 * margin - 40) / 2
#     flier_h = (height - 2 * margin - 60) / 2
#     positions = [
#         (margin + 5, height - margin - flier_h - 5),
#         (margin + flier_w + 25, height - margin - flier_h - 5),
#         (margin + 5, margin + 25),
#         (margin + flier_w + 25, margin + 25)
#     ]

#     for i, (path, pos) in enumerate(zip(flier_paths, positions), start=1):
#         if os.path.exists(path):
#             c.drawImage(ImageReader(path), pos[0], pos[1],
#                         width=flier_w, height=flier_h,
#                         preserveAspectRatio=True, anchor='c')
#             c.setFont(font_name, 9)
#             c.setFillColor(king_blue)
#             c.drawString(pos[0] + 4, pos[1] - 12, f"flier {i}")

#     c.save()
    
# _pdf_0907_corecity_GET_clickablewords_pdf(
#     "Core_City_Community_Sundays_FINAL_with_Fliers.pdf",
#     proposal_lines,
#     gear_links
# )

# %%
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
from reportlab.lib.colors import HexColor
from reportlab.lib.utils import ImageReader
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
import os

def _pdf_0907_corecity_GET_clickablewords_pdf(output_path, content_lines, link_map):
    king_blue = HexColor("#3366CC")
    yellow = HexColor("#FFD700")
    green = HexColor("#66CC66")
    background_blue = HexColor("#EAF2FB")
    flier_paths = [flier_1, flier_2, flier_3, flier_4]

    # Font registration
    try:
        pdfmetrics.registerFont(TTFont("Professional", "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"))
        font_name = "Professional"
    except:
        font_name = "Helvetica"

    font_size = 11
    char_width = 5.9
    line_height = 14
    margin = 40
    width, height = A4
    c = canvas.Canvas(output_path, pagesize=A4)

    def draw_framed_background(color):
        c.setStrokeColor(color)
        c.setLineWidth(3)
        c.rect(margin, margin, width - 2 * margin, height - 2 * margin)
        c.setFillColor(background_blue)
        c.rect(margin + 2, margin + 2, width - 2 * margin - 4, height - 2 * margin - 4, fill=1, stroke=0)

    y = height - 60
    page = 1
    draw_framed_background(king_blue)

    for line in content_lines:
        c.setFont(font_name, font_size)
        c.setFillColor(HexColor("#000000"))
        c.drawString(margin + 10, y, line)

        # Overlay hyperlinks after drawing text
        for label, url in link_map.items():
            if label in line:
                x = margin + 10 + (line.index(label) * char_width)
                c.linkURL(url, (x, y - 2, x + len(label) * char_width, y + 10), relative=0)

        y -= line_height
        if y < 60:
            c.showPage()
            page += 1
            if page == 2:
                draw_framed_background(yellow)
            elif page == 3:
                draw_framed_background(green)
            else:
                draw_framed_background(king_blue)
            y = height - 60

    # Add flier page
    c.showPage()
    draw_framed_background(king_blue)
    flier_w = (width - 2 * margin - 40) / 2.1
    flier_h = (height - 2 * margin - 60) / 2.1
    positions = [
        (margin + 5, height - margin - flier_h - 5),
        (margin + flier_w + 25, height - margin - flier_h - 5),
        (margin + 5, margin + 25),
        (margin + flier_w + 25, margin + 25)
    ]

    for i, (path, pos) in enumerate(zip(flier_paths, positions), start=1):
        if os.path.exists(path):
            c.drawImage(ImageReader(path), pos[0], pos[1],
                        width=flier_w, height=flier_h,
                        preserveAspectRatio=True, anchor='c')
            c.setFont(font_name, 9)
            c.setFillColor(king_blue)
            c.drawString(pos[0] + 4, pos[1] - 12, f"flier {i}")

    c.save()

# %%
_pdf_0907_corecity_GET_clickablewords_pdf(
    "Core_City_Community_Sundays_FINAL_with_Fliers.pdf",
    proposal_lines,
    gear_links
)

# %% [markdown]
# ## FEEDBACK

# %%
feedback_lines = [
    "────────────────────────────────────────────────────────────",
    "         FEEDBACK – Things I LOVE      ",
    "────────────────────────────────────────────────────────────",
    "",
    "» 1. Landscaping: Soft Boundaries That Breathe",
    "────────────────────────────────────────────────────────────",
    "The way you’ve designed the plant landscaping around the house",
    "is brilliant — it creates a sense of privacy and calm while still",
    "keeping us connected to the surrounding neighbors.",
    "",
    "It feels intentional, not isolating — like a soft boundary",
    "that brings peace without cutting us off.",
    "",
    "» 2. Lighting: Atmosphere in Dialogue",
    "────────────────────────────────────────────────────────────",
    "The lighting fixtures are so well-chosen — they don't just",
    "illuminate, they complement the space.",
    "",
    "The warmth and softness feel like they’re in conversation with",
    "the interior — never harsh or clinical.",
    "",
    "It's rare to live somewhere where the lights seem to “dance”",
    "with your sightline instead of disrupting it.",
    "",
    "» 3. Entry Flow: Thoughtful Arrival",
    "────────────────────────────────────────────────────────────",
    "The arrival and departure experience is genuinely one of my",
    "favorite parts of living here.",
    "",
    "The parking layout is incredibly intentional — easy access right",
    "at the entrance, which is a rare luxury this close to the city.",
    "",
    "Even better, there’s space for guests, and the ability to see your",
    "vehicle from multiple angles inside the house adds a layer of",
    "ease and security.",
    "",
    "It feels like the whole entry sequence was designed for actual",
    "daily living — not just aesthetics.",
    "",
    "» BONUS: Windows that Open the World",
    "────────────────────────────────────────────────────────────",
    "This might sound obvious, but the windows are one of the top",
    "three things every single person mentions when they visit.",
    "",
    "They completely transform the experience of being inside —",
    "not just a place with great light, but a space that opens to",
    "the outside world.",
    "",
    "You don’t just see out — you feel connected.",
    "It’s the opposite of being boxed in by walls.",
    "",
    "The views, the natural light, and the way the architecture",
    "frames it all — this is honestly one of the most powerful,",
    "mood-shifting design features of the entire place.",
    "",
    "Even more impressive is how the space interacts with sunlight",
    "throughout the day — especially during late afternoon.",
    "",
    "There’s this intentional flow where light enters but never overwhelms.",
    "There are areas where you can rest, hide from the sun if it strikes hard,",
    "or let it bathe the room gently — it feels deliberate, like the house",
    "understands your body needs a break.",
    "",
    "The way light plays with the textures and colors — outstanding.",
    "",
    "My friend from NYC, an interior designer, visited and was floored.",
    "She literally said, “I want to shoot a film here.” We toured the",
    "Caterpillar unit, and she was already writing the story in her head.",
    "It was real fire. Hilarious and so NY.",
    "",
    "────────────────────────────────────────────────────────────",
    "            FEEDBACK - Room for Improvement          ",
    "────────────────────────────────────────────────────────────",
    "",
    "» 1. Entrance Light — Bug Magnet at Night",
    "────────────────────────────────────────────────────────────",
    "One small but noticeable design quirk is the exterior light",
    "by the entrance. Since it stays on continuously, it attracts",
    "a lot of bugs — especially in warmer months.",
    "",
    "This can make coming and going feel less smooth, especially for",
    "those more sensitive to insects.",
    "",
    "It's not a dealbreaker — just something a motion sensor or",
    "better placement could easily fix, bringing the experience",
    "in line with the rest of the home’s thoughtful design.",
    "",
    "» 2. Courtyard — Underactivated Beauty",
    "────────────────────────────────────────────────────────────",
    "Spending time at home makes me reflect on how spaces invite interaction.",
    "",
    "In Mexico City, some courtyards weren’t in plain view — just",
    "out of the way enough to feel like discoveries. You’d find",
    "people stretching, relaxing, or passing through — and those",
    "moments made the place feel alive.",
    "",
    "Here, the central courtyard is visually stunning but centrally",
    "exposed. It feels more like a passageway than a place to linger.",
    "",
    "A few subtle, sculptural additions could shift that energy:",
    "  – A concrete ping pong or chess table",
    "  – A small gym element — monkey bars or stretching post",
    "  – A minimal yoga corner — two angled walls to create calm",
    "",
    "Nothing flashy — just useful, raw, and intentional.",
    "Simple moves to transform it into a daily ritual space.",
    "",
    "» 3. Sound Buffering — One Architectural Move",
    "────────────────────────────────────────────────────────────",
    "Having lived in over 20 places in Michigan — mostly lofts —",
    "I’ve learned that architecture shapes peace of mind.",
    "",
    "Two of the best were a 3,000 sq ft loft at 222 Brooklyn and",
    "one above Supino’s in Eastern Market — both gave better bedroom",
    "insulation (light and sound) than here.",
    "",
    "The current openness is beautiful, yes — but for couples with",
    "slightly different schedules, it’s tough.",
    "",
    "For my wife, especially, uninterrupted sleep has been tricky",
    "due to how open the bedroom space is.",
    "",
    "Even a partial wall between the lower stair and the upper level,",
    "or something that blocks the back-office light/sound path,",
    "would make a huge difference.",
    "",
    "We knew it was a trade-off when we moved in — and the benefits",
    "still outweigh it — but it’s the one thing that slightly hinders",
    "daily life.",
    "",
    "If there were an elegant option (even at cost) to add a minimal,",
    "tasteful sound-buffering intervention, we’d support it fully.",
    ""
]

# %%
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
from reportlab.lib.colors import HexColor
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
import os

def _pdf_0907_feedback_GET_pdf(output_path, feedback_lines):
    border_color = HexColor("#444444")
    background_fill = HexColor("#FAFAFA")
    text_color = HexColor("#222222")
    section_color = HexColor("#3366CC")

    try:
        pdfmetrics.registerFont(TTFont("Serif", "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"))
        font_name = "Serif"
    except:
        font_name = "Helvetica"

    width, height = A4
    margin = 50
    line_height = 16
    font_size = 11
    section_font_size = 12
    c = canvas.Canvas(output_path, pagesize=A4)

    def draw_clean_page():
        c.setFillColor(background_fill)
        c.rect(0, 0, width, height, fill=1, stroke=0)
        c.setStrokeColor(border_color)
        c.setLineWidth(1.5)
        c.rect(margin - 10, margin - 10, width - 2 * (margin - 10), height - 2 * (margin - 10))

    y = height - margin
    draw_clean_page()

    for line in feedback_lines:
        if line.strip() == "":
            y -= line_height // 2
            continue

        if line.strip().startswith("»"):
            c.setFont(font_name, section_font_size)
            c.setFillColor(section_color)
            c.drawString(margin, y, line.strip())
        else:
            c.setFont(font_name, font_size)
            c.setFillColor(text_color)
            c.drawString(margin, y, line)

        y -= line_height
        if y < margin:
            c.showPage()
            draw_clean_page()
            y = height - margin

    c.save()



#!#!#!#!#! RUNNING STATEMENT #!#!#!#!#!
output_path = "corecity_feedback.pdf"
_pdf_0907_feedback_GET_pdf(output_path, feedback_lines)
print(f"PDF successfully saved to: {output_path}")
# Out:
# PDF successfully saved to: corecity_feedback.pdf
