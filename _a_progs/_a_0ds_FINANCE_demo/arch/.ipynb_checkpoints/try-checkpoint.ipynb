# %%
import pandas as pd
df= pd.read_pickle(f'_1_tables/_df_0_init_UNITS.pkl')

# %%
exec(open(f"_0_a1_PORTFOLIO_entry_updt_.py",encoding="utf-8").read())
# Out:
#  3
#  3
# Select a stock by number to indicate a SELL action, or press enter to exit:
# 1. DHOF.AX
# 2. ILB.AX
# 3. QPON.AX
# 4. TACT.XA
# 5. GROW.AX
# 6. MVA.AX
# 7. GOLD.AX
# 8. AMC.AX
# 9. ALD.AX
# 10. ANZ.AX
# 11. APA.AX
# 12. BHP.AX
# 13. SQ2.AX
# 14. BXB.AX
# 15. CHC.AX
# 16. COL.AX
# 17. CBA.AX
# 18. CSL.AX
# 19. CSR.AX
# 20. IAG.AX
# 21. JLG.AX
# 22. 360.AX
# 23. PXA.AX
# 24. RHC.AX
# 25. RMD.AX
# 26. SHL.AX
# 27. TLS.AX
# 28. TCL.AX
# 29. EX20.AX
# 30. WES.AX
# 31. VCX.AX
# 32. XRO.AX
# 33. QUAL.AX
# 34. ANN.AX
# 35. GLOB.AX
# 36. FEMX.AX
# 37. MCSI.XA
# 38. CLDD.AX
# 39. DJRE.AX
# 40. ACDC.AX
# 41. TSLA
# 42. MQG.AX
# 43. VHY.AX
# 44. MIN.AX
# 45. USIG.AX
# 46. SEMI.AX
# 47. IJH.AX
# 48. HCRD.AX
# 49. BUGG.AX
# >  43
# Current number of UNITS of VHY.AX: 24.706160440386146
# Enter the % amount to be sold (0-100):  3
# Enter the month (e.g., Jan, February):  Feb
# Enter the day (DD):  11
# Enter the year (YYYY):  2022
# Is this date correct? (Y/N) 2022-02-11:  y
# Confirmed date (yyyy-mm-dd): 2022-02-11
# Your entered date is: 2022-02-11
#
#
#  TABLE
#
#
# For the stock VHY.AX, you are selling = 3.0%
#
# E >>> Select stocks by typing their **number** or name to indicate a SELL action,
#  >>> type **CASH** if part of this SALE will go to straight to CASH:
#  >>> type a **new stock** name to add it, or press enter to exit:
#
# 1. DHOF.AX
# 2. ILB.AX
# 3. QPON.AX
# 4. TACT.XA
# 5. GROW.AX
# 6. MVA.AX
# 7. GOLD.AX
# 8. AMC.AX
# 9. ALD.AX
# 10. ANZ.AX
# 11. APA.AX
# 12. BHP.AX
# 13. SQ2.AX
# 14. BXB.AX
# 15. CHC.AX
# 16. COL.AX
# 17. CBA.AX
# 18. CSL.AX
# 19. CSR.AX
# 20. IAG.AX
# 21. JLG.AX
# 22. 360.AX
# 23. PXA.AX
# 24. RHC.AX
# 25. RMD.AX
# 26. SHL.AX
# 27. TLS.AX
# 28. TCL.AX
# 29. EX20.AX
# 30. WES.AX
# 31. VCX.AX
# 32. XRO.AX
# 33. QUAL.AX
# 34. ANN.AX
# 35. GLOB.AX
# 36. FEMX.AX
# 37. MCSI.XA
# 38. CLDD.AX
# 39. DJRE.AX
# 40. ACDC.AX
# 41. TSLA
# 42. MQG.AX
# 43. VHY.AX
# 44. MIN.AX
# 45. USIG.AX
# 46. SEMI.AX
# 47. IJH.AX
# 48. HCRD.AX
# 49. BUGG.AX
# >  45
# E >>> Select stocks by typing their **number** or name to indicate a SELL action,
#  >>> type **CASH** if part of this SALE will go to straight to CASH:
#  >>> type a **new stock** name to add it, or press enter to exit:
#
# 1. DHOF.AX
# 2. ILB.AX
# 3. QPON.AX
# 4. TACT.XA
# 5. GROW.AX
# 6. MVA.AX
# 7. GOLD.AX
# 8. AMC.AX
# 9. ALD.AX
# 10. ANZ.AX
# 11. APA.AX
# 12. BHP.AX
# 13. SQ2.AX
# 14. BXB.AX
# 15. CHC.AX
# 16. COL.AX
# 17. CBA.AX
# 18. CSL.AX
# 19. CSR.AX
# 20. IAG.AX
# 21. JLG.AX
# 22. 360.AX
# 23. PXA.AX
# 24. RHC.AX
# 25. RMD.AX
# 26. SHL.AX
# 27. TLS.AX
# 28. TCL.AX
# 29. EX20.AX
# 30. WES.AX
# 31. VCX.AX
# 32. XRO.AX
# 33. QUAL.AX
# 34. ANN.AX
# 35. GLOB.AX
# 36. FEMX.AX
# 37. MCSI.XA
# 38. CLDD.AX
# 39. DJRE.AX
# 40. ACDC.AX
# 41. TSLA
# 42. MQG.AX
# 43. VHY.AX
# 44. MIN.AX
# 45. USIG.AX
# 46. SEMI.AX
# 47. IJH.AX
# 48. HCRD.AX
# 49. BUGG.AX
# >  45
# E >>> Select stocks by typing their **number** or name to indicate a SELL action,
#  >>> type **CASH** if part of this SALE will go to straight to CASH:
#  >>> type a **new stock** name to add it, or press enter to exit:
#
# 1. DHOF.AX
# 2. ILB.AX
# 3. QPON.AX
# 4. TACT.XA
# 5. GROW.AX
# 6. MVA.AX
# 7. GOLD.AX
# 8. AMC.AX
# 9. ALD.AX
# 10. ANZ.AX
# 11. APA.AX
# 12. BHP.AX
# 13. SQ2.AX
# 14. BXB.AX
# 15. CHC.AX
# 16. COL.AX
# 17. CBA.AX
# 18. CSL.AX
# 19. CSR.AX
# 20. IAG.AX
# 21. JLG.AX
# 22. 360.AX
# 23. PXA.AX
# 24. RHC.AX
# 25. RMD.AX
# 26. SHL.AX
# 27. TLS.AX
# 28. TCL.AX
# 29. EX20.AX
# 30. WES.AX
# 31. VCX.AX
# 32. XRO.AX
# 33. QUAL.AX
# 34. ANN.AX
# 35. GLOB.AX
# 36. FEMX.AX
# 37. MCSI.XA
# 38. CLDD.AX
# 39. DJRE.AX
# 40. ACDC.AX
# 41. TSLA
# 42. MQG.AX
# 43. VHY.AX
# 44. MIN.AX
# 45. USIG.AX
# 46. SEMI.AX
# 47. IJH.AX
# 48. HCRD.AX
# 49. BUGG.AX
# >  45
# E >>> Select stocks by typing their **number** or name to indicate a SELL action,
#  >>> type **CASH** if part of this SALE will go to straight to CASH:
#  >>> type a **new stock** name to add it, or press enter to exit:
#
# 1. DHOF.AX
# 2. ILB.AX
# 3. QPON.AX
# 4. TACT.XA
# 5. GROW.AX
# 6. MVA.AX
# 7. GOLD.AX
# 8. AMC.AX
# 9. ALD.AX
# 10. ANZ.AX
# 11. APA.AX
# 12. BHP.AX
# 13. SQ2.AX
# 14. BXB.AX
# 15. CHC.AX
# 16. COL.AX
# 17. CBA.AX
# 18. CSL.AX
# 19. CSR.AX
# 20. IAG.AX
# 21. JLG.AX
# 22. 360.AX
# 23. PXA.AX
# 24. RHC.AX
# 25. RMD.AX
# 26. SHL.AX
# 27. TLS.AX
# 28. TCL.AX
# 29. EX20.AX
# 30. WES.AX
# 31. VCX.AX
# 32. XRO.AX
# 33. QUAL.AX
# 34. ANN.AX
# 35. GLOB.AX
# 36. FEMX.AX
# 37. MCSI.XA
# 38. CLDD.AX
# 39. DJRE.AX
# 40. ACDC.AX
# 41. TSLA
# 42. MQG.AX
# 43. VHY.AX
# 44. MIN.AX
# 45. USIG.AX
# 46. SEMI.AX
# 47. IJH.AX
# 48. HCRD.AX
# 49. BUGG.AX
# >
# Exiting... You've selected the following stocks: USIG.AX
# Allocating percentages for the following selected stocks: USIG.AX
#
#  & % >> Automatically allocating the remaining 100% to USIG.AX.
#
#
#       Stock  PercentSold keep_drop trans_type   DateTrans exchange_stocks  \
# 0  VHY.AX          3.0         d          s  2022-02-11       [USIG.AX]
#
#   sell_perc              id_time
# 0     [100]  VHY.AX_2022-02-11_s
#
#
#  ATTN : Are you sure you want to write this new entry to the tables_add?
#   ... y ... TO WRITE to tables and RUN updates  << or >> PRESS ENTER to EXIT
#
#  y
