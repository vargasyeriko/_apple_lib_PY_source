# %%
exec(open(f"_14_Graphs_and_PDF.py",encoding="utf-8").read())
df_all =df.copy()
df_all.head()
brokerage_paid = 700 #do function 
initial_investment= 100000 - brokerage_paid
d_start_date= '2022-07-01'

# %%
# Monthly returns table 
df = df.drop_duplicates(subset=['period'], keep='first')
df = df[['AnalysisEndDate','period', 'period_cash' ,
       'period_divs','period_total_cash',
       'period_stocks_value','period_total_holds'
      ]]
#########

per_inv = len(df)
new_row = {
    "AnalysisEndDate": d_start_date,
    "period": per_inv,  # Assigning -1 to denote initial state before period 0
    "period_cash": 0,
    "period_divs": 0,
    "period_total_cash": 0,
    "period_stocks_value": 0,
    "period_total_holds": initial_investment
}

# Appending the new row
df = df.append(new_row, ignore_index=True)
df.sort_values(by='period', ascending=True, inplace=True)
# Calculate monthly returns
df['previous_total_holds'] = df['period_total_holds'].shift(-1)
# 

# MONTHLY RETURNS full AMOUNT
df['monthly_return'] = ((df['period_total_holds'] - df['previous_total_holds']) / df['previous_total_holds']) * 100
df['total_return'] = ((df['period_total_holds']/initial_investment)-1)*100

# %%
df.head()
# Out:
#   AnalysisEndDate  period  period_cash  period_divs  period_total_cash  \
# 0      2024-05-07       0   485.885395      5929.68            6415.57
# 1      2024-04-07       1   485.885395      5839.47            6325.35
# 2      2024-03-07       2   485.885395      5666.22            6152.11
# 3      2024-02-07       3  2968.228177      5328.25            8296.48
# 4      2024-01-07       4  2968.228177      5233.61            8201.84
#
#    period_stocks_value  period_total_holds  previous_total_holds  \
# 0            116557.57           122973.14             121846.84
# 1            115521.49           121846.84             121634.21
# 2            115482.10           121634.21             116316.47
# 3            108019.99           116316.47             114613.42
# 4            106411.58           114613.42             112553.60
#
#    monthly_return  total_return
# 0        0.924357     23.840020
# 1        0.174811     22.705780
# 2        4.571786     22.491652
# 3        1.485908     17.136425
# 4        1.830079     15.421370

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'AnalysisEndDate' contains date as string
# Convert 'AnalysisEndDate' to datetime just once for the whole DataFrame
df['AnalysisEndDate'] = pd.to_datetime(df['AnalysisEndDate'])

# Get the first and last date from the DataFrame
start_date = df.iloc[1]['AnalysisEndDate']
end_date = df.iloc[0]['AnalysisEndDate']

# Since start_date and end_date are already datetime objects, you can directly use them
# Extract the day of the month for both start and end dates
start_day = start_date.day
end_day = end_date.day

# Format these dates to extract month and year
start_month = start_date.strftime('%B %Y')
end_month = end_date.strftime('%B %Y')

# Get the return percentage from the first recordable calculation
total_return = df.iloc[0]['monthly_return']  # This picks the latest month's return

# Create the message
message_mr = f"""The total return of the fund including dividends and,
cash flow from {start_date.strftime('%d %B %Y')} to {end_date.strftime('%d %B %Y')}, was: {total_return:.2f}%
"""
print(message_mr)
# Out:
# The total return of the fund including dividends and,
# cash flow from 07 April 2024 to 07 May 2024, was: 0.92%

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'AnalysisEndDate' contains date as string
# Convert 'AnalysisEndDate' to datetime just once for the whole DataFrame
df['AnalysisEndDate'] = pd.to_datetime(df['AnalysisEndDate'])

# Get the first and last date from the DataFrame
start_date = df.iloc[-1]['AnalysisEndDate']
end_date = df.iloc[0]['AnalysisEndDate']

# Since start_date and end_date are already datetime objects, you can directly use them
# Extract the day of the month for both start and end dates
start_day = start_date.day
end_day = end_date.day

# Format these dates to extract month and year
start_month = start_date.strftime('%B %Y')
end_month = end_date.strftime('%B %Y')

# Get the return percentage from the first recordable calculation
total_return = df.iloc[0]['total_return']  # This picks the latest month's return

# Create the message
message_tr = f"""The total return of the fund including dividends and,
cash flow from {start_date.strftime('%d %B %Y')} to {end_date.strftime('%d %B %Y')}, was: {total_return:.2f}%
"""
#print(message)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'AnalysisEndDate' contains date as string
# Convert 'AnalysisEndDate' to datetime just once for the whole DataFrame
df['AnalysisEndDate'] = pd.to_datetime(df['AnalysisEndDate'])

# Get the first and last date from the DataFrame
start_date = df.iloc[-1]['AnalysisEndDate']
end_date = df.iloc[0]['AnalysisEndDate']

# Since start_date and end_date are already datetime objects, you can directly use them
# Extract the day of the month for both start and end dates
start_day = start_date.day
end_day = end_date.day

# Format these dates to extract month and year
start_month = start_date.strftime('%B %Y')
end_month = end_date.strftime('%B %Y')

# Get the return percentage from the first recordable calculation
total_return_stocks = df.iloc[0]['period_stocks_value']  # This picks the latest month's return

# Create the message
message_psr = f"""The total Stock Holding Value from {start_date.strftime('%d %B %Y')} to {end_date.strftime('%d %B %Y')}, was: {total_return_stocks:.2f} $
"""
#print(message)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'AnalysisEndDate' contains date as string
# Convert 'AnalysisEndDate' to datetime just once for the whole DataFrame
df['AnalysisEndDate'] = pd.to_datetime(df['AnalysisEndDate'])

# Get the first and last date from the DataFrame
start_date = df.iloc[-1]['AnalysisEndDate']
end_date = df.iloc[0]['AnalysisEndDate']

# Since start_date and end_date are already datetime objects, you can directly use them
# Extract the day of the month for both start and end dates
start_day = start_date.day
end_day = end_date.day

# Format these dates to extract month and year
start_month = start_date.strftime('%B %Y')
end_month = end_date.strftime('%B %Y')

# Get the return percentage from the first recordable calculation
total_return_divs = df.iloc[0]['period_divs']  # This picks the latest month's return

# Create the message
message_psd = f"""The total Dividends from {start_date.strftime('%d %B %Y')} to {end_date.strftime('%d %B %Y')}, was: {total_return_divs:.2f} $
"""
#print(message)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'AnalysisEndDate' contains date as string
# Convert 'AnalysisEndDate' to datetime just once for the whole DataFrame
df['AnalysisEndDate'] = pd.to_datetime(df['AnalysisEndDate'])

# Get the first and last date from the DataFrame
start_date = df.iloc[-1]['AnalysisEndDate']
end_date = df.iloc[0]['AnalysisEndDate']

# Since start_date and end_date are already datetime objects, you can directly use them
# Extract the day of the month for both start and end dates
start_day = start_date.day
end_day = end_date.day

# Format these dates to extract month and year
start_month = start_date.strftime('%B %Y')
end_month = end_date.strftime('%B %Y')

# Get the return percentage from the first recordable calculation
total_return = df.iloc[0]['period_cash']  # This picks the latest month's return

# Create the message
message_pcb = f"""The total Cash Balance from {start_date.strftime('%d %B %Y')} to {end_date.strftime('%d %B %Y')}, was: {total_return:.2f} $
"""
#print(message)

# %%
# Assuming 'df' is your DataFrame and 'AnalysisEndDate' contains date as string
# Convert 'AnalysisEndDate' to datetime just once for the whole DataFrame
df['AnalysisEndDate'] = pd.to_datetime(df['AnalysisEndDate'])

# Get the first and last date from the DataFrame
start_date = df.iloc[-1]['AnalysisEndDate']
end_date = df.iloc[0]['AnalysisEndDate']

# Since start_date and end_date are already datetime objects, you can directly use them
# Extract the day of the month for both start and end dates
start_day = start_date.day
end_day = end_date.day

# Format these dates to extract month and year
start_month = start_date.strftime('%B %Y')
end_month = end_date.strftime('%B %Y')

# Get the return percentage from the first recordable calculation
total_return = df.iloc[0]['period_total_cash']  # This picks the latest month's return

# Create the message
message_pca = f"""The total Cash Amount accouting for Dividends and Cash Flow was: {total_return:.2f} $
"""
#print(message)

# %%
total_adjusted_final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 total_adjusted_final
#
# NameError: name 'total_adjusted_final' is not defined

# %%
# CAGR

# Get the first and last date from the DataFrame
start_date = df.iloc[-1]['AnalysisEndDate']
end_date = df.iloc[0]['AnalysisEndDate']

final_value = total_return_stocks
dividends_received = total_return_divs

total_adjusted_final = final_value - initial_investment + dividends_received - brokerage_paid
time_difference = (end_date - start_date).days / 365.25  # Use 365.25 to account for leap years

CAGR = ((final_value + dividends_received - brokerage_paid) / initial_investment) ** (1 / time_difference) - 1
CAGR_percentage = CAGR * 100

message_cagr =f"""
The Compound Annual Growth Rate (CAGR) for the portfolio
from {start_date.strftime('%d %B %Y')} to {end_date.strftime('%d %B %Y')} is approximately {CAGR_percentage:.2f}% per annum
"""

# %%
#################################

# %%
report_p1 = f"""
Assuming Balance Growth, we have the following:

Portfolio Initial investment is: ${initial_investment+brokerage_paid} 
Approximately, we have blockage costs of: ${brokerage_paid}

{message_mr}
{message_tr}
{message_psr}
 -{message_psd}
 -{message_pcb}
{message_pca}

{message_cagr}
"""

# %%
print(report_p1)
# Out:
# Assuming Balance Growth, we have the following:
#
# Portfolio Initial investment is: $100000
# Approximately, we have blockage costs of: $700
#
# The total return of the fund including dividends and,
# cash flow from 07 April 2024 to 07 May 2024, was: 0.92%
#
# The total return of the fund including dividends and,
# cash flow from 01 July 2022 to 07 May 2024, was: 23.84%
#
#
#     monthly_return  total_return
# 0         0.924357     23.840020
# 1         0.174811     22.705780
# 2         4.571786     22.491652
# 3         1.485908     17.136425
# 4         1.830079     15.421370
# 5         2.268015     13.347029
# 6         0.128006     10.833313
# 7        -2.827363     10.691621
# 8        -0.266626     13.912336
# 9         1.807425     14.216868
# 10        0.029254     12.189134
# 11        1.599724     12.156324
# 12        0.128063     10.390383
# 13       -0.756320     10.249194
# 14        0.172718     11.089386
# 15        4.459817     10.897845
# 16       -1.925550      6.163162
# 17        2.386265      8.247523
# 18        1.757050      5.724653
# 19       -0.490450      3.899094
# 20       -2.672627      4.411178
# 21        4.220950      7.278328
# 22        2.933555      2.933555
# 23             NaN      0.000000

# %%
# Ensure dates are converted to datetime and sorted if needed
df['AnalysisEndDate'] = pd.to_datetime(df['AnalysisEndDate'])
df = df.sort_values(by='AnalysisEndDate')

# Get the first and last date from the DataFrame
start_date = df.iloc[0]['AnalysisEndDate']  # Assuming the DataFrame is sorted in ascending order
end_date = df.iloc[-1]['AnalysisEndDate']

# Debug: print intermediate values
print(f"Start Date: {start_date}, End Date: {end_date}")
print(f"Initial Investment: {initial_investment}, Final Value: {final_value}, Dividends Received: {dividends_received}, Brokerage Paid: {brokerage_paid}")

total_adjusted_final = final_value - initial_investment + dividends_received - brokerage_paid
time_difference = (end_date - start_date).days / 365.25

# Debug: print calculated total and time difference
print(f"Total Adjusted Final: {total_adjusted_final}, Time Difference: {time_difference}")

CAGR = (total_adjusted_final / initial_investment) ** (1 / time_difference) - 1
CAGR_percentage = CAGR * 100

message_cagr = f"""
The Compound Annual Growth Rate (CAGR) for the portfolio
from {start_date.strftime('%d %B %Y')} to {end_date.strftime('%d %B %Y')} is approximately {CAGR_percentage:.2f}% per annum.
"""
print(message_cagr)
# Out:
# Start Date: 2022-07-01 00:00:00, End Date: 2024-05-07 00:00:00
# Initial Investment: 99300, Final Value: 116557.57, Dividends Received: 5929.68, Brokerage Paid: 700
# Total Adjusted Final: 22487.250000000007, Time Difference: 1.8507871321013005
#
# The Compound Annual Growth Rate (CAGR) for the portfolio
# from 01 July 2022 to 07 May 2024 is approximately -55.18% per annum.

# %%
# Given data
final_value = total_return_stocks
dividends_received = total_return_divs

# Total value at the end adjusted for dividends and brokerage
total_adjusted_final = final_value - initial_investment + dividends_received - brokerage_paid

# Time difference in years
time_difference = 1.8507871321013005

# CAGR calculation
CAGR = ((final_value + dividends_received - brokerage_paid) / initial_investment) ** (1 / time_difference) - 1
CAGR_percentage = CAGR * 100

# Output the result
print(f"The Compound Annual Growth Rate (CAGR) for the portfolio from 01 July 2022 to 07 May 2024 is approximately {CAGR_percentage:.2f}% per annum.")
# Out:
# The Compound Annual Growth Rate (CAGR) for the portfolio from 01 July 2022 to 07 May 2024 is approximately 12.01% per annum.
