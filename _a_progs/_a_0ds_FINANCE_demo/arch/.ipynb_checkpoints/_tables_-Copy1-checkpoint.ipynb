# %%
exec(open(f"_0_PORTFOLIO_updt.py",encoding="utf-8").read()) #paths
# Out:
# Please select your risk profile by entering the corresponding number:
#
# 1 - Moderate
# 2 - Balanced
# 3 - Balanced Growth
# 4 - Growth
# 5 - High Growth
# 	Enter the number of your choice (1/2/3/4/5):  4
# Defensive investment:	 20000.0
#
# Growth investment:	 80000.0
# Defensive
# History INIT wrote in pkl _1_tables/D_historic_data_.pkl
#
#
#
#
#  Initial Investment is 20000.0
#
#  ['DHOF.AX', 'ILB.AX', 'QPON.AX', 'TACT.XA', 'GROW.AX', 'MVA.AX', 'GOLD.AX']
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
exec(open(f"fns/_0_fns_PORTFOLIO_updt.py",encoding="utf-8").read()) #paths

exec(open(f"fns_D_PORTS_HIST.py",encoding="utf-8").read()) #paths

# import pandas as pd
# from datetime import datetime
# ############################################################################
# #


# initial_investment = initial_investment_D  # AUD
# #
# print(f'\n\n Initial Investment is {initial_investment}')
# # Calculate the total percentage currently allocated to stocks
# total_percentage_allocated = sum(portfolio_percentages)
# cash_percentage = 1 - total_percentage_allocated  # Remaining percentage for cash

# # Update the portfolio to include cash
# portfolio_percentages.append(cash_percentage)
# portfolio_labels.append('Cash')

# # Calculate invested amounts including the cash component
# invested_amounts = [percentage * initial_investment for percentage in portfolio_percentages]

# # Determine the transaction fee, assuming no fee for cash
# transaction_fees = []
# for amount in invested_amounts[:-1]:  # Exclude cash for fee calculation
#     if amount > 7334:
#         fee = amount * 0.0009
#     if amount == 0.0:
#         fee = 0.0
#     else:
#         fee = 6.60
#     transaction_fees.append(fee)
# transaction_fees.append(0)  # No fee for cash

# # Calculate net cash value after fees for all components including cash
# net_cash_values = [amount - fee for amount, fee in zip(invested_amounts, transaction_fees)]

# # Create a DataFrame to display the portfolio with cash values
# portfolio_df = pd.DataFrame({
#     'Stock': portfolio_labels,
#     'Invested Amount (AUD)': invested_amounts,
#     'Transaction Fee (AUD)': transaction_fees,
#     'Net Cash Value (AUD)': net_cash_values
# })
# # Calculate totals and sums for transactions
# total_sum_inv = portfolio_df['Invested Amount (AUD)'].sum()
# entry_sum_trans = portfolio_df['Transaction Fee (AUD)'].sum()
# entry_inv_from_trans = 0
# net_trans_cost = 0 + entry_sum_trans

# # Assign transaction cost summary
# # New row values
# new_row_values = ['trans_cost', entry_inv_from_trans, entry_sum_trans, net_trans_cost]

# # Adding new row using loc
# portfolio_df.loc[len(portfolio_df)] = new_row_values

# # Assign Start Date to each row
# portfolio_df['StartDate'] = start_date

# # Convert StartDate column to a list
# start_dates_list = portfolio_df['StartDate'].tolist()

# ############

# # Calculate the percentages for the legend
# portfolio_df['Percentage'] = (portfolio_df['Net Cash Value (AUD)'] / portfolio_df['Net Cash Value (AUD)'].sum()) * 100

# df_cash_start = portfolio_df.tail(2)
# cash_start_value = portfolio_df.loc[portfolio_df['Stock'] == 'Cash', 'Invested Amount (AUD)'].values[0]

# ##################


# # Getting the first column excluding the last two rows
# stock_names = portfolio_df.iloc[:-2, 0].tolist()
# stock_net_start = portfolio_df.iloc[:-2, 3].tolist()


# print('\n',stock_names,'\n\n')


# # Creating a DataFrame to hold the investment details
# investment_details = []

# # Iterate over stocks and their corresponding start dates and investment amounts
# for stock_symbol, start_date, investment_amount in zip(stock_names, start_dates_list, stock_net_start):
#     # Adjusted to pass a list containing a single start date
#     results = calculate_investment_details([start_date], stock_symbol, investment_amount)
#     for start_price, latest_price, current_value, percentage_change in results:
#         investment_details.append({
#             "Stock": stock_symbol,
#             "Price Bought": start_price,
#             "Latest Price": latest_price,
#             # Add more fields as needed
#         })

# # Convert investment details to DataFrame
# investment_df = pd.DataFrame(investment_details)

# # Merging with the original portfolio DataFrame
# df = pd.merge(investment_df, portfolio_df, on='Stock', how='outer')
# df['hold_units_at_init'] = df['Net Cash Value (AUD)'] / df['Price Bought']
# df
# #print('\nTHIS US first df :\n ',df)
# df.to_pickle('_1_tables/D_init_inv_.pkl')
# print('\n\n INITIAL INV D_init_inv_.pkl has been written \n')

# ##### HIST
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 exec(open(f"fns/_0_fns_PORTFOLIO_updt.py",encoding="utf-8").read()) #paths
#       3 exec(open(f"fns_D_PORTS_HIST.py",encoding="utf-8").read()) #paths
#       5 # import pandas as pd
#       6 # from datetime import datetime
#       7 # ############################################################################
#    (...)
#     110
#     111 # ##### HIST
#
# File <string>:56
#
# NameError: name 'datetime' is not defined

# %%
### ############################################################################
print('GROWTH')
### Start Dates -> they are 9 because of cash and trans_cost
start_date = ['2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01']

### Initial Investment 
total_inv = 100000 

### Initial investments and portfolio setup
portfolio_percentages =[ .0311, .0142, .0255, .011, .0255, .0089, .0127, .0283, .0177, .025, 
                        .032, .0099, .0085, .0095, .0144, .022, .0105, .0144, .012, .0142,
                        .01, .0442, .0211, .0111, .0111, .1177, .0305, .1177, .101, .0408, .03684,.048, .062]
    
    
portfolio_labels = ['AMC.AX', 'ALD.AX', 'ANZ.AX', 'APA.AX', 'BHP.AX','SQ2.AX', 'BXB.AX', 'CHC.AX', 'COL.AX', 'CBA.AX', 
                    'CSL.AX', 'CSR.AX', 'IAG.AX', 'JLG.AX', '360.AX',
                    'PXA.AX', 'RHC.AX', 'RMD.AX', 'SHL.AX', 'TLS.AX', 
                    'TCL.AX', 'EX20.AX', 'WES.AX', 'VCX.AX', 'XRO.AX',
                    'QUAL.AX', 'ANN.AX', 'GLOB.AX', 'FEMX.AX', 'MCSI.XA',
                    'CLDD.AX','DJRE.AX', 'ACDC.AX']
############################################################################
#
#
initial_investment = initial_investment_G  # AUD
#
print(f'\n\n Initial Investment is {initial_investment}')
#
# Calculate the total percentage currently allocated to stocks
total_percentage_allocated = sum(portfolio_percentages)
cash_percentage = 1 - total_percentage_allocated  # Remaining percentage for cash

# Update the portfolio to include cash
portfolio_percentages.append(cash_percentage)
portfolio_labels.append('Cash')

# Calculate invested amounts including the cash component
invested_amounts = [percentage * initial_investment for percentage in portfolio_percentages]

# Determine the transaction fee, assuming no fee for cash
transaction_fees = []
for amount in invested_amounts[:-1]:  # Exclude cash for fee calculation
    if amount > 7334:
        fee = amount * 0.0009
    if amount == 0.0:
        fee = 0.0
    else:
        fee = 6.60
    transaction_fees.append(fee)
transaction_fees.append(0)  # No fee for cash

# Calculate net cash value after fees for all components including cash
net_cash_values = [amount - fee for amount, fee in zip(invested_amounts, transaction_fees)]

# Create a DataFrame to display the portfolio with cash values
portfolio_df = pd.DataFrame({
    'Stock': portfolio_labels,
    'Invested Amount (AUD)': invested_amounts,
    'Transaction Fee (AUD)': transaction_fees,
    'Net Cash Value (AUD)': net_cash_values
})
# Calculate totals and sums for transactions
total_sum_inv = portfolio_df['Invested Amount (AUD)'].sum()
entry_sum_trans = portfolio_df['Transaction Fee (AUD)'].sum()
entry_inv_from_trans = 0
net_trans_cost = 0 + entry_sum_trans

# Assign transaction cost summary
# New row values
new_row_values = ['trans_cost', entry_inv_from_trans, entry_sum_trans, net_trans_cost]

# Adding new row using loc
portfolio_df.loc[len(portfolio_df)] = new_row_values

# Assign Start Date to each row
portfolio_df['StartDate'] = start_date

# Convert StartDate column to a list
start_dates_list = portfolio_df['StartDate'].tolist()

############

# Calculate the percentages for the legend
portfolio_df['Percentage'] = (portfolio_df['Net Cash Value (AUD)'] / portfolio_df['Net Cash Value (AUD)'].sum()) * 100

df_cash_start = portfolio_df.tail(2)
cash_start_value = portfolio_df.loc[portfolio_df['Stock'] == 'Cash', 'Invested Amount (AUD)'].values[0]

##################


# Getting the first column excluding the last two rows
stock_names = portfolio_df.iloc[:-2, 0].tolist()
stock_net_start = portfolio_df.iloc[:-2, 3].tolist()


print('\n',stock_names,'\n\n')


# Creating a DataFrame to hold the investment details
investment_details = []

# Iterate over stocks and their corresponding start dates and investment amounts
for stock_symbol, start_date, investment_amount in zip(stock_names, start_dates_list, stock_net_start):
    # Adjusted to pass a list containing a single start date
    results = calculate_investment_details([start_date], stock_symbol, investment_amount)
    for start_price, latest_price, current_value, percentage_change in results:
        investment_details.append({
            "Stock": stock_symbol,
            "Price Bought": start_price,
            "Latest Price": latest_price,
            # Add more fields as needed
        })

# Convert investment details to DataFrame
investment_df = pd.DataFrame(investment_details)

# Merging with the original portfolio DataFrame
df_g = pd.merge(investment_df, portfolio_df, on='Stock', how='outer')
df_g['hold_units_at_init'] = df_g['Net Cash Value (AUD)'] / df_g['Price Bought']

#print('\nTHIS US first df :\n ',df)
df_g.to_pickle('_1_tables/G_init_inv_.pkl')
print('\n\n INITIAL INV G_init_inv_.pkl has been written \n')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# GROWTH
#
#
#  Initial Investment is 50000.0
#
#  ['AMC.AX', 'ALD.AX', 'ANZ.AX', 'APA.AX', 'BHP.AX', 'SQ2.AX', 'BXB.AX', 'CHC.AX', 'COL.AX', 'CBA.AX', 'CSL.AX', 'CSR.AX', 'IAG.AX', 'JLG.AX', '360.AX', 'PXA.AX', 'RHC.AX', 'RMD.AX', 'SHL.AX', 'TLS.AX', 'TCL.AX', 'EX20.AX', 'WES.AX', 'VCX.AX', 'XRO.AX', 'QUAL.AX', 'ANN.AX', 'GLOB.AX', 'FEMX.AX', 'MCSI.XA', 'CLDD.AX', 'DJRE.AX', 'ACDC.AX']
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
# ############################################################################2
# ############################################################################
# ############################################################################

# import pandas as pd
# df_columns = ['Stock', 'PercentSold', 'keep_drop', 'trans_type', 'DateTrans','exchange_stocks','sell_perc']
# hist_df = pd.DataFrame(columns=df_columns)  # Initialize with the updated columns

# # The data to append as a DataFrame, now excluding 'AmountSold' and 'AmountBought' # history of sells
# data_to_append_df = pd.DataFrame([
#     {'Stock': 'TACT.XA', 'PercentSold': 25.0, 'keep_drop': 'd', 'trans_type': 's',
#      'DateTrans': '2023-05-03','exchange_stocks': ['ILB.AX'] ,'sell_perc': [100]},
    
#     {'Stock': 'GOLD.AX', 'PercentSold': 33.0, 'keep_drop': 'd', 'trans_type': 's', 
#      'DateTrans': '2023-07-20','exchange_stocks':['QPON.AX']  ,'sell_perc': [100]},
    
#     {'Stock': 'MVA.AX', 'PercentSold': 100.0, 'keep_drop': 'd', 'trans_type': 's', 
#      'DateTrans': '2023-09-11','exchange_stocks': ['QPON.AX', 'ILB.AX']  ,'sell_perc': [50, 50]},
    
#     {'Stock': 'QPON.AX', 'PercentSold': 23.0, 'keep_drop': 'd', 'trans_type': 's', 
#      'DateTrans': '2024-02-13','exchange_stocks':['HCRD.AX', 'USIG.AX']  ,'sell_perc': [50, 50]},
    
#     {'Stock': 'ILB.AX', 'PercentSold': 23.0, 'keep_drop': 'd', 'trans_type': 's', 
#      'DateTrans': '2024-02-13','exchange_stocks':['HCRD.AX', 'USIG.AX']  ,'sell_perc': [50, 50]},

# ])

# hist_df = pd.concat([hist_df, data_to_append_df], ignore_index=True)

# # Ensure that all entries in 'exchange_stocks' and 'sell_perc' are lists of strings
# hist_df['exchange_stocks'] = hist_df['exchange_stocks'].apply(lambda lst: [str(item) for item in lst])
# hist_df['sell_perc'] = hist_df['sell_perc'].apply(lambda lst: [str(percentage) for percentage in lst])
# hist_df['id_time'] = hist_df['Stock'] + "_" + hist_df['DateTrans'] + "_" + hist_df['trans_type']

# # Save the DataFrame as a pickle file
# hist_df.to_pickle('tables/D_0_historic_data_.pkl')

# print('History INIT wrote in pkl D_0_historic_data_.pkl \n\n')
# Out:
# Defensive
# History INIT wrote in pkl D_0_historic_data_.pkl

# %%
df_D = pd.read_pickle('tables/D_0_historic_data_.pkl')
df_D['port_type'] = 'D'

df_D
# Out:
#      Stock  PercentSold keep_drop trans_type   DateTrans     exchange_stocks  \
# 0  TACT.XA         25.0         d          s  2023-05-03            [ILB.AX]
# 1  GOLD.AX         33.0         d          s  2023-07-20           [QPON.AX]
# 2   MVA.AX        100.0         d          s  2023-09-11   [QPON.AX, ILB.AX]
# 3  QPON.AX         23.0         d          s  2024-02-13  [HCRD.AX, USIG.AX]
# 4   ILB.AX         23.0         d          s  2024-02-13  [HCRD.AX, USIG.AX]
#
#   sell_perc               id_time port_type
# 0     [100]  TACT.XA_2023-05-03_s         D
# 1     [100]  GOLD.AX_2023-07-20_s         D
# 2  [50, 50]   MVA.AX_2023-09-11_s         D
# 3  [50, 50]  QPON.AX_2024-02-13_s         D
# 4  [50, 50]   ILB.AX_2024-02-13_s         D

# %%
############################################################################
############################################################################
print('GROWTH')
### Start Dates -> they are 9 because of cash and trans_cost
start_date = ['2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01','2022-07-01','2022-07-01','2022-07-01',
              '2022-07-01']

### Initial Investment 
total_inv = 100000 

### Initial investments and portfolio setup
portfolio_percentages =[ .0311, .0142, .0255, .011, .0255, .0089, .0127, .0283, .0177, .025, 
                        .032, .0099, .0085, .0095, .0144, .022, .0105, .0144, .012, .0142,
                        .01, .0442, .0211, .0111, .0111, .1177, .0305, .1177, .101, .0408, .03684,.048, .062]
    
    
portfolio_labels = ['AMC.AX', 'ALD.AX', 'ANZ.AX', 'APA.AX', 'BHP.AX','SQ2.AX', 'BXB.AX', 'CHC.AX', 'COL.AX', 'CBA.AX', 
                    'CSL.AX', 'CSR.AX', 'IAG.AX', 'JLG.AX', '360.AX',
                    'PXA.AX', 'RHC.AX', 'RMD.AX', 'SHL.AX', 'TLS.AX', 
                    'TCL.AX', 'EX20.AX', 'WES.AX', 'VCX.AX', 'XRO.AX',
                    'QUAL.AX', 'ANN.AX', 'GLOB.AX', 'FEMX.AX', 'MCSI.XA',
                    'CLDD.AX','DJRE.AX', 'ACDC.AX']

############################################################################
############################################################################
# history 
df_columns = ['Stock', 'PercentSold', 'keep_drop', 'trans_type', 'DateTrans','exchange_stocks','sell_perc']
hist_df = pd.DataFrame(columns=df_columns)  # Initialize with the updated columns

# The data to append as a DataFrame, now excluding 'AmountSold' and 'AmountBought' # history of sells
data_to_append_df = pd.DataFrame([
    {'Stock': 'SQ2.AX', 'PercentSold': 30.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2022-10-27','exchange_stocks': ['RHC.AX'] ,'sell_perc': [100]},
    {'Stock': 'CBA.AX', 'PercentSold': 25.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2022-12-01','exchange_stocks':['IAG.AX']  ,'sell_perc': [100]},
    {'Stock': 'BHP.AX', 'PercentSold': 19.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-03-10','exchange_stocks': ['TCL.AX']  ,'sell_perc': [100]}, 
    {'Stock': 'BXB.AX', 'PercentSold': 15.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-03-10','exchange_stocks':['TCL.AX']  ,'sell_perc': [100]},
    {'Stock': 'JLG.AX', 'PercentSold': 15.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-03-10','exchange_stocks':['TCL.AX']  ,'sell_perc': [100]},

    {'Stock': 'EX20.AX', 'PercentSold': 50.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-03-13','exchange_stocks':['VHY.AX']  ,'sell_perc': [100]},
    {'Stock': 'QUAL.AX', 'PercentSold': 30.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-03-10','exchange_stocks':['FEMX.AX']  ,'sell_perc': [100]},
    {'Stock': 'CSL.AX', 'PercentSold': 38.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-07-20','exchange_stocks':['SHL.AX']  ,'sell_perc': [100]},  
    {'Stock': 'DJRE.AX', 'PercentSold': 100.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-07-20','exchange_stocks':['IJH.AX', 'ANZ.AX']  ,'sell_perc': [50, 50]},
    {'Stock': 'ACDC.AX', 'PercentSold': 100.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-07-20','exchange_stocks':['TSLA.AX']  ,'sell_perc': [100]},
    
    {'Stock': 'FEMX.AX', 'PercentSold': 50.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-09-11','exchange_stocks':['TLS.AX', 'CSR.AX']  ,'sell_perc': [33, 67]},
   
    {'Stock': 'CLDD.AX', 'PercentSold': 15.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-10-10','exchange_stocks':['CASH','TSLA.AX']  ,'sell_perc': [70, 30]},
    {'Stock': 'QUAL.AX', 'PercentSold': 15.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2023-10-10','exchange_stocks':['CASH','TSLA.AX']  ,'sell_perc': [70, 30]},

    {'Stock': 'ANN.AX', 'PercentSold': 100.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2024-01-10','exchange_stocks':['RMD.AX']  ,'sell_perc': [100]},

    {'Stock': 'PXA.AX', 'PercentSold': 100.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2024-02-13','exchange_stocks':['MQG.AX']  ,'sell_perc': [100]},
    {'Stock': 'VCX.AX', 'PercentSold': 100.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2024-02-13','exchange_stocks':['MIN.AX']  ,'sell_perc': [100]},
    #{'Stock': 'ANN.AX', 'PercentSold': 23.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2024-02-13','exchange_stocks':['FEMX.AX', 'SHL.AX']  ,'sell_perc': [50, 50]},

    {'Stock': 'CLDD.AX', 'PercentSold': 100.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2024-02-13','exchange_stocks':['SEMI.AX']  ,'sell_perc': [100]},
    {'Stock': 'CASH', 'PercentSold': 30.0, 'keep_drop': 'd', 'trans_type': 's', 'DateTrans': '2024-02-13','exchange_stocks':['BUGG.AX']  ,'sell_perc': [100]},

])

hist_df = pd.concat([hist_df, data_to_append_df], ignore_index=True)

# Ensure that all entries in 'exchange_stocks' and 'sell_perc' are lists of strings
hist_df['exchange_stocks'] = hist_df['exchange_stocks'].apply(lambda lst: [str(item) for item in lst])
hist_df['sell_perc'] = hist_df['sell_perc'].apply(lambda lst: [str(percentage) for percentage in lst])

hist_df['id_time'] = hist_df['Stock'] + "_" + hist_df['DateTrans'] + "_" + hist_df['trans_type']

# Save the DataFrame as a pickle file
hist_df.to_pickle('tables/G_0_historic_data_.pkl')
print('History INIT wrote in pkl _0_historic_data_.pkl \n\n')
############################################################################
############################################################################

############################################################################
############################4
################################################

#exec(open(f"run.py",encoding="utf-8").read()) #paths



############################################################################
############################################################################
# Out:
# GROWTH
# History INIT wrote in pkl _0_historic_data_.pkl

# %%
df_G = pd.read_pickle('tables/G_0_historic_data_.pkl')

# %%
df_G['port_type'] = 'G'
df_G
# Out:
#       Stock  PercentSold keep_drop trans_type   DateTrans   exchange_stocks  \
# 0    SQ2.AX         30.0         d          s  2022-10-27          [RHC.AX]
# 1    CBA.AX         25.0         d          s  2022-12-01          [IAG.AX]
# 2    BHP.AX         19.0         d          s  2023-03-10          [TCL.AX]
# 3    BXB.AX         15.0         d          s  2023-03-10          [TCL.AX]
# 4    JLG.AX         15.0         d          s  2023-03-10          [TCL.AX]
# 5   EX20.AX         50.0         d          s  2023-03-13          [VHY.AX]
# 6   QUAL.AX         30.0         d          s  2023-03-10         [FEMX.AX]
# 7    CSL.AX         38.0         d          s  2023-07-20          [SHL.AX]
# 8   DJRE.AX        100.0         d          s  2023-07-20  [IJH.AX, ANZ.AX]
# 9   ACDC.AX        100.0         d          s  2023-07-20         [TSLA.AX]
# 10  FEMX.AX         50.0         d          s  2023-09-11  [TLS.AX, CSR.AX]
# ...

# %%
import yfinance as yf
import pandas as pd

def fetch_data(symbols, start_date, end_date):
    # Exclude 'CASH' from symbols as it's no longer relevant
    symbols_without_cash = [symbol for symbol in symbols if symbol != 'CASH']
    
    # Download historical price data for the symbols
    data = yf.download(symbols_without_cash, start=start_date, end=end_date)
    
    # No need to adjust for cash balance or dividends, so we return the data directly
    return data

# Example usage
symbols = portfolio_labels  # Add your symbols here
start_date = '2022-07-01'  # Start date in 'YYYY-MM-DD' format
end_date = '2024-04-01'  # End date in 'YYYY-MM-DD' format

# Call the modified function without cash_balance
all_data_open_close = fetch_data(symbols, start_date, end_date)

# Depending on your data structure, you can directly access the necessary financial information.
# Out:
# [*********************100%%**********************]  33 of 33 completed

# %%
all_data_open_close
# Out:
# Price      Adj Close                                                         \
# Ticker        360.AX    ACDC.AX     ALD.AX     AMC.AX     ANN.AX     ANZ.AX
# Date
# 2022-07-01      2.84  73.096207  30.788462  16.501415  20.958344  19.721687
# 2022-07-04      2.91  73.096207  30.943176  16.795916  21.270731  19.972689
# 2022-07-05      3.24  73.038147  31.225306  16.795916  21.431660  19.900974
# 2022-07-06      3.69  71.877129  29.896568  16.768307  21.649384  20.080261
# 2022-07-07      3.63  72.476997  30.224203  16.933966  22.226828  20.438839
# ...              ...        ...        ...        ...        ...        ...
# 2024-03-22     13.70  93.250000  40.290001  14.140000  23.500000  29.040001
# 2024-03-25     13.10  92.709999  40.349998  14.200000  24.250000  29.150000
# 2024-03-26     13.09  92.959999  39.759998  14.160000  24.400000  29.059999
# 2024-03-27     12.84  93.309998  39.470001  14.150000  24.709999  29.260000
# ...

# %%
import yfinance as yf
import pandas as pd

def fetch_data_with_dividends(symbols, start_date, end_date):
    # Exclude 'CASH' from symbols as it's no longer relevant
    symbols_without_cash = [symbol for symbol in symbols if symbol != 'CASH']
    
    # Initialize a DataFrame to store all data
    all_data = pd.DataFrame()
    
    for symbol in symbols_without_cash:
        # Download historical price data for the symbol
        ticker = yf.Ticker(symbol)
        hist = ticker.history(start=start_date, end=end_date)
        
        # Extracting open, close, and dividends
        data = hist[['Open', 'Close', 'Dividends']]
        
        # Creating a MultiIndex for columns with the symbol name as the top level
        data.columns = pd.MultiIndex.from_product([[symbol], data.columns])
        
        # If all_data is empty, initialize it with data
        if all_data.empty:
            all_data = data
        else:
            # Otherwise, join this symbol's data with the existing all_data
            all_data = all_data.join(data, how='outer')
    
    # Remove days without any trading data across all symbols
    all_data.dropna(how='all', subset=[idx for idx in all_data.columns if 'Open' in idx or 'Close' in idx], inplace=True)
    
    return all_data

# Example usage
start_date = '2022-07-01'  # Start date in 'YYYY-MM-DD' format
end_date = '2024-04-01'  # End date in 'YYYY-MM-DD' format

# Call the function to get price and dividends data
all_data_open_close_dividends = fetch_data_with_dividends(symbols, start_date, end_date)
all_data_open_close_dividends
# Out:
#                               AMC.AX                          ALD.AX  \
#                                 Open      Close Dividends       Open
# Date
# 2022-07-01 00:00:00+10:00  16.611853  16.501415       0.0  31.370921
# 2022-07-04 00:00:00+10:00  16.878745  16.795916       0.0  30.806661
# 2022-07-05 00:00:00+10:00  16.795916  16.795916       0.0  31.170699
# 2022-07-06 00:00:00+10:00  16.759103  16.768307       0.0  30.488130
# 2022-07-07 00:00:00+10:00  17.025998  16.933966       0.0  29.978477
# ...                              ...        ...       ...        ...
# 2024-03-22 00:00:00+11:00  14.050000  14.140000       0.0  40.459999
# 2024-03-25 00:00:00+11:00  14.170000  14.200000       0.0  40.520000
# 2024-03-26 00:00:00+11:00  14.160000  14.160000       0.0  40.700001
# 2024-03-27 00:00:00+11:00  14.080000  14.150000       0.0  39.439999
# 2024-03-28 00:00:00+11:00  14.410000  14.440000       0.0  39.889999
#
# ...

# %%
all_data_open_close_dividends.to_pickle('tables/_0_open_close_div.pkl')

# %%
import pandas as pd

def dividend_count(symbols, start_date, end_date):
    # Initialize a dictionary to store dividend counts
    dividend_counts = {}

    for symbol in symbols:
        # Fetch the historical data for the symbol
        ticker = yf.Ticker(symbol)
        hist = ticker.history(start=start_date, end=end_date)
        
        # Count non-zero dividends and add to the dictionary
        non_zero_dividends = hist['Dividends'].astype(bool).sum()
        dividend_counts[symbol] = non_zero_dividends
    
    # Convert the dictionary to a DataFrame for better readability
    dividend_counts_df = pd.DataFrame(list(dividend_counts.items()), columns=['Symbol', 'Dividend Count'])
    
    return dividend_counts_df

# %%
dividend_counts_data = dividend_count(symbols, start_date, end_date)
dividend_counts_data
# Out:
#      Symbol  Dividend Count
# 0    AMC.AX               7
# 1    ALD.AX               4
# 2    ANZ.AX               3
# 3    APA.AX               3
# 4    BHP.AX               4
# 5    SQ2.AX               0
# 6    BXB.AX               4
# 7    CHC.AX               3
# 8    COL.AX               4
# 9    CBA.AX               4
# 10   CSL.AX               4
# 11   CSR.AX               3
# 12   IAG.AX               4
# 13   JLG.AX               4
# 14   360.AX               0
# 15   PXA.AX               0
# 16   RHC.AX               4
# 17   RMD.AX               7
# 18   SHL.AX               4
# 19   TLS.AX               4
# 20   TCL.AX               3
# 21  EX20.AX               4
# 22   WES.AX               4
# 23   VCX.AX               4
# 24   XRO.AX               0
# 25  QUAL.AX               1
# 26   ANN.AX               4
# 27  GLOB.AX               4
# 28  FEMX.AX               2
# 29  MCSI.XA               4
# 30  CLDD.AX               1
# 31  DJRE.AX               3
# ...
