# %%
import pandas as pd
df= pd.read_pickle(f'_1_tables/_df_0_init_UNITS.pkl')

# %%
exec(open(f"_0_a1_PORTFOLIO_entry_updt_.py",encoding="utf-8").read())
# Out:
# Select a stock by number to indicate a SELL action, or press enter to exit:
# 1. DHOF.AX
# 2. ILB.AX
# 3. QPON.AX
# 4. TACT.XA
# 5. GROW.AX
# 6. MVA.AX
# 7. GOLD.AX
# 8. AMC.AX
# 9. ALD.AX
# 10. ANZ.AX
# 11. APA.AX
# 12. BHP.AX
# 13. SQ2.AX
# 14. BXB.AX
# 15. CHC.AX
# 16. COL.AX
# 17. CBA.AX
# 18. CSL.AX
# 19. CSR.AX
# 20. IAG.AX
# 21. JLG.AX
# 22. 360.AX
# 23. PXA.AX
# 24. RHC.AX
# 25. RMD.AX
# 26. SHL.AX
# 27. TLS.AX
# 28. TCL.AX
# 29. EX20.AX
# 30. WES.AX
# 31. VCX.AX
# 32. XRO.AX
# 33. QUAL.AX
# 34. ANN.AX
# 35. GLOB.AX
# 36. FEMX.AX
# 37. MCSI.XA
# 38. CLDD.AX
# 39. DJRE.AX
# 40. ACDC.AX
# 41. TSLA
# 42. MQG.AX
# 43. VHY.AX
# 44. MIN.AX
# 45. USIG.AX
# 46. SEMI.AX
# 47. IJH.AX
# 48. HCRD.AX
# 49. BUGG.AX
# >  2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
#       Stock  Price Bought  Latest Price  Invested Amount (AUD)  \
# 0   DHOF.AX      9.380000      9.620000                 4230.0
# 1    ILB.AX    117.300003    124.019997                 5598.0
# 2   QPON.AX     25.510000     26.020000                 5598.0
# 3   TACT.XA     45.439999     47.779999                 5298.0
# 4   GROW.AX      3.510000      3.650000                 2070.0
# 5    MVA.AX     20.180000     21.420000                 3000.0
# 6   GOLD.AX     24.490000     32.340000                 2400.0
# 7    AMC.AX     17.930000     15.120000                 2177.0
# 8    ALD.AX     33.830002     35.290001                  994.0
# 9    ANZ.AX     21.825901     28.480000                 1785.0
# 10   APA.AX     11.600000      8.380000                  770.0
# 11   BHP.AX     40.049999     42.410000                 1785.0
# 12   SQ2.AX     88.010002    116.440002                  623.0
# 13   BXB.AX     11.050000     14.380000                  889.0
# ...
