# %%
# import pandas as pd

# # Load the DataFrame containing closing prices
# df_close = pd.read_pickle("_1_fetch/_0_fetched_stock_data_prices.pkl")

# # Ensure that the index is of datetime type if it isn't already
# if not pd.api.types.is_datetime64_any_dtype(df_close.index):
#     df_close.index = pd.to_datetime(df_close.index)

# %%
# %run _01_a_b_D_G_PORTFOLIO_updt_.py
# Out:
# Did you make any changes in the previous month? <Enter:skip> <y:add_change>
# No CHANGES made ... CNTD ...
# *
# *
# *
# *
# *
#  ENTER now > RESTART PROGRAM for complete update & <n> to exit
# STARTING PROGRAM ...
#
# Please select your risk profile by entering the corresponding number:
#
# 1 - Moderate
# 2 - Balanced
# 3 - Balanced Growth
# 4 - Growth
# 5 - High Growth
# 	Enter the number of your choice (1/2/3/4/5):  3
# Defensive investment:	 30000.0
#
# Growth investment:	 70000.0
#
#  -> DEFENSIVE
#
# Initial Investment is 30000.0
#
#  -> GROWTH
#
# Initial Investment is 70000.0
# _df_0 >>> df_master with up-to-date units balances written df_0  :
# _df_1 >>> df_add    with ALL Exchange transactions written df_1  :
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_

# %%
df
# Out:
#       Stock  Price Bought  Latest Price  Invested Amount (AUD)  \
# 0   DHOF.AX      9.380000      9.553306                 4230.0
# 1    ILB.AX    117.300003    124.407150                 5598.0
# 2   QPON.AX     25.510000     26.053835                 5598.0
# 3   TACT.XA     45.439999     47.853874                 5298.0
# 4   GROW.AX      3.510000      3.619213                 2070.0
# 5    MVA.AX     20.180000     21.393482                 3000.0
# 6   GOLD.AX     24.490000     33.188795                 2400.0
# 7    AMC.AX     17.930000     13.844978                 2177.0
# 8    ALD.AX     33.830002     38.706577                  994.0
# 9    ANZ.AX     21.825901     28.329318                 1785.0
# 10   APA.AX     11.600000      8.412492                  770.0
# 11   BHP.AX     40.049999     44.652435                 1785.0
# 12   SQ2.AX     88.010002    114.481914                  623.0
# 13   BXB.AX     11.050000     14.662936                  889.0
# ...

# %%
dfd = pd.read_pickle('_1_tables/G_init_inv_.pkl')
dfd
# Out:
#          Stock  Price Bought  Latest Price  Invested Amount (AUD)  \
# 0       AMC.AX     17.930000     13.844978                 2177.0
# 1       ALD.AX     33.830002     38.706577                  994.0
# 2       ANZ.AX     21.825901     28.329318                 1785.0
# 3       APA.AX     11.600000      8.412492                  770.0
# 4       BHP.AX     40.049999     44.652435                 1785.0
# 5       SQ2.AX     88.010002    114.481914                  623.0
# 6       BXB.AX     11.050000     14.662936                  889.0
# 7       CHC.AX     11.040000     11.811135                 1981.0
# 8       COL.AX     17.840000     16.319687                 1239.0
# 9       CBA.AX     90.699997    113.845492                 1750.0
# 10      CSL.AX    269.230011    276.080654                 2240.0
# 11      CSR.AX      4.060000      8.863613                  693.0
# 12      IAG.AX      4.340000      6.435746                  595.0
# ...

# %%
investment_df_d
# Out:
#      Stock  Price Bought  Latest Price
# 0  DHOF.AX      9.380000      9.553306
# 1   ILB.AX    117.300003    124.407150
# 2  QPON.AX     25.510000     26.053835
# 3  TACT.XA     45.439999     47.853874
# 4  GROW.AX      3.510000      3.619213
# 5   MVA.AX     20.180000     21.393482
# 6  GOLD.AX     24.490000     33.188795

# %%
portfolio_df
# Out:
#          Stock  Invested Amount (AUD)  Transaction Fee (AUD)  \
# 0       AMC.AX                 2177.0                    6.6
# 1       ALD.AX                  994.0                    6.6
# 2       ANZ.AX                 1785.0                    6.6
# 3       APA.AX                  770.0                    6.6
# 4       BHP.AX                 1785.0                    6.6
# 5       SQ2.AX                  623.0                    6.6
# 6       BXB.AX                  889.0                    6.6
# 7       CHC.AX                 1981.0                    6.6
# 8       COL.AX                 1239.0                    6.6
# 9       CBA.AX                 1750.0                    6.6
# 10      CSL.AX                 2240.0                    6.6
# 11      CSR.AX                  693.0                    6.6
# 12      IAG.AX                  595.0                    6.6
# 13      JLG.AX                  665.0                    6.6
# ...

# %%
investment_df_d
# Out:
#      Stock  Price Bought  Latest Price
# 0  DHOF.AX      9.380000      9.553306
# 1   ILB.AX    117.300003    124.407150
# 2  QPON.AX     25.510000     26.053835
# 3  TACT.XA     45.439999     47.853874
# 4  GROW.AX      3.510000      3.619213
# 5   MVA.AX     20.180000     21.393482
# 6  GOLD.AX     24.490000     33.188795

# %%
df_d
# Out:
#         Stock  Price Bought  Latest Price  Invested Amount (AUD)  \
# 0     DHOF.AX      9.380000      9.553306                 4230.0
# 1      ILB.AX    117.300003    124.407150                 5598.0
# 2     QPON.AX     25.510000     26.053835                 5598.0
# 3     TACT.XA     45.439999     47.853874                 5298.0
# 4     GROW.AX      3.510000      3.619213                 2070.0
# 5      MVA.AX     20.180000     21.393482                 3000.0
# 6     GOLD.AX     24.490000     33.188795                 2400.0
# 7        Cash           NaN           NaN                 1806.0
# 8  trans_cost           NaN           NaN                    0.0
#
#    Transaction Fee (AUD)  Net Cash Value (AUD)   StartDate  Percentage  \
# 0                    6.6                4223.4  2022-07-01      14.078
# 1                    6.6                5591.4  2022-07-01      18.638
# 2                    6.6                5591.4  2022-07-01      18.638
# ...

# %%
df_g
# Out:
#       Stock  Price Bought  Latest Price  Invested Amount (AUD)  \
# 0    AMC.AX     17.930000     13.810000                 2177.0
# 1    ALD.AX     33.830002     38.080002                  994.0
# 2    ANZ.AX     21.825901     28.070000                 1785.0
# 3    APA.AX     11.600000      8.350000                  770.0
# 4    BHP.AX     40.049999     42.970001                 1785.0
# 5    SQ2.AX     88.010002    114.900002                  623.0
# 6    BXB.AX     11.050000     14.490000                  889.0
# 7    CHC.AX     11.040000     11.860000                 1981.0
# 8    COL.AX     17.840000     16.270000                 1239.0
# 9    CBA.AX     90.699997    113.839996                 1750.0
# 10   CSL.AX    269.230011    275.000000                 2240.0
# 11   CSR.AX      4.060000      8.920000                  693.0
# 12   IAG.AX      4.340000      6.390000                  595.0
# 13   JLG.AX      5.930000      5.660000                  665.0
# ...

# %%
# READ TABLES
exec(open(f"_0_0_read_all_tables.py",encoding="utf-8").read())

# %%
# DIVIDEND GRAPHS
exec(open(f"_0_fn_graphs/_graphs_div_1_2.py",encoding="utf-8").read())

# %%
exec(open(f"_0_fn_graphs/_graphs_div_3.py",encoding="utf-8").read())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 exec(open(f"_0_fn_graphs/_graphs_div_3.py",encoding="utf-8").read())
#
# File <string>:18
#
# NameError: name 'colors_list' is not defined

# %%
exec(open(f"_0_fn_graphs/_graphs_div_31_added.py",encoding="utf-8").read())

# %%
exec(open(f"_0_fn_graphs/_graphs_div_4_return_hist_.py",encoding="utf-8").read())

# %%
exec(open(f"_0_fn_graphs/_graphs_div_5d_D_break_down.py",encoding="utf-8").read())

# %%
exec(open(f"_0_fn_graphs/_graphs_div_5g_G_break_down.py",encoding="utf-8").read())
