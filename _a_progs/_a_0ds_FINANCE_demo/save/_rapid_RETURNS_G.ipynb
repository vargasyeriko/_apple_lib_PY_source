# %%
exec(open(f"_12_a_DIV_CASH_RET_tables_.py",encoding="utf-8").read())
exec(open(f"_13_Graph_REPORT_and_PDF.py",encoding="utf-8").read())

# Assuming Benchmark is 95% of 'Growth 97 Model Portfolio'
df['Benchmark'] = df['total_return'] * 0.95
# Out:
#  ATTN !! _22_ LEDGER EXPORTED _df_costs_1_2_complete_LEDGER.pkl
#
#
# BROCKAGE COSTS till 2022-07-01 are $ 606
# Type 'cd' for today's date or 'pd' for the past adjusted date or the last day of the month:  pd
# Enter the number of months ago:  1
# Selected cutoff date: 2024-04-30
# 2024-04-30 00:00:00
# 2024-04-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2024-03-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2024-02-29
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2024-01-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-12-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-11-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-10-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-09-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-08-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-07-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-06-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-05-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-04-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-03-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-02-28
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2023-01-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2022-12-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2022-11-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2022-10-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2022-09-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2022-08-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# 2022-07-30
# - - - - - - - - - - - - - > LEDGER PROCESSED
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:523, in open_for_read.<locals>.open_for_read(name, mode)
#     522 try:
# --> 523     return open_for_read_by_name(name,mode)
#     524 except:
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:463, in open_for_read_by_name(name, mode)
#     462 try:
# --> 463     return open(name,mode)
#     464 except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '_returns_graph.png'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:530, in open_for_read.<locals>.open_for_read(name, mode)
#     529             raise ValueError('Attempted untrusted host access')
# --> 530     return BytesIO((datareader if name[:5].lower()=='data:' else rlUrlRead)(name))
#     531 except:
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:476, in rlUrlRead(name)
#     475 def rlUrlRead(name):
# --> 476     return urlopen(name).read()
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/urllib/request.py:509, in OpenerDirector.open(self, fullurl, data, timeout)
#     508 if isinstance(fullurl, str):
# --> 509     req = Request(fullurl, data)
#     510 else:
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/urllib/request.py:328, in Request.__init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     325 def __init__(self, url, data=None, headers={},
#     326              origin_req_host=None, unverifiable=False,
#     327              method=None):
# --> 328     self.full_url = url
#     329     self.headers = {}
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/urllib/request.py:354, in Request.full_url(self, url)
#     353 self._full_url, self.fragment = _splittag(self._full_url)
# --> 354 self._parse()
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/urllib/request.py:383, in Request._parse(self)
#     382 if self.type is None:
# --> 383     raise ValueError("unknown url type: %r" % self.full_url)
#     384 self.host, self.selector = _splithost(rest)
#
# ValueError: unknown url type: '_returns_graph.png'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:643, in ImageReader.__init__(self, fileName, ident)
#     642     raise ValueError('imageReaderFlags values other than 0 are no longer supported; all images are interned now')
# --> 643 fp = open_for_read(fileName,'b')
#     644 if not isinstance(fp, BytesIO):
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:534, in open_for_read(name, mode)
#     533 globals()['open_for_read'] = open_for_read
# --> 534 return open_for_read(name,mode)
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:532, in open_for_read.<locals>.open_for_read(name, mode)
#     531 except:
# --> 532     raise IOError('Cannot open resource "%s"' % name)
#
# OSError: Cannot open resource "_returns_graph.png"
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 2
#       1 exec(open(f"_12_a_DIV_CASH_RET_tables_.py",encoding="utf-8").read())
# ----> 2 exec(open(f"_13_Graph_REPORT_and_PDF.py",encoding="utf-8").read())
#       4 # Assuming Benchmark is 95% of 'Growth 97 Model Portfolio'
#       5 df['Benchmark'] = df['total_return'] * 0.95
#
# File <string>:365
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:655, in ImageReader.__init__(self, fileName, ident)
#     653         self.jpeg_fh = self._jpeg_fh
#     654 except:
# --> 655     annotateException('\nfileName=%r identity=%s'%(fileName,self.identity()))
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:1176, in annotateException(msg, enc, postMsg, sep)
#    1174 '''add msg to the args of an existing exception'''
#    1175 t,v,b=sys.exc_info()
# -> 1176 rl_reraise(t,t(sep.join((_ for _ in (msg,str(v),postMsg) if _))),b)
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:138, in rl_reraise(t, v, b)
#     136 def rl_reraise(t, v, b=None):
#     137     if v.__traceback__ is not b:
# --> 138         raise v.with_traceback(b)
#     139     raise v
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:643, in ImageReader.__init__(self, fileName, ident)
#     641 if imageReaderFlags != 0:
#     642     raise ValueError('imageReaderFlags values other than 0 are no longer supported; all images are interned now')
# --> 643 fp = open_for_read(fileName,'b')
#     644 if not isinstance(fp, BytesIO):
#     645     tfp, fp = fp, BytesIO(fp.read())
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:534, in open_for_read(name, mode)
#     532             raise IOError('Cannot open resource "%s"' % name)
#     533 globals()['open_for_read'] = open_for_read
# --> 534 return open_for_read(name,mode)
#
# File ~/_envs/SRC_envs/src_env0/lib/python3.8/site-packages/reportlab/lib/utils.py:532, in open_for_read.<locals>.open_for_read(name, mode)
#     530     return BytesIO((datareader if name[:5].lower()=='data:' else rlUrlRead)(name))
#     531 except:
# --> 532     raise IOError('Cannot open resource "%s"' % name)
#
# OSError:
# fileName='_returns_graph.png' identity=[ImageReader@0x12ea4c2e0 filename='_returns_graph.png'] Cannot open resource "_returns_graph.png"

# %%
df_master
# Out:
#         Stock  StartDate    EndDate  units_hold AnalysisEndDate    run_date  \
# 0      360.AX 2022-07-01 2024-05-09  352.605644      2024-04-30  2024-05-09
# 1     ACDC.AX 2022-07-01 2023-07-20   57.358039      2023-07-20  2024-05-09
# 2     ACDC.AX 2023-07-21 2024-05-09    0.000000      2024-04-30  2024-05-09
# 3      ALD.AX 2022-07-01 2024-05-09   29.187110      2024-04-30  2024-05-09
# 4      AMC.AX 2022-07-01 2024-05-09  121.048520      2024-04-30  2024-05-09
# ...       ...        ...        ...         ...             ...         ...
# 1484  USIG.AX 2022-07-01 2024-02-13    0.000000      2022-07-30  2024-05-09
# 1485   VCX.AX 2022-07-01 2024-02-13  420.983597      2022-07-30  2024-05-09
# 1486   VHY.AX 2022-07-01 2023-03-13    0.000000      2022-07-30  2024-05-09
# 1487   WES.AX 2022-07-01 2024-05-09   34.884933      2022-07-30  2024-05-09
# 1488   XRO.AX 2022-07-01 2024-05-09   10.003895      2022-07-30  2024-05-09
#
#      count_back_from_date   Dividends  period  total_divs
# 0              2024-04-30    0.000000       0    0.000000
# 1              2024-04-30  200.154203       0  200.154203
# 2              2024-04-30    0.000000       0  200.154203
# 3              2024-04-30   94.858109       0   94.858109
# 4              2024-04-30  157.254132       0  157.254132
# ...                   ...         ...     ...         ...
# 1484           2022-07-30    0.000000      21    0.000000
# 1485           2022-07-30    0.000000      21    0.000000
# 1486           2022-07-30    0.000000      21    0.000000
# 1487           2022-07-30    0.000000      21    0.000000
# 1488           2022-07-30    0.000000      21    0.000000
#
# [1489 rows x 10 columns]

# %%
df= df_report.copy()

# %%
df
# Out:
#         Stock  units_hold AnalysisEndDate  period  price_end_date  total_divs  \
# 0      360.AX      352.61      2024-04-30       0           13.77        0.00
# 1     ACDC.AX        0.00      2024-04-30       0           95.50      200.15
# 2      ALD.AX       29.19      2024-04-30       0           36.81       94.86
# 3      AMC.AX      121.05      2024-04-30       0           13.82      157.25
# 4      ANN.AX        0.00      2024-04-30       0           25.59      110.21
# ...       ...         ...             ...     ...             ...         ...
# 1073  USIG.AX        0.00      2022-07-30      21            0.00        0.00
# 1074   VCX.AX      420.98      2022-07-30      21            2.07        0.00
# 1075   VHY.AX        0.00      2022-07-30      21            0.00        0.00
# 1076   WES.AX       34.88      2022-07-30      21           46.63        0.00
# 1077   XRO.AX       10.00      2022-07-30      21           92.99        0.00
#
#       stock_value_hold  period_cash  period_divs  period_total_cash  \
# 0              4855.38   485.885395      5873.99            6359.88
# 1                 0.00   485.885395      5873.99            6359.88
# 2              1074.38   485.885395      5873.99            6359.88
# 3              1672.89   485.885395      5873.99            6359.88
# 4                 0.00   485.885395      5873.99            6359.88
# ...                ...          ...          ...                ...
# 1073              0.00  1852.200000       770.75            2622.95
# 1074            871.44  1852.200000       770.75            2622.95
# 1075              0.00  1852.200000       770.75            2622.95
# 1076           1626.68  1852.200000       770.75            2622.95
# 1077            930.26  1852.200000       770.75            2622.95
#
#       period_stocks_value  period_total_holds
# 0               116047.03           122406.90
# 1               116047.03           122406.90
# 2               116047.03           122406.90
# 3               116047.03           122406.90
# 4               116047.03           122406.90
# ...                   ...                 ...
# 1073            102514.51           105137.46
# 1074            102514.51           105137.46
# 1075            102514.51           105137.46
# 1076            102514.51           105137.46
# 1077            102514.51           105137.46
#
# [1078 rows x 12 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.gridspec as gridspec
import numpy as np
from matplotlib.ticker import FuncFormatter

# Assume df is your existing DataFrame with the correct data
# df should have columns: 'AnalysisEndDate', 'total_return', 'Benchmark'

# Remove the last row from the DataFrame
#df = df.iloc[:-1]

# Assuming Benchmark is 95% of 'Growth 97 Model Portfolio'
df['Benchmark'] = df['total_return'] * 0.95

# Scale the 'total_return' and 'Benchmark' by 100000
df['total_return'] *= 100000
df['Benchmark'] *= 100000

# Ensure 'AnalysisEndDate' is a datetime type for proper plotting
df['AnalysisEndDate'] = pd.to_datetime(df['AnalysisEndDate'])

# Plotting
plt.style.use('ggplot')
fig = plt.figure(tight_layout=True, figsize=(12, 8))
gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1])

ax1 = fig.add_subplot(gs[0])
ax1.plot(df['AnalysisEndDate'], df['total_return'], label='Total Return', color='blue', marker='o', linewidth=0.8)
ax1.plot(df['AnalysisEndDate'], df['Benchmark'], label='Benchmark', color='orange', marker='o', linewidth=0.8)
ax1.set_title('Growth of Investment Over Time', fontsize=16)
ax1.set_xlabel('Date', fontsize=12)
ax1.set_ylabel('Dollar Value (Starting Value $ 100,000)', fontsize=12)
ax1.legend()

# Format y-axis labels to display full value
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

# Adding monthly vertical lines
dates = df['AnalysisEndDate']
for date in dates:
    ax1.axvline(x=date, color='gray', linestyle='--', linewidth=0.5)

# Generating synthetic monthly performance data for demonstration (you can replace this with actual data)
monthly_performance = np.random.uniform(0.3, 1.5, len(dates)).round(2)
performance_data = {
    'Months': dates.dt.strftime('%Y-%m'),  # Corrected use of strftime
    'Performance': [f"{p}%" for p in monthly_performance]
}

performance_df = pd.DataFrame(performance_data)

ax2 = fig.add_subplot(gs[1])
ax2.axis('tight')
ax2.axis('off')
table = ax2.table(cellText=performance_df.values, colLabels=performance_df.columns, rowLabels=['']*len(dates), cellLoc='center', loc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(.8, .8)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.gridspec as gridspec
import numpy as np
from matplotlib.ticker import FuncFormatter

# Assume df is your existing DataFrame with the correct data
# df should have columns: 'AnalysisEndDate', 'total_return', 'Benchmark'

# Assuming Benchmark is 95% of 'Growth 97 Model Portfolio'
df['Benchmark'] = df['total_return'] * 0.95

# Scale the 'total_return' and 'Benchmark' by 100000
df['total_return_scaled'] = df['total_return'] * 100000
df['Benchmark_scaled'] = df['Benchmark'] * 100000

# Ensure 'AnalysisEndDate' is a datetime type for proper plotting
df['AnalysisEndDate'] = pd.to_datetime(df['AnalysisEndDate'])

# Plotting
plt.style.use('ggplot')
fig = plt.figure(tight_layout=True, figsize=(12, 8))
gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1])

ax1 = fig.add_subplot(gs[0])
ax1.plot(df['AnalysisEndDate'], df['total_return_scaled'], label='Total Return (Scaled)', color='blue', marker='o', linewidth=0.8)
ax1.plot(df['AnalysisEndDate'], df['Benchmark_scaled'], label='Benchmark (Scaled)', color='orange', marker='o', linewidth=0.8)
ax1.set_title('Growth of Investment Over Time', fontsize=16)
ax1.set_xlabel('Date', fontsize=12)
ax1.set_ylabel('Dollar Value (x100,000)', fontsize=12)
ax1.legend()

# Format y-axis labels to display full value
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

# Adding monthly vertical lines
dates = df['AnalysisEndDate']
for date in dates:
    ax1.axvline(x=date, color='gray', linestyle='--', linewidth=0.5)

# Generating synthetic monthly performance data for demonstration (you can replace this with actual data)
monthly_performance = np.random.uniform(0.3, 1.5, len(dates)).round(2)
performance_data = {
    'Months': dates.dt.strftime('%Y-%m'),  # Corrected use of strftime
    'Performance': [f"{p}%" for p in monthly_performance]
}

performance_df = pd.DataFrame(performance_data)

ax2 = fig.add_subplot(gs[1])
ax2.axis('tight')
ax2.axis('off')
table = ax2.table(cellText=performance_df.values, colLabels=performance_df.columns, rowLabels=['']*len(dates), cellLoc='center', loc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(.8, .8)

plt.show()
