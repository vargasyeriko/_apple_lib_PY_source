# %% [markdown]
# ##  --------------------------------  >>>  PD

# %%
# %%writefile C:\Users\yerik\OneDrive\_Source\PY\pd.py
######################################################################################################### sys/pylib/pd_desc
print('*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n*\n',
      '* * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * Welcome Yeriko * * * * * * ',
      '\n*\n*\n*\n*\n**\n** <pd>   ::: ::: :::  starting loop program ::: ::: ::: pd.py ::: ::: ::: loading ... ')     

#rsp = 'a'
#exec(open(f"C:/Users/yerik/OneDrive/_Source/pd_sys_updates.py",encoding="utf-8").read()) #system updates Gsheets
while rsp != 'b':
    exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/pylib.py",encoding="utf-8").read()) #packages, variables, ds, functions
    #
    #################################################################################################### Notifications
    print('__________________________________________________________________________________________________') 
    #f_red_print('\n\n\n\n\n\n\n\n\n\n\n\n\n\n  NOTIFICATIONS')
    #f_red_print('  *************') 
    exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/MAIN/pd_rec_apt.py",encoding="utf-8").read())
    
    f_lcyan_print('__________________________________________________________________________________________________') 
    
#     hello = '''
#                                ▄▀▄     ▄▀▄
#                               ▄█░░▀▀▀▀▀░░█▄
#                           ▄▄  █░ hi there █  ▄▄
#                          █▄▄█ █░░▀░░┬░░▀░░█ █▄▄█
#     '''

######################################################################################################### W Iterations 
    exec(open(f"{path_main}/pd_w_cal.py",encoding="utf-8").read())
    f_lcyan_print('__________________________________________________________________________________________________') 
#     f_lcyan_print('\n  ALL PD')
#     f_lcyan_print('  ******                                                                             MAIN :::\n')
#     exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/all_pd.py",encoding="utf-8").read())
    
#   Programs ####################################################################################### Programs

    
    while rsp != "b":
         
        f_lcyan_print(          "\n <pd>    <<< b <-> break | ALL_PD | LIBS  | J-MSGS  |  JOB  |  RANK   |  TASKS  >>>") 
        rsp =input("\n ::::    <<< b <-> break | : a :  | : l : |  : m :  | : j : |  : r :  |  : t :  >>>  ")
         
        if rsp == "m":   
            exec(open(f"{path_main}/jmsg.py",encoding="utf-8").read())
        if rsp == "j":   
            exec(open(f"{path_main}/c_job.py",encoding="utf-8").read())
        if rsp == "r":   
            exec(open(f"{path_main}/pd_rank_music_midi.py",encoding="utf-8").read())
        if rsp == "t":   
            exec(open(f"{path_main}/pd_tasks.py",encoding="utf-8").read())
        if rsp == "a":   
            # CUSTOM Programs ########################################################################### pd programs
            path_programs = f'{path_source}/PY/MAIN'
            f_green_print('\n  ALL PY')
            print('                                                                                     MAIN :::\n')         
            exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/all_py.py",encoding="utf-8").read())  
        if rsp == "l":   
            # CUSTOM Programs ########################################################################### libs programs
            path_programs = 'C:/Users/yerik/OneDrive/_Source/all_libraries'
            f_green_print('\n LIBRARIES')
            print('                                                                                   SOURCE :::\n')         
            exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/all_libs_py.py",encoding="utf-8").read())   # this has special fn to open dbs
        else: p=0
# JOB CL #################################################################################################### JOB CL

    if day_name in {"Monday","Tuesday","Wednesday", 'Thursday', 'Friday'}:
        pattern_start(4)
        jacl = input('\n                       |||||||||||||-JOB-||||||||||||  \n                       | - | - | CHECKLISTS | - | - |  \n ** JOB *              ******************************        JOB | checklists >>> \n\n :pd:\t <<<E| y >>>\t... to OPEN Job Checklist\t... ')
        if jacl == "y":              
            exec(open(f"{path_main}/pd_checklist_job.py",encoding="utf-8").read())
        else:
            print(" <pd>\t\t\t ! NOT opened/saved\n")
# MUSIC CL ##################################################################################################  MUSIC CL

    if day_name in {"Monday","Tuesday","Wednesday", 'Thursday', 'Friday','Sunday'}:
        pattern_start(4)
        if datetime.now().strftime("%H:%M") > '11:46':
            row_init_0 = pd.Series([date,'link',0,0,'y/n','y/n','y/n','erase', 'folder name','folder_coment'], index=df_cl_music.columns)
            df_cl_music = pd.concat([df_cl_music, pd.DataFrame([row_init_0])])
            df_cl_music_today     = df_cl_music[df_cl_music['date'].str.contains(f'{date}')]
            df_cl_music_today_sum = df_cl_music_today.groupby(['date'])[['guitar']].sum()
            val_break_guitar_sum  = df_cl_music_today_sum.iloc[0,0]

            if val_break_guitar_sum < 15:
                jacl = input('\n                       |||||||||||-MUSIC-||||||||||||  \n                       | - | - | CHECKLISTS | - | - |  \n ** DJ  *              ******************************        GUITAR | CL >>> \n\n :pd:\t <<<E| y >>>\t... to OPEN MUSIC Checklist\t... ')
                if jacl == "y":   
                    exec(open(f"{path_main}/pd_checklist_music.py",encoding="utf-8").read())
                else:
                    print(" <pd>\t\t\t ! NOT opened/saved\n")
# CONTENT CL ################################################################################################## CONTENT CL

    if day_name in {"Monday","Tuesday","Wednesday", 'Thursday'}:     
        pattern_start(4)
        day_q = input('\n                       |||||||||||-CONTENT-||||||||||  \n                       | - | - | CHECKLISTS | - | - |  \n ** CAI *              ******************************     CONTENT | CL/exe >>>  \n\n :pd:\t <<<E| y >>>\t... to open CAI YV CONTENT Checklist\t... ')
        if day_q == "y":
            exec(open(f"{path_main}/pd_checklist_content.py",encoding="utf-8").read())
        
    
######################################################################################################### Daily checklist
    ##

 ######################################################################################################### Weekly Back-up
    ##
#     folder_exist = os.path.exists(f'C:/Users/yerik/OneDrive/Back_UPS/_Source_Back-up_{date}')
#     if folder_exist == 'False':
#         if day_name in {"Wednesday", "Sunday"}: 
#             b_ask = input('\n                                ***-BACK_UP-***              \n\n pd:\t <<<E| y >>>\t... to BACK UP _SOURCE_ ... ')
#             if b_ask == 'y':
#                 copy_tree("C:/Users/yerik/OneDrive/_Source", f"C:/Users/yerik/OneDrive/Back_UPS/_Source_Back-up_{date}")
#                 print(f" <pd>\t\t\t ! BACKED UP today {date} /saved\n")
#             else:
#                 print(" <pd>\t\t\t ! NOT backed-up \n")
#     f_lyellow_print('______________________________________________________________________________________________\n')
    
print('\n** *  *   *    *    *     *       *         *            *       *       *    *   *  * **END*\n')
print('______________________________________________________________________________________________')
# Out:
# Overwriting C:\Users\yerik\OneDrive\_Source\PY\pd.py

# %% [markdown]
# # --------------------------->> all_py

# %%
# %%writefile C:\Users\yerik\OneDrive\_Source\PY\all_py.py

    
# MASTER CODE SLOWLY BUILD 
# time print
time_hr = dt.datetime.now().hour;time_min = dt.datetime.now().minute;time_sec = dt.datetime.now().second
time_print = f'{time_hr}:{time_min} - {day_name} | {written_date}'

    
formats = ['.py']
#------------------------------------------------- 1 list all the files with above formats
list_f=[]
# Get names of file
for file in os.listdir(path_programs):  
    if file.endswith('.py'):  
        file = f'{file}' 
        list_f.append(file)

number_of_elements = len(list_f)       # n of elements
list_g = [Fore.GREEN +Style.BRIGHT+ f' >>>  \t'+ Style.RESET_ALL + li for li in list_f] # add a character
        
# #depending on how many do a random ids as string values
id_str = [str(x) for x in list(range(0,number_of_elements))]
# # joins two string lists
prog_ids = [f'{i}' +j for i, j in zip(id_str,list_g)]

# PRINT PROGRAMS
for i in list(range(0,number_of_elements)):
    print('\t ',prog_ids[i], '- ' + Fore.GREEN +Style.BRIGHT+ f'{i}'+ Style.RESET_ALL)
    f_lcyan_print('          --------------------------------------------------------------------------------|||')


try:
    f_lcyan_print(f"\n  < # >  to OPEN Program >>              * # *             {time_print} \n") # 3
    f_green_print('   .^.       ')
    id_to_open = int(input('                                           '))
    if id_to_open < number_of_elements:
        program_selection = list_f[id_to_open]
        print(f'\n Opening ::: {list_f[id_to_open]} \n')
        exec(open(f"{path_programs}/{program_selection}",encoding="utf-8").read())
    
except ValueError:
    f_blue_print("\n           \t                                           ERROR ... try again ")
# Out:
# Overwriting C:\Users\yerik\OneDrive\_Source\PY\all_py.py

# %% [markdown]
# # --------------------------->> all_libs_py

# %%
# %%writefile C:\Users\yerik\OneDrive\_Source\PY\all_libs_py.py
    
# MASTER CODE SLOWLY BUILD 
# time print
time_hr = dt.datetime.now().hour;time_min = dt.datetime.now().minute;time_sec = dt.datetime.now().second
time_print = f'{time_hr}:{time_min} - {day_name} | {written_date}'

    
formats = ['.py']
#------------------------------------------------- 1 list all the files with above formats
list_f=[]
path_programs='C:/Users/yerik/OneDrive/_Source/all_libraries'
# Get names of file
for file in os.listdir(path_programs):  
    if file.endswith('.py'):  
        file = f'{file}' 
        list_f.append(file)

mylist = list_f
myorder = [2, 4, 3, 1, 5,0]
list_f = [mylist[i] for i in myorder] 

number_of_elements = len(list_f)       # n of elements

list_g = [Fore.GREEN +Style.BRIGHT+ f' >>>  \t'+ Style.RESET_ALL + li for li in list_f] # add a character
        
# #depending on how many do a random ids as string values
id_str = [str(x) for x in list(range(0,number_of_elements))]
# # joins two string lists
prog_ids = [f'{i}' +j for i, j in zip(id_str,list_g)]

# PRINT PROGRAMS
for i in list(range(0,number_of_elements)):
    print('\t ',prog_ids[i], '- ' + Fore.GREEN +Style.BRIGHT+ f'{i}'+ Style.RESET_ALL)
    f_red_print('          --------------------------------------------------------------------------------|||')


try:
    f_lcyan_print(f"\n  < # >  to OPEN Program >>              * # *             {time_print} \n") # 3
    f_green_print('   .^.       ')
    id_to_open = int(input('                                           '))
    if id_to_open < number_of_elements:
        program_selection = list_f[id_to_open]
        print(f'\n Opening ::: {list_f[id_to_open]} \n')
        exec(open(f"{path_programs}/{program_selection}",encoding="utf-8").read())
    
except ValueError:
    f_blue_print("\n           \t                                           ERROR ... try again ")
# Out:
# Writing C:\Users\yerik\OneDrive\_Source\PY\all_libs_py.py

# %% [markdown]
# ## ----------------------------------------- > PD SYS UPDATES

# %%
# %%writefile C:\Users\yerik\OneDrive\_Source\pd_sys_updates.py
# %load C:\Users\yerik\OneDrive\_Source\sys_updates.py

# %load C:\Users\yerik\OneDrive\_Source\sys_updates.py

# %%writefile C:\Users\yerik\OneDrive\_Source\sys_updates.py
#

#-----I--------------------------------------------------------------------------------------------------------PACKAGES--->
import calendar;from datetime import date;import os;from datetime import date
from datetime import datetime
import pandas as pd
#............................................................................dates
today = date.today()
date = today.strftime("%d_%m_%Y");year = f"{date[6:10]}"; month_number = f"{date[3:5]}";day = f"{date[0:2]}"
month = calendar.month_name[int(month_number)]; written_date = f"{month} {day}, {year} "
day_name = calendar.day_name[today.weekday()] 

#..................................................................................................GLOBAL VAR ->
#........................................................................PATHS
#.....general dircetory paths, sheets ids
path_arch_source =     "C:/Users/yerik/OneDrive/_Source_Archive"
path_archive= path_arch_source
path_source =          "C:/Users/yerik/OneDrive/_Source"
path_desktop =         "C:/Users/yerik/OneDrive/Desktop"
path_content =         f'{path_source}/Content'
path_picturebank =     f'{path_content}/_PictureBank_'
path_fonts =           f'{path_content}/_Fonts'
#.....data paths
path_Gdrive_csv =     'G:/My Drive/CVS_to_DB'
path_arch_all_data =   f"{path_arch_source}/all_data"
path_all_data =        f"{path_source}/all_data"
path_databankexamples= f'{path_all_data}/_DataBankExamples_'
path_cl =              f'{path_all_data}/Checklists'
path_content_txt =     f'{path_all_data}/Content'
path_music_examples = f'{path_databankexamples}/music_midi_examples
#-----I---------------------------------------------------------------------------------Sheets-UPDATE-DATA SETS--->
#sheet Ids
sheet_id_contacts = '1rsYsrIodBScCOI0qBVeXRJuyk1F0FpnMCWvMYCx1HsI'
sheet_id_rec_info = '1gGlue2RLskUJ8wk8PdzC6m01k5lBxrLPt-6YpbV54h4'
sheet_id_inv_log = '1R-b1K09yDcpaeFriMo2KpX8PMlMwL6_kL-nXMjkjyVI'
sheet_id_fin_log = '1lSKpEOnVN0YJpqV0acbN9yshuhQDXnr-scmh77CYdF8'
sheet_id_daily = '1WZSgd9ywwkM8jLlw3oEf1e5EY_qnrzo_glGA5yOGXrs'

# READ sheet from google drive
con_info = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id_contacts}/export?format=csv")
rec_info = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id_rec_info}/export?format=csv")
inv_log = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id_inv_log}/export?format=csv")
fin_log = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id_fin_log}/export?format=csv")
daily = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id_daily}/export?format=csv")


#................. Write sheets to xlsx file to all data path
con_info.to_excel(f'{path_all_data}/3_ALL_CONTACT_INFO.xlsx',sheet_name='general',index= False)#Contact info
rec_info.to_excel(f'{path_all_data}/4_REC_CONTACT_INFO.xlsx',sheet_name='general',index= False)#Recruiters info
inv_log.to_excel(f'{path_all_data}/5_INV_LOG.xlsx',sheet_name='general',index= False)#Investment Logs
fin_log.to_excel(f'{path_all_data}/6_FIN_LOG.xlsx',sheet_name='general',index= False)#Finantial Logs
daily.to_excel(f'{path_cl}/1_DAILY_CL.xlsx',sheet_name='general',index= False)#Finantial Logs


#-----II-------------------------------------------------------------------------------------------Other updates--->


#-----III-------------------------------------------------------------------------------------------back ups--->

#-----IV---------------------------------------------------------------------------------------------------COMMUNICATIONS---->
print('*\n*\n*\n*')
print( '** <_Source/pd_sys_updates:> ! 5 G-Sheets are updated in all_data')
print('*')

#here do some system updates and BACK UP every week, do formula
# Out:
# Overwriting C:\Users\yerik\OneDrive\_Source\pd_sys_updates.py

# %%
#end
