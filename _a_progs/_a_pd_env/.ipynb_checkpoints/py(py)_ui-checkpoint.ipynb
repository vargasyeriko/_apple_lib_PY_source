# %% [markdown]
# # py.py

# %%
# %%writefile py.py
######################################################################################################### sys/pylib/pd_desc
print(           ':::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::')
print(           '::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::') 
print(           '::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::')
print(           '\n:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::|:::::::::::::::::'*50) 
rsp = 'd'
while rsp != 'b':
    print(       '\n:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::|:::::::::::::::::'*50)
    print(       "\n <py> <<< a|i|s | 0:ds  | 1:tm  |  2:ms  | 3:co  |  4:yy  |  5:bh  | Enter ::: pd >>>") 
    print(       '\n:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::|:::::::::::::::::'*23) 
    rsp =input(  "\n :::: <<< a|i|s | : 0 : | : 1 : |  : 2 : | : 3 : | : 4 :  |  : 5 : | START  AGAIN >>>  ")

    if rsp == "a":   
         exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/in.py",encoding="utf-8").read())
    if rsp == "i":   
         exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/in.py",encoding="utf-8").read())
    
    
    if rsp == '2':   
        exec(open(f"C:/Users/yerik/OneDrive/_Source/py2ms/ms.py",encoding="utf-8").read())
    if rsp == '4':   
        exec(open(f"C:/Users/yerik/OneDrive/_Source/py4yy/yy.py",encoding="utf-8").read())
   
    # if rsp_p == "r":   
    #     exec(open(f"{path_main}/pd_rank_music_midi.py",encoding="utf-8").read())
    # if rsp_p == "t":   
    #     exec(open(f"{path_main}/pd_tasks.py",encoding="utf-8").read())
    # #if rsp_p == "a": inpy
    #     exec(open(f"{path_main}/pd_tasks.py",encoding="utf-8").read())
    # #if rsp_p == "a":


    #rsp= 'a'   
    #exec(open(f"C:/Users/yerik/OneDrive/_Source/pd_sys_updates.py",encoding="utf-8").read()) #system updates Gsheets
    exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/pd.py",encoding="utf-8").read()) #packages, variables, ds, functions
    rsp = 'd'
# Out:
# Overwriting py.py

# %% [markdown]
# # Arithmetic Operators
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
