# %% [markdown]
# # PY - PY - PY - PY -PY - PY - PY - PY -PY - PY - PY - PY -PY - PY - PY - PY

# %% [markdown]
# ## _SOURCE /// PY /// -------------------------------------------------------------------------- PYLIB

# %%
# %%writefile C:\Users\yerik\OneDrive\_Source\PY\pylib.py
#---------------------------------------------------------------------------------------------PYLIB
# %%writefile C:\Users\yerik\OneDrive\_Source\PY\pylib.py
# %load C:\Users\yerik\OneDrive\_Source\PY\pylib.py

#-----I-------------------------------------------------------------------------------------------------F-and-PACKAGES--->

exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/f_and_packages.py",encoding="utf-8").read())

#-----II----------------------------------------------------------------------------------------PATHS-GLOBAL-VARIABLES--->

#...............................................................................VARIABLES ::: dates
today = date.today();date = today.strftime("%d_%m_%Y")
year = f"{date[6:10]}"; month_number=f"{date[3:5]}"; month=calendar.month_name[int(month_number)]; day=f"{date[0:2]}"
written_date = f"{month} {day}, {year} ";day_name=calendar.day_name[today.weekday()] 
time_hr = dt.datetime.now().hour
time_min = dt.datetime.now().minute
time_sec = dt.datetime.now().second

#................................................................................PATHS ::: MAIN DRIVES
path_one =             'C:/Users/yerik/OneDrive'            # ONE DRIVE
path_icloud =          'C:/Users/yerik/iCloudDrive'         # ICLOUD storage  
path_google =          'G:/My Drive'                        # GOOGLE drive
#................................................................................PATHS ::: deffaults
path_arch_source =      f'{path_one}/_Source_Archive'
path_archive=              path_arch_source
path_source =           f'{path_one}/_Source'
path_desktop =          f'{path_one}/Desktop'
path_main =             f'{path_source}/PY/MAIN'
#................................................................................PATHS ::: content 
path_content =         f'{path_source}/Content'
path_picturebank =     f'{path_content}/_PictureBank_'
path_fonts =           f'{path_content}/_Fonts'
#................................................................................PATHS ::: data
path_all_data =        f"{path_source}/all_data"
path_inbox =           f'{path_all_data}/Inbox'
path_databankexamples= f'{path_all_data}/_DataBankExamples_'
path_cl =              f'{path_all_data}/Checklists'
path_content_txt =     f'{path_all_data}/Content'
path_arch_all_data =   f"{path_arch_source}/all_data_archive"
path_kimva_py =        f'{path_icloud}/1_DB/all_shared/KimVa/PY' 
path_Gdrive_csv =      f'{path_google}/CVS_to_DB'
path_midi_examples =   f'{path_databankexamples}/music_midi_examples'  # MUSIC
path_store_midi =      f'{path_one}/Music_back_up/MIDI'
#-----III---------------------------------------------------------------------------------Sheets-UPDATE-DATA SETS--->

#exec(open(f"C:/Users/yerik/OneDrive/_Source/PY/sys_updates.py",encoding="utf-8").read())#

#-----IV-------------------------------------------------------------------------------------------READ-DATA SETS--->
# 0 _DataBankExamples_
ds_raw_diab = pd.read_csv(f'{path_databankexamples}/diabetes.csv')

with open(f'{path_databankexamples}/perceptron.txt') as f:
    book_perceptron = f.read() 

# 1
df_exp_descriptions = pd.read_excel(open(f'{path_source}/all_data/DS_jobs.xlsx', 'rb'),sheet_name='Job_Descriptions')
# 2
df_experience_info= pd.read_excel(open(f'{path_source}/all_data/DS_jobs.xlsx', 'rb'),sheet_name='Job_General') 
# 3
df_python = pd.read_excel(open(f'{path_source}/all_data/DS_jobs.xlsx', 'rb'),sheet_name='Python')
# 4
df_education = pd.read_excel(open(f'{path_source}/all_data/DS_jobs.xlsx', 'rb'),sheet_name='Education_Cert')
# 5
with open(f'{path_source}/all_data/py_functions.txt') as f:
    py = f.read()      
# 6 
df_fin_log = pd.read_excel(open(f'{path_all_data}/6_FIN_LOG.xlsx','rb'),sheet_name='general')
# 7
df_inv_log = pd.read_excel(open(f'{path_all_data}/5_INV_LOG.xlsx','rb'),sheet_name='general')
# 8
df_rec_info = pd.read_excel(open(f'{path_all_data}/4_REC_CONTACT_INFO.xlsx','rb'),sheet_name='general')
# 9 
df_con_info = pd.read_excel(open(f'{path_all_data}/3_ALL_CONTACT_INFO.xlsx','rb'),sheet_name='general')
# 10
df_accounts = pd.read_excel(open(f'{path_source}/all_data/2_Plannification.xlsx','rb'),sheet_name='ACCOUNTS')
# 11
df_cl_job_applications = pd.read_excel(open(f'{path_cl}/Checklists_job_app.xlsx','rb'),sheet_name='job_app')
# 12
df_w = pd.read_excel(open(f'{path_all_data}/1_CALENDARS_2022-2023.xlsx','rb'),sheet_name='W',skiprows = range(1,61),usecols="R:AF")
# 13
quotes_cai_vy = pd.read_excel(open(f'{path_content_txt}/CAI_VY_quotes.xlsx','rb'),sheet_name='quotes')
# 14
df_cl_music = pd.read_excel(open(f'{path_cl}/CheckLists_Music.xlsx','rb'),sheet_name='general')
# 15
df_cl_daily = pd.read_excel(open(f'{path_cl}/1_DAILY_CL.xlsx','rb'),sheet_name='general')
# 16
df_cl_content = pd.read_excel(open(f'{path_cl}/2_CONTENT_CL.xlsx','rb'),sheet_name='general')
# 17
df_cl_w = pd.read_excel(open(f'{path_cl}/3_W_CL.xlsx','rb'),sheet_name='general')
# 18
df_cl_w_resp = pd.read_excel(open(f'{path_cl}/3_W_CL_responses.xlsx','rb'),sheet_name='general')
# 19
df_kimva_tasks = pd.read_excel(open(f'{path_kimva_py}/tasks.xlsx','rb'))

#-----II------------------------------------------------------------------------------------------------SEMI-GLOBAL-VARIABLES--->
#.........................................................................API KEYS
#................................................CAI qcai twitter 
cai_acess_secret_token = df_accounts.iloc[10,10]
cai_access_token = df_accounts.iloc[10,11]
cai_bearer_token = df_accounts.iloc[10,12]
cai_api_key = df_accounts.iloc[10,13]
cai_api_secret_key = df_accounts.iloc[10,14]

hashtags_ai = '''#tensorflow #github #hackathon #dataanalytics #neuralnetworks #bigdata 
#artificialintelligence #deeplearning #dataanalysis #machinelearning'''
#-----IV---------------------------------------------------------------------------------------------------COMMUNICATIONS---->

print('** <pylib:> ! Standard Packages, Vars, dfs and fnctions ! help:print(py) ', written_date)
# Out:
# Overwriting C:\Users\yerik\OneDrive\_Source\PY\pylib.py

# %% [markdown]
# ## _SOURCE /// PY ///  ---------------------------------------------------------------------- f_and_PACKAGES

# %%
# %%writefile C:\Users\yerik\OneDrive\_Source\PY\f_and_packages.py
# %load C:\Users\yerik\OneDrive\_Source\PY\packages.py
# %load C:\Users\yerik\OneDrive\_Source\PY\packages.py
#
# -------------------------------------------------------------------------------------------- PACKAGES
#%%writefile C:\Users\yerik\OneDrive\_Source\PY\packages.py
#
# comment all by ctr + / -> THIS ONE ISI THE EDITABLE FOR ALL FUTURE ITERATIONS - > will be modify in a diff folder after dulpicated
#-----I---------------------------------------PACKAGES-------------------------------------------------------------------->
#
#...................................................................................................SYSTEM 
import os;import sys;from sys import stdout;from distutils.dir_util import copy_tree;import shutil  #copy files etc
from colorama import init, Fore, Back, Style
init(convert=True) #colors
import json
#......................................................................................DATA MANIPULATION
import docx;from docx import Document;import pandas as pd;from docx2pdf import convert
import numpy as np;from scipy import io;import webbrowser;import random;
#.......................................................................................TIMES
from time import gmtime, strftime
#.......................................................................................DATES
import calendar;from datetime import date, datetime, timedelta
import datetime as dt

print('** <f_and_packages:> ! installed data and dates modules ')
#.............................................................................................VIZUALIZATION
# import matplotlib.pyplot as plt
# print('** <PY/f_and_packages:> ! installed VISUALS modules')
#.......................................................................................IMAGES_processing
# from PIL import Image;from PIL import ImageDraw;from PIL import ImageFont;import cv2
# #......................................................................................text in images 
# import textwrap
#.......................................................................................MACHINE LEARNING  ..... above all STANDARD
#from sklearn import preprocessing;from sklearn.cluster import KMeans

#.......................................................................................DEEP LEARNING
#training 
# from sklearn.model_selection import train_test_split;import tensorflow as tf
# from numpy import loadtxt;from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense;from keras.models import Sequential
# import keras;print('*** installed dl and ml modules \n')

#................................................................................................NLP
# from nltk.tokenize import sent_tokenize, word_tokenize
# from nltk.stem import WordNetLemmatizer;import nltk;import gensim
# nltk.download('punkt');nltk.download("stopwords");nltk.download('tagsets')
# nltk.download('averaged_perceptron_tagger');nltk.download('wordnet')
# from nltk.corpus import stopwords;from nltk.tokenize import word_tokenize
# from nltk.stem import PorterStemmer;from nltk.tokenize import word_tokenize
# #import ghostscript
# print('*** installed NLP modules \n')

#..........................................................................................SOFTWARE REQUIREMENTS
# from platform import python_version
# # print('tensorflow version:', tf.__version__,'\n')
# # print('Keras version:', keras.__version__,'\n')
# print('python version:', python_version(),'\n')


#sort packages websites
#from selenium import webdriver #print(driver.title)
#from selenium.webdriver.common.keys import Keys
#from selenium.webdriver.common.by import By


#................................................................................................... FUNCTIONS

#------------------------------------------------------------------------------------------- FUNCTIONS - all function start with f_
## %%writefile C:\Users\yerik\OneDrive\_Source\PY\functions.py
#

# ---------------------------------------------------------Data Manipulations   
def f_date_format(df,column):
    df[f"{column}"] = pd.to_datetime(df["date"]).dt.strftime('%d_%m_%Y')

# COLORS
from colorama import init, Fore, Back, Style;init(convert=True) #colors
# RED

def f_lred_print(var):
    print(Fore.LIGHTRED_EX + Style.BRIGHT + var+ Style.RESET_ALL)
def f_red_print(var):
    print(Fore.RED + var+ Style.RESET_ALL)
def f_mag_print(var):
    print(Fore.MAGENTA  + var+ Style.RESET_ALL)
def f_lmag_print(var):
    print(Fore.LIGHTMAGENTA_EX + Style.BRIGHT + var+ Style.RESET_ALL)    
    
    
# GREEN

def f_green_print(var):
    print(Fore.GREEN +  var+ Style.RESET_ALL)    
def f_lgreen_print(var):
    print(Fore.LIGHTGREEN_EX+ Style.BRIGHT + var+ Style.RESET_ALL)
    
# YELLOW
    
def f_yellow_print(var):
    print(Fore.YELLOW  + var+ Style.RESET_ALL)    
def f_lyellow_print(var):
    print(Fore.LIGHTYELLOW_EX + Style.BRIGHT + var+ Style.RESET_ALL)
    
# BLUE 

def f_blue_print(var):
    print(Fore.BLUE + var+ Style.RESET_ALL)
def f_lblue_print(var):
    print(Fore.LIGHTBLUE_EX + Style.BRIGHT + var+ Style.RESET_ALL)
def f_cyan_print(var):
    print(Fore.CYAN  + var+ Style.RESET_ALL)
def f_lcyan_print(var):
    print(Fore.LIGHTCYAN_EX + Style.BRIGHT + var+ Style.RESET_ALL)  


    
    #ADD a section for packages 
    
    # !pip install ... (so we have all in case of migration )
#................................................................................................... FUNCTIONS
# sys.path.append("C:/Users/yerik/OneDrive/_Source/PY/")
def pattern(size):

# right triangle star pattern
    for i in range(size):
        for j in range(1, size - i):
            print(" ", end="")
        for k in range(0, i + 1):
            print("*", end="")
        print()
        
def pattern_start(size):

# right triangle star pattern
    for i in range(size):
        for j in range(1, size - i):
            print(" ", end="")
        for k in range(0, i + 1):
            print("*", end="")
        print()



print('*')
# Out:
# Overwriting C:\Users\yerik\OneDrive\_Source\PY\f_and_packages.py

# %% [markdown]
# ## _SOURCE /// PY ///  ----------------------------------------------------------------------jup_fun

# %%
# %%writefile C:\Users\yerik\OneDrive\_Source\PY\jup_fun.py

    # DF_1
def jup_df_add_col(df , col_name,value_or_string):
    '''DF ADDS ONE COLUMN TO DF # loop '''
    
    k='j'
    while k != 'b':
        answ = input('Do you want to add another COLUMN')
        if answ == 'y':
            col_name = input("ADD Variables? what is the name: var_add ... ")
            value_or_string= input("VALUE of var_add ... ")  
            df[f'{col_name}'] = value_or_string  
        k = input('Close loop? b to break')
     
    

 # DF_2

def jup_df_generator_add_cols(var_1,var_2):
    '''DF generator and ADDS ONE COLUMN TO DF and writes it automatically to inbox'''
    #x=list(range(row_number))
    #y=list(range(row_number))

    checklist_ = {f'{var_1}': ['0','0'],f'{var_2}':['0','0']}
    dp = pd.DataFrame(data=checklist_)           
    
    k='o'
    while k != 'b':
        answ = input('Do you want to add another COLUMN')
        if answ == 'y':
            col_name = input("ADD Variables? what is the name: var_add ... ")
            value_or_string= input("VALUE of var_add ... ")  
            dp[f'{col_name}'] = value_or_string  
        k = input('Close loop? b to break')
    f_df_write_xlsx(dp,f"new_data_frame_{date}")
    print(f'Data Set was created to all_data/inbox/new_data_frame_{date}.xlsx')
    return dp

 # DF_3 #write one more to read data right away
def jup_df_write_xlsx(df,name): 
    '''Writes df to all_data/inbox to a sheet called: general'''
    
    df.to_excel(f'{path_inbox}/{name}.xlsx',sheet_name = 'general',index= False)
    print(f'\n\n Data Set was created to all_data/inbox/{name}.xlsx')
   
    # DF_4
def jup_date_format(df,column):
    df[f"{column}"] = pd.to_datetime(df["date"]).dt.strftime('%d_%m_%Y')
    
 
    # DF_5
def jup_list_py(path):
    '''Returns list of PY files'''
    list_f_main_pd_py = []
    print(f'\nattn:: The following are the ALL_PY files in {path} ::: \n')
    for file in os.listdir(path):  
        if file.endswith('.py'):
            list_f_main_pd_py.append(file)
            print(file)

def iii_df():
    ''' Data Frame iii for INFO '''
    print(f"\ndf = pd.DataFrame(data=yml_name)             # <---:::> YML 2 pd.DATA.FRAME <:::---> # print(df",
        f"\n\nl_dfvar_names = list(df)                     # <---:::> DF COLUMN NAMES     <:::---> # print(l_dfvar_names",
        f"\n\ndf['var'].replace('_','c',regex=True)        # <---:::> DF STR replace CHAR <:::---> # ",
        f"\n\ndf.to_excel(f'path_inbox.xlsx,index= False)  # <---:::> DF STR replace CHAR <:::---> # ",
        f"\n\npd.read_excel(open(f'path_inbox .xlsx', 'rb')# <---:::> DF STR replace CHAR <:::---> # ")
         
    

    
#COMMUNICATIONS            
print('\n*\n** <JUP_fun:> For function start by <jup> + Tab')
# Out:
# Overwriting C:\Users\yerik\OneDrive\_Source\PY\jup_fun.py

# %%
#end
