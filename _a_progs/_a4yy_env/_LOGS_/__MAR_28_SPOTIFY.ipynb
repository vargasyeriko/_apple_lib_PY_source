# %% [markdown]
# ## Spotify
# The Personalization (PZN) team makes deciding what to play next on Spotify easier and more enjoyable for every listener. We seek to understand the world of music, podcasts and audiobooks better than anyone else so that we can make great recommendations to every individual and keep the world listening. Every day, hundreds of millions of people all over the world use the products we build which include destinations like Home and Search as well as original playlists such as Made For You, Discover Weekly and Daily Mix.

# %% [markdown]
# # RESPONSE SPOTIFY

# %% [markdown]
# I always wondered amongst those who like art and science. From many points I know I am the right candidate for this
# position. I am extremely grateful to find something that fits all the dimensions of my work for the last 10 years.
# Furthermore I am so happy, that for once I get to talk about my work without making it fit to the position, finally
# I get to chat about my work as a DJ, Music Curator, Data Scientist and Python ML consultant.
#
# I live in Detroit, and for the last 4 years I have been doing the work of my life. In Detroit , the poeple here
# knows me as a dj but also as a coder, where I have helped dozens of people implementing apps for DJs. You can see the list
# of apps in my portfolio, but mainly I wanted to chat about the biggest one I have built. I wanted to have a better way
# to organize music so I build an app that takes
