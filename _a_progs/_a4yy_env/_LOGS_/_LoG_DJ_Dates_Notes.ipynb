# %%
### 2026  #### SUBJECT : new dj name DOGX313

# %% [markdown]
# ## GET DATE - ARCH LOGS

# %%
from datetime import datetime

print(datetime.now().strftime("📅 %A, %B %d, %Y  |  ⏰ %I:%M:%S %p"))
# Out:
# 📅 Saturday, March 14, 2026  |  ⏰ 02:29:49 PM

# %% [markdown]
# # NEXT ->

# %%
# NEXT -> CANNONS prepare

# %% [markdown]
# # SPKR

# %%
# Steven owes me ? - yes 100 
# Alex and Sherif

## TYLR ; give his rock from mexico 

## 2026 #### SUBJECT : SPKR dates  

# Spkr

# Feb 23 ( Ashton + Arlee)
# March 16
# April 13
# Movement 18 25
# June 8 29 

# be close to metroplex ppl and also britty and duck

# %%
# BRANDING

# %% [markdown]
# # YOGA

# %%
# hit up ppl from citizen here and there

# %% [markdown]
# # YEARLY EVENTS

# %% [markdown]
# Nain Rouge (Sun, Mar 23) –
# Movement (Thu, May 22 - Sat, May 24) – Memorial Weekend

# %% [markdown]
# # festivals and future

# %% [markdown]
# Envision
#
# Nayarit
#
#
# Global calendar
#
# Feb : black history month
# March : rouge
# MARCH (WOMANS MONTH )
#
# Movement
#
# Pride
#
# Alley in the Alley
#
# Mexico
# Art week
#
# * send set to ELORIAN CDMX

# %% [markdown]
# # produciton

# %% [markdown]
# Make sound as if there were tronidos sparkles all over for a build up
