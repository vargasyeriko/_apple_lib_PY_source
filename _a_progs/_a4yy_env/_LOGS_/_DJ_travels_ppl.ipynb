# %% [markdown]
# # MExico

# %% [markdown]
# ![image.png](attachment:19b13ebb-8c94-4d95-a211-490bf1f61498.png)

# %% [markdown]
# ![image.png](attachment:3a46e3a5-16db-4451-85c8-5e503db1403e.png)

# %% [markdown]
# ![image.png](attachment:cb162cc3-cb3f-4669-b391-2f007f15a978.png)

# %% [markdown]
# # MEXICO 2026

# %% [markdown]
# # NYC

# %% [markdown]
# ![image.png](attachment:ef7dfbbb-b20f-4452-a080-21bd3ce7c202.png)

# %% [markdown]
# ![image.png](attachment:c803d8d6-3b61-4d13-ba90-2674c4a0ec09.png)

# %% [markdown]
# ![image.png](attachment:7b7a748c-6c56-4227-aaee-0eb102cd5f30.png)

# %% [markdown]
# ![image.png](attachment:d5236dc9-4b61-4940-8963-f7f19c995055.png)

# %% [markdown]
# # DENVER

# %% [markdown]
# ![image.png](attachment:6e501124-afb0-4307-b099-4631774039a5.png)
