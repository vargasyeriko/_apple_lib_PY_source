# %% [markdown]
# # JOB right now can hit up people in the scene

# %%
# Eastern Market in genreal 
# akash 
# Nelson
# b

# %% [markdown]
# # SOOJIN - DOCUMENT ! DOCUMENT ! DOCUMENT !

# %%
# send deductions - simple just stating the info she needs 
# Glass kitchen 
# LEase plan 
# FIx car 
# insuracne tax doc 2025 
########### Strategic move very important about her coming so many times 
# and leaving stuff in here

# %% [markdown]
# # This week

# %%
######## Francisco money MX transfer ASAP 
######## PAy DTE ASAP

# %% [markdown]
# # SPKRBOX

# %%
# post Musica 2026 DJS
# upcoming April 13

# %% [markdown]
# # important dates 2026

# %%
# APR 3 -> Open day 4 hr dj set
# APR 13 -> Musica on monday 

# MAY -> MVMNT SPKRbox booking 
# MAy -> SPKRBOX PIXCIE + woman line up 
# 


#SEPTEMBR Weeding Andrew September
