# %% [markdown]
# # JOB right now can hit up people in the scene -ideas

# %%
# Eastern Market in genreal 
# akash 
# Nelson
#

# %%
#

# %% [markdown]
# # SOOJIN

# %%
# Tax finish them !
# bother her quite often - what do you want in life

# %% [markdown]
# # This week

# %%
######## Francisco money MX transfer ASAP -> let him know when its moved 
######## PAy DTE ASAP

# %% [markdown]
# # SPKRBOX

# %%
# post Musica 2026 DJS
# upcoming April 13

# %% [markdown]
# # important dates 2026

# %%
# ART night Duck b2b MAr 25 
# APR 3 -> Open day 4 hr dj set
# APR 13 -> Musica on monday 

# MAY -> MVMNT SPKRbox booking 
# MAy -> SPKRBOX PIXCIE + woman line up (Think about it )
# 


#SEPTEMBR Weeding Andrew September

# %% [markdown]
# # Thought of the day

# %%
# Life is Short ! DO not focus in whats not & Focus on what is ! -> Be the Judge
