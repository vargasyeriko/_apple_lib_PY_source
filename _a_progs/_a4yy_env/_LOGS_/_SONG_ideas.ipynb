# %% [markdown]
# # SONG IDEAS

# %% [markdown]
# ![image.png](attachment:9ba65ccf-150a-403d-ba12-ca989eca2478.png)

# %% [markdown]
# ![image.png](attachment:92e04fe8-a932-4994-b392-c715c62e6b67.png)

# %% [markdown]
# ![image.png](attachment:6f173af7-e92f-4c72-ac18-a6d33f18d652.png)

# %% [markdown]
# ![image.png](attachment:22d5fa62-a56d-4943-bb48-aa991edefdf4.png)

# %% [markdown]
# ![image.png](attachment:2d71cb74-28f3-4dfe-815c-59eedb101efb.png)

# %% [markdown]
# ![image.png](attachment:b79a52cc-d811-407e-a819-1a792b2264ed.png)

# %% [markdown]
# ![image.png](attachment:dec941ea-5197-48be-ac1b-b3f9fb62c8df.png)

# %% [markdown]
# ![image.png](attachment:6f96f33a-fe2f-4335-b5a3-b9ba16c5f45a.png)

# %% [markdown]
# ![image.png](attachment:cbccd8a8-cc0a-418a-9d33-4eddc9d2eff9.png)

# %% [markdown]
# ![image.png](attachment:0e6bc341-d601-4fb1-8ca1-62eb76cd15d7.png)

# %% [markdown]
# # ARTIST INSPO

# %% [markdown]
# Beach boys

# %% [markdown]
# _

# %% [markdown]
# _

# %% [markdown]
# _

# %% [markdown]
# _

# %% [markdown]
# _

# %% [markdown]
# _

# %% [markdown]
# _
