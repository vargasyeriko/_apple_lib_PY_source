# %%
# y-finance 
# download data -> (20  min) 
# clumns -> data frame 


# time     , volume , open_price , close_price , 
# 12/122024  23,444   12.4         15.7           


# df -> frequency tables with share partitions -> 
# normal or unusual -> anomaly detection 
# Feauture engeenering -> 
# + more questions or ideas to tell you stock info


# a python app that will be ran and output avobe .
# graphs, patterns, anomaly detection and updated prices 

# cluster analysis 

# it makes clusters (healthy) (unhealthy) based on over 100 of attributes 
# Random Forest . shape forest to find the anomaly 

# Normality -> N(0,1) 

# There is only 2 types of data (labeled , and unlabeled) 
# supervised = labeled 
# unsupervised = unlabeled -> cluster  

# good vs bad stock (if you takle the name of the stock out then we have  unsupervised = unlabeled -> cluster  

# data with 80 attributes (sector, subsector , prices .. dividends)
# cluster , you can take each group , each cluster (and find the average return )


# "PCA (dimensionality reduction ) + clustering " -> what do they do together ?
