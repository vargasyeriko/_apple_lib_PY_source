# %%
# denver expenses

# %% [markdown]
# # TAXES 2025 - DEDUCTIONS

# %% [markdown]
# # pic receipts for important ITEMS
#
# # Jan - mac book
# ![image.png](attachment:184028ce-2d50-4546-82a8-f7c8e98ac998.png)
#
# # Mar - Sweetwater - pioneer mixer XDJ RR
# ![image.png](attachment:0f2c1720-37d1-4273-8b31-117597c1ae63.png)
#
# # Jan APPLE CARE - M3 mac book
# ![image.png](attachment:780d054c-ce07-4a18-a392-d7db393a6954.png)
#
# # April - cables etc
# ![image.png](attachment:52ee24b9-cf9a-47f6-8e96-3b550d89089b.png)
#
# # July - Go Pro
# ![image.png](attachment:7b4a9d81-25b8-42fc-b9d3-4bb261a24d30.png)
#
# # Nov -  Hostel Denver + flights + dj trip  ( did not get paid from this only promotion oportunities )
# ![image.png](attachment:6f417c44-c7fb-4f75-ab78-f85ad3271378.png)
# ![image.png](attachment:032ad0a2-95c8-4f55-b180-951d4bed6f0d.png)
# ![image.png](attachment:d36fb705-6d58-41c8-b877-de16b2ee1087.png)
#
# # everything else I can prove I have email receipts if needed

# %%
import pandas as pd

df_deductions_bestbuy = pd.DataFrame([
    {
        "date": "2025-01-09",
        "vendor": "Best Buy",
        "amount": 1385.41,
        "category": "Equipment",
        "description": "MacBook Pro for DJ/business use"
    },
    {
        "date": "2025-04-28",
        "vendor": "Best Buy",
        "amount": 100.68,
        "category": "Supplies",
        "description": "GoPro accessories (media mod, cables)"
    },
    {
            "date": "2025-01-09",
            "vendor": "Apple",
            "amount": 279.00,
            "category": "Equipment",
            "description": "AppleCare for MacBook Pro (business equipment protection)"
        },
    {
        "date": "2025-04-28",
        "vendor": "Best Buy",
        "amount": 331.78,
        "category": "Equipment",
        "description": "GoPro Hero12 camera + protection plan for DJ/content use"
    },
    {
        "date": "2025-07-11",
        "vendor": "SoundCloud (cant find receipt)",
        "amount": 144.00,
        "category": "Software",
        "description": "SoundCloud Next Pro annual subscription for music distribution and promotion"
    },
    {
            "date": "2025-04-23",
            "vendor": "Restream",
            "amount": 19.00,
            "category": "Software",
            "description": "Restream subscription for DJ streaming"
        },
    {
            "date": "2025-06-23",
            "vendor": "Restream",
            "amount": 19.00,
            "category": "Software",
            "description": "Restream subscription for DJ streaming"
        },
    {
            "date": "2025-07-23",
            "vendor": "Restream",
            "amount": 19.00,
            "category": "Software",
            "description": "Restream subscription for DJ streaming"
        },
    {
            "date": "2025-09-05",
            "vendor": "Micro Center",
            "amount": 88.99,
            "category": "Supplies",
            "description": "Cables and USB accessories for DJ setup"
        },
    {
            "date": "2025-09-22",
            "vendor": "Kevin M Reynolds",
            "amount": 1500.00,
            "category": "Equipment",
            "description": "DJ mixer (PLAYdifferently Model 1) purchase"
        },
    {
            "date": "2025-11-01",
            "vendor": "11th Avenue Hostel",
            "amount": 220.38,
            "category": "Travel",
            "description": "Hotel stay for DJ event in Denver"
        },
    {
            "date": "2025-11-01",
            "vendor": "Frontier",
            "amount": 86.98,
            "category": "Travel",
            "description": "Flight to Denver for DJ event"
        },
        {
            "date": "2025-11-03",
            "vendor": "Delta",
            "amount": 118.48,
            "category": "Travel",
            "description": "Return flight from Denver DJ event"
        },
    {
            "date": "2025-03-14",  # <- if you know it, replace it (or keep approx month)
            "vendor": "Sweetwater",
            "amount": 1111.94,
            "category": "Equipment",
            "description": "XDJ-RR all-in-one DJ system"
        },
    {
            "date": "2025-05-25",  # <- if you know it, replace it (or keep approx month)
            "vendor": "MicroCenter (physical receipt)",
            "amount": 61.43,
            "category": "Equipment",
            "description": "Cables"
        },
    {
            "date": "2025-03-14",  # <- if you know it, replace it (or keep approx month)
            "vendor": "GuitarCenter(physical receipt)",
            "amount": 401.71,
            "category": "Equipment",
            "description": "mixer + field recorder"
        }
    
])


df_deductions_bestbuy
# Out:
#           date                          vendor   amount   category  \
# 0   2025-01-09                        Best Buy  1385.41  Equipment
# 1   2025-04-28                        Best Buy   100.68   Supplies
# 2   2025-01-09                           Apple   279.00  Equipment
# 3   2025-04-28                        Best Buy   331.78  Equipment
# 4   2025-07-11  SoundCloud (cant find receipt)   144.00   Software
# 5   2025-04-23                        Restream    19.00   Software
# 6   2025-06-23                        Restream    19.00   Software
# 7   2025-07-23                        Restream    19.00   Software
# 8   2025-09-05                    Micro Center    88.99   Supplies
# 9   2025-09-22                Kevin M Reynolds  1500.00  Equipment
# 10  2025-11-01              11th Avenue Hostel   220.38     Travel
# 11  2025-11-01                        Frontier    86.98     Travel
# 12  2025-11-03                           Delta   118.48     Travel
# ...

# %%
len(df_deductions_bestbuy)
# Out:
# 16

# %% [markdown]
# # Republican AI

# %%
df_deductions_bestbuy = pd.concat([
    df_deductions_bestbuy,
    pd.DataFrame([
        {"date": "2025-07-30", "vendor": "Republiclabs", "amount": 25.00, "category": "Software", "description": "AI video generation subscription"},
        {"date": "2025-08-30", "vendor": "Republiclabs", "amount": 25.00, "category": "Software", "description": "AI video generation subscription"},
        {"date": "2025-09-30", "vendor": "Republiclabs", "amount": 25.00, "category": "Software", "description": "AI video generation subscription"},
        {"date": "2025-10-30", "vendor": "Republiclabs", "amount": 25.00, "category": "Software", "description": "AI video generation subscription"},
        {"date": "2025-11-30", "vendor": "Republiclabs", "amount": 25.00, "category": "Software", "description": "AI video generation subscription"},
        {"date": "2025-12-30", "vendor": "Republiclabs", "amount": 25.00, "category": "Software", "description": "AI video generation subscription"}
    ])
], ignore_index=True)

df_deductions_bestbuy = pd.concat([
    df_deductions_bestbuy,
    pd.DataFrame([
        {"date": "2025-08-05", "vendor": "Republiclabs", "amount": 10.00, "category": "Software", "description": "AI video generation extra credits"},
        {"date": "2025-10-29", "vendor": "Republiclabs", "amount": 10.00, "category": "Software", "description": "AI video generation extra credits"},
    ])
], ignore_index=True)

# %%
len(df_deductions_bestbuy)
# Out:
# 24

# %% [markdown]
# # CHAT GPT

# %%
df_deductions_bestbuy = pd.concat([
    df_deductions_bestbuy,
    pd.DataFrame([
        {"date": "2025-01-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-02-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-03-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-04-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-05-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-06-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-07-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-08-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-09-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-10-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-11-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"},
        {"date": "2025-12-01", "vendor": "ChatGPT", "amount": 20.00, "category": "Software", "description": "AI assistant for coding and DJ business"}
    ])
], ignore_index=True)

# %%
len(df_deductions_bestbuy)
# Out:
# 36

# %% [markdown]
# # PayPal Beatport + Bandcamp

# %%
df_deductions_bestbuy = pd.concat([
    df_deductions_bestbuy,
    pd.DataFrame([
        {"date": "2025-12-30", "vendor": "BANDCAMP", "amount": 348.81, "category": "Buying songs", "description": "Bandcamp PAGE shows all trans - Paypal"},
        {"date": "2025-12-30", "vendor": "BEATPORT", "amount": 3776.18, "category": "Buying songs", "description": "Beatport PAGE shows all trans - Paypal"},
      ])
], ignore_index=True)

# %% [markdown]
# # TOTAL deductions

# %%
bestbuy_total = df_deductions_bestbuy['amount'].sum()
print(f"Clear 2025 deductions (BestBuy only — excludes Ubers, DTE, rent, car expenses): ${bestbuy_total:,.2f}")
# Out:
# Clear 2025 deductions (BestBuy only — excludes Ubers, DTE, rent, car expenses): $10,422.77

# %%
df_deductions_bestbuy
# Out:
#           date                          vendor   amount      category  \
# 0   2025-01-09                        Best Buy  1385.41     Equipment
# 1   2025-04-28                        Best Buy   100.68      Supplies
# 2   2025-01-09                           Apple   279.00     Equipment
# 3   2025-04-28                        Best Buy   331.78     Equipment
# 4   2025-07-11  SoundCloud (cant find receipt)   144.00      Software
# 5   2025-04-23                        Restream    19.00      Software
# 6   2025-06-23                        Restream    19.00      Software
# 7   2025-07-23                        Restream    19.00      Software
# 8   2025-09-05                    Micro Center    88.99      Supplies
# 9   2025-09-22                Kevin M Reynolds  1500.00     Equipment
# 10  2025-11-01              11th Avenue Hostel   220.38        Travel
# 11  2025-11-01                        Frontier    86.98        Travel
# ...

# %% [markdown]
# # PAYING DJS deductions

# %%
# checking row by row sum

# %%
total = 200*4 + 200 + 100 + 100 + 1000 + 200 +400 +50 +225 + 1000 + 400 + 700 +400 +150 +200 +150 +200 + 600 +400 + 120 # last amount spkr check

# %%
total
# Out:
# 7395
