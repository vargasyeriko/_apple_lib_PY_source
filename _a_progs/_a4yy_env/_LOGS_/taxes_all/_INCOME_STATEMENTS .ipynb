# %% [markdown]
# # puma 2025

# %% [markdown]
# ![image.png](attachment:84440478-f93a-4c19-8b44-80ef011fa1e6.png)

# %%
# 32361 as taxable income 
total_income_puma = 32361 
total_income_puma
# Out:
# 32361

# %% [markdown]
# # Third ST 2025 -> they dont have my w9

# %%
# check 22 times 

total_income_3rd = 22*100
total_income_3rd
# Out:
# 2200
