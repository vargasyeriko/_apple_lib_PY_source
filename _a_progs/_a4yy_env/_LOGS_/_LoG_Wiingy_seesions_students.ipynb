# %%
# Student TJ

session_1 :
session_2 :

# next I have to design a pipeline to get stocks, prices etc, and app to get the data and save it then read it . 
# say next time we can make a function to add things to a ledger 

# Make FINANCE APP WORK !!! so you KEEP TJ longer
