# %%
import sys
print(sys.executable)
# shows what kernel am I working with
# Out:
# /Users/yerik/_apple_lib/_b_envs/_0ds_job_apply_worki/bin/python

# %%
#%%writefile RUN.py 
exec(open(f"/Users/yerik/_apple_source/PY/GLOBAL/_1_paths.py", encoding="utf-8").read())  # GLOBAL

import subprocess
import webbrowser
#...............................................................................VARIABLES ::: dates
from docx import Document
document = Document()



def welcome_job_app():
    options = ["Print > INFO STRATEGY for APPLYING \t  <input>:: <#> or \t1) < about - strategy - links >",
               "Print > MESG recruiters TEMPLATES \t  <input>:: <#> or \t2) < msgs >",
               "Print > [CV/RES_DS_entry_level] \t  <input>:: <#> or \t3) < cv/res >",
               "nan", #gonna be like version b of avobe or maybe other versions inside .... 
               "nan", # ds tutor here maybe
               "EDIT  > EDIT EDIT EDIT STRATEGY \t  <input>:: <#> or \t6) < edit >",
               "Copy  > COPY FIELDS - APPLY fast\t  <input>:: <#> or \t7) < gral & experience>",
              ]
    
    while True:
        print("\n*** JOB APPLICATION APP PACKAGE *** Please choose an option: by <#> or <code>\n*\n*\n*\n*\n*")
        for i, option in enumerate(options, start=1):
            print(f"{i}. {option}")

        user_input = input("*\nEnter your choice by <#> or <code> or <q/quit> ... \n")
            ############# ------------------------------------------ i ---
        if user_input.lower() == '1' or user_input.lower() == 'info':
            #
            # 1 --<<IMPOR_fns>>>
            exec(open(f"fns/_1ds_jobs_info_.py", encoding="utf-8").read()) 
            
            # 4 --<<EXPORTS>>
            #
            ############# ------------------------------------------ ii ---
        elif user_input.lower() == '2' or user_input.lower() == 'msgs':
            #
            # 1 --<<IMPOR_fns>>>
            from fns._2ds_job_msg_ import worki_msg_rec #
            #subprocess.run(["python", "fns/_2ds_job_msg_.py"])
            # 2 --<<TABLES>>
            #
            # 3 --<<RUN>>
            worki_msg_rec(date)
            # 4 --<<EXPORTS>>

            #############
            ############# ------------------------------------------ iii ---
        elif user_input.lower() == '3' or user_input.lower() == 'cv':
            #
            # 1 --<<IMPOR_fns>>>
            from fns._3ds_job_cv_ import ds_cv
            #subprocess.run(["python", "fns/_2ds_job_msg_.py"])
            # 2 --<<TABLES>>
            #
            # 3 --<<RUN>>
            doc_export = ds_cv()


        # elif user_input.lower() == '4' or user_input.lower() == 'res':
        #     #
        #     # 1 --<<IMPOR_fns>>>
        #     #subprocess.run(["python", "fns/_2ds_job_msg_.py"])
        #     # 2 --<<TABLES>>
        #     #
        #     # 3 --<<RUN>>
        #     exec(open(f"fns/_4ds_job_res_.py", encoding="utf-8").read())  # GLOBAL

            

     #   elif user_input.lower() == '5' or user_input.lower() == 'por':
            #
            # 1 --<<IMPOR_fns>>>
            #subprocess.run(["python", "fns/_2ds_job_msg_.py"])
            # 2 --<<TABLES>>
            
            # 3 --<<RUN>>
          
            

        elif user_input.lower() == '6' or user_input.lower() == 'edit':
            #
            # 1 --<<IMPOR_fns>>>
            from fns._6ds_edit_vars_ import edit_file
            #subprocess.run(["python", "fns/_2ds_job_msg_.py"])
            # 2 --<<TABLES>>
            #
            # 3 --<<RUN>>
            file_path = 'fns/_1ds_jobs_info_.py'

            edit_file(file_path) #    file_path = ... /PY/libs/_pyENVS/_Source/src_env0/_0ds_vars.py'
        ####################### COPY FIELDS Programs

        elif user_input.lower() == '7' or user_input.lower() == 'c_gral':
            #
            # 1 --<<IMPOR_fns>>>
            
            exec(open(f"fns/_7ds_COPY_GENERAL.py", encoding="utf-8").read())  







        
        
            # 4 --<<EXPORTS>>
#             direc_exp = '/Users/yerik/_apple_source/d_OUT/_0ds/apply_now/'
#             doc_export.save(f'{direc_exp}Yeriko Vargas - {date} {position} - Cover Letter.docx')#WORD
#             # EDIT then come back and 
#             input('Go modify and come back to (1) convert to pdf and (2) Archive')
            
#             # (1)2PDF
#             convert(f"{path_company_arch}/Yeriko Vargas - {date} {position} - Cover Letter.docx",
#                     f"{path_company_arch}/Yeriko Vargas - {date} {position} - Cover Letter.pdf" ) #pdf
#             # (2)zARCHIVE
#             direc_arch = '/Users/yerik/_apple_source/d_OUT/zARCHIVE/_0ds/apply_now/cvs/'
#             my_cv = docx.Document(f'{direc_exp}Yeriko Vargas - {date} {position} - Cover Letter.docx') # read modified
#             doc_export.save(f'{direc_arch}Yeriko Vargas - {date} {position} - Cover Letter.docx"')#WORD
            #############
            #enter to proceed
            
                  
                  
                  
            #############
            #############
            #############
            #############
            #############
            
            
        elif user_input.lower() == 'q':
            print("Quitting the application.")
            break
        else:
            print("Invalid input, try again.")

# Call the function
welcome_job_app()
# Out:
# ATTN - > TO start coding in this NOTEBOOK & following FNS :::  run ::: hi_jupy()
# ATTN at the end RUN > py and cleans py ready to be copied >  runpy()
# ATTN - > TO get all GLOBAL, libs and functions & ALL_DATA inputs, stats, temp, tables files info > db_paths()
# ATTN - > TO move files from input to curr_direc > move_files(input_folder_path, curr_direc)
# ATTN - > TO COPY program > copy_files_and_subdirectories(path_2_copy, dest_direc) --- respects original copied
# ATTN - > TO get all GAME PLANS TO EXPORT ALPHA and BETA programs  > game_plan()
# define program_folder_name before running runpy()
#
# *** JOB APPLICATION APP PACKAGE *** Please choose an option: by <#> or <code>
# *
# *
# *
# *
# *
# 1. Print > INFO STRATEGY for APPLYING 	  <input>:: <#> or 	1) < about - strategy - links >
# 2. Print > MESG recruiters TEMPLATES 	  <input>:: <#> or 	2) < msgs >
# 3. Print > [CV/RES_DS_entry_level] 	  <input>:: <#> or 	3) < cv/res >
# 4. nan
# 5. nan
# 6. EDIT  > EDIT EDIT EDIT STRATEGY 	  <input>:: <#> or 	6) < edit >
# 7. Copy  > COPY FIELDS - APPLY fast	  <input>:: <#> or 	7) < gral & experience>
# *
# Enter your choice by <#> or <code> or <q/quit> ...
#  1
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
#
# ************************************
# RN AFTER APPLYING TO 5 you would FEEL MORE RELAXED and maybe you can do the following ::
#
#
# Caí
# Website figure it out
#
#
# Make a small presentation caí ( list all in the iPad in a diagram) very simple start doing that
#
# Music prod/dj
# Figure out website
# Master a new song
# Prepare next video record this week.
#
#
# ***********************************
#
# STRATEGY THIS WEEK
#
# - Job Search ITERATION (min 5 daily)
#
# * FIND DS JOBS :
#
# 1. Search DS JOBS in MICHIGAN
#
# * CV - < read it
#
# * RESUME - < FORD first & do not erase just add more bullet points
#
# * I am WHITE -> NOT LATINO for bias.
#
# *(FOLLOW in SOCIAL / FIND HIRING MANAGERS / do custom messages to them )
#
# - Job Search IMPROVEMENT (Just one weekly)
#
#  * Desc program to add descriptions to EXCEL
#
#  * start organizing files (ref letters, Sample WORK more organized and clean )
#
#  * GITHUB
#
# **************************** TELL ME ABOUT YOURSELF ********************************
#
# I'm Yeriko Vargas, a seasoned Python Developer with a Master’s in Applied Statistics and extensive experience in machine learning and AI. Over the past 7 years, I've spearheaded impactful projects, from enhancing marketing strategies with ML models to developing AI solutions for automotive challenges. My expertise lies in transforming complex data into actionable insights and innovative solutions using Python. Passionate about driving progress through technology, I thrive on solving challenging problems and contributing to projects that leverage AI for the greater good. I'm excited about the possibility of bringing my blend of skills in Python programming, data science, and machine learning to this company, aiming to make a significant impact in the tech landscape.
#
#
# HERE WE WILL HAVE A VERY SIMPKY GUIDE FOR INTERVIEW REMINDERS
# Strategies Printed <E> to go to JOB SEARCH today ... web-browser will open >>>
# *** JOB APPLICATION APP PACKAGE *** Please choose an option: by <#> or <code>
# *
# *
# *
# *
# *
# 1. Print > INFO STRATEGY for APPLYING 	  <input>:: <#> or 	1) < about - strategy - links >
# 2. Print > MESG recruiters TEMPLATES 	  <input>:: <#> or 	2) < msgs >
# 3. Print > [CV/RES_DS_entry_level] 	  <input>:: <#> or 	3) < cv/res >
# 4. nan
# 5. nan
# 6. EDIT  > EDIT EDIT EDIT STRATEGY 	  <input>:: <#> or 	6) < edit >
# 7. Copy  > COPY FIELDS - APPLY fast	  <input>:: <#> or 	7) < gral & experience>
# *
# Enter your choice by <#> or <code> or <q/quit> ...
#  2
#
#  				  <<< RECRUITER name >>> ...   ggh
#
#  				  <<< JOB Position CODE ::: ds/ml/dl >>> ...   ds
#
#  				  <<< COMPANY name >>> ...   ttt
#  1)  Recruiter Reaches out it has been MONTHS
#
#
#  2)  Recruiter Reaches out within DAYS
#
#
#  3)   linked in - CAI - with link:
#
#
#  4)  Explaining my status
#
#
#  5)  Short and sweet
#
#
#  6)  Part-time
# 	 <<< # of message do you want to print ::: 1/2/3/4/5/6 >>> ...  4
# ---------------------------------------
#
#     MAIL_SUBJECT::4: Follow-Up Data Scientist at ttt
#
#     Hello ggh, I appreciate you reaching out, and ohh wow this is amazing, I am so interested in the position     of Data Scientist, at ttt. I am very sorry I missed your call.
#
#     This is an incredible position, and I am sure I have what it takes to succeed on it, I just wanted to let you know     beforehand my work status here in the USA. I have a current EDA that is being extended through the end of next year.     But good news is that within that same year I will get my Green Card guaranteed, as I got married with a citizen     more than a year ago and started the paperwork for my change of status on May 2022.    I really don't want us to waste our time, but this is necessary info I needed tell you first. I am sure there is a way     to move forward with this opportunity.I would love to see if you think things can align properly and I     can have an interview? Otherwise, lets stay in touch!
#
#      p.s. I receive so many calls lately that I had to have a small     process to schedule them, do you mind just filling up my scheduling form? : https://docs.google.com/forms/d/e/1FAIpQLSeGaBJOzwphOI9Rde6yk4XMJKEHVBce4FnDPneWfkWGDN320g/viewform?usp=sf_link
#
#     ::: p.s. :::     PLEASE fill up this sheet, this is extremely helpful for me to establish communication with you, schedule our first call,     and understand all of your needs. I do have more colleagues to send your way if that's helpful to you too!     thanks again, here is the link: https://docs.google.com/forms/d/e/1FAIpQLSeGaBJOzwphOI9Rde6yk4XMJKEHVBce4FnDPneWfkWGDN320g/viewform?usp=sf_link
#
#     Best,
#     Yeriko Vargas
#     Data Scientist
#     (646)-771-6111
#     ygvargas93@gmail.com | linkedin.com/in/yeriko-vargas/ | twitter.com/VargasYeriko
#     handle: @vargasyeriko
#
#
# ---------------------------------------
# 	 <<< Continue without saving ::: enter/s (zARCHIVE) >>> ...  s
# *** JOB APPLICATION APP PACKAGE *** Please choose an option: by <#> or <code>
# *
# *
# *
# *
# *
# 1. Print > INFO STRATEGY for APPLYING 	  <input>:: <#> or 	1) < about - strategy - links >
# 2. Print > MESG recruiters TEMPLATES 	  <input>:: <#> or 	2) < msgs >
# 3. Print > [CV/RES_DS_entry_level] 	  <input>:: <#> or 	3) < cv/res >
# 4. nan
# 5. nan
# 6. EDIT  > EDIT EDIT EDIT STRATEGY 	  <input>:: <#> or 	6) < edit >
# 7. Copy  > COPY FIELDS - APPLY fast	  <input>:: <#> or 	7) < gral & experience>
# *
# Enter your choice by <#> or <code> or <q/quit> ...
#  6
# Finished opening fns/_1ds_jobs_info_.py in TextEdit
#
# *** JOB APPLICATION APP PACKAGE *** Please choose an option: by <#> or <code>
# *
# *
# *
# *
# *
# 1. Print > INFO STRATEGY for APPLYING 	  <input>:: <#> or 	1) < about - strategy - links >
# 2. Print > MESG recruiters TEMPLATES 	  <input>:: <#> or 	2) < msgs >
# 3. Print > [CV/RES_DS_entry_level] 	  <input>:: <#> or 	3) < cv/res >
# 4. nan
# 5. nan
# 6. EDIT  > EDIT EDIT EDIT STRATEGY 	  <input>:: <#> or 	6) < edit >
# 7. Copy  > COPY FIELDS - APPLY fast	  <input>:: <#> or 	7) < gral & experience>
# *
# Enter your choice by <#> or <code> or <q/quit> ...
#  7
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 142
#     139             print("Invalid input, try again.")
#     141 # Call the function
# --> 142 welcome_job_app()
#
# Cell In[5], line 99, in welcome_job_app()
#      93         ####################### COPY FIELDS Programs
#      95         elif user_input.lower() == '7' or user_input.lower() == 'c_gral':
#      96             #
#      97             # 1 --<<IMPOR_fns>>>
# ---> 99             exec(open(f"fns/_7ds_COPY_GENERAL.py", encoding="utf-8").read())
#     109             # 4 --<<EXPORTS>>
#     110 #             direc_exp = '/Users/yerik/_apple_source/d_OUT/_0ds/apply_now/'
#     111 #             doc_export.save(f'{direc_exp}Yeriko Vargas - {date} {position} - Cover Letter.docx')#WORD
#    (...)    131             #############
#     132             #############
#     135         elif user_input.lower() == 'q':
#
# File <string>:32
#
# ModuleNotFoundError: No module named 'pyperclip'
